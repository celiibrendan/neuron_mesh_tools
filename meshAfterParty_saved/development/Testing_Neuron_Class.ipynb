# %%
from os import sys
sys.path.append("../../meshAfterParty/")

# %%
"""
For testing networkx properties when making the neuron class

"""

# %%
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import neuron
import networkx_utils as xu

# %%
new_graph = nx.from_edgelist([["S1",1],["S1",2],["S0",3],["S0",1]])
nx.draw(new_graph,with_labels=True)

# %%
ex_skeleton = np.array([[[1,3,4],[4,5,6]]])
b = neuron.Branch(ex_skeleton)
new_graph.add_edges_from([[b,2]])
nx.draw(new_graph,with_labels=True)

# %%
my_graph = xu.GraphOrderedEdges()

# %%
my_graph.add_nodes_from(["1","2","3","4"])
nx.draw(my_graph,with_labels=True)
