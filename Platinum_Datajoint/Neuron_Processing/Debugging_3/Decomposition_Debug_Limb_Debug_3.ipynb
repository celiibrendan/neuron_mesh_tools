# %%
"""
Purpose: To Run the neuron preprocessing


"""

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import datajoint as dj
import trimesh
from tqdm.notebook import tqdm
from pathlib import Path

from os import sys
sys.path.append("/meshAfterParty/")

import datajoint_utils as du
from importlib import reload
import system_utils as su
# Out:
# INFO - 2020-12-22 16:51:48,687 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2020-12-22 16:51:48,689 - settings - Setting database.user to celiib
# INFO - 2020-12-22 16:51:48,689 - settings - Setting database.password to newceliipass
# INFO - 2020-12-22 16:51:48,693 - settings - Setting stores to {'minnie65': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65', 'stage': '/mnt/dj-stor01/platinum/minnie65'}, 'meshes': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/meshes', 'stage': '/mnt/dj-stor01/platinum/minnie65/02/meshes'}, 'decimated_meshes': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/decimated_meshes', 'stage': '/mnt/dj-stor01/platinum/minnie65/02/decimated_meshes'}, 'skeletons': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/skeletons'}}
# INFO - 2020-12-22 16:51:48,694 - settings - Setting enable_python_native_blobs to True
# INFO - 2020-12-22 16:51:48,706 - connection - Connected celiib@at-database.ad.bcm.edu:3306
# Connecting celiib@at-database.ad.bcm.edu:3306
# INFO - 2020-12-22 16:51:48,929 - settings - Setting enable_python_native_blobs to True

# %% [markdown]
# # configuring the virtual module

# %%
import minfig
import time
import numpy as np
#want to add in a wait for the connection part
random_sleep_sec = np.random.randint(0, 30)
print(f"Sleeping {random_sleep_sec} sec before conneting")
#time.sleep(random_sleep_sec)
print("Done sleeping")

du.config_celii()
du.set_minnie65_config_segmentation(minfig)
du.print_minnie65_config_paths(minfig)

#configuring will include the adapters
minnie,schema = du.configure_minnie_vm()
# Out:
# INFO - 2020-12-22 16:51:49,007 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2020-12-22 16:51:49,008 - settings - Setting database.user to celiib
# INFO - 2020-12-22 16:51:49,009 - settings - Setting database.password to newceliipass
# INFO - 2020-12-22 16:51:49,011 - settings - Setting enable_python_native_blobs to True
# Sleeping 13 sec before conneting
# Done sleeping
# Current path for external_segmentation_path = /mnt/dj-stor01/platinum/minnie65/02
# Current path for external_mesh_path = /mnt/dj-stor01/platinum/minnie65/02/meshes
# Current path for external_decimated_mesh_path = /mnt/dj-stor01/platinum/minnie65/02/decimated_meshes
# Current path for external_skeleton_path = /mnt/dj-stor01/platinum/minnie65/02/skeletons
# INFO - 2020-12-22 16:51:49,236 - settings - Setting enable_python_native_blobs to True

# %% [markdown]
# # Defining Our Table

# %%
import neuron_utils as nru
import neuron
import trimesh_utils as tu
import numpy as np

# %%
import meshlab
meshlab.set_meshlab_port(current_port=None)
# Out:
# No port chosen so picked random port 515

# %%
#so that it will have the adapter defined
from datajoint_utils import *

# %% [markdown]
# # Segment_id we are currently checking

# %%
segment_id=864691135104011853

# %% [markdown]
# # Debugging the neuron creation

# %%
#1) Get the segment id from the key
description = "0_25"
print(f"\n\n----- Working on {segment_id}-------")
global_start = time.time()

#2) Get the decimated mesh
current_neuron_mesh = du.fetch_segment_id_mesh(segment_id)

#3) Get the somas info *************************** Need to change this when actually run *******************
somas = du.get_soma_mesh_list(segment_id) 
print(f"somas = {somas}")
#4) Run the preprocessing


total_neuron_process_time = time.time()
# Out:
# ----- Working on 864691135104011853-------
# somas = [[<trimesh.Trimesh(vertices.shape=(23123, 3), faces.shape=(46015, 3))>], array([282.7661]), array([0.733])]

# %%
du.plot_decimated_mesh_with_somas(segment_id)
# Out:
# Segment_id = 864691135104011853
# vertices = 601017, faces= = 1203040
# /usr/local/lib/python3.6/dist-packages/traittypes/traittypes.py:101: UserWarning: Given trait value dtype "float64" does not match required type "float64". A coerced copy has been created.
#   np.dtype(self.dtype).name))
# VBox(children=(Figure(camera=PerspectiveCamera(fov=46.0, position=(0.0, 0.0, 2.0), quaternion=(0.0, 0.0, 0.0, …

# %%
import preprocessing_vp2 as pre
import soma_extraction_utils as sm
import skeleton_utils as sk

import neuron
tu = reload(tu)
du = reload(du)
sm = reload(sm)
pre = reload(pre)
import compartment_utils as cu
cu = reload(cu)
sk= reload(sk)

neuron = reload(neuron)
print(f"\n--- Beginning preprocessing of {segment_id}---")
recovered_neuron = neuron.Neuron(
mesh = current_neuron_mesh,
somas = somas,
segment_id=segment_id,
description=description,
suppress_preprocessing_print=False,
suppress_output=False,
calculate_spines=True,
widths_to_calculate=["no_spine_median_mesh_center"]

        )
# Out:
# --- Beginning preprocessing of 864691135104011853---
# --- 0) Having to preprocess the Neuron becuase no preprocessed data
# Please wait this could take a while.....
# Skipping the hole filling
# use_meshafterparty = True
# Using pre-computed somas: soma_mesh_list = [<trimesh.Trimesh(vertices.shape=(23123, 3), faces.shape=(46015, 3))>]
# Soma List = [<trimesh.Trimesh(vertices.shape=(23123, 3), faces.shape=(46015, 3))>]
# soma_mesh_list_centers = [array([1246827.0243913 ,  697863.76504779,  716944.12169701])]
# xvfb-run -n 515 -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Platinum_Datajoint/Neuron_Processing/Debugging_3/temp/neuron_359.off -o /notebooks/Platinum_Datajoint/Neuron_Processing/Debugging_3/temp/neuron_359_remove_interior.off -s /notebooks/Platinum_Datajoint/Neuron_Processing/Debugging_3/temp/remove_interior_746593.mls
# removed temporary input file: /notebooks/Platinum_Datajoint/Neuron_Processing/Debugging_3/temp/neuron_359.off
# removed temporary output file: /notebooks/Platinum_Datajoint/Neuron_Processing/Debugging_3/temp/neuron_359_remove_interior.off
# /notebooks/Platinum_Datajoint/Neuron_Processing/Debugging_3/temp/remove_interior_746593.mls is being deleted....
# Removing the following inside neurons: [<trimesh.Trimesh(vertices.shape=(7183, 3), faces.shape=(16025, 3))>, <trimesh.Trimesh(vertices.shape=(529, 3), faces.shape=(968, 3))>]
# Total time for removing interior = 55.414549827575684
# Total time for splitting mesh = 1.423234462738037
# # total split meshes = 97
# There were 95 pieces found after size threshold
#
# -----Before filtering away multiple disconneted soma pieces-----
# # of soma containing seperate meshes = 1
# meshes with somas = {0: [0]}
# Number of not_processed_soma_containing_meshes = 0
#
# -----After filtering away multiple disconneted soma pieces-----
# # of soma containing seperate meshes = 1
# meshes with somas = {0: [0]}
#
#
# ----Working on soma-containing mesh piece 0----
#
# inside Soma subtraction
# Total Time for soma mesh cancellation = 1.697
# Total time for Subtract Soam = 1.6978654861450195
# Total time for Original_mesh_faces_map for mesh_pieces without soma= 0.8066513538360596
# Total time for Original_mesh_faces_map for somas= 0.718041181564331
# new_floating_pieces = []
# Total time for sig_non_soma_pieces= 6.13058066368103
# Total time for split= 1.1920928955078125e-06
# Total time for mesh_pieces_connectivity= 12.192681789398193
# # of insignificant_limbs = 0 with trimesh : []
# # of not_processed_soma_containing_meshes = 0 with trimesh : []
#
#
# ----- Working on Proper Limb # 0 ---------
# meshparty_segment_size = 100
# root_curr = [1252786.   686784.   714136.5]
# Time for preparing soma vertices and root: 0.00026869773864746094
# cc_vertex_thresh = 10
#   0%|          | 0/1 [00:00<?, ?it/s]
# HBox(children=(FloatProgress(value=0.0, max=243613.0), HTML(value='')))
# 100%|██████████| 1/1 [00:13<00:00, 13.23s/it]
# meshparty_segment_size = 100
# Time for 1st pass MP skeletonization: 15.29113507270813
# connecting at the root
# branches_touching_root = [192]
# length of Graph = 27690
# Working on path [7245. 7259. 7267. 7286. 7299. 7304.]
# path_degrees = [3, 2, 2, 2, 2, 3]
# Working on path [13766. 13771. 13776. 13784. 13801. 13804.]
# path_degrees = [3, 2, 2, 2, 2, 3]
# Working on path [16074. 16089. 16107. 16137. 16157. 16162.]
# path_degrees = [3, 2, 2, 2, 2, 3]
# Working on path [18503. 18532. 18545.]
# path_degrees = [3, 2, 3]
# Working on path [20745. 20764. 20779. 20799. 20810.]
# path_degrees = [3, 2, 2, 2, 3]
# max(kept_branches_idx) = 192, len(kept_branches_idx) = 188
# empty_indices % = 0.0
#  conflict_indices % = 0.019261776418878607
# HBox(children=(FloatProgress(value=0.0, max=96.0), HTML(value='')))
# AFTER face_lookup_resolved_test
# HBox(children=(FloatProgress(value=0.0, max=188.0), HTML(value='')))
# Decomposing first pass: 29.574164152145386
# Attempting to use MeshAfterParty Skeletonization and Mesh Correspondence
# Another print
# Found len(mesh_large_idx) MAP candidates: [3288, 488, 1552, 2786, 393, 674, 5795, 2645, 5409, 5398, 1937, 4816, 3452, 3494, 756, 2050, 1512, 2626, 7750, 8994, 17075, 288, 143, 8950, 1211, 249, 3652, 1174, 2719, 378, 9368, 1827, 835, 360, 10073, 3734]
# mesh_large_connectivity: 0.8085310459136963
# Finding MAP candidates connected components: 0.0003650188446044922
# len(filtered_pieces) = 2
# skeleton_connectivity_MP : 0.954237699508667
# Grouping MP Sublimbs by Graph: 0.25762224197387695
# Divinding into MP and MAP pieces: 1.1920928955078125e-06
# --- Working on MAP piece 0---
# MAP Filtering Soma Pieces: 0.004599332809448242
# inside skeletonize_connected_branch and use_surface_after_CGAL=False, surface_reconstruction_size=1000
# The mesh passed has 81 pieces so just taking the largest one <trimesh.Trimesh(vertices.shape=(33402, 3), faces.shape=(64663, 3))>
#      Starting Screened Poisson
# xvfb-run -n 515 -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Platinum_Datajoint/Neuron_Processing/Debugging_3/temp/None.off -o /notebooks/Platinum_Datajoint/Neuron_Processing/Debugging_3/temp/None_poisson.off -s /notebooks/Platinum_Datajoint/Neuron_Processing/Debugging_3/temp/poisson_763576.mls
# removed temporary input file: /notebooks/Platinum_Datajoint/Neuron_Processing/Debugging_3/temp/None.off
# removed temporary output file: /notebooks/Platinum_Datajoint/Neuron_Processing/Debugging_3/temp/None_poisson.off
# Using the close holes feature
# xvfb-run -n 515 -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Platinum_Datajoint/Neuron_Processing/Debugging_3/temp/neuron_72341.off -o /notebooks/Platinum_Datajoint/Neuron_Processing/Debugging_3/temp/neuron_72341_fill_holes.off -s /notebooks/Platinum_Datajoint/Neuron_Processing/Debugging_3/temp/fill_holes_964509.mls
# removed temporary input file: /notebooks/Platinum_Datajoint/Neuron_Processing/Debugging_3/temp/neuron_72341.off
# removed temporary output file: /notebooks/Platinum_Datajoint/Neuron_Processing/Debugging_3/temp/neuron_72341_fill_holes.off
# -----Time for Screened Poisson= 23.01990818977356
# mesh_pieces = [<trimesh.Trimesh(vertices.shape=(90324, 3), faces.shape=(180652, 3))>, <trimesh.Trimesh(vertices.shape=(775, 3), faces.shape=(1546, 3))>, <trimesh.Trimesh(vertices.shape=(630, 3), faces.shape=(1256, 3))>]
#      Starting Calcification (12/2 Change only going to do the largest piece)
# min_edge_length = 75
# node_degrees = [4 2 3 2 2 2 2 2 2 2 2 2]
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# No skeletons to stack so returning empty list
# The process was using a temp folder
# Checking connected components after skeletonize_connected_branch
#     Total time for skeletonizing branch: 32.06854820251465
# Checking connected components after removing cycles
# Total time for mesh KDTree = 0.42597198486328125
# sbv[0].reshape(-1,3) = [[1252786.   686784.   714136.5]]
# closest_sk_pt_coord BEFORE = [1253830.  686392.  713808.]
# current_skeleton.shape = (1514, 2, 3)
# Current stitch point was a branch or endpoint
# change_status for create soma extending pieces = False
# closest_sk_pt_coord AFTER = [1253830.  686392.  713808.]
# skipping soma 0 because closest skeleton node was already end node
# endpoints_must_keep = {0: array([[1253830.,  686392.,  713808.]])}
#     Total time for Fixing Skeleton Soma Endpoint Extension : 0.8316996097564697
# filter_end_node_length = 4500
# Using Distance measure skeletal_distance
# endpoints_must_keep = [[1253830.  686392.  713808.]]
# Number of end_nodes BEFORE filtering = 22
# all_single_nodes_to_eliminate = [20]
# HBox(children=(FloatProgress(value=0.0, max=19.0), HTML(value='')))
# Checking connected components after clean_skeleton
# after DISTANCE cleaning limb size of skeleton = (1388, 2, 3)
# ********COMBINING CLOSE SKELETON NODES WITHIN 700 DISTANCE**********
# Found 0 valid paths to replace
# valid_paths = []
# valid_path_lengths = []
# No valid paths found so just returning the original
# skeletonize_and_clean_connected_branch_CGAL: 35.12921977043152
# Working on limb correspondence for #0 MAP piece
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Total time for decomposition = 5.233158826828003
# mesh_correspondence_first_pass: 5.233188629150391
# Limb decomposed into 7 branches
# divided_skeleton_graph_recovered = (1388, 2, 3) and
# current_mesh_data[0]['branch_skeletons_cleaned'].shape = (1388, 2, 3)
#
# Number of connected components in deocmposed recovered graph = 1
# Number of connected components in cleaned skeleton graph= 1
# The downsampled branches number of connected components = 1
# Empty submeshes = []
#
#
# --- Working on 1-to-1 correspondence-----
# max(original_labels),len(original_labels) = (6, 7)
# empty_indices % = 0.17504063520375138
#  conflict_indices % = 0.02865321269832137
# HBox(children=(FloatProgress(value=0.0, max=139.0), HTML(value='')))
# AFTER face_lookup_resolved_test
# Took 0 iterations to expand the label back
# empty_indices % = 0.0
#  conflict_indices % = 0.0
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# AFTER face_lookup_resolved_test
# HBox(children=(FloatProgress(value=0.0, max=7.0), HTML(value='')))
# Total time for MAP sublimb #0 mesh processing = 46.616267681121826
# correspondence_1_to_1: 6.249210357666016
# --- Working on MAP piece 1---
# MAP Filtering Soma Pieces: 0.0040090084075927734
# inside skeletonize_connected_branch and use_surface_after_CGAL=False, surface_reconstruction_size=1000
# The mesh passed has 17 pieces so just taking the largest one <trimesh.Trimesh(vertices.shape=(29358, 3), faces.shape=(58312, 3))>
#      Starting Screened Poisson
# xvfb-run -n 515 -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Platinum_Datajoint/Neuron_Processing/Debugging_3/temp/None.off -o /notebooks/Platinum_Datajoint/Neuron_Processing/Debugging_3/temp/None_poisson.off -s /notebooks/Platinum_Datajoint/Neuron_Processing/Debugging_3/temp/poisson_786463.mls
# removed temporary input file: /notebooks/Platinum_Datajoint/Neuron_Processing/Debugging_3/temp/None.off
# removed temporary output file: /notebooks/Platinum_Datajoint/Neuron_Processing/Debugging_3/temp/None_poisson.off
# Using the close holes feature
# xvfb-run -n 515 -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Platinum_Datajoint/Neuron_Processing/Debugging_3/temp/neuron_35715.off -o /notebooks/Platinum_Datajoint/Neuron_Processing/Debugging_3/temp/neuron_35715_fill_holes.off -s /notebooks/Platinum_Datajoint/Neuron_Processing/Debugging_3/temp/fill_holes_312927.mls
# removed temporary input file: /notebooks/Platinum_Datajoint/Neuron_Processing/Debugging_3/temp/neuron_35715.off
# removed temporary output file: /notebooks/Platinum_Datajoint/Neuron_Processing/Debugging_3/temp/neuron_35715_fill_holes.off
# -----Time for Screened Poisson= 18.976572513580322
# mesh_pieces = [<trimesh.Trimesh(vertices.shape=(80663, 3), faces.shape=(161334, 3))>]
#      Starting Calcification (12/2 Change only going to do the largest piece)
# min_edge_length = 75
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# No skeletons to stack so returning empty list
# The process was using a temp folder
# Checking connected components after skeletonize_connected_branch
#     Total time for skeletonizing branch: 25.139789819717407
# Checking connected components after removing cycles
#     Total time for Fixing Skeleton Soma Endpoint Extension : 0.09830331802368164
# filter_end_node_length = 4500
# Using Distance measure skeletal_distance
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# Checking connected components after clean_skeleton
# after DISTANCE cleaning limb size of skeleton = (1863, 2, 3)
# ********COMBINING CLOSE SKELETON NODES WITHIN 700 DISTANCE**********
# Found 0 valid paths to replace
# valid_paths = []
# valid_path_lengths = []
# No valid paths found so just returning the original
# Inside MAP decomposition and curr_limb_endpoints_must_keep was None
# skeletonize_and_clean_connected_branch_CGAL: 28.196186065673828
# Working on limb correspondence for #1 MAP piece
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Total time for decomposition = 7.631782054901123
# mesh_correspondence_first_pass: 7.63182520866394
# Limb decomposed into 3 branches
# divided_skeleton_graph_recovered = (1863, 2, 3) and
# current_mesh_data[0]['branch_skeletons_cleaned'].shape = (1863, 2, 3)
#
# Number of connected components in deocmposed recovered graph = 1
# Number of connected components in cleaned skeleton graph= 1
# The downsampled branches number of connected components = 1
# Empty submeshes = []
#
#
# --- Working on 1-to-1 correspondence-----
# max(original_labels),len(original_labels) = (2, 3)
# empty_indices % = 0.05777472998457055
#  conflict_indices % = 0.004320246871249786
# HBox(children=(FloatProgress(value=0.0, max=88.0), HTML(value='')))
# AFTER face_lookup_resolved_test
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Total time for MAP sublimb #1 mesh processing = 40.056621074676514
# correspondence_1_to_1: 4.2245941162109375
# Total time for MAP sublimb processing 86.67311787605286
# ---- Working on MP Decomposition #0 ----
# Computing the current soma touching verts dict manually
# MP filtering soma verts: 0.0017921924591064453
# Do Not Need to Fix MP Decomposition 0 so just continuing
# ---- Working on MP Decomposition #1 ----
# Computing the current soma touching verts dict manually
# MP filtering soma verts: 0.001283884048461914
# Do Not Need to Fix MP Decomposition 1 so just continuing
# ---- Working on MP Decomposition #2 ----
# Computing the current soma touching verts dict manually
# MP filtering soma verts: 0.0004527568817138672
# Do Not Need to Fix MP Decomposition 2 so just continuing
# ---- Working on MP Decomposition #3 ----
# Computing the current soma touching verts dict manually
# MP filtering soma verts: 0.0005125999450683594
# Do Not Need to Fix MP Decomposition 3 so just continuing
# ---- Working on MP Decomposition #4 ----
# Computing the current soma touching verts dict manually
# MP filtering soma verts: 0.0025839805603027344
# Do Not Need to Fix MP Decomposition 4 so just continuing
# ---- Working on MP Decomposition #5 ----
# Computing the current soma touching verts dict manually
# MP filtering soma verts: 0.0026061534881591797
# Do Not Need to Fix MP Decomposition 5 so just continuing
# ---- Working on MP Decomposition #6 ----
# Computing the current soma touching verts dict manually
# MP filtering soma verts: 0.0022249221801757812
# Do Not Need to Fix MP Decomposition 6 so just continuing
# ---- Working on MP Decomposition #7 ----
# Computing the current soma touching verts dict manually
# MP filtering soma verts: 0.0018377304077148438
# Do Not Need to Fix MP Decomposition 7 so just continuing
# ---- Working on MP Decomposition #8 ----
# Computing the current soma touching verts dict manually
# MP filtering soma verts: 0.0020232200622558594
# Do Not Need to Fix MP Decomposition 8 so just continuing
# ---- Working on MP Decomposition #9 ----
# Computing the current soma touching verts dict manually
# MP filtering soma verts: 0.0021233558654785156
# Do Not Need to Fix MP Decomposition 9 so just continuing
# ---- Working on MP Decomposition #10 ----
# Computing the current soma touching verts dict manually
# MP filtering soma verts: 0.0005147457122802734
# Do Not Need to Fix MP Decomposition 10 so just continuing
# ---- Working on MP Decomposition #11 ----
# Computing the current soma touching verts dict manually
# MP filtering soma verts: 0.002232789993286133
# Do Not Need to Fix MP Decomposition 11 so just continuing
# ---- Working on MP Decomposition #12 ----
# Computing the current soma touching verts dict manually
# MP filtering soma verts: 0.0032806396484375
# Do Not Need to Fix MP Decomposition 12 so just continuing
# ---- Working on MP Decomposition #13 ----
# Computing the current soma touching verts dict manually
# MP filtering soma verts: 0.001386404037475586
# Do Not Need to Fix MP Decomposition 13 so just continuing
# ---- Working on MP Decomposition #14 ----
# Computing the current soma touching verts dict manually
# MP filtering soma verts: 0.0015156269073486328
# Do Not Need to Fix MP Decomposition 14 so just continuing
# ---- Working on MP Decomposition #15 ----
# Computing the current soma touching verts dict manually
# MP filtering soma verts: 0.0013802051544189453
# Do Not Need to Fix MP Decomposition 15 so just continuing
# ---- Working on MP Decomposition #16 ----
# Computing the current soma touching verts dict manually
# MP filtering soma verts: 0.0009009838104248047
# Do Not Need to Fix MP Decomposition 16 so just continuing
# ---- Working on MP Decomposition #17 ----
# Computing the current soma touching verts dict manually
# MP filtering soma verts: 0.002657651901245117
# Do Not Need to Fix MP Decomposition 17 so just continuing
# ---- Working on MP Decomposition #18 ----
# Computing the current soma touching verts dict manually
# MP filtering soma verts: 0.0015616416931152344
# Do Not Need to Fix MP Decomposition 18 so just continuing
# ---- Working on MP Decomposition #19 ----
# Computing the current soma touching verts dict manually
# MP filtering soma verts: 0.0004279613494873047
# Do Not Need to Fix MP Decomposition 19 so just continuing
# ---- Working on MP Decomposition #20 ----
# Computing the current soma touching verts dict manually
# MP filtering soma verts: 0.0014815330505371094
# Do Not Need to Fix MP Decomposition 20 so just continuing
# ---- Working on MP Decomposition #21 ----
# Computing the current soma touching verts dict manually
# MP filtering soma verts: 0.002399444580078125
# Do Not Need to Fix MP Decomposition 21 so just continuing
# ---- Working on MP Decomposition #22 ----
# Computing the current soma touching verts dict manually
# MP filtering soma verts: 0.0004372596740722656
# Do Not Need to Fix MP Decomposition 22 so just continuing
# ---- Working on MP Decomposition #23 ----
# Computing the current soma touching verts dict manually
# MP filtering soma verts: 0.00021719932556152344
# Do Not Need to Fix MP Decomposition 23 so just continuing
# ---- Working on MP Decomposition #24 ----
# Computing the current soma touching verts dict manually
# MP filtering soma verts: 0.0002148151397705078
# Do Not Need to Fix MP Decomposition 24 so just continuing
# ---- Working on MP Decomposition #25 ----
# Computing the current soma touching verts dict manually
# MP filtering soma verts: 0.0007359981536865234
# Do Not Need to Fix MP Decomposition 25 so just continuing
# ---- Working on MP Decomposition #26 ----
# Computing the current soma touching verts dict manually
# MP filtering soma verts: 0.00043010711669921875
# Do Not Need to Fix MP Decomposition 26 so just continuing
# ---- Working on MP Decomposition #27 ----
# Computing the current soma touching verts dict manually
# MP filtering soma verts: 0.0031938552856445312
# Do Not Need to Fix MP Decomposition 27 so just continuing
# Edge (2, 13) was not kept
# Edge (8, 13) was not kept
# Edge (6, 16) was not kept
# Edge (23, 24) was not kept
# Successful mesh connectivity with type edges
#
# ---- Working on (0, 0) connection-----
# Current stitch point was not a branch or endpoint, shortest_path_length to one = 1696.0861605761463
# sk_conn = [3]
# conn = [3]
# winning_vertex = [1236533.07487324  597044.44487935  708926.73870092]
# MP_branches_with_stitch_point = [3]
# MAP_branches_with_stitch_point = [1]
# MAP_stitch_point_on_end_or_branch = False
# Found winning edge: [44, 45.0]
# in remove edge
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# --- Working on 1-to-1 correspondence-----
# max(original_labels),len(original_labels) = (1, 2)
# empty_indices % = 0.1308543854669316
#  conflict_indices % = 0.002554640931024695
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# AFTER face_lookup_resolved_test
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# --- Working on 1-to-1 correspondence-----
# max(original_labels),len(original_labels) = (2, 3)
# empty_indices % = 0.22655601659751037
#  conflict_indices % = 0.03153526970954357
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))
# AFTER face_lookup_resolved_test
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Deleting branches from dictionary
# MP_branches_with_stitch_point= [3]
# MP_branches_for_correspondence = [3]
# MP_leftover = [], MP_leftover_idx = []
#  Finished with (0, 0)
#
#
#
#
# ---- Working on (2, 0) connection-----
# Current stitch point was not a branch or endpoint, shortest_path_length to one = 10081.086902438632
# sk_conn = [0]
# conn = [0]
# winning_vertex = [1251657.23145503  586527.04081045  699883.22296725]
# MP_branches_with_stitch_point = [0]
# MAP_branches_with_stitch_point = [3]
# MAP_stitch_point_on_end_or_branch = False
# Using max stitch distance (300) for smoothing because stitch_distance greater (2306.715574548579)
# Found winning edge: [9, 10.0]
# in remove edge
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# --- Working on 1-to-1 correspondence-----
# max(original_labels),len(original_labels) = (1, 2)
# empty_indices % = 0.4388927984987098
#  conflict_indices % = 0.023574947220267418
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# AFTER face_lookup_resolved_test
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# --- Working on 1-to-1 correspondence-----
# max(original_labels),len(original_labels) = (2, 3)
# empty_indices % = 0.39323456278491503
#  conflict_indices % = 0.06294032324906755
# HBox(children=(FloatProgress(value=0.0, max=7.0), HTML(value='')))
# AFTER face_lookup_resolved_test
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Deleting branches from dictionary
# MP_branches_with_stitch_point= [0]
# MP_branches_for_correspondence = [0]
# MP_leftover = [], MP_leftover_idx = []
#  Finished with (2, 0)
#
#
#
#
# ---- Working on (3, 0) connection-----
# Current stitch point was not a branch or endpoint, shortest_path_length to one = 3204.9150884985556
# sk_conn = [0]
# conn = [0]
# winning_vertex = [1248070.29813392  592569.62520858  708499.24516692]
# MP_branches_with_stitch_point = [0]
# MAP_branches_with_stitch_point = [3]
# MAP_stitch_point_on_end_or_branch = False
# Using max stitch distance (300) for smoothing because stitch_distance greater (1335.8155668010716)
# Found winning edge: [8, 10.0]
# in remove edge
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# --- Working on 1-to-1 correspondence-----
# max(original_labels),len(original_labels) = (1, 2)
# empty_indices % = 0.3233942104609268
#  conflict_indices % = 0.00360293204124736
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# AFTER face_lookup_resolved_test
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# --- Working on 1-to-1 correspondence-----
# max(original_labels),len(original_labels) = (2, 3)
# empty_indices % = 0.3348250981824824
#  conflict_indices % = 0.02265047036259019
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# AFTER face_lookup_resolved_test
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Deleting branches from dictionary
# MP_branches_with_stitch_point= [0]
# MP_branches_for_correspondence = [0]
# MP_leftover = [], MP_leftover_idx = []
#  Finished with (3, 0)
#
#
#
#
# ---- Working on (4, 0) connection-----
# Current stitch point was not a branch or endpoint, shortest_path_length to one = 12797.120139604065
# sk_conn = [0]
# conn = [0]
# winning_vertex = [1253784.42202671  657797.05559523  709822.0250368 ]
# MP_branches_with_stitch_point = [0]
# MAP_branches_with_stitch_point = [4]
# MAP_stitch_point_on_end_or_branch = False
# Using max stitch distance (300) for smoothing because stitch_distance greater (438.3136426708407)
# Found winning edge: [9, 10.0]
# in remove edge
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# --- Working on 1-to-1 correspondence-----
# max(original_labels),len(original_labels) = (1, 2)
# empty_indices % = 0.10916813346598302
#  conflict_indices % = 0.001760159179612765
# HBox(children=(FloatProgress(value=0.0, max=61.0), HTML(value='')))
# AFTER face_lookup_resolved_test
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# --- Working on 1-to-1 correspondence-----
# max(original_labels),len(original_labels) = (2, 3)
# empty_indices % = 0.11018514799791156
#  conflict_indices % = 0.012169163420217679
# HBox(children=(FloatProgress(value=0.0, max=64.0), HTML(value='')))
# AFTER face_lookup_resolved_test
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Deleting branches from dictionary
# MP_branches_with_stitch_point= [0]
# MP_branches_for_correspondence = [0]
# MP_leftover = [], MP_leftover_idx = []
#  Finished with (4, 0)
#
#
#
#
# ---- Working on (6, 0) connection-----
# Current stitch point was not a branch or endpoint, shortest_path_length to one = 1153.2863838612395
# sk_conn = [5]
# conn = [5]
# winning_vertex = [1252943.1626911   596411.0058164   701056.80553515]
# MP_branches_with_stitch_point = [5]
# MAP_branches_with_stitch_point = [8]
# MAP_stitch_point_on_end_or_branch = False
# Using max stitch distance (300) for smoothing because stitch_distance greater (436.5566031067071)
# Found winning edge: [171, 172.0]
# in remove edge
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# empty mesh_correspondence_indices_2 returned so returning original mesh correspondence
#
#
#
# --- Working on 1-to-1 correspondence-----
# max(original_labels),len(original_labels) = (1, 2)
# empty_indices % = 0.5449828899437024
#  conflict_indices % = 0.0020973617397063694
# HBox(children=(FloatProgress(value=0.0, max=17.0), HTML(value='')))
# AFTER face_lookup_resolved_test
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# --- Working on 1-to-1 correspondence-----
# max(original_labels),len(original_labels) = (2, 3)
# empty_indices % = 0.45242196651278166
#  conflict_indices % = 0.03913732515675601
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# AFTER face_lookup_resolved_test
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Deleting branches from dictionary
# MP_branches_with_stitch_point= [5]
# MP_branches_for_correspondence = [5]
# MP_leftover = [], MP_leftover_idx = []
#  Finished with (6, 0)
#
#
#
#
# ---- Working on (8, 0) connection-----
# Current stitch point was not a branch or endpoint, shortest_path_length to one = 1149.368558036866
# sk_conn = [2, 7]
# conn = [2, 7]
# winning_vertex = [1250727.12681023  586663.18975423  698995.35383401]
# MP_branches_with_stitch_point = [2, 7]
# MAP_branches_with_stitch_point = [8]
# MAP_stitch_point_on_end_or_branch = False
# Using max stitch distance (300) for smoothing because stitch_distance greater (3306.0737240161516)
# Found winning edge: [108, 109.0]
# in remove edge
# Using max stitch distance (300) for smoothing because stitch_distance greater (3298.5315635571524)
# Found winning edge: [69, 71.0]
# in remove edge
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# --- Working on 1-to-1 correspondence-----
# max(original_labels),len(original_labels) = (1, 2)
# empty_indices % = 0.6037694013303769
#  conflict_indices % = 0.0
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# AFTER face_lookup_resolved_test
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# --- Working on 1-to-1 correspondence-----
# max(original_labels),len(original_labels) = (3, 4)
# empty_indices % = 0.4867507886435331
#  conflict_indices % = 0.03003154574132492
# HBox(children=(FloatProgress(value=0.0, max=7.0), HTML(value='')))
# AFTER face_lookup_resolved_test
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))
# Deleting branches from dictionary
# MP_branches_with_stitch_point= [2, 7]
# MP_branches_for_correspondence = [2 7]
# MP_leftover = [], MP_leftover_idx = []
#  Finished with (8, 0)
#
#
#
#
# ---- Working on (9, 0) connection-----
# Current stitch point was a branch or endpoint
# sk_conn = [2, 12]
# conn = [2, 12]
# winning_vertex = [1247677.12547876  580364.48650467  694485.3838291 ]
# MP_branches_with_stitch_point = [2, 12]
# MAP_branches_with_stitch_point = [8, 9]
# MAP_stitch_point_on_end_or_branch = True
# Using max stitch distance (300) for smoothing because stitch_distance greater (11070.83049001138)
# Found winning edge: [9, 10.0]
# in remove edge
# Using max stitch distance (300) for smoothing because stitch_distance greater (11060.957815165028)
# Found winning edge: [9, 10.0]
# in remove edge
#
# Revising the MAP pieces index:
# MAP_pieces_idx_touching_border = [8], MAP_branches_with_stitch_point = [8, 9]
# MAP_pieces_for_correspondence = [8]
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# empty mesh_correspondence_indices_2 returned so returning original mesh correspondence
#
#
#
# --- Working on 1-to-1 correspondence-----
# max(original_labels),len(original_labels) = (2, 3)
# empty_indices % = 0.6785660033419414
#  conflict_indices % = 0.01276013975391159
# Doing No Color conflicts iteration 2 because missing_labels = {1, 2}
# Doing No Color conflicts iteration 3 because missing_labels = {1, 2}
# Doing No Color conflicts iteration 4 because missing_labels = {1, 2}
# Doing No Color conflicts iteration 2 because missing_labels = {1, 2}
# Doing No Color conflicts iteration 3 because missing_labels = {1, 2}
# Doing No Color conflicts iteration 4 because missing_labels = {1, 2}
# leftover_labels = [-1  0]
# no_missing_labels = [0, 1, 2]
# missing_labels = {1, 2}
# Saved object at /notebooks/Platinum_Datajoint/Neuron_Processing/Debugging_3/curr_limb_mesh.pbz2
# File size is 0.866533 MB
# Saved object at /notebooks/Platinum_Datajoint/Neuron_Processing/Debugging_3/face_lookup.pbz2
# File size is 0.015251 MB
# Saved object at /notebooks/Platinum_Datajoint/Neuron_Processing/Debugging_3/no_missing_labels.pbz2
# File size is 6e-05 MB
# Saved object at /notebooks/Platinum_Datajoint/Neuron_Processing/Debugging_3/max_submesh_threshold.pbz2
# File size is 5e-05 MB
# Saved object at /notebooks/Platinum_Datajoint/Neuron_Processing/Debugging_3/branch_skeletons.pbz2
# File size is 0.008506 MB
# Errored in 1 to 1 correspondence in stitching so just reverting to the original mesh assignments
# MP_branches_with_stitch_point= [2, 12]
# MP_branches_for_correspondence = [ 2 12]
# MP_leftover = [], MP_leftover_idx = []
#  Finished with (9, 0)
#
#
#
#
# ---- Working on (11, 0) connection-----
# Current stitch point was not a branch or endpoint, shortest_path_length to one = 7001.017926554143
# sk_conn = [0]
# conn = [0]
# winning_vertex = [1253059.67682182  650456.37680584  708653.69490587]
# MP_branches_with_stitch_point = [0]
# MAP_branches_with_stitch_point = [4]
# MAP_stitch_point_on_end_or_branch = False
# Using max stitch distance (300) for smoothing because stitch_distance greater (896.6572425991122)
# Found winning edge: [1050, 1053.0]
# in remove edge
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# --- Working on 1-to-1 correspondence-----
# max(original_labels),len(original_labels) = (1, 2)
# empty_indices % = 0.10989213607449064
#  conflict_indices % = 0.0015672536185120309
# HBox(children=(FloatProgress(value=0.0, max=48.0), HTML(value='')))
# AFTER face_lookup_resolved_test
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# --- Working on 1-to-1 correspondence-----
# max(original_labels),len(original_labels) = (2, 3)
# empty_indices % = 0.14195404903249195
#  conflict_indices % = 0.006412289844564281
# HBox(children=(FloatProgress(value=0.0, max=59.0), HTML(value='')))
# AFTER face_lookup_resolved_test
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Deleting branches from dictionary
# MP_branches_with_stitch_point= [0]
# MP_branches_for_correspondence = [0]
# MP_leftover = [], MP_leftover_idx = []
#  Finished with (11, 0)
#
#
#
#
# ---- Working on (12, 0) connection-----
# Current stitch point was not a branch or endpoint, shortest_path_length to one = 3103.389792098111
# sk_conn = [8, 10]
# conn = [8, 10]
# winning_vertex = [1251928.73404482  594114.68676733  697866.24159884]
# MP_branches_with_stitch_point = [8, 10]
# MAP_branches_with_stitch_point = [12]
# MAP_stitch_point_on_end_or_branch = False
# Using max stitch distance (300) for smoothing because stitch_distance greater (1904.1086917433645)
# Found winning edge: [9, 10.0]
# in remove edge
# Using max stitch distance (300) for smoothing because stitch_distance greater (1944.928025859995)
# Found winning edge: [23, 24.0]
# in remove edge
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# --- Working on 1-to-1 correspondence-----
# max(original_labels),len(original_labels) = (1, 2)
# empty_indices % = 0.22693373108885576
#  conflict_indices % = 0.015555082037076498
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# AFTER face_lookup_resolved_test
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# --- Working on 1-to-1 correspondence-----
# max(original_labels),len(original_labels) = (3, 4)
# empty_indices % = 0.41591189790037053
#  conflict_indices % = 0.057739810621655
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# AFTER face_lookup_resolved_test
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))
# Deleting branches from dictionary
# MP_branches_with_stitch_point= [8, 10]
# MP_branches_for_correspondence = [ 8 10]
# MP_leftover = [], MP_leftover_idx = []
#  Finished with (12, 0)
#
#
#
#
# ---- Working on (13, 0) connection-----
# Current stitch point was not a branch or endpoint, shortest_path_length to one = 3097.8728910871287
# sk_conn = [4, 5]
# conn = [4, 5]
# winning_vertex = [1248271.92319863  587414.01731303  704951.44598387]
# MP_branches_with_stitch_point = [4, 5]
# MAP_branches_with_stitch_point = [9]
# MAP_stitch_point_on_end_or_branch = False
# Using max stitch distance (300) for smoothing because stitch_distance greater (2409.247954627088)
# Found winning edge: [86, 87.0]
# in remove edge
# Using max stitch distance (300) for smoothing because stitch_distance greater (2367.612885080255)
# Found winning edge: [29, 31.0]
# in remove edge
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# --- Working on 1-to-1 correspondence-----
# max(original_labels),len(original_labels) = (1, 2)
# empty_indices % = 0.3448682658277625
#  conflict_indices % = 0.023856337658933018
# HBox(children=(FloatProgress(value=0.0, max=26.0), HTML(value='')))
# AFTER face_lookup_resolved_test
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# --- Working on 1-to-1 correspondence-----
# max(original_labels),len(original_labels) = (3, 4)
# empty_indices % = 0.2962159347335532
#  conflict_indices % = 0.14450616212463113
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# AFTER face_lookup_resolved_test
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))
# Deleting branches from dictionary
# MP_branches_with_stitch_point= [4, 5]
# MP_branches_for_correspondence = [4 5]
# MP_leftover = [], MP_leftover_idx = []
#  Finished with (13, 0)
#
#
#
#
# ---- Working on (14, 0) connection-----
# Current stitch point was a branch or endpoint
# sk_conn = [3, 7]
# conn = [3, 7]
# winning_vertex = [1235682.13592237  595600.84760534  709225.02789427]
# MP_branches_with_stitch_point = [3, 7]
# MAP_branches_with_stitch_point = [1]
# MAP_stitch_point_on_end_or_branch = True
# Using max stitch distance (300) for smoothing because stitch_distance greater (401.2982345506699)
# Found winning edge: [88, 89.0]
# in remove edge
# Using max stitch distance (300) for smoothing because stitch_distance greater (502.5853210522602)
# Found winning edge: [9, 10.0]
# in remove edge
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# --- Working on 1-to-1 correspondence-----
# max(original_labels),len(original_labels) = (2, 3)
# empty_indices % = 0.2098092643051771
#  conflict_indices % = 0.062216167120799276
# HBox(children=(FloatProgress(value=0.0, max=6.0), HTML(value='')))
# AFTER face_lookup_resolved_test
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# MP_branches_with_stitch_point= [3, 7]
# MP_branches_for_correspondence = [3 7]
# MP_leftover = [], MP_leftover_idx = []
#  Finished with (14, 0)
#
#
#
#
# ---- Working on (16, 0) connection-----
# Current stitch point was not a branch or endpoint, shortest_path_length to one = 23146.227279454622
# sk_conn = [6]
# conn = [6]
# winning_vertex = [1251094.40500602  618117.04596103  699948.58752234]
# MP_branches_with_stitch_point = [6]
# MAP_branches_with_stitch_point = [4]
# MAP_stitch_point_on_end_or_branch = False
# Using max stitch distance (300) for smoothing because stitch_distance greater (384.41062230520475)
# Found winning edge: [9, 10.0]
# in remove edge
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# --- Working on 1-to-1 correspondence-----
# max(original_labels),len(original_labels) = (1, 2)
# empty_indices % = 0.13012459807073956
#  conflict_indices % = 0.0005024115755627009
# HBox(children=(FloatProgress(value=0.0, max=49.0), HTML(value='')))
# AFTER face_lookup_resolved_test
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# --- Working on 1-to-1 correspondence-----
# max(original_labels),len(original_labels) = (2, 3)
# empty_indices % = 0.12815457413249212
#  conflict_indices % = 0.005964116719242902
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))
# AFTER face_lookup_resolved_test
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Deleting branches from dictionary
# MP_branches_with_stitch_point= [6]
# MP_branches_for_correspondence = [6]
# MP_leftover = [], MP_leftover_idx = []
#  Finished with (16, 0)
#
#
#
#
# ---- Working on (17, 0) connection-----
# Current stitch point was not a branch or endpoint, shortest_path_length to one = 3384.782312685693
# sk_conn = [5]
# conn = [5]
# winning_vertex = [1245898.56623207  602693.65803178  717142.23109215]
# MP_branches_with_stitch_point = [5]
# MAP_branches_with_stitch_point = [2]
# MAP_stitch_point_on_end_or_branch = False
# Using max stitch distance (300) for smoothing because stitch_distance greater (759.196509376166)
# Found winning edge: [9, 10.0]
# in remove edge
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# --- Working on 1-to-1 correspondence-----
# max(original_labels),len(original_labels) = (1, 2)
# empty_indices % = 0.13133498145859085
#  conflict_indices % = 0.005253399258343634
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# AFTER face_lookup_resolved_test
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# --- Working on 1-to-1 correspondence-----
# max(original_labels),len(original_labels) = (2, 3)
# empty_indices % = 0.15716680637049454
#  conflict_indices % = 0.055532271584241406
# HBox(children=(FloatProgress(value=0.0, max=6.0), HTML(value='')))
# AFTER face_lookup_resolved_test
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Deleting branches from dictionary
# MP_branches_with_stitch_point= [5]
# MP_branches_for_correspondence = [5]
# MP_leftover = [], MP_leftover_idx = []
#  Finished with (17, 0)
#
#
#
#
# ---- Working on (18, 0) connection-----
# Current stitch point was not a branch or endpoint, shortest_path_length to one = 366.33854180731964
# Changing the stitch point becasue the distance to end or branch node was 366.33854180731964
# New stitch point has degree 1
# sk_conn = [6, 9]
# conn = [6, 9]
# winning_vertex = [1245661.3356755   604576.90410042  718595.60475706]
# MP_branches_with_stitch_point = [6, 9]
# MAP_branches_with_stitch_point = [2]
# MAP_stitch_point_on_end_or_branch = True
# Found winning edge: [128, 129.0]
# in remove edge
# Found winning edge: [7, 8.0]
# in remove edge
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# --- Working on 1-to-1 correspondence-----
# max(original_labels),len(original_labels) = (2, 3)
# empty_indices % = 0.4261241970021413
#  conflict_indices % = 0.009059463020919124
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# AFTER face_lookup_resolved_test
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# MP_branches_with_stitch_point= [6, 9]
# MP_branches_for_correspondence = [6 9]
# MP_leftover = [], MP_leftover_idx = []
#  Finished with (18, 0)
#
#
#
#
# ---- Working on (19, 0) connection-----
# Current stitch point was not a branch or endpoint, shortest_path_length to one = 17495.008529700368
# sk_conn = [0]
# conn = [0]
# winning_vertex = [1250686.93264839  633416.76661369  705451.80842311]
# MP_branches_with_stitch_point = [0]
# MAP_branches_with_stitch_point = [4]
# MAP_stitch_point_on_end_or_branch = False
# Using max stitch distance (300) for smoothing because stitch_distance greater (598.6091238905224)
# Found winning edge: [9, 10.0]
# in remove edge
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# --- Working on 1-to-1 correspondence-----
# max(original_labels),len(original_labels) = (1, 2)
# empty_indices % = 0.0844633519454046
#  conflict_indices % = 0.0015953203935123637
# HBox(children=(FloatProgress(value=0.0, max=21.0), HTML(value='')))
# AFTER face_lookup_resolved_test
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# --- Working on 1-to-1 correspondence-----
# max(original_labels),len(original_labels) = (2, 3)
# empty_indices % = 0.09562154001006543
#  conflict_indices % = 0.01451098808924677
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# AFTER face_lookup_resolved_test
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Deleting branches from dictionary
# MP_branches_with_stitch_point= [0]
# MP_branches_for_correspondence = [0]
# MP_leftover = [], MP_leftover_idx = []
#  Finished with (19, 0)
#
#
#
#
# ---- Working on (20, 0) connection-----
# Current stitch point was not a branch or endpoint, shortest_path_length to one = 8432.243556434163
# sk_conn = [0]
# conn = [0]
# winning_vertex = [1254283.10555483  677376.12870177  711313.21241617]
# MP_branches_with_stitch_point = [0]
# MAP_branches_with_stitch_point = [6]
# MAP_stitch_point_on_end_or_branch = False
# Using max stitch distance (300) for smoothing because stitch_distance greater (1282.6190394787761)
# Found winning edge: [955, 956.0]
# in remove edge
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# --- Working on 1-to-1 correspondence-----
# max(original_labels),len(original_labels) = (1, 2)
# empty_indices % = 0.05086688637340593
#  conflict_indices % = 0.006734489181831208
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# AFTER face_lookup_resolved_test
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# --- Working on 1-to-1 correspondence-----
# max(original_labels),len(original_labels) = (2, 3)
# empty_indices % = 0.10117407225640832
#  conflict_indices % = 0.01740345048888218
# HBox(children=(FloatProgress(value=0.0, max=54.0), HTML(value='')))
# AFTER face_lookup_resolved_test
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Deleting branches from dictionary
# MP_branches_with_stitch_point= [0]
# MP_branches_for_correspondence = [0]
# MP_leftover = [], MP_leftover_idx = []
#  Finished with (20, 0)
#
#
#
#
# ---- Working on (21, 0) connection-----
# Current stitch point was not a branch or endpoint, shortest_path_length to one = 785.9807391735033
# sk_conn = [1, 3]
# conn = [1, 3]
# winning_vertex = [1234111.08600813  664515.90299305  741762.53168965]
# MP_branches_with_stitch_point = [1, 3]
# MAP_branches_with_stitch_point = [0]
# MAP_stitch_point_on_end_or_branch = False
# Using max stitch distance (300) for smoothing because stitch_distance greater (727.3053713232182)
# Found winning edge: [376, 378.0]
# in remove edge
# Using max stitch distance (300) for smoothing because stitch_distance greater (598.0034395918852)
# Found winning edge: [9, 10.0]
# in remove edge
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# --- Working on 1-to-1 correspondence-----
# max(original_labels),len(original_labels) = (1, 2)
# empty_indices % = 0.16880382775119618
#  conflict_indices % = 0.023062200956937798
# HBox(children=(FloatProgress(value=0.0, max=30.0), HTML(value='')))
# AFTER face_lookup_resolved_test
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# --- Working on 1-to-1 correspondence-----
# max(original_labels),len(original_labels) = (3, 4)
# empty_indices % = 0.16657493316559208
#  conflict_indices % = 0.012541280075483567
# HBox(children=(FloatProgress(value=0.0, max=50.0), HTML(value='')))
# AFTER face_lookup_resolved_test
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))
# Deleting branches from dictionary
# MP_branches_with_stitch_point= [1, 3]
# MP_branches_for_correspondence = [1 3]
# MP_leftover = [], MP_leftover_idx = []
#  Finished with (21, 0)
#
#
#
#
# ---- Working on (22, 0) connection-----
# Current stitch point was a branch or endpoint
# sk_conn = [0]
# conn = [0]
# winning_vertex = [1247318.80559244  581870.11145457  695184.2767054 ]
# MP_branches_with_stitch_point = [0]
# MAP_branches_with_stitch_point = [8, 15]
# MAP_stitch_point_on_end_or_branch = True
# Using max stitch distance (300) for smoothing because stitch_distance greater (9741.503688039887)
# Found winning edge: [88, 89.0]
# in remove edge
#
# Revising the MAP pieces index:
# MAP_pieces_idx_touching_border = [8], MAP_branches_with_stitch_point = [8, 15]
# MAP_pieces_for_correspondence = [8]
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# empty mesh_correspondence_indices_2 returned so returning original mesh correspondence
#
#
#
# --- Working on 1-to-1 correspondence-----
# max(original_labels),len(original_labels) = (1, 2)
# empty_indices % = 0.6145070422535212
#  conflict_indices % = 0.0
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# AFTER face_lookup_resolved_test
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# MP_branches_with_stitch_point= [0]
# MP_branches_for_correspondence = [0]
# MP_leftover = [], MP_leftover_idx = []
#  Finished with (22, 0)
#
#
#
#
# ---- Working on (26, 0) connection-----
# Current stitch point was not a branch or endpoint, shortest_path_length to one = 5998.446172317356
# sk_conn = [0]
# conn = [0]
# winning_vertex = [1247568.79916369  598627.73046418  711947.28833969]
# MP_branches_with_stitch_point = [0]
# MAP_branches_with_stitch_point = [17]
# MAP_stitch_point_on_end_or_branch = False
# Using max stitch distance (300) for smoothing because stitch_distance greater (338.47269827924754)
# Found winning edge: [92, 93.0]
# in remove edge
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# --- Working on 1-to-1 correspondence-----
# max(original_labels),len(original_labels) = (1, 2)
# empty_indices % = 0.15098241985522234
#  conflict_indices % = 0.011720096518441917
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# AFTER face_lookup_resolved_test
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# --- Working on 1-to-1 correspondence-----
# max(original_labels),len(original_labels) = (2, 3)
# empty_indices % = 0.26479600064505726
#  conflict_indices % = 0.0859538784067086
# HBox(children=(FloatProgress(value=0.0, max=7.0), HTML(value='')))
# AFTER face_lookup_resolved_test
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Deleting branches from dictionary
# MP_branches_with_stitch_point= [0]
# MP_branches_for_correspondence = [0]
# ...
# Working on limb L0 branch 22
# Working on limb L0 branch 184
# Working on limb L0 branch 148
# Working on limb L0 branch 151
# No spines and using precomputed width
# Working on limb L0 branch 5
# Working on limb L0 branch 11
# No spines and using precomputed width
# Working on limb L0 branch 144
# No spines and using precomputed width
# Working on limb L0 branch 147
# No spines and using precomputed width
# Working on limb L0 branch 14
# Working on limb L0 branch 65
# Working on limb L0 branch 143
# No spines and using precomputed width
# Working on limb L0 branch 145
# No spines and using precomputed width
# Working on limb L0 branch 146
# No spines and using precomputed width
# Working on limb L0 branch 150
# No spines and using precomputed width
# Working on limb L0 branch 12
# Working on limb L0 branch 112
# Working on limb L0 branch 114
# Working on limb L0 branch 64
# No spines and using precomputed width
# Working on limb L0 branch 69
# No spines and using precomputed width
# Working on limb L0 branch 75
# No spines and using precomputed width
# Working on limb L0 branch 8
# No spines and using precomputed width
# Working on limb L0 branch 80
# No spines and using precomputed width
# Working on limb L0 branch 85
# Working on limb L0 branch 106
# Working on limb L0 branch 111
# No spines and using precomputed width
# Working on limb L0 branch 63
# No spines and using precomputed width
# Working on limb L0 branch 66
# No spines and using precomputed width
# Working on limb L0 branch 15
# Working on limb L0 branch 41
# Working on limb L0 branch 90
# No spines and using precomputed width
# Working on limb L0 branch 100
# No spines and using precomputed width
# Working on limb L0 branch 175
# No spines and using precomputed width
# Working on limb L0 branch 79
# No spines and using precomputed width
# Working on limb L0 branch 87
# No spines and using precomputed width
# Working on limb L0 branch 82
# No spines and using precomputed width
# Working on limb L0 branch 86
# No spines and using precomputed width
# Working on limb L0 branch 105
# No spines and using precomputed width
# Working on limb L0 branch 109
# No spines and using precomputed width
# Working on limb L0 branch 107
# No spines and using precomputed width
# Working on limb L0 branch 108
# No spines and using precomputed width
# Working on limb L0 branch 110
# No spines and using precomputed width
# Working on limb L0 branch 62
# No spines and using precomputed width
# Working on limb L0 branch 67
# Working on limb L0 branch 9
# Working on limb L0 branch 119
# Working on limb L0 branch 120
# No spines and using precomputed width
# Working on limb L0 branch 26
# Working on limb L0 branch 27
# Working on limb L0 branch 42
# No spines and using precomputed width
# Working on limb L0 branch 91
# No spines and using precomputed width
# Working on limb L0 branch 94
# No spines and using precomputed width
# Working on limb L0 branch 78
# No spines and using precomputed width
# Working on limb L0 branch 81
# No spines and using precomputed width
# Working on limb L0 branch 83
# No spines and using precomputed width
# Working on limb L0 branch 84
# No spines and using precomputed width
# Working on limb L0 branch 104
# No spines and using precomputed width
# Working on limb L0 branch 113
# No spines and using precomputed width
# Working on limb L0 branch 61
# No spines and using precomputed width
# Working on limb L0 branch 71
# No spines and using precomputed width
# Working on limb L0 branch 68
# No spines and using precomputed width
# Working on limb L0 branch 70
# No spines and using precomputed width
# Working on limb L0 branch 3
# No spines and using precomputed width
# Working on limb L0 branch 43
# Working on limb L0 branch 118
# No spines and using precomputed width
# Working on limb L0 branch 130
# No spines and using precomputed width
# Working on limb L0 branch 121
# No spines and using precomputed width
# Working on limb L0 branch 127
# No spines and using precomputed width
# Working on limb L0 branch 23
# Working on limb L0 branch 40
# No spines and using precomputed width
# Working on limb L0 branch 52
# No spines and using precomputed width
# Working on limb L0 branch 57
# Working on limb L0 branch 98
# No spines and using precomputed width
# Working on limb L0 branch 99
# No spines and using precomputed width
# Working on limb L0 branch 60
# No spines and using precomputed width
# Working on limb L0 branch 74
# No spines and using precomputed width
# Working on limb L0 branch 72
# No spines and using precomputed width
# Working on limb L0 branch 73
# No spines and using precomputed width
# Working on limb L0 branch 7
# Working on limb L0 branch 21
# No spines and using precomputed width
# Working on limb L0 branch 44
# No spines and using precomputed width
# Working on limb L0 branch 45
# No spines and using precomputed width
# Working on limb L0 branch 117
# No spines and using precomputed width
# Working on limb L0 branch 128
# No spines and using precomputed width
# Working on limb L0 branch 122
# No spines and using precomputed width
# Working on limb L0 branch 124
# Working on limb L0 branch 28
# No spines and using precomputed width
# Working on limb L0 branch 102
# No spines and using precomputed width
# Working on limb L0 branch 51
# No spines and using precomputed width
# Working on limb L0 branch 55
# No spines and using precomputed width
# Working on limb L0 branch 50
# No spines and using precomputed width
# Working on limb L0 branch 56
# No spines and using precomputed width
# Working on limb L0 branch 59
# No spines and using precomputed width
# Working on limb L0 branch 97
# Working on limb L0 branch 101
# Working on limb L0 branch 89
# No spines and using precomputed width
# Working on limb L0 branch 92
# No spines and using precomputed width
# Working on limb L0 branch 1
# Working on limb L0 branch 36
# Working on limb L0 branch 17
# Working on limb L0 branch 183
# Working on limb L0 branch 116
# No spines and using precomputed width
# Working on limb L0 branch 129
# No spines and using precomputed width
# Working on limb L0 branch 123
# No spines and using precomputed width
# Working on limb L0 branch 125
# No spines and using precomputed width
# Working on limb L0 branch 31
# No spines and using precomputed width
# Working on limb L0 branch 179
# No spines and using precomputed width
# Working on limb L0 branch 48
# No spines and using precomputed width
# Working on limb L0 branch 49
# No spines and using precomputed width
# Working on limb L0 branch 53
# No spines and using precomputed width
# Working on limb L0 branch 58
# No spines and using precomputed width
# Working on limb L0 branch 88
# No spines and using precomputed width
# Working on limb L0 branch 96
# No spines and using precomputed width
# Working on limb L0 branch 134
# Working on limb L0 branch 138
# No spines and using precomputed width
# Working on limb L0 branch 35
# Working on limb L0 branch 37
# No spines and using precomputed width
# Working on limb L0 branch 2
# Working on limb L0 branch 157
# Working on limb L0 branch 115
# No spines and using precomputed width
# Working on limb L0 branch 126
# No spines and using precomputed width
# Working on limb L0 branch 30
# Working on limb L0 branch 176
# No spines and using precomputed width
# Working on limb L0 branch 177
# No spines and using precomputed width
# Working on limb L0 branch 178
# No spines and using precomputed width
# Working on limb L0 branch 47
# No spines and using precomputed width
# Working on limb L0 branch 54
# Working on limb L0 branch 93
# No spines and using precomputed width
# Working on limb L0 branch 95
# No spines and using precomputed width
# Working on limb L0 branch 133
# No spines and using precomputed width
# Working on limb L0 branch 140
# No spines and using precomputed width
# Working on limb L0 branch 135
# Working on limb L0 branch 137
# No spines and using precomputed width
# Working on limb L0 branch 34
# Working on limb L0 branch 38
# No spines and using precomputed width
# Working on limb L0 branch 165
# No spines and using precomputed width
# Working on limb L0 branch 168
# Working on limb L0 branch 153
# No spines and using precomputed width
# Working on limb L0 branch 156
# Working on limb L0 branch 32
# Working on limb L0 branch 181
# No spines and using precomputed width
# Working on limb L0 branch 132
# No spines and using precomputed width
# Working on limb L0 branch 136
# No spines and using precomputed width
# Working on limb L0 branch 33
# No spines and using precomputed width
# Working on limb L0 branch 39
# No spines and using precomputed width
# Working on limb L0 branch 160
# No spines and using precomputed width
# Working on limb L0 branch 167
# Working on limb L0 branch 152
# No spines and using precomputed width
# Working on limb L0 branch 155
# No spines and using precomputed width
# Working on limb L0 branch 24
# Working on limb L0 branch 25
# Working on limb L0 branch 180
# No spines and using precomputed width
# Working on limb L0 branch 182
# No spines and using precomputed width
# Working on limb L0 branch 131
# Working on limb L0 branch 139
# No spines and using precomputed width
# Working on limb L0 branch 161
# No spines and using precomputed width
# Working on limb L0 branch 162
# No spines and using precomputed width
# Working on limb L0 branch 164
# No spines and using precomputed width
# Working on limb L0 branch 166
# Working on limb L0 branch 154
# No spines and using precomputed width
# Working on limb L0 branch 158
# No spines and using precomputed width
# Working on limb L0 branch 76
# No spines and using precomputed width
# Working on limb L0 branch 77
# Working on limb L0 branch 29
# No spines and using precomputed width
# Working on limb L0 branch 141
# Working on limb L0 branch 142
# Working on limb L0 branch 159
# No spines and using precomputed width
# Working on limb L0 branch 163
# No spines and using precomputed width
# Working on limb L1 branch 0
# No spines and using precomputed width
# Working on limb L1 branch 1
# Working on limb L1 branch 2
# Working on limb L1 branch 4
# Working on limb L1 branch 60
# Working on limb L1 branch 5
# Working on limb L1 branch 61
# Working on limb L1 branch 56
# Working on limb L1 branch 58
# Working on limb L1 branch 3
# No spines and using precomputed width
# Working on limb L1 branch 14
# No spines and using precomputed width
# Working on limb L1 branch 57
# No spines and using precomputed width
# Working on limb L1 branch 59
# Working on limb L1 branch 53
# Working on limb L1 branch 55
# No spines and using precomputed width
# Working on limb L1 branch 13
# No spines and using precomputed width
# Working on limb L1 branch 24
# No spines and using precomputed width
# Working on limb L1 branch 52
# No spines and using precomputed width
# Working on limb L1 branch 54
# Working on limb L1 branch 12
# No spines and using precomputed width
# Working on limb L1 branch 36
# No spines and using precomputed width
# Working on limb L1 branch 23
# No spines and using precomputed width
# Working on limb L1 branch 47
# No spines and using precomputed width
# Working on limb L1 branch 11
# No spines and using precomputed width
# Working on limb L1 branch 43
# No spines and using precomputed width
# Working on limb L1 branch 22
# No spines and using precomputed width
# Working on limb L1 branch 28
# No spines and using precomputed width
# Working on limb L1 branch 10
# No spines and using precomputed width
# Working on limb L1 branch 34
# No spines and using precomputed width
# Working on limb L1 branch 21
# No spines and using precomputed width
# Working on limb L1 branch 50
# No spines and using precomputed width
# Working on limb L1 branch 27
# No spines and using precomputed width
# Working on limb L1 branch 38
# No spines and using precomputed width
# Working on limb L1 branch 9
# No spines and using precomputed width
# Working on limb L1 branch 31
# No spines and using precomputed width
# Working on limb L1 branch 33
# No spines and using precomputed width
# Working on limb L1 branch 41
# No spines and using precomputed width
# Working on limb L1 branch 20
# No spines and using precomputed width
# Working on limb L1 branch 29
# No spines and using precomputed width
# Working on limb L1 branch 49
# No spines and using precomputed width
# Working on limb L1 branch 51
# No spines and using precomputed width
# Working on limb L1 branch 8
# No spines and using precomputed width
# Working on limb L1 branch 15
# No spines and using precomputed width
# Working on limb L1 branch 30
# No spines and using precomputed width
# Working on limb L1 branch 46
# No spines and using precomputed width
# Working on limb L1 branch 40
# No spines and using precomputed width
# Working on limb L1 branch 48
# No spines and using precomputed width
# Working on limb L1 branch 19
# No spines and using precomputed width
# Working on limb L1 branch 45
# No spines and using precomputed width
# Working on limb L1 branch 7
# No spines and using precomputed width
# Working on limb L1 branch 35
# No spines and using precomputed width
# Working on limb L1 branch 18
# No spines and using precomputed width
# Working on limb L1 branch 37
# No spines and using precomputed width
# Working on limb L1 branch 6
# No spines and using precomputed width
# Working on limb L1 branch 42
# No spines and using precomputed width
# Working on limb L1 branch 44
# No spines and using precomputed width
# Working on limb L1 branch 17
# No spines and using precomputed width
# Working on limb L1 branch 39
# No spines and using precomputed width
# Working on limb L1 branch 16
# No spines and using precomputed width
# Working on limb L1 branch 26
# No spines and using precomputed width
# Working on limb L1 branch 25
# No spines and using precomputed width
# Working on limb L1 branch 32
# No spines and using precomputed width
# Working on limb L2 branch 0
# No spines and using precomputed width
# Working on limb L2 branch 3
# No spines and using precomputed width
# Working on limb L2 branch 8
# No spines and using precomputed width
# Working on limb L2 branch 2
# No spines and using precomputed width
# Working on limb L2 branch 14
# No spines and using precomputed width
# Working on limb L2 branch 7
# No spines and using precomputed width
# Working on limb L2 branch 10
# No spines and using precomputed width
# Working on limb L2 branch 1
# No spines and using precomputed width
# Working on limb L2 branch 13
# No spines and using precomputed width
# Working on limb L2 branch 6
# No spines and using precomputed width
# Working on limb L2 branch 25
# No spines and using precomputed width
# Working on limb L2 branch 9
# No spines and using precomputed width
# Working on limb L2 branch 16
# No spines and using precomputed width
# Working on limb L2 branch 12
# No spines and using precomputed width
# Working on limb L2 branch 19
# No spines and using precomputed width
# Working on limb L2 branch 5
# No spines and using precomputed width
# Working on limb L2 branch 18
# No spines and using precomputed width
# Working on limb L2 branch 15
# No spines and using precomputed width
# Working on limb L2 branch 22
# No spines and using precomputed width
# Working on limb L2 branch 11
# No spines and using precomputed width
# Working on limb L2 branch 20
# No spines and using precomputed width
# Working on limb L2 branch 4
# Working on limb L2 branch 26
# No spines and using precomputed width
# Working on limb L2 branch 17
# Working on limb L2 branch 24
# No spines and using precomputed width
# Working on limb L2 branch 21
# No spines and using precomputed width
# Working on limb L2 branch 23
# No spines and using precomputed width
# Working on limb L3 branch 2
# Working on limb L3 branch 1
# No spines and using precomputed width
# Working on limb L3 branch 6
# Working on limb L3 branch 0
# Working on limb L3 branch 5
# Working on limb L3 branch 3
# Working on limb L3 branch 4
# No spines and using precomputed width
# Working on limb L4 branch 2
# Working on limb L4 branch 1
# Working on limb L4 branch 6
# Working on limb L4 branch 0
# Working on limb L4 branch 5
# Working on limb L4 branch 3
# Working on limb L4 branch 4
# No spines and using precomputed width
# Working on limb L5 branch 0
# Working on limb L5 branch 2
# Working on limb L5 branch 3
# Working on limb L5 branch 1
# Working on limb L5 branch 4
# No spines and using precomputed width
# Working on limb L6 branch 0
# Working on limb L6 branch 1
# Working on limb L6 branch 3
# Working on limb L6 branch 2
# Working on limb L6 branch 4
# No spines and using precomputed width
# Working on limb L7 branch 0
# Working on limb L8 branch 2
# No spines and using precomputed width
# Working on limb L8 branch 0
# Working on limb L8 branch 1
# No spines and using precomputed width
# Total time for neuron instance creation = 1308.7674748897552

# %%
debug
# Out:
# > /meshAfterParty/skeleton_utils.py(1376)calcification()
#    1374         min_edge_length,
#    1375         edge_length_multiplier,
# -> 1376         print_parameters
#    1377     )
#    1378
#
# ipdb> u
# > /meshAfterParty/skeleton_utils.py(2783)skeletonize_connected_branch()
#    2781                 #print(f"Path sending to calcification = {written_path[:-4]}")
#    2782                 returned_value, sk_file_name = calcification(written_path,
# -> 2783                                                                min_edge_length = current_min_edge)
#    2784                 if skeleton_print:
#    2785                     print(f"returned_value = {returned_value}")
#
# ipdb> u
# > /meshAfterParty/skeleton_utils.py(4393)skeletonize_and_clean_connected_branch_CGAL()
#    4391     branch = mesh
#    4392     clean_time = time.time()
# -> 4393     current_skeleton = skeletonize_connected_branch(branch,**kwargs)
#    4394
#    4395     print("Checking connected components after skeletonize_connected_branch")
#
# ipdb> u
# > /meshAfterParty/preprocessing_vp2.py(1069)preprocess_limb()
#    1067             combine_close_skeleton_nodes_threshold=combine_close_skeleton_nodes_threshold,
#    1068         use_surface_after_CGAL=use_surface_after_CGAL,
# -> 1069         surface_reconstruction_size=surface_reconstruction_size)
#    1070
#    1071         if not curr_limb_endpoints_must_keep is None:
#
# ipdb> u
# > /meshAfterParty/preprocessing_vp2.py(2794)preprocess_neuron()
#    2792                        meshparty_n_surface_downsampling = meshparty_n_surface_downsampling,
#    2793
# -> 2794                         use_meshafterparty=use_meshafterparty,
#    2795
#    2796                        )
#
# ipdb> limb_correspondence[0]
# {0: {'branch_skeleton': array([[[1233780.,  664489.,  741016.],
#         [1233610.,  664438.,  740982.]],
#
#        [[1233780.,  664489.,  741016.],
#         [1234060.,  664504.,  741064.]],
#
#        [[1234060.,  664504.,  741064.],
#         [1234230.,  664489.,  741052.]],
#
#        [[1233510.,  664415.,  740962.],
#         [1233610.,  664438.,  740982.]]]), 'width_from_skeleton': 2218.513658123369, 'branch_mesh': <trimesh.Trimesh(vertices.shape=(92, 3), faces.shape=(154, 3))>, 'branch_face_idx': array([320435, 320465, 320466, 320467, 320476, 320477, 320480, 320485,
#        320486, 320487, 320489, 320493, 320497, 320533, 320536, 320537,
#        320546, 320547, 320548, 320555, 320556, 320618, 320619, 320620,
#        320621, 320622, 320623, 320626, 320628, 320636, 320637, 320638,
#        320639, 320640, 320642, 320669, 320670, 320925, 320926, 320927,
#        320939, 320940, 320941, 320942, 320949, 320951, 320952, 320971,
#        320972, 320973, 320974, 320975, 320976, 320977, 320978, 320979,
#        320984, 320985, 320986, 320987, 320988, 320989, 320990, 320991,
#        320992, 320993, 320994, 320995, 320996, 320997, 320998, 320999,
#        321000, 321001, 321002, 321003, 321004, 321005, 321006, 321007,
#        321008, 321009, 321010, 321011, 321012, 321013, 321020, 321021,
#        321025, 321029, 321030, 321031, 321032, 321034, 321035, 321036,
#        321037, 321038, 321040, 321042, 321164, 321165, 321166, 321215,
#        321216, 321217, 321226, 321227, 321285, 321289, 321290, 321291,
#        321292, 321293, 321294, 321301, 321316, 321317, 321318, 321319,
#        321320, 321321, 321322, 321323, 321324, 321325, 321326, 321327,
#        321328, 321329, 321330, 321331, 321332, 321333, 321334, 321335,
#        321336, 321337, 321338, 321339, 321340, 321341, 321342, 321343,
#        321344, 321345, 321373, 320496, 320549, 320535, 320545, 320634,
#        320645, 320646])}, 1: {'branch_skeleton': array([[[1235500.,  595949.,  709286.],
#         [1235550.,  596122.,  709273.]],
#
#        [[1235550.,  596122.,  709273.],
#         [1235600.,  596259.,  709280.]],
#
#        [[1235600.,  596259.,  709280.],
#         [1235650.,  596388.,  709284.]],
#
#        [[1235650.,  596388.,  709284.],
#         [1235720.,  596501.,  709283.]],
#
#        [[1235720.,  596501.,  709283.],
#         [1235880.,  596691.,  709267.]],
#
#        [[1235880.,  596691.,  709267.],
#         [1236020.,  596823.,  709249.]],
#
#        [[1236020.,  596823.,  709249.],
#        [[1249890.,  629709.,  703824.],
#         [1249900.,  629807.,  703864.]],
#
#        [[1249900.,  629807.,  703864.],
#         [1249920.,  629934.,  703907.]],
#
#        [[1249910.,  626482.,  702004.],
#         [1249940.,  626339.,  701951.]],
#
#        [[1249920.,  629934.,  703907.],
#         [1249940.,  630050.,  703946.]],
#
#        [[1249940.,  626339.,  701951.],
#         [1249990.,  626187.,  701888.]],
#
#        [[1249940.,  630050.,  703946.],
#         [1249960.,  630147.,  703978.]],
#
#        [[1249960.,  630147.,  703978.],
#         [1249990.,  630297.,  704018.]],
#
#        [[1249990.,  626187.,  701888.],
#         [1250020.,  626104.,  701855.]],
#
#        [[1249990.,  630297.,  704018.],
#         [1250000.,  630426.,  704057.]],
#
#        [[1250000.,  630426.,  704057.],
#         [1250040.,  630617.,  704107.]],
#
#        [[1250020.,  626104.,  701855.],
#         [1250060.,  625965.,  701798.]],
#
#        [[1250040.,  630617.,  704107.],
#         [1250070.,  630750.,  704141.]],
#
#        [[1250060.,  625965.,  701798.],
#         [1250080.,  625892.,  701767.]],
#
#        [[1250070.,  630750.,  704141.],
#         [1250100.,  630872.,  704172.]],
#
#        [[1250070.,  633564.,  705607.],
#         [1250170.,  633383.,  705551.]],
#
#        [[1250080.,  625892.,  701767.],
#         [1250120.,  625791.,  701724.]],
#
#        [[1250100.,  630872.,  704172.],
#         [1250120.,  630998.,  704210.]],
#
#        [[1250120.,  625791.,  701724.],
#         [1250150.,  625701.,  701686.]],
#
#        [[1250120.,  630998.,  704210.],
#         [1250150.,  631130.,  704247.]],
#
#        [[1250150.,  625701.,  701686.],
#         [1250180.,  625591.,  701640.]],
#
#        [[1250150.,  631130.,  704247.],
#         [1250160.,  631190.,  704265.]],
#
#        [[1250160.,  631190.,  704265.],
#         [1250170.,  631282.,  704294.]],
#
#        [[1250170.,  631282.,  704294.],
#         [1250190.,  631386.,  704330.]],
#
#        [[1250170.,  633383.,  705551.],
#         [1250240.,  633225.,  705482.]],
#
#        [[1250180.,  625591.,  701640.],
#         [1250210.,  625493.,  701601.]],
#
#        [[1250190.,  631386.,  704330.],
#         [1250210.,  631521.,  704384.]],
#
#        [[1250210.,  625493.,  701601.],
#         [1250230.,  625387.,  701559.]],
#
#        [[1250210.,  631521.,  704384.],
#         [1250210.,  631629.,  704432.]],
#
#        [[1250210.,  631629.,  704432.],
#         [1250220.,  631740.,  704484.]],
#
#        [[1250220.,  631740.,  704484.],
#         [1250230.,  631857.,  704542.]],
#
#        [[1250220.,  633007.,  705252.],
#         [1250220.,  633077.,  705318.]],
#
#        [[1250220.,  633007.,  705252.],
#         [1250230.,  632867.,  705151.]],
#
#        [[1250220.,  633077.,  705318.],
#         [1250240.,  633225.,  705482.]],
#
#        [[1250230.,  625387.,  701559.],
#         [1250260.,  625291.,  701520.]],
#
#        [[1250230.,  631857.,  704542.],
#         [1250230.,  631956.,  704593.]],
#
#        [[1250230.,  631956.,  704593.],
#         [1250240.,  632109.,  704674.]],
#
#        [[1250230.,  632783.,  705083.],
#         [1250230.,  632867.,  705151.]],
#
#        [[1250230.,  632783.,  705083.],
#         [1250240.,  632656.,  704996.]],
#
#        [[1250240.,  632109.,  704674.],
#         [1250240.,  632236.,  704744.]],
#
#        [[1250240.,  632236.,  704744.],
#         [1250240.,  632419.,  704850.]],
#
#        [[1250240.,  632419.,  704850.],
#         [1250240.,  632568.,  704940.]],
#
#        [[1250240.,  632568.,  704940.],
#         [1250240.,  632656.,  704996.]],
#
#        [[1250260.,  625291.,  701520.],
#         [1250290.,  625155.,  701465.]],
#
#        [[1250290.,  625155.,  701465.],
#         [1250330.,  624991.,  701395.]],
#
#        [[1250300.,  622044.,  699669.],
#         [1250300.,  622163.,  699717.]],
#
#        [[1250300.,  622044.,  699669.],
#         [1250310.,  622014.,  699657.]],
#
#        [[1250300.,  622163.,  699717.],
#         [1250310.,  622352.,  699810.]],
#
#        [[1250310.,  622014.,  699657.],
#         [1250320.,  621885.,  699615.]],
#
#        [[1250310.,  622352.,  699810.],
#         [1250320.,  622438.,  699858.]],
#
#        [[1250320.,  621885.,  699615.],
#         [1250360.,  621735.,  699575.]],
#
#        [[1250320.,  622438.,  699858.],
#         [1250340.,  622566.,  699934.]],
#
#        [[1250330.,  624991.,  701395.],
#         [1250350.,  624883.,  701348.]],
#
#        [[1250340.,  622566.,  699934.],
#         [1250370.,  622698.,  700023.]],
#
#        [[1250350.,  624883.,  701348.],
#         [1250370.,  624757.,  701291.]],
#
#        [[1250360.,  621735.,  699575.],
#         [1250430.,  621492.,  699529.]],
#
#        [[1250370.,  622698.,  700023.],
#         [1250410.,  622887.,  700153.]],
#
#        [[1250370.,  624757.,  701291.],
#         [1250410.,  624600.,  701217.]],
#
#        [[1250410.,  622887.,  700153.],
#         [1250440.,  623012.,  700242.]],
#
#        [[1250410.,  624600.,  701217.],
#         [1250470.,  624261.,  701043.]],
#
#        [[1250430.,  621492.,  699529.],
#         [1250500.,  621344.,  699519.]],
#
#        [[1250440.,  623012.,  700242.],
#         [1250470.,  623108.,  700312.]],
#
#        [[1250470.,  623108.,  700312.],
#         [1250510.,  623269.,  700428.]],
#
#        [[1250470.,  624261.,  701043.],
#         [1250500.,  624131.,  700974.]],
#
#        [[1250500.,  621344.,  699519.],
#         [1250540.,  621270.,  699517.]],
#
#        [[1250500.,  624131.,  700974.],
#         [1250530.,  623945.,  700869.]],
#
#        [[1250510.,  623269.,  700428.],
#         [1250530.,  623379.,  700506.]],
#
#        [[1250530.,  623379.,  700506.],
#         [1250550.,  623484.,  700576.]],
#
#        [[1250530.,  623945.,  700869.],
#         [1250550.,  623792.,  700776.]],
#
#        [[1250540.,  621270.,  699517.],
#         [1250580.,  621205.,  699520.]],
#
#        [[1250550.,  623484.,  700576.],
#         [1250550.,  623564.,  700630.]],
#
#        [[1250550.,  623564.,  700630.],
#         [1250560.,  623647.,  700685.]],
#
#        [[1250550.,  623792.,  700776.],
#         [1250560.,  623694.,  700715.]],
#
#        [[1250560.,  623647.,  700685.],
#         [1250560.,  623694.,  700715.]],
#
#        [[1250580.,  621205.,  699520.],
#         [1250670.,  621044.,  699533.]],
#
#         [1247552.85329185,  599107.50352667,  711218.26565592]],
#
#        [[1247552.85329185,  599107.50352667,  711218.26565592],
#         [1247585.36308927,  599069.07463932,  711304.67360514]],
#
#        [[1247585.36308927,  599069.07463932,  711304.67360514],
#         [1247617.8728867 ,  599030.64575197,  711391.08155436]],
#
#        [[1247617.8728867 ,  599030.64575197,  711391.08155436],
#         [1247650.38268412,  598992.21686462,  711477.48950358]],
#
#        [[1247650.38268412,  598992.21686462,  711477.48950358],
#         [1247682.89248154,  598953.78797727,  711563.8974528 ]],
#
#        [[1247682.89248154,  598953.78797727,  711563.8974528 ],
#         [1247715.40227897,  598915.35908992,  711650.30540202]],
#
#        [[1247715.40227897,  598915.35908992,  711650.30540202],
#         [1247747.91207639,  598876.93020257,  711736.71335124]],
#
#        [[1247747.91207639,  598876.93020257,  711736.71335124],
#         [1247780.        ,  598839.        ,  711822.        ]]]), 'width_from_skeleton': 1918.2334040035876, 'branch_mesh': <trimesh.Trimesh(vertices.shape=(1589, 3), faces.shape=(3162, 3))>, 'branch_face_idx': array([138334, 138335, 138336, ..., 151811, 151812, 168593])}, 183: {'branch_skeleton': array([[[1251360.        ,  612037.        ,  701135.        ],
#         [1251457.3469039 ,  612018.43249564,  701121.62733822]],
#
#        [[1251457.3469039 ,  612018.43249564,  701121.62733822],
#         [1251554.6938078 ,  611999.86499129,  701108.25467645]],
#
#        [[1251554.6938078 ,  611999.86499129,  701108.25467645],
#         [1251652.0407117 ,  611981.29748693,  701094.88201467]],
#
#        ...,
#
#        [[1309266.85709987,  543693.95034776,  697806.01001429],
#         [1309317.51115712,  543608.6014862 ,  697793.7966608 ]],
#
#        [[1309317.51115712,  543608.6014862 ,  697793.7966608 ],
#         [1309368.35601854,  543523.15444352,  697783.14167418]],
#
#        [[1309368.35601854,  543523.15444352,  697783.14167418],
#         [1309374.64423321,  543512.59665109,  697781.88852481]]]), 'width_from_skeleton': 1103.5908303055767, 'branch_mesh': <trimesh.Trimesh(vertices.shape=(9170, 3), faces.shape=(18262, 3))>, 'branch_face_idx': array([   903,    913,    925, ..., 484279, 484280, 484281])}}
# ipdb> su.compressed_pickle(limb_correspondence[0],"limb_correspondence")
# Saved object at /notebooks/Platinum_Datajoint/Neuron_Processing/Debugging_3/limb_correspondence.pbz2
# File size is 16.699283 MB
# ipdb> su.compressed_pickle(limb_network_stating_info[0],"network_starting_info")
# Saved object at /notebooks/Platinum_Datajoint/Neuron_Processing/Debugging_3/network_starting_info.pbz2
# File size is 0.000849 MB
# ipdb> c

# %% [markdown]
# # Saving off the Neuron

# %%
nviz.visualize_neuron(recovered_neuron,
                     visualize_type=["mesh","skeleton"],
                     limb_branch_dict="all")
# Out:
#  Working on visualization type: mesh
#
#  Working on visualization type: skeleton
# VBox(children=(Figure(camera=PerspectiveCamera(fov=46.0, position=(0.0, 0.0, 2.0), quaternion=(0.0, 0.0, 0.0, …

# %%
ret_path = recovered_neuron.save_compressed_neuron(output_folder="/notebooks/test_neurons/multi_soma/Seg_3/",
                                       export_mesh=True,
                                       return_file_path=True)

#curr_file = "/notebooks/test_neurons/multi_soma/Seg_3/864691135560502753_0_25"
neuron_obj = nru.decompress_neuron(filepath=ret_path,
                                  original_mesh=ret_path)
# Out:
# Saving Neuorn in suppress_output mode...please wait
# Saved File at location: /notebooks/test_neurons/multi_soma/Seg_3/864691135104011853_0_25
# Decompressing Neuron in minimal output mode...please wait
