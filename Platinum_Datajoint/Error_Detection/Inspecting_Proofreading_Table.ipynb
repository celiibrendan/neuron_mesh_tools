# %%
from os import sys
sys.path.append("/meshAfterParty/")

# %%
from importlib import reload

import neuron_utils as nru

import neuron

import neuron_visualizations as nviz

import time

import datajoint_utils as du
# Out:
# INFO - 2020-11-28 01:19:43,674 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2020-11-28 01:19:43,676 - settings - Setting database.user to celiib
# INFO - 2020-11-28 01:19:43,676 - settings - Setting database.password to newceliipass

# %%
minnie,schema = du.configure_minnie_vm()
(minnie.Decomposition() & "n_somas = 1" & "n_faces>500000") & "n_same_soma_multi_touching_limbs>0"
# Out:
# INFO - 2020-11-28 01:20:15,178 - settings - Setting stores to {'minnie65': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65', 'stage': '/mnt/dj-stor01/platinum/minnie65'}, 'meshes': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/meshes', 'stage': '/mnt/dj-stor01/platinum/minnie65/02/meshes'}, 'decimated_meshes': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/decimated_meshes', 'stage': '/mnt/dj-stor01/platinum/minnie65/02/decimated_meshes'}, 'skeletons': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/skeletons'}}
# INFO - 2020-11-28 01:20:15,180 - settings - Setting enable_python_native_blobs to True
# INFO - 2020-11-28 01:20:15,194 - connection - Connected celiib@at-database.ad.bcm.edu:3306
# Connecting celiib@at-database.ad.bcm.edu:3306
# INFO - 2020-11-28 01:20:15,444 - settings - Setting enable_python_native_blobs to True
# *segment_id    *decimation_ve *decimation_ra decomposit n_vertices     n_faces     n_error_limbs  n_same_soma_mu n_multi_soma_t n_somas     n_limbs     n_branches     max_limb_n_bra skeletal_lengt max_limb_skele median_branch_ width_median   width_no_spine width_90_perc  width_no_spine n_spines     spine_density  spines_per_bra skeletal_lengt n_spine_eligib spine_density_ spines_per_bra total_spine_vo spine_volume_m spine_volume_d spine_volume_d spine_volume_p run_time
# +------------+ +------------+ +------------+ +--------+ +------------+ +---------+ +------------+ +------------+ +------------+ +---------+ +---------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +----------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +-----------+
# 86469113488474 0              0.25           =BLOB=     843280         1700959     2              2              0              1           10          583            190            9413167.750364 3368032.161881 7808.186       114.566        114.566        435.79         391.447        3034         0.000322314451 5.204116638078 4757150.4      249            nan            nan            191374383459.0 42245315.42166 20330.49750459 40228.78558960 768571821.1208 4240.5491
# 86469113488474 0              0.25           =BLOB=     374888         770862      1              1              0              1           7           102            37             3947733.185359 1493754.033057 18624.179      122.975        122.975        536.469        471.729        1555         0.000393896934 15.24509803921 2460060.756    45             nan            nan            72821276363.55 30931750.13158 18446.35210748 29601.41378051 1618250585.856 2185.5764
# 86469113488474 0              0.25           =BLOB=     298676         599981      1              1              0              1           8           461            220            6381578.759465 2926907.670452 8563.802       74.779         74.779         117.861        117.861        5            7.835051777091 0.010845986984 235742.906     23             nan            nan            182351327.9916 22639885.75833 28.57464192872 773.5177744507 7928318.608333 1002.7609
# 86469113488474 0              0.25           =BLOB=     333547         690610      1              1              0              1           6           227            150            5923256.260350 3562420.952841 15945.722      91.936         91.936         247.021        245.172        141          2.380447405995 0.621145374449 871126.173     30             nan            nan            6818450888.328 26686104.13832 1151.132179434 7827.167980554 227281696.2776 1224.9961
# 86469113488474 0              0.25           =BLOB=     408678         840775      1              1              0              1           5           116            58             2857353.604366 1383537.606889 10653.49       383.725        296.325        509.887        490.661        2202         0.000770643156 18.98275862068 2724171.909    91             nan            nan            166090592271.9 48686052.66318 58127.41972786 60969.20378747 1825171343.647 2592.1839
# 86469113488475 0              0.25           =BLOB=     421724         868316      1              1              0              1           7           157            60             3891046.292054 1585908.143910 13025.813      164.71         164.71         495.423        413.902        2320         0.000596240657 14.77707006369 2509957.646    89             nan            nan            117627626385.2 31832415.77442 30230.33332331 46864.38696394 1321658723.429 1450.6105
# 86469113488476 0              0.25           =BLOB=     558183         1132950     1              1              0              1           6           193            56             4434613.767862 1710711.920609 12779.018      359.991        297.716        510.219        464.549        2505         0.000564874447 12.97927461139 3974606.818    150            nan            nan            193505892108.9 40990324.51216 43635.34283667 48685.54324231 1290039280.726 3021.3421
# 86469113488476 0              0.25           =BLOB=     410066         832497      1              1              0              1           5           226            157            5450158.626807 3745453.174271 12536.998      91.816         91.816         397.163        323.952        1311         0.000240543457 5.800884955752 2086085.11     55             nan            nan            98613799181.82 44933690.00417 18093.74844555 47272.18401066 1792978166.942 1897.7155
# 86469113488476 0              0.25           =BLOB=     336541         688506      1              1              0              1           7           82             27             3013319.539190 1188847.740581 10868.974      288.977        257.212        452.129        439.431        1387         0.000460289717 16.91463414634 2330964.887    48             nan            nan            92578021091.34 43503077.82966 30722.93525040 39716.60903502 1928708772.736 2540.9794
# 86469113488476 0              0.25           =BLOB=     502399         1020319     1              1              0              1           8           173            65             5292181.242704 2389187.241241 16840.218      240.21         240.21         505.143        460.206        1840         0.000347682725 10.63583815028 3096793.95     96             nan            nan            108908474470.6 32666286.85000 20579.12786354 35168.13718610 1134463275.736 2018.8499
# 86469113488476 0              0.25           =BLOB=     664830         1346855     1              1              0              1           5           390            347            10889893.90145 9210213.344902 18387.62       105.811        105.811        290.357        283.921        723          6.639183141200 1.853846153846 4215836.509    131            nan            nan            28224369323.97 26407007.38917 2591.794702445 6694.844371626 215453200.9463 2864.1325
# 86469113488477 0              0.25           =BLOB=     355525         726891      1              1              0              1           6           136            59             3879516.810573 1608770.100882 17891.307      218.894        214.875        433.328        411.255        874          0.000225285787 6.426470588235 2007505.586    74             nan            nan            55465670915.66 25501161.10749 14297.05646963 27629.14898094 749536093.4549 922.4049
#    ...
#  (Total: 6277)

# %% [markdown]
# # Checking the tables

# %%
#(schema.jobs & "table_name='__decomposition_error_labels'" & "status='error'")#.delete()
(schema.jobs & "table_name='__decomposition_error_labels'")#.delete()
# Out:
# *table_name    *key_hash      status       key        error_message  error_stac user           host           pid     connection_id  timestamp
# +------------+ +------------+ +----------+ +--------+ +------------+ +--------+ +------------+ +------------+ +-----+ +------------+ +------------+
# __decompositio 006cd7323700e3 error        =BLOB=     OperationalErr =BLOB=     celiib@10.28.0 at-node31      29      114206         2020-11-28 20:
# __decompositio 019f8efc46e13e error        =BLOB=     ValueError: Wr =BLOB=     celiib@10.28.0 at-compute003  29      114159         2020-11-28 20:
# __decompositio 01dacbecea838e error        =BLOB=     OperationalErr =BLOB=     celiib@10.28.0 at-compute003  29      114164         2020-11-28 20:
# __decompositio 02fa3807dabd73 error        =BLOB=     OperationalErr =BLOB=     celiib@10.28.0 at-node46      29      114200         2020-11-28 20:
# __decompositio 04c0e540f141af error        =BLOB=     OperationalErr =BLOB=     celiib@10.28.0 at-node25      30      114217         2020-11-28 20:
# __decompositio 067d03717d9de1 error        =BLOB=     OperationalErr =BLOB=     celiib@10.28.0 at-node45      29      114156         2020-11-28 20:
# __decompositio 068d51d0870447 error        =BLOB=     OperationalErr =BLOB=     celiib@10.28.0 at-node35      29      114207         2020-11-28 20:
# __decompositio 0725f8345f7e56 error        =BLOB=     OperationalErr =BLOB=     celiib@10.28.0 at-node20      29      114168         2020-11-28 20:
# __decompositio 073b40d09b58c7 error        =BLOB=     OperationalErr =BLOB=     celiib@10.28.0 at-node41      29      114191         2020-11-28 20:
# __decompositio 076aef9fad89b4 error        =BLOB=     OperationalErr =BLOB=     celiib@10.28.0 at-node28      29      114188         2020-11-28 20:
# __decompositio 07d2026c50c1ad reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node33      29      114175         2020-11-28 20:
# __decompositio 09a31d51338848 error        =BLOB=     OperationalErr =BLOB=     celiib@10.28.0 at-node2       29      114242         2020-11-28 20:
#    ...
#  (Total: 407)

# %%
minnie.DecompositionErrorLabels()
# Out:
# *segment_id    *decimation_ve *decimation_ra n_face_errors  face_idx_f
# +------------+ +------------+ +------------+ +------------+ +--------+
# 86469113488474 0              0.25           159052         =BLOB=
# 86469113488474 0              0.25           40238          =BLOB=
# 86469113488474 0              0.25           208443         =BLOB=
# 86469113488474 0              0.25           81085          =BLOB=
# 86469113488474 0              0.25           119620         =BLOB=
# 86469113488474 0              0.25           139734         =BLOB=
# 86469113488474 0              0.25           3345139        =BLOB=
# 86469113488474 0              0.25           25349          =BLOB=
# 86469113488474 0              0.25           102810         =BLOB=
# 86469113488474 0              0.25           88201          =BLOB=
# 86469113488474 0              0.25           112670         =BLOB=
# 86469113488474 0              0.25           426708         =BLOB=
#    ...
#  (Total: 18732)

# %%
minnie.DecompositionErrorLabels
# Out:
# 408

# %%
22000/70/60
# Out:
# 5.238095238095238

# %%
minnie.SynapseExclude.drop()
# Out:
# `microns_minnie65_02`.`synapse_exclude` (2428847 tuples)
# Proceed? [yes, No]: yes
# INFO - 2020-11-29 02:57:26,880 - table - Dropped table `microns_minnie65_02`.`synapse_exclude`
# Tables dropped.  Restart kernel.

# %% [markdown]
# # Checking autoproofread table

# %%
(schema.jobs & "table_name='__auto_proofread_labels'")#.delete()
# Out:
# *table_name    *key_hash    status     key        error_message  error_stac user     host     pid     connection_id  timestamp
# +------------+ +----------+ +--------+ +--------+ +------------+ +--------+ +------+ +------+ +-----+ +------------+ +-----------+
#
#  (Total: 0)

# %%
minnie.SynapseExclude()
# Out:
# *synapse_id    *timestamp     *criteria_id   segment_id
# +------------+ +------------+ +------------+ +------------+
# 46004093       2020-11-02 07: 0              86469113488474
# 46004443       2020-11-02 07: 0              86469113488474
# 46274915       2020-11-02 07: 0              86469113488474
# 46858604       2020-11-02 07: 0              86469113488474
# 47505881       2020-11-02 07: 0              86469113488474
# 47506602       2020-11-02 07: 0              86469113488474
# 47809706       2020-11-02 07: 0              86469113488474
# 48724550       2020-11-02 07: 0              86469113488474
# 50770599       2020-11-02 07: 0              86469113488474
# 50770637       2020-11-02 07: 0              86469113488474
# 50770688       2020-11-02 07: 0              86469113488474
# 50771026       2020-11-02 07: 0              86469113488474
#    ...
#  (Total: 5709)

# %%
minnie, _ = du.configure_minnie_vm()
# Out:
# INFO - 2020-11-29 03:41:01,012 - settings - Setting enable_python_native_blobs to True
# INFO - 2020-11-29 03:41:01,260 - settings - Setting enable_python_native_blobs to True

# %%
minnie.AutoProofreadLabels()
# Out:
# *segment_id    *decimation_ve *decimation_ra n_face_errors  face_idx_f n_synapses     n_errored_syna
# +------------+ +------------+ +------------+ +------------+ +--------+ +------------+ +------------+
# 86469113488474 0              0.25           208443         =BLOB=     469            207
# 86469113488474 0              0.25           13216          =BLOB=     214            19
# 86469113488474 0              0.25           325377         =BLOB=     477            181
# 86469113488474 0              0.25           81085          =BLOB=     227            59
# 86469113488474 0              0.25           119620         =BLOB=     303            68
# 86469113488474 0              0.25           139734         =BLOB=     358            66
# 86469113488474 0              0.25           3345139        =BLOB=     7028           5096
# 86469113488474 0              0.25           25374          =BLOB=     269            13
#  (Total: 8)
