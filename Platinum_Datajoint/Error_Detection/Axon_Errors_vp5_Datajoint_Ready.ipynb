# %%
from os import sys
sys.path.append("/meshAfterParty/")

# %%
from importlib import reload

import neuron_utils as nru

import neuron

import neuron_visualizations as nviz

import time

import datajoint_utils as du
# Out:
# INFO - 2020-11-27 21:52:22,125 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2020-11-27 21:52:22,127 - settings - Setting database.user to celiib
# INFO - 2020-11-27 21:52:22,127 - settings - Setting database.password to newceliipass

# %%
minnie,schema = du.configure_minnie_vm()
(minnie.Decomposition() & "n_somas = 1" & "n_faces>500000") #& "n_same_soma_multi_touching_limbs>0"
# Out:
# INFO - 2020-11-27 21:52:24,889 - settings - Setting stores to {'minnie65': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65', 'stage': '/mnt/dj-stor01/platinum/minnie65'}, 'meshes': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/meshes', 'stage': '/mnt/dj-stor01/platinum/minnie65/02/meshes'}, 'decimated_meshes': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/decimated_meshes', 'stage': '/mnt/dj-stor01/platinum/minnie65/02/decimated_meshes'}, 'skeletons': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/skeletons'}}
# INFO - 2020-11-27 21:52:24,891 - settings - Setting enable_python_native_blobs to True
# INFO - 2020-11-27 21:52:24,905 - connection - Connected celiib@at-database.ad.bcm.edu:3306
# Connecting celiib@at-database.ad.bcm.edu:3306
# INFO - 2020-11-27 21:52:25,111 - settings - Setting enable_python_native_blobs to True
# ...

# %%
import neuron_visualizations as nviz
curr_seg_id = 864691134884742906

# %%
neuron_obj = (minnie.Decomposition() & dict(segment_id=curr_seg_id)).fetch1("decomposition")
# Out:
# INFO - 2020-11-27 21:52:38,189 - settings - Setting enable_python_native_blobs to True
# INFO - 2020-11-27 21:52:38,416 - settings - Setting enable_python_native_blobs to True
# Decompressing Neuron in minimal output mode...please wait

# %%
ret_col = nviz.visualize_neuron(neuron_obj,
                     visualize_type=["mesh","skeleton"],
                     limb_branch_dict="all",
                     return_color_dict=True)
# Out:
#  Working on visualization type: mesh
#
#  Working on visualization type: skeleton
# Working on  new stand alone scatter points
# ...

# %% [markdown]
# # Identifying the Axons

# %%
import error_detection as ed
ed = reload(ed)

# %%
returned_error_faces = ed.error_faces_by_axons(neuron_obj,verbose=True,visualize_errors_at_end=True)
# Out:
# functions_list = [<function width at 0x7f363acf6a60>, <function median_mesh_center at 0x7f363acf6d08>, <function n_spines at 0x7f363acf6b70>, <function n_faces_branch at 0x7f363acf68c8>, <function skeleton_distance_branch at 0x7f363acf6ae8>, <function spines_per_skeletal_length at 0x7f363acf8048>, <function no_spine_median_mesh_center at 0x7f363acf6e18>]
# functions_list = [<function axon_segment at 0x7f363acf86a8>]
# Axons not keeping because of soma: {}
#
# ----- Working on L0 ------
# -- Axon Group 0 of size 5--
#    Working on soma 0, starting_node 4
# Not using AIS angle threshold
# sk_angle= 154.9820589278177
# *****Path to axon group not valid******
#
#
# For limb 0 the valid axon branches are []
# The following are not valid: [15, 16, 18, 19, 20]
#
# ----- Working on L1 ------
# -- Axon Group 0 of size 129--
#    Working on soma 0, starting_node 0
# Not using AIS angle threshold
# sk_angle= 68.93950116854329
# *****Path to axon group not valid******
#
#
# ...

# %% [markdown]
# # Get the synapses associated with that mesh

# %% [markdown]
# # Compile the Process into datajoint function

# %%
ed = reload(ed)

# %%
data_to_write_new = ed.get_error_synapse_inserts(neuron_obj,returned_error_faces,minnie=minnie,verbose=True)
if len(data_to_write_new)>0:
    if verbose:
        print("Preparing to write errored synapses")
    minnie.SynapseExclude.insert(data_to_write_new,skip_duplicates=True)
# Out:
# Processing 477 synapses
# maximum mapping distance = 220.1332929536758
# Number of errored synapses = (142,)
# Preparing to write errored synapses

# %%
25000*1/60/100
# Out:
# 4.166666666666667
