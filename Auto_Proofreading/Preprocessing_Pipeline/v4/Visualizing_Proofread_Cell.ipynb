# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import datajoint as dj
import trimesh
from tqdm.notebook import tqdm
from pathlib import Path

from os import sys
sys.path.append("/meshAfterParty/")
sys.path.append("/meshAfterParty/meshAfterParty")

import datajoint_utils as du
from importlib import reload
# Out:
# INFO - 2021-05-07 15:25:46,272 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-05-07 15:25:46,274 - settings - Setting database.user to celiib
# INFO - 2021-05-07 15:25:46,275 - settings - Setting database.password to newceliipass
# INFO - 2021-05-07 15:25:46,286 - settings - Setting stores to {'minnie65': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65', 'stage': '/mnt/dj-stor01/platinum/minnie65'}, 'meshes': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/meshes', 'stage': '/mnt/dj-stor01/platinum/minnie65/02/meshes'}, 'decimated_meshes': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/decimated_meshes', 'stage': '/mnt/dj-stor01/platinum/minnie65/02/decimated_meshes'}, 'skeletons': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/skeletons'}}
# INFO - 2021-05-07 15:25:46,287 - settings - Setting enable_python_native_blobs to True
# ...

# %%
minnie, _ = du.configure_minnie_vm()
# Out:
# INFO - 2021-05-07 15:26:22,091 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-05-07 15:26:22,092 - settings - Setting database.user to celiib
# INFO - 2021-05-07 15:26:22,093 - settings - Setting database.password to newceliipass
# INFO - 2021-05-07 15:26:22,097 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-05-07 15:26:22,584 - settings - Setting enable_python_native_blobs to True

# %%
du.m65mat.ProofreadNucSynInfo() & "pre_is_core = 1"
# Out:
# *ver     *synapse_id    *presyn        *postsyn       *presyn_nucleu *postsyn_nucle pre_is_core    post_is_core   n_presyn_nuc   n_postsyn_nuc
# +------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+
# 0.20     15188521       86469113690314 86469113596887 236197         123212         1              0              1              1
# 0.20     18916977       86469113690314 86469113692277 236197         81463          1              0              1              1
# 0.20     29347715       86469113690314 86469113633936 236197         126192         1              0              1              1
# 0.20     29678043       86469113608413 86469113631182 258307         81445          1              0              1              1
# 0.20     29690283       86469113525624 86469113574025 331945         73219          1              0              1              1
# ...

# %% [markdown]
# # Visualize the Proofread Neuron

# %%
segment_id = 864691136903228594
segment_id = 864691135462463389
segment_id = 864691135692702655
segment_id = 864691135583652216
#segment_id = 864691136903144370

# %%
minnie.BaylorSegmentCentroid() & dict(segment_id=segment_id)
# Out:
# *segment_id    *decimation_ve *decimation_ra *soma_index    *ver      centroid_x     centroid_y     centroid_z     n_vertices     n_faces     mesh       multiplicity   sdf       volume         max_side_ratio bbox_volume_ra max_hole_lengt run_time
# +------------+ +------------+ +------------+ +------------+ +-------+ +------------+ +------------+ +------------+ +------------+ +---------+ +--------+ +------------+ +-------+ +------------+ +------------+ +------------+ +------------+ +----------+
# 86469113558365 0              0.25           1              30.00     151828         156780         21612          12643          23554       =BLOB=     1              0.871     708.6963564226 2.11           0.058          9112776.865    220.9345
#  (Total: 1)

# %%
minnie.Decomposition() & dict(segment_id=segment_id)
# Out:
# *segment_id    *decimation_ve *decimation_ra *ver      *process_versi *index    multiplicity   decomposit n_vertices     n_faces     n_not_processe n_error_limbs  n_same_soma_mu n_multi_soma_t n_somas     n_limbs     n_branches     max_limb_n_bra skeletal_lengt max_limb_skele median_branch_ width_median   width_no_spine width_90_perc  width_no_spine n_spines     spine_density  spines_per_bra skeletal_lengt n_spine_eligib spine_density_ spines_per_bra total_spine_vo spine_volume_m spine_volume_d spine_volume_d spine_volume_p run_time
# ...

# %%
minnie.AutoProofreadNeurons3() & dict(segment_id=segment_id)
# Out:
# *segment_id    *decimation_ve *decimation_ra *ver      *process_versi *index    *split_index   *proof_version multiplicity   cell_type_pred spine_category n_axons     n_apicals     axon_length    axon_area     nucleus_id     nuclei_distanc n_nuclei_in_ra n_nuclei_in_bb soma_x     soma_y     soma_z     max_soma_n_fac max_soma_volum n_vertices     n_faces     n_not_processe n_error_limbs  n_same_soma_mu n_multi_soma_t n_somas     n_limbs     n_branches     max_limb_n_bra skeletal_lengt max_limb_skele median_branch_ width_median   width_no_spine width_90_perc  width_no_spine n_spines     spine_density  spines_per_bra skeletal_lengt n_spine_eligib spine_density_ spines_per_bra total_spine_vo spine_volume_m spine_volume_d spine_volume_d spine_volume_p axon_angle_max spine_density_ n_branches_pro skeletal_lengt n_branches_in_ skeletal_lengt run_time
# ...

# %%
du.plot_proofread_neuron(segment_id,
                        plot_errored_faces=True,
                        plot_proofreading_synapses=True,
                        plot_axon=True)
# Out:
# Synapsse Results:
# Total Number of Synapses = 1279
# n_valid_syn_ids_presyn = 696
# n_errored_syn_ids_presyn = 134
# n_valid_syn_ids_postsyn = 215
# n_errored_syn_ids_postsyn = 234
# No axon to plot
# /usr/local/lib/python3.6/dist-packages/traittypes/traittypes.py:101: UserWarning: Given trait value dtype "float64" does not match required type "float64". A coerced copy has been created.
#   np.dtype(self.dtype).name))
# ...

# %%
import neuron_visualizations as nviz

# %%
n_obj = (minnie.DecompositionAxon() & dict(segment_id=864691135462463389)).fetch1("decomposition")

# %%
n_obj
# Out:
# PosixPath('/mnt/dj-stor01/platinum/minnie65/02/decomposition/864691135462463389_0_split_axon_v4.pbz2')

# %%
neuron_obj = du.fetch_neuron_obj_manual(n_obj)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-53-82818a8e1e90> in <module>
# ----> 1 neuron_obj = du.fetch_neuron_obj_manual(n_obj)
#
# /meshAfterParty/meshAfterParty/datajoint_utils.py in fetch_neuron_obj_manual(segment_id, ending, border_validation)
#     279 def fetch_neuron_obj_manual(segment_id,ending="",
#     280                            border_validation=False):
# --> 281     dec_mesh = fetch_segment_id_mesh(segment_id)
#     282     filename=f"{segment_id}_0_25"
#     283
#
# /meshAfterParty/meshAfterParty/datajoint_utils.py in fetch_segment_id_mesh(seg_id, decimation_ratio)
#     651 def fetch_segment_id_mesh(seg_id,decimation_ratio=0.25):
#     652     key = dict(segment_id=seg_id,decimation_ratio=decimation_ratio)
# --> 653     new_mesh = (minnie.Decimation() & key).fetch1("mesh")
# ...

# %%
segment_mesh,error_mesh,original_mesh = du.fetch_proofread_neuron_with_error_mesh(segment_id,
                                            split_index=0,
                                                                    return_original_mesh=True,
                                                                validation=False)

# %%
sc = np.array([145066,163155,21295])*np.array([4,4,40])
from pykdtree.kdtree import KDTree
kd_t = KDTree(original_mesh.vertices)
kd_t.query(sc.reshape(-1,3))
# Out:
# (array([42.96801136]), array([155236], dtype=uint32))

# %%
nviz.plot_objects(main_mesh=segment_mesh,
                 meshes=[error_mesh],
                 meshes_colors="red")
# Out:
# /usr/local/lib/python3.6/dist-packages/traittypes/traittypes.py:101: UserWarning: Given trait value dtype "float64" does not match required type "float64". A coerced copy has been created.
#   np.dtype(self.dtype).name))
# ...

# %%
nviz.plot_objects(scatters=[sc],
                  scatter_size=1,
                  scatters_colors="blue",
                 append_figure=True,
                 show_at_end=False)
