# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import datajoint as dj
import trimesh
from tqdm.notebook import tqdm
from pathlib import Path

from os import sys
sys.path.append("/meshAfterParty/")
sys.path.append("/meshAfterParty/meshAfterParty")

import datajoint_utils as du
from importlib import reload
# Out:
# INFO - 2021-06-02 16:43:25,987 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-06-02 16:43:26,033 - settings - Setting database.user to celiib
# INFO - 2021-06-02 16:43:26,034 - settings - Setting database.password to newceliipass
# INFO - 2021-06-02 16:43:26,042 - settings - Setting stores to {'minnie65': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65', 'stage': '/mnt/dj-stor01/platinum/minnie65'}, 'meshes': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/meshes', 'stage': '/mnt/dj-stor01/platinum/minnie65/02/meshes'}, 'decimated_meshes': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/decimated_meshes', 'stage': '/mnt/dj-stor01/platinum/minnie65/02/decimated_meshes'}, 'skeletons': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/skeletons'}}
# INFO - 2021-06-02 16:43:26,044 - settings - Setting enable_python_native_blobs to True
# ...

# %%
import neuron_visualizations as nviz
import neuron_utils as nru
import proofreading_utils as pru
import time
import system_utils as su
import axon_utils as au
import trimesh_utils as tu
import allen_utils as alu

# %%
minnie,_ = du.configure_minnie_vm()
# Out:
# INFO - 2021-06-02 16:43:28,687 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-06-02 16:43:28,688 - settings - Setting database.user to celiib
# INFO - 2021-06-02 16:43:28,689 - settings - Setting database.password to newceliipass
# INFO - 2021-06-02 16:43:28,694 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-06-02 16:43:29,379 - settings - Setting enable_python_native_blobs to True

# %% [markdown]
# # Getting the Table and Exporting the CSV

# %%
minnie.AutoProofreadStatsAllen5()
# Out:
# INFO - 2021-06-02 16:51:14,111 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-06-02 16:51:14,112 - settings - Setting database.user to celiib
# INFO - 2021-06-02 16:51:14,112 - settings - Setting database.password to newceliipass
# INFO - 2021-06-02 16:51:14,113 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-06-02 16:51:14,114 - settings - Setting database.user to celiib
# INFO - 2021-06-02 16:51:14,114 - settings - Setting database.password to newceliipass
# INFO - 2021-06-02 16:51:14,123 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-06-02 16:51:16,332 - settings - Setting enable_python_native_blobs to True
# ...

# %%
file_name = "./allen_v4_6_2_crossovers_and_more_metadata.csv"

# %%
ret_df = alu.stats_table_to_auto_proof_red_blue_suggestions_df(
    minnie.AutoProofreadStatsAllen5(),
    neurons_table = minnie.AutoProofreadNeuronsAllen5(),
    max_entries = 50,
    output_type = "server",
output_filepath=file_name)
# Out:
# # of Entries Processing = 8
# Workin on 864691135207738489, split 0
# error_type = axon_on_dendrite_merges
# error_type = high_degree_branching
# error_type = axon_webbing_t_merges
# error_type = thick_t_merge
# error_type = width_jump_up_dendrite
# error_type = width_jump_up_axon
# error_type = double_back_dendrite
# error_type = double_back_axon_thin
# error_type = double_back_axon_thick
# error_type = axon_fork_divergence
# Workin on 864691135337702374, split 0
# error_type = axon_on_dendrite_merges
# error_type = high_degree_branching
# error_type = axon_webbing_t_merges
# error_type = thick_t_merge
# error_type = width_jump_up_dendrite
# error_type = width_jump_up_axon
# error_type = double_back_dendrite
# error_type = double_back_axon_thin
# error_type = double_back_axon_thick
# error_type = axon_fork_divergence
# Workin on 864691135462101700, split 0
# error_type = axon_on_dendrite_merges
# error_type = high_degree_branching
# error_type = axon_webbing_t_merges
# ...

# %% [markdown]
# # Debugging

# %%
ret_df["neuroglancer_link"].to_list()[0]
# Out:
# 'http://neuromancer-seung-import.appspot.com/?json_url=https://globalv1.daf-apis.com/nglstate/api/v1/6200664476614656'

# %%
import system_utils as su
import numpy as np
auto_edit_df_5_10 = su.decompress_pickle("auto_edit_df_6_2")
np.unique(auto_edit_df_5_10["segment_id"].to_list()).shape
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-f8dba065d3a5> in <module>
#       1 import system_utils as su
#       2 import numpy as np
# ----> 3 auto_edit_df_5_10 = su.decompress_pickle("auto_edit_df_6_2")
#       4 np.unique(auto_edit_df_5_10["segment_id"].to_list()).shape
#
# /meshAfterParty/meshAfterParty/system_utils.py in decompress_pickle(filename)
#     233         filename += ".pbz2"
#     234
# --> 235     data = bz2.BZ2File(filename, 'rb')
#     236     data = cPickle.load(data)
#     237     return data
#
# /usr/lib/python3.6/bz2.py in __init__(self, filename, mode, buffering, compresslevel)
#      94
#      95         if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 96             self._fp = _builtin_open(filename, mode)
#      97             self._closefp = True
#      98             self._mode = mode_code
#
# ...
