# %%
"""
Purpose: To be able and extract a local upstream and/or downtream graph
around a certain node

Applications: helps get the relevant skeleton/nodes/nodes and attributes together

"""
# Out:
# '\nPurpose: To be able and extract a local upstream and/or downtream graph\naround a certain node\n\nApplications: helps get the relevant skeleton/nodes/nodes and attributes together\n\n'

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import datajoint as dj
import trimesh
from tqdm.notebook import tqdm
from pathlib import Path

from os import sys
sys.path.append("/meshAfterParty/")
sys.path.append("/meshAfterParty/meshAfterParty")

import datajoint_utils as du
from importlib import reload

# %%
import neuron_utils as nru
import neuron_visualizations as nviz

# %% [markdown]
# # Downloading a Neuron to Play with

# %%
segment_id = 864691136194042326

# %%
import system_utils as su
original_mesh = su.decompress_pickle("original_mesh.pbz2")

# %%
neuron_obj = nru.decompress_neuron("./864691136194042326_0_25_axon_v5.pbz2",
                                  original_mesh=original_mesh)
# Out:
# Decompressing Neuron in minimal output mode...please wait

# %%
nviz.visualize_neuron(neuron_obj,
                     limb_branch_dict="all")
# Out:
# Recieved another instance of Neuron class in init -- so just copying data
#
#  Working on visualization type: mesh
#
#  Working on visualization type: skeleton
# No Synapses to plot
# ...

# %% [markdown]
# # getting the subgraph of upstream/downstream nodes

# %%
import concept_network_utils as cnu

# %%
nviz.visualize_neuron_specific_limb(neuron_obj,
                                   neuron_obj.axon_limb_idx)
# Out:
# limb_name = L0
# Recieved another instance of Neuron class in init -- so just copying data
#
#  Working on visualization type: mesh
#
#  Working on visualization type: skeleton
# No Synapses to plot
# ...
# No limb name was given so using L0 because was the limb in the first key

# %%
upstream_node_list = cnu.subgraph_around_branch(limb_obj,
                           branch_idx,
                           downstream_distance=comparison_distance + offset + 1000,
                            upstream_distance=-1,
                            only_non_branching_downstream = True,
                          include_branch_in_upstream_dist=True,
                           include_branch_idx = True,
                          return_branch_idxs=True,
                                                    verbose = verbose
                          )

# %% [markdown]
# # How to get the upstream skeleton

# %%
import neuron_statistics as nst
nst.find_parent_child_skeleton_angle_upstream_downstream(limb_obj,
                                                         branch_1_idx=90,
                                                         branch_2_idx=97,
                                                         branch_1_type = "upstream",
                                                         branch_2_type = "downstream",
                                                        verbose = True,
                                                        offset=1500,
                                                        min_comparison_distance = 1000,
                                                        comparison_distance = 100000,
                                                         skeleton_resolution = 100,
                                                        plot_extracted_skeletons = True,
                                                         use_upstream_skeleton_restriction=True,
                                                        )
# Out:
# upstream_node_list = [ 42  43  71  85  90 222]
# upstream 90 endpoint: [713119.  629582.8 847374.9]
# branch_idx_dist = 18328.02899503038
# upstream_distance = -18329.02899503038
# downstream_distance = 84171.97100496962
# upstream_brancehs= []
# downstream_branches = [ 19  47  76  81  82  83  84  93  94  96  97 100 106 107 108 109 115 118
#  120 123 124 125 126 132 133 220]
#
# After only_non_branching_downstream:
# downstream_branches = []
# total_branches = [97]
# downstream_node_list = [97]
# downstream 97 endpoint: [713119.  629582.8 847374.9]
# curr_angle = 6.81
# Parent (90):red, child (97):blue
# ...
# 6.81
