# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import datajoint as dj
import trimesh
from tqdm.notebook import tqdm
from pathlib import Path

from os import sys
sys.path.append("/meshAfterParty/")
sys.path.append("/meshAfterParty/meshAfterParty")

import datajoint_utils as du
from importlib import reload
# Out:
# INFO - 2021-04-22 14:26:16,149 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-04-22 14:26:16,152 - settings - Setting database.user to celiib
# INFO - 2021-04-22 14:26:16,153 - settings - Setting database.password to newceliipass
# INFO - 2021-04-22 14:26:16,176 - settings - Setting stores to {'minnie65': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65', 'stage': '/mnt/dj-stor01/platinum/minnie65'}, 'meshes': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/meshes', 'stage': '/mnt/dj-stor01/platinum/minnie65/02/meshes'}, 'decimated_meshes': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/decimated_meshes', 'stage': '/mnt/dj-stor01/platinum/minnie65/02/decimated_meshes'}, 'skeletons': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/skeletons'}}
# INFO - 2021-04-22 14:26:16,177 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-04-22 14:26:16,190 - connection - Connected celiib@at-database.ad.bcm.edu:3306
# Connecting celiib@at-database.ad.bcm.edu:3306
# INFO - 2021-04-22 14:26:16,588 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-04-22 14:26:16,592 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-04-22 14:26:16,593 - settings - Setting database.user to celiib
# INFO - 2021-04-22 14:26:16,594 - settings - Setting database.password to newceliipass
# INFO - 2021-04-22 14:26:16,595 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-04-22 14:26:16,596 - settings - Setting database.user to celiib
# INFO - 2021-04-22 14:26:16,597 - settings - Setting database.password to newceliipass
# INFO - 2021-04-22 14:26:16,599 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-04-22 14:26:16,985 - settings - Setting enable_python_native_blobs to True

# %%
#configuring will include the adapters
minnie,schema = du.configure_minnie_vm()
# Out:
# INFO - 2021-04-22 14:26:19,134 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-04-22 14:26:19,153 - settings - Setting database.user to celiib
# INFO - 2021-04-22 14:26:19,155 - settings - Setting database.password to newceliipass
# INFO - 2021-04-22 14:26:19,164 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-04-22 14:26:19,573 - settings - Setting enable_python_native_blobs to True

# %%
import validation_utils as vu
import neuron_visualizations as nviz
import neuron_utils as nru

# %% [markdown]
# # Downloading the Neuron

# %%
segment_id = 864691136194042326
minnie.Decomposition() & f"segment_id = {segment_id}"
# Out:
# *segment_id    *decimation_ve *decimation_ra *ver      *process_versi *index    multiplicity   decomposit n_vertices     n_faces     n_not_processe n_error_limbs  n_same_soma_mu n_multi_soma_t n_somas     n_limbs     n_branches     max_limb_n_bra skeletal_lengt max_limb_skele median_branch_ width_median   width_no_spine width_90_perc  width_no_spine n_spines     spine_density  spines_per_bra skeletal_lengt n_spine_eligib spine_density_ spines_per_bra total_spine_vo spine_volume_m spine_volume_d spine_volume_d spine_volume_p run_time
# +------------+ +------------+ +------------+ +-------+ +------------+ +-------+ +------------+ +--------+ +------------+ +---------+ +------------+ +------------+ +------------+ +------------+ +---------+ +---------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +----------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +-----------+
# 86469113619404 0              0.25           30.00     7              0         1              =BLOB=     543348         1100473     0              0              0              0              1           5           134            92             5711902.431454 3489105.382868 24117.997      87.607         87.607         543.496        482.187        1643         0.000287644969 12.26119402985 3062061.696    52             0.000536566589 31.596         495451480854.5 172336953.2987 86740.18626896 161803.2326068 9527913093.356 5274.2019
#  (Total: 1)

# %%
neuron_obj = du.fetch_neuron_obj_manual(segment_id=segment_id,
                                       border_validation=False)
# Out:
# Decompressing Neuron in minimal output mode...please wait

# %%
import axon_utils as au
neuron_obj_axon = au.complete_axon_processing(neuron_obj)
neuron_obj_axon
# Out:
# endnodes_to_test = [6439]
# Skeleton paths distances = [24875.94892122]
# Filtered indexes = [0]
# len(filtered_skeletons) = 1
# sk_angles = [163.42321265]
# base_final_widths = [247.32330276 261.0630474  470.27929054]
# overall_ais_width = 247.32330275585625
# ais_width = 326.22188023001485
# endnodes_to_test = []
# endnodes_to_test = []
# Starting axon branch was not the limb starting node so generating border vertices and computing upstream branch
# upstream_node_to_axon_starting_branch = 11
# More than 1 seperated mesh (taking the top one): [<trimesh.Trimesh(vertices.shape=(86009, 3), faces.shape=(171648, 3))>
#  <trimesh.Trimesh(vertices.shape=(54, 3), faces.shape=(104, 3))>]
# root_curr = [702011.6 557766.6 844787.4]
# Time for preparing soma vertices and root: 0.0004143714904785156
# invalidation_d = 1500
# smooth_neighborhood = 0
# smooth_neighborhood = 0
# soma_pt = [702011.6 557766.6 844787.4]
# invalidation_d = 1500
# cc_vertex_thresh = 25
# cc_vertex_thresh = 10
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/86008 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.89s/it]
# all_paths = [[[63488, 67626, 17985, 68497, 62517, 21671, 23698, 13393, 49437, 15589, 12072, 43533, 85713, 43493, 7234, 78106, 68143, 44061, 77620, 35013, 20221, 16004, 41838, 81792, 15815, 59076, 21163, 2060, 80831, 13127, 78414, 77082, 66564, 18855, 49156, 76519, 24, 34464, 37394, 31273, 57477, 80301, 64471, 84157, 37944, 43689, 70768, 3581, 27451, 68499, 44177, 64550, 11143, 77461, 1201, 77115, 12289, 71891, 765, 22259, 20525, 56469, 30352, 12828, 5349, 16013, 57708, 7759, 80553, 48923, 68299, 83513, 2118, 68917, 33035, 83392, 63603, 78916, 82884, 26995, 13039, 38245, 31310, 65448, 65960, 74973, 44491, 8933, 82605, 29834, 58826, 75014, 32746, 65204, 67817, 71716, 83431, 71907, 32862, 17678, 4564, 27471, 61074, 46366, 2616, 60926, 32890, 22496, 76407, 46757, 24569, 15562, 1794, 43293, 28269, 25962, 38722, 74898, 70365, 33727, 41653, 39873, 30906, 64595, 46986, 67031, 31078, 63108, 47192, 62327, 65170, 9473, 27191, 72903, 37531, 50690, 53289, 27453, 68484, 33155, 31043, 77124, 80308, 66538, 70214, 33505, 59615, 70817, 81, 39782, 75879, 59625, 80555, 35562, 76965, 39096, 39675, 41231, 31768, 69252, 19878, 63846, 30247, 30669, 29872, 66642, 17595, 32920, 1701, 72173, 52751, 32333, 7468, 50185, 49341, 39335, 32665, 63190, 46957, 13224, 13407, 38865, 7393, 42104, 54566, 24707, 67435, 28438, 54758, 15429, 77793, 57221, 79891, 62487, 65634, 38790, 72347, 34391, 12191, 61819, 42577, 62977, 85287, 34642, 27127, 31255, 62592, 42907, 29496, 44629, 52391, 44545, 62512, 80134, 45503, 23246, 49759, 27633, 67086, 31381, 6792, 48307, 83345, 19290, 45942, 74571, 43822, 83701, 6612, 9448, 72902, 52845, 7392, 64093, 62314, 3263, 71145, 78038, 69539, 57763, 81254, 39319, 10909, 30828, 31568, 69857, 75330, 59448, 57697, 7171, 47206, 61328, 16997, 15373, 80050, 44535, 38210, 57797, 59322, 37705, 37772, 84670, 13184, 52585, 15344, 64027, 66380, 61306, 44301, 68894, 6767, 34544, 38049, 763, 23856, 43985, 58863, 29640, 6642, 13153, 31502, 65406, 38578, 67745, 79437, 53301, 28507, 11444, 12768, 28702, 40296, 62905, 64404, 23198, 1212
3981.4091796875, 91944.28947257996, 1817.5045318603516, 102555.48918914795, 3510.112258911133, 2617.083450317383, 22648.1912689209, 1501.5897674560547, 2208.5547790527344, 2860.331123352051, 14499.027885437012, 2118.2040786743164, 1700.414306640625, 1654.6464920043945, 7682.609619140625, 5141.772758483887, 2813.471389770508, 3075.4734649658203, 2170.307300567627, 16945.169998168945, 11180.699615478516, 4941.199981689453, 8882.755126953125, 11062.93952178955, 3243.3758697509766, 2788.4334106445312, 2040.1396942138672, 1714.1453552246094, 2217.1039276123047, 13259.033241271973, 1791.588882446289, 1580.4389953613281, 1548.1698303222656, 91851.60717773438, 2034.0023498535156, 2186.633056640625, 1504.7502059936523, 2342.329147338867, 1736.818962097168, 1927.053472518921, 4215.167587280273, 19353.5849609375, 1594.4847259521484, 1772.6450958251953, 2650.9259185791016, 1654.980712890625, 1863.0306854248047, 1554.4653396606445, 13839.052070617676, 14089.730194091797, 3783.2053756713867, 2002.7382507324219, 2766.8544387817383, 2530.560791015625, 24783.286590576172, 17036.271446228027, 2021.0919036865234, 2019.8638381958008, 2733.1238861083984, 1852.7474670410156, 1688.3653411865234, 2202.5636825561523, 1842.1431274414062]]
# meshparty_segment_size = 100
# Time for 1st pass MP skeletonization: 6.863631010055542
# connecting at the root
# branches_touching_root = [232]
# combining close nodes
# combine_threshold = 1300
# length of Graph = 23465
# After combining close endpoints max(kept_branches_idx) = 232, len(kept_branches_idx) = 220
# empty_indices % = 0.0
#  conflict_indices % = 0.025580459468444353
#   0%|          | 0/105 [00:00<?, ?it/s]
# AFTER face_lookup_resolved_test
#   0%|          | 0/220 [00:00<?, ?it/s]
# Decomposing first pass: 20.48817753791809
# Only Using MeshParty Skeletonization and Mesh Correspondence
# Another print
# Divinding into MP and MAP pieces: 5.5789947509765625e-05
# Total time for MAP sublimb processing 5.245208740234375e-06
# ---- Working on MP Decomposition #0 ----
# Using Quicker soma_to_piece_touching_vertices because no MAP and only one sublimb_mesh piece
# MP filtering soma verts: 5.507469177246094e-05
# Fixing Possible Soma Extension Branch for Sublimb 0
# Total time for mesh KDTree = 0.00180816650390625
# sbv[0].reshape(-1,3) = [[702011.6 557766.6 844787.4]]
# closest_sk_pt_coord BEFORE = [701918.45484595 558104.73354719 844930.25875126]
# current_skeleton.shape = (31, 2, 3)
# node_for_stitch = 24: [701918.45484595 558104.73354719 844930.25875126]
# node_for_stitch AFTER = 24: [701918.45484595 558104.73354719 844930.25875126]
# possible_node_loc = [ 4 31]
# possible_node_loc AFTER = [ 4 31]
# curr_shortest_path = [24, 25.0, 26.0, 27.0, 28.0, 29.0, 30.0, 31.0]
# Current stitch point was not a branch or endpoint, shortest_path_length to one = 620.4652144739
# Changing the stitch point becasue the distance to end or branch node was 620.4652144739
# New stitch point has degree 1
# change_status for create soma extending pieces = True
# closest_sk_pt_coord AFTER = [702162.4 557596.6 844955.4]
# skipping soma 0 because closest skeleton node was already end node
# endpoints_must_keep = {0: array([[702162.4, 557596.6, 844955.4]])}
# match_sk_branches = [219]
# The new branch info was none so skipping
#
# No soma extending branch was added for this sublimb even though it had a soma border (means they already existed)
# MP (because soma touching verts) soma extension add: 11.663957595825195
# There were not both MAP and MP pieces so skipping the stitch resolving phase
# Time for decomp of Limb = 39.74997115135193
# Number of matching vertices = 25
# Only one endpoint after filtering away the endpoints that are not on the skeleton
# Using Distance measure skeletal_distance
