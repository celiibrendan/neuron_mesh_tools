# %%
"""
Purpose: To explore if we can use the inside mesh
algorithm for identifying and deleting glia mes


"""

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from os import sys
sys.path.append("/meshAfterParty/")

# %%
import datajoint_utils as du
import neuron_visualizations as nviz

# %%
minnie,schema = du.configure_minnie_vm()
# Out:
# INFO - 2021-01-08 08:14:30,313 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-01-08 08:14:30,524 - settings - Setting enable_python_native_blobs to True

# %% [markdown]
# # Selecting and Downloading the Glia Cell

# %%
segment_id = 864691135462301853

# %%
current_neuron_mesh = du.fetch_segment_id_mesh(segment_id)

# %%
nviz.plot_objects(current_neuron_mesh)
# Out:
# /usr/local/lib/python3.6/dist-packages/traittypes/traittypes.py:101: UserWarning: Given trait value dtype "float64" does not match required type "float64". A coerced copy has been created.
#   np.dtype(self.dtype).name))
# VBox(children=(Figure(camera=PerspectiveCamera(fov=46.0, position=(0.0, 0.0, 2.0), quaternion=(0.0, 0.0, 0.0, …

# %%
import trimesh_utils as tu

# %%
new_mesh,inside_pieces = tu.remove_mesh_interior(current_neuron_mesh,
                       size_threshold_to_remove=20000,
                        connectivity="edges",
                        try_hole_close=False,
                        return_removed_pieces =True
                       )
# Out:
# xvfb-run -n 2220 -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Auto_Proofreading/Removing_Glia_and_Trash/temp/neuron_41545.off -o /notebooks/Auto_Proofreading/Removing_Glia_and_Trash/temp/neuron_41545_remove_interior.off -s /notebooks/Auto_Proofreading/Removing_Glia_and_Trash/temp/remove_interior_78067.mls
# removed temporary input file: /notebooks/Auto_Proofreading/Removing_Glia_and_Trash/temp/neuron_41545.off
# removed temporary output file: /notebooks/Auto_Proofreading/Removing_Glia_and_Trash/temp/neuron_41545_remove_interior.off
# /notebooks/Auto_Proofreading/Removing_Glia_and_Trash/temp/remove_interior_78067.mls is being deleted....
# WARNING - 2021-01-08 08:29:31,498 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:31,504 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:31,544 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:31,545 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:31,545 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:31,546 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:31,596 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:31,597 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:31,650 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:31,652 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:31,653 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:31,654 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:31,655 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:31,669 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:31,671 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:31,693 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:31,694 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:31,713 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:31,729 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:31,893 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:31,894 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:31,911 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:31,924 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:31,973 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:31,976 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:31,979 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:31,981 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,015 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,015 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,108 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,117 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,148 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,149 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,159 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,160 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,166 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,167 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,177 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,190 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,215 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,217 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,220 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,220 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,221 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,226 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,227 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,235 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,241 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,247 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,249 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,254 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,255 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,256 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,257 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,260 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,261 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,262 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,263 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,266 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,266 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,269 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,270 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,270 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,271 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,278 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,278 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,282 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,283 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,284 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,285 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,289 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,290 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,291 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,292 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,292 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,297 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,298 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,299 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,300 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,301 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,306 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,307 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,329 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,329 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,330 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,331 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,366 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,368 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,385 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,386 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,403 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,404 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,672 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,673 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,674 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,675 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,676 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,677 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,678 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,679 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,695 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,703 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,703 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,714 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,787 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,801 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,802 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,804 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,805 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,805 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,806 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,807 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,808 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,809 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,838 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,839 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,875 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,877 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,960 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,961 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,962 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,963 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,990 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,990 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,991 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,992 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,995 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,996 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,997 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:32,997 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,001 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,007 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,007 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,019 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,021 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,022 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,044 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,045 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,047 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,048 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,069 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,082 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,083 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,094 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,095 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,108 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,114 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,116 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,118 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,130 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,203 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,207 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,214 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,215 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,239 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,247 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,248 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,257 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,292 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,341 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,356 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,401 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,404 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,420 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,491 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,493 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,494 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,501 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,523 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,534 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,538 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,551 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,552 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,553 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,554 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,554 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,560 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,570 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,575 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,601 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,657 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,672 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,673 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,688 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,689 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,690 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,691 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,692 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,780 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,818 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,857 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,858 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,912 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,929 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,939 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,940 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,944 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,945 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,971 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,972 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:33,985 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,003 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,006 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,007 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,010 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,011 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,014 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,023 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,029 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,032 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,288 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,300 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,301 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,302 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,304 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,313 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,314 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,316 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,350 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,354 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,369 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,370 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,371 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,372 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,406 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,421 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,421 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,423 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,425 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,427 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,428 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,449 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,460 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,477 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,478 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,496 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,504 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,505 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,536 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,537 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,540 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,542 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,543 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,554 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,555 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,556 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,559 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,560 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,564 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,571 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,576 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,588 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,591 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,597 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,598 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,599 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,602 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,602 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,603 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,620 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,621 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,646 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,646 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,647 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,648 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,650 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,654 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,654 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,659 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,660 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,670 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,672 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,673 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,673 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,674 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,675 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,675 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,676 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,677 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,679 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,692 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,693 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,694 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,697 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,699 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,700 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,700 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,702 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,720 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,726 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,729 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,730 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,779 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,780 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,784 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,796 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,797 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,823 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,823 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,836 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,846 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,847 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,867 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,868 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,869 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,874 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,876 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,876 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,894 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,895 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,900 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,902 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,903 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,905 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,918 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,919 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,966 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:34,969 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,020 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,080 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,080 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,096 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,097 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,152 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,291 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,296 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,309 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,310 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,480 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,486 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,486 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,507 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,601 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,602 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,603 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,604 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,616 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,616 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,639 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,642 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,651 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,652 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,655 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,656 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,687 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,688 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,713 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,714 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,715 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,716 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,732 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,748 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,756 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,757 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,762 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,762 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,764 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,764 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,777 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,778 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,811 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,837 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,854 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,862 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,865 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,868 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,956 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,979 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,998 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:35,999 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,016 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,190 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,200 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,201 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,209 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,212 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,213 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,227 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,230 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,267 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,268 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,268 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,279 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,279 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,281 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,282 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,282 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,306 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,310 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,350 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,351 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,355 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,356 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,363 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,372 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,381 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,401 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,402 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,406 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,406 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,410 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,435 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,437 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,438 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,440 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,441 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,446 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,471 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,474 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,475 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,475 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,477 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,477 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,478 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,481 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,492 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,493 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,493 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,494 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,495 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,495 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,500 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,501 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,504 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,504 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,512 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,516 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,525 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,525 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,527 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,528 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,603 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,604 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,608 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,609 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,611 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,612 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,639 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,645 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,645 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,658 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,659 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,664 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,669 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,677 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,677 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,680 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:29:36,681 - base - face_normals all zero, ignoring!
# Removing the following inside neurons: [<trimesh.Trimesh(vertices.shape=(578310, 3), faces.shape=(1094125, 3))>]

# %%
nviz.plot_objects(meshes=inside_pieces)
# Out:
# VBox(children=(Figure(camera=PerspectiveCamera(fov=46.0, position=(0.0, 0.0, 2.0), quaternion=(0.0, 0.0, 0.0, …

# %%
nviz.plot_objects(new_mesh
                 )
# Out:
# VBox(children=(Figure(camera=PerspectiveCamera(fov=46.0, position=(0.0, 0.0, 2.0), quaternion=(0.0, 0.0, 0.0, …

# %%
inside_glia = inside_pieces[0]

# %%
import copy
from pykdtree.kdtree import KDTree

# %%
"""
Purpose: Getting all of the points close to glia and removing them

1) Get the inner glia mesh
2) Build a KDTree fo the inner glia
3) Query the faces of the remainingn mesh
4) Get all the faces beyond a certain distance and get the submesh
5) Filter away all floating pieces in a certain region of the bounding box
"""

verbose = True
glia_distance_threshold = 2000
filter_away_floating_pieces = True
bbox_filter_away_ratio = 1.2


import numpy as np

mesh_removed_glia = copy.deepcopy(new_mesh)
for j,inside_glia in enumerate(inside_pieces):
    if verbose:
        print(f"\n ---- Working on inside piece {j} ------")
    
    #2) Build a KDTree fo the inner glia
    glia_kd = KDTree(inside_glia.triangles_center.reshape(-1,3))
    
    
    #3) Query the faces of the remainingn mesh
    dist, _ = glia_kd.query(mesh_removed_glia.triangles_center)
    
    #4) Get all the faces beyond a certain distance and get the submesh
    within_threshold_faces = np.where(dist>= glia_distance_threshold)[0]
    
    
    if len(within_threshold_faces)>0:
        mesh_removed_glia = mesh_removed_glia.submesh([within_threshold_faces],append=True,repair=False)
        
    if verbose:
        print(f"For glia mesh {j} there were {len(within_threshold_faces)} faces within {glia_distance_threshold} distane")
        print(f"New mesh size is {mesh_removed_glia}")
        
    
    if filter_away_floating_pieces:
        all_floating_pieces = tu.split_significant_pieces(mesh_removed_glia,significance_threshold=0,connectivity="edges")
        
        check_meshes_inside_mesh_bbox(inside_glia,all_floating_pieces)
# Out:
#  ---- Working on inside piece 0 ------
# For glia mesh 0 there were 1746179 faces within 2000 distane
# New mesh size is <trimesh.Trimesh(vertices.shape=(861237, 3), faces.shape=(1746179, 3))>

# %%
bbox_multiply_ratio = 1.2

bb_corners = tu.bounding_box_corners(inside_glia)

bbox_center = np.mean(bb_corners,axis=0)
bbox_distance = np.max(bb_corners,axis=0)-bbox_center
new_corners = np.array([bbox_center - bbox_multiply_ratio*bbox_distance,
                        bbox_center + bbox_multiply_ratio*bbox_distance
                       ]).reshape(-1,3)
new_corners
# Out:
# array([[807506.12, 355325.2 , 757352.27],
#        [868354.28, 391298.8 , 812319.83]])

# %%
nviz.plot_objects(inside_glia.bounding_box,
                 scatters=[tu.bounding_box_corners(inside_glia.bounding_box,1.5)],
                 scatter_size=1)
# Out:
# VBox(children=(Figure(camera=PerspectiveCamera(fov=46.0, position=(0.0, 0.0, 2.0), quaternion=(0.0, 0.0, 0.0, …

# %%
bbox_center = np.mean(bb_corners,axis=0)
bbox_distance = np.max(bb_corners,axis=0)-bbox_center

tu.curr_bbox_corners(inside_glia)

# %%
# how to create an extended bounding box

# %%
all_floating_pieces = tu.split_significant_pieces(mesh_removed_glia,significance_threshold=0,connectivity="edges")
all_floating_pieces
# Out:
# WARNING - 2021-01-08 08:53:50,398 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:50,406 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:50,458 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:50,459 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:50,460 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:50,462 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:50,516 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:50,517 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:50,578 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:50,579 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:50,580 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:50,582 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:50,583 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:50,599 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:50,600 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:50,620 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:50,621 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:50,641 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:50,658 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:50,807 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:50,808 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:50,827 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:50,840 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:50,886 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:50,889 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:50,894 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:50,895 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:50,929 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:50,930 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,014 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,023 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,049 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,050 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,060 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,062 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,068 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,069 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,075 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,086 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,111 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,112 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,115 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,116 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,116 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,121 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,122 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,130 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,136 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,142 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,144 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,149 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,150 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,151 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,152 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,156 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,156 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,157 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,158 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,161 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,162 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,166 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,169 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,170 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,170 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,177 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,177 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,180 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,182 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,182 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,183 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,187 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,187 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,189 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,189 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,190 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,190 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,191 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,191 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,193 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,194 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,198 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,199 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,219 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,220 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,221 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,222 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,259 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,260 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,280 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,281 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,299 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,300 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,568 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,569 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,570 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,571 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,572 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,572 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,574 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,575 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,589 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,596 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,597 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,609 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,686 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,701 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,702 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,703 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,704 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,705 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,706 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,707 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,707 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,708 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,735 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,736 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,774 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,775 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,861 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,862 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,864 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,865 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,890 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,891 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,892 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,893 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,897 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,898 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,899 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,899 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,903 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,909 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,910 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,920 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,923 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,924 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,949 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,950 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,952 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,952 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,975 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,989 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:51,990 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,000 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,002 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,014 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,020 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,021 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,024 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,037 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,111 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,115 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,120 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,121 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,123 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,124 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,151 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,162 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,163 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,171 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,207 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,212 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,213 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,258 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,275 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,319 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,322 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,333 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,404 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,405 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,406 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,414 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,432 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,445 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,449 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,460 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,460 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,461 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,462 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,463 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,467 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,476 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,481 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,509 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,557 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,571 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,572 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,589 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,589 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,590 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,591 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,592 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,686 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,724 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,767 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,786 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,796 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,797 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,801 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,802 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,828 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,829 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,844 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,863 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,867 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,868 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,871 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,872 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,875 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,885 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,893 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:52,896 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,154 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,167 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,168 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,170 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,171 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,180 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,181 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,183 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,220 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,223 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,238 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,239 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,240 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,241 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,280 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,295 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,296 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,298 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,300 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,301 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,302 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,325 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,337 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,354 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,355 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,374 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,383 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,384 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,413 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,414 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,418 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,419 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,420 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,431 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,432 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,433 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,436 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,437 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,441 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,448 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,452 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,463 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,464 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,467 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,469 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,476 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,477 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,477 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,479 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,480 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,481 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,488 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,489 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,500 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,501 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,523 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,524 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,525 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,526 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,528 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,532 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,533 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,538 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,539 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,545 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,547 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,547 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,548 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,548 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,549 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,550 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,550 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,552 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,554 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,566 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,567 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,568 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,568 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,570 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,571 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,572 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,573 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,591 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,597 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,600 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,601 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,648 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,649 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,653 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,665 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,666 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,695 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,696 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,706 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,715 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,716 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,737 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,738 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,738 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,743 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,744 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,745 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,766 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,767 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,772 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,774 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,776 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,778 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,787 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,788 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,818 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,821 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,933 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,934 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,950 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:53,951 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:54,830 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:54,961 - base - face_normals all zero, ignoring!
# WARNING - 2021-01-08 08:53:54,966 - base - face_normals all zero, ignoring!
# [<trimesh.Trimesh(vertices.shape=(776878, 3), faces.shape=(1549928, 3))>,
#  <trimesh.Trimesh(vertices.shape=(7843, 3), faces.shape=(15662, 3))>,
#  <trimesh.Trimesh(vertices.shape=(7531, 3), faces.shape=(15110, 3))>,
#  <trimesh.Trimesh(vertices.shape=(1745, 3), faces.shape=(4086, 3))>,
#  <trimesh.Trimesh(vertices.shape=(1730, 3), faces.shape=(3992, 3))>,
#  <trimesh.Trimesh(vertices.shape=(1608, 3), faces.shape=(3178, 3))>,
#  <trimesh.Trimesh(vertices.shape=(1571, 3), faces.shape=(3632, 3))>,
#  <trimesh.Trimesh(vertices.shape=(1518, 3), faces.shape=(3394, 3))>,
#  <trimesh.Trimesh(vertices.shape=(1423, 3), faces.shape=(3235, 3))>,
#  <trimesh.Trimesh(vertices.shape=(1384, 3), faces.shape=(2778, 3))>,
#  <trimesh.Trimesh(vertices.shape=(1355, 3), faces.shape=(2584, 3))>,
#  <trimesh.Trimesh(vertices.shape=(1346, 3), faces.shape=(2700, 3))>,
#  <trimesh.Trimesh(vertices.shape=(1310, 3), faces.shape=(2603, 3))>,
#  <trimesh.Trimesh(vertices.shape=(1287, 3), faces.shape=(2977, 3))>,
#  <trimesh.Trimesh(vertices.shape=(1179, 3), faces.shape=(2760, 3))>,
#  <trimesh.Trimesh(vertices.shape=(1151, 3), faces.shape=(1754, 3))>,
#  <trimesh.Trimesh(vertices.shape=(1114, 3), faces.shape=(2558, 3))>,
#  <trimesh.Trimesh(vertices.shape=(1109, 3), faces.shape=(1675, 3))>,
#  <trimesh.Trimesh(vertices.shape=(1098, 3), faces.shape=(2181, 3))>,
#  <trimesh.Trimesh(vertices.shape=(1084, 3), faces.shape=(2160, 3))>,
#  <trimesh.Trimesh(vertices.shape=(1079, 3), faces.shape=(1675, 3))>,
#  <trimesh.Trimesh(vertices.shape=(1071, 3), faces.shape=(2090, 3))>,
#  <trimesh.Trimesh(vertices.shape=(1069, 3), faces.shape=(1655, 3))>,
#  <trimesh.Trimesh(vertices.shape=(1055, 3), faces.shape=(1603, 3))>,
#  <trimesh.Trimesh(vertices.shape=(1044, 3), faces.shape=(2416, 3))>,
#  <trimesh.Trimesh(vertices.shape=(1044, 3), faces.shape=(1581, 3))>,
#  <trimesh.Trimesh(vertices.shape=(1032, 3), faces.shape=(1576, 3))>,
#  <trimesh.Trimesh(vertices.shape=(1017, 3), faces.shape=(1568, 3))>,
#  <trimesh.Trimesh(vertices.shape=(1012, 3), faces.shape=(1557, 3))>,
#  <trimesh.Trimesh(vertices.shape=(995, 3), faces.shape=(1501, 3))>,
#  <trimesh.Trimesh(vertices.shape=(992, 3), faces.shape=(2200, 3))>,
#  <trimesh.Trimesh(vertices.shape=(990, 3), faces.shape=(1528, 3))>,
#  <trimesh.Trimesh(vertices.shape=(985, 3), faces.shape=(1491, 3))>,
#  <trimesh.Trimesh(vertices.shape=(973, 3), faces.shape=(1467, 3))>,
#  <trimesh.Trimesh(vertices.shape=(957, 3), faces.shape=(1460, 3))>,
#  <trimesh.Trimesh(vertices.shape=(955, 3), faces.shape=(1457, 3))>,
#  <trimesh.Trimesh(vertices.shape=(947, 3), faces.shape=(1442, 3))>,
#  <trimesh.Trimesh(vertices.shape=(908, 3), faces.shape=(1814, 3))>,
#  <trimesh.Trimesh(vertices.shape=(891, 3), faces.shape=(2040, 3))>,
#  <trimesh.Trimesh(vertices.shape=(807, 3), faces.shape=(1624, 3))>,
#  <trimesh.Trimesh(vertices.shape=(777, 3), faces.shape=(1744, 3))>,
#  <trimesh.Trimesh(vertices.shape=(744, 3), faces.shape=(1475, 3))>,
#  <trimesh.Trimesh(vertices.shape=(653, 3), faces.shape=(1453, 3))>,
#  <trimesh.Trimesh(vertices.shape=(651, 3), faces.shape=(1266, 3))>,
#  <trimesh.Trimesh(vertices.shape=(647, 3), faces.shape=(1456, 3))>,
#  <trimesh.Trimesh(vertices.shape=(629, 3), faces.shape=(931, 3))>,
#  <trimesh.Trimesh(vertices.shape=(610, 3), faces.shape=(1334, 3))>,
#  <trimesh.Trimesh(vertices.shape=(603, 3), faces.shape=(879, 3))>,
#  <trimesh.Trimesh(vertices.shape=(588, 3), faces.shape=(862, 3))>,
#  <trimesh.Trimesh(vertices.shape=(586, 3), faces.shape=(858, 3))>,
#  <trimesh.Trimesh(vertices.shape=(572, 3), faces.shape=(832, 3))>,
#  <trimesh.Trimesh(vertices.shape=(568, 3), faces.shape=(834, 3))>,
#  <trimesh.Trimesh(vertices.shape=(566, 3), faces.shape=(1254, 3))>,
#  <trimesh.Trimesh(vertices.shape=(564, 3), faces.shape=(826, 3))>,
#  <trimesh.Trimesh(vertices.shape=(545, 3), faces.shape=(779, 3))>,
#  <trimesh.Trimesh(vertices.shape=(542, 3), faces.shape=(798, 3))>,
#  <trimesh.Trimesh(vertices.shape=(541, 3), faces.shape=(1072, 3))>,
#  <trimesh.Trimesh(vertices.shape=(537, 3), faces.shape=(773, 3))>,
#  <trimesh.Trimesh(vertices.shape=(534, 3), faces.shape=(1156, 3))>,
#  <trimesh.Trimesh(vertices.shape=(532, 3), faces.shape=(763, 3))>,
#  <trimesh.Trimesh(vertices.shape=(532, 3), faces.shape=(778, 3))>,
#  <trimesh.Trimesh(vertices.shape=(531, 3), faces.shape=(995, 3))>,
#  <trimesh.Trimesh(vertices.shape=(525, 3), faces.shape=(1044, 3))>,
#  <trimesh.Trimesh(vertices.shape=(514, 3), faces.shape=(734, 3))>,
#  <trimesh.Trimesh(vertices.shape=(508, 3), faces.shape=(740, 3))>,
#  <trimesh.Trimesh(vertices.shape=(508, 3), faces.shape=(740, 3))>,
#  <trimesh.Trimesh(vertices.shape=(505, 3), faces.shape=(716, 3))>,
#  <trimesh.Trimesh(vertices.shape=(487, 3), faces.shape=(977, 3))>,
#  <trimesh.Trimesh(vertices.shape=(467, 3), faces.shape=(670, 3))>,
#  <trimesh.Trimesh(vertices.shape=(465, 3), faces.shape=(660, 3))>,
#  <trimesh.Trimesh(vertices.shape=(462, 3), faces.shape=(660, 3))>,
#  <trimesh.Trimesh(vertices.shape=(453, 3), faces.shape=(637, 3))>,
#  <trimesh.Trimesh(vertices.shape=(443, 3), faces.shape=(946, 3))>,
#  <trimesh.Trimesh(vertices.shape=(439, 3), faces.shape=(577, 3))>,
#  <trimesh.Trimesh(vertices.shape=(439, 3), faces.shape=(581, 3))>,
#  <trimesh.Trimesh(vertices.shape=(438, 3), faces.shape=(853, 3))>,
#  <trimesh.Trimesh(vertices.shape=(407, 3), faces.shape=(813, 3))>,
#  <trimesh.Trimesh(vertices.shape=(404, 3), faces.shape=(787, 3))>,
#  <trimesh.Trimesh(vertices.shape=(354, 3), faces.shape=(487, 3))>,
#  <trimesh.Trimesh(vertices.shape=(351, 3), faces.shape=(494, 3))>,
#  <trimesh.Trimesh(vertices.shape=(350, 3), faces.shape=(492, 3))>,
#  <trimesh.Trimesh(vertices.shape=(349, 3), faces.shape=(478, 3))>,
#  <trimesh.Trimesh(vertices.shape=(317, 3), faces.shape=(439, 3))>,
#  <trimesh.Trimesh(vertices.shape=(311, 3), faces.shape=(670, 3))>,
#  <trimesh.Trimesh(vertices.shape=(308, 3), faces.shape=(421, 3))>,
#  <trimesh.Trimesh(vertices.shape=(297, 3), faces.shape=(576, 3))>,
#  <trimesh.Trimesh(vertices.shape=(296, 3), faces.shape=(577, 3))>,
#  <trimesh.Trimesh(vertices.shape=(294, 3), faces.shape=(557, 3))>,
#  <trimesh.Trimesh(vertices.shape=(287, 3), faces.shape=(567, 3))>,
#  <trimesh.Trimesh(vertices.shape=(286, 3), faces.shape=(378, 3))>,
#  <trimesh.Trimesh(vertices.shape=(281, 3), faces.shape=(554, 3))>,
#  <trimesh.Trimesh(vertices.shape=(281, 3), faces.shape=(368, 3))>,
#  <trimesh.Trimesh(vertices.shape=(280, 3), faces.shape=(545, 3))>,
#  <trimesh.Trimesh(vertices.shape=(274, 3), faces.shape=(584, 3))>,
#  <trimesh.Trimesh(vertices.shape=(262, 3), faces.shape=(537, 3))>,
#  <trimesh.Trimesh(vertices.shape=(251, 3), faces.shape=(306, 3))>,
#  <trimesh.Trimesh(vertices.shape=(250, 3), faces.shape=(305, 3))>,
#  <trimesh.Trimesh(vertices.shape=(250, 3), faces.shape=(334, 3))>,
#  <trimesh.Trimesh(vertices.shape=(247, 3), faces.shape=(486, 3))>,
#  <trimesh.Trimesh(vertices.shape=(241, 3), faces.shape=(467, 3))>,
#  <trimesh.Trimesh(vertices.shape=(241, 3), faces.shape=(316, 3))>,
#  <trimesh.Trimesh(vertices.shape=(232, 3), faces.shape=(446, 3))>,
#  <trimesh.Trimesh(vertices.shape=(232, 3), faces.shape=(291, 3))>,
#  <trimesh.Trimesh(vertices.shape=(225, 3), faces.shape=(277, 3))>,
#  <trimesh.Trimesh(vertices.shape=(218, 3), faces.shape=(279, 3))>,
#  <trimesh.Trimesh(vertices.shape=(218, 3), faces.shape=(276, 3))>,
#  <trimesh.Trimesh(vertices.shape=(217, 3), faces.shape=(277, 3))>,
#  <trimesh.Trimesh(vertices.shape=(216, 3), faces.shape=(272, 3))>,
#  <trimesh.Trimesh(vertices.shape=(212, 3), faces.shape=(438, 3))>,
#  <trimesh.Trimesh(vertices.shape=(199, 3), faces.shape=(264, 3))>,
#  <trimesh.Trimesh(vertices.shape=(193, 3), faces.shape=(369, 3))>,
#  <trimesh.Trimesh(vertices.shape=(193, 3), faces.shape=(252, 3))>,
#  <trimesh.Trimesh(vertices.shape=(192, 3), faces.shape=(363, 3))>,
#  <trimesh.Trimesh(vertices.shape=(191, 3), faces.shape=(373, 3))>,
#  <trimesh.Trimesh(vertices.shape=(189, 3), faces.shape=(363, 3))>,
#  <trimesh.Trimesh(vertices.shape=(186, 3), faces.shape=(239, 3))>,
#  <trimesh.Trimesh(vertices.shape=(184, 3), faces.shape=(235, 3))>,
#  <trimesh.Trimesh(vertices.shape=(173, 3), faces.shape=(323, 3))>,
#  <trimesh.Trimesh(vertices.shape=(157, 3), faces.shape=(291, 3))>,
#  <trimesh.Trimesh(vertices.shape=(151, 3), faces.shape=(290, 3))>,
#  <trimesh.Trimesh(vertices.shape=(149, 3), faces.shape=(292, 3))>,
#  <trimesh.Trimesh(vertices.shape=(146, 3), faces.shape=(285, 3))>,
#  <trimesh.Trimesh(vertices.shape=(143, 3), faces.shape=(270, 3))>,
#  <trimesh.Trimesh(vertices.shape=(143, 3), faces.shape=(259, 3))>,
#  <trimesh.Trimesh(vertices.shape=(143, 3), faces.shape=(276, 3))>,
#  <trimesh.Trimesh(vertices.shape=(143, 3), faces.shape=(277, 3))>,
#  <trimesh.Trimesh(vertices.shape=(137, 3), faces.shape=(259, 3))>,
#  <trimesh.Trimesh(vertices.shape=(132, 3), faces.shape=(262, 3))>,
#  <trimesh.Trimesh(vertices.shape=(130, 3), faces.shape=(252, 3))>,
#  <trimesh.Trimesh(vertices.shape=(127, 3), faces.shape=(242, 3))>,
#  <trimesh.Trimesh(vertices.shape=(127, 3), faces.shape=(153, 3))>,
#  <trimesh.Trimesh(vertices.shape=(124, 3), faces.shape=(225, 3))>,
#  <trimesh.Trimesh(vertices.shape=(120, 3), faces.shape=(231, 3))>,
#  <trimesh.Trimesh(vertices.shape=(119, 3), faces.shape=(228, 3))>,
#  <trimesh.Trimesh(vertices.shape=(119, 3), faces.shape=(219, 3))>,
#  <trimesh.Trimesh(vertices.shape=(119, 3), faces.shape=(146, 3))>,
#  <trimesh.Trimesh(vertices.shape=(119, 3), faces.shape=(137, 3))>,
#  <trimesh.Trimesh(vertices.shape=(118, 3), faces.shape=(230, 3))>,
#  <trimesh.Trimesh(vertices.shape=(118, 3), faces.shape=(240, 3))>,
#  <trimesh.Trimesh(vertices.shape=(112, 3), faces.shape=(132, 3))>,
#  <trimesh.Trimesh(vertices.shape=(102, 3), faces.shape=(187, 3))>,
#  <trimesh.Trimesh(vertices.shape=(101, 3), faces.shape=(194, 3))>,
#  <trimesh.Trimesh(vertices.shape=(100, 3), faces.shape=(192, 3))>,
#  <trimesh.Trimesh(vertices.shape=(99, 3), faces.shape=(168, 3))>,
#  <trimesh.Trimesh(vertices.shape=(90, 3), faces.shape=(165, 3))>,
#  <trimesh.Trimesh(vertices.shape=(89, 3), faces.shape=(186, 3))>,
#  <trimesh.Trimesh(vertices.shape=(88, 3), faces.shape=(170, 3))>,
#  <trimesh.Trimesh(vertices.shape=(85, 3), faces.shape=(139, 3))>,
#  <trimesh.Trimesh(vertices.shape=(85, 3), faces.shape=(161, 3))>,
#  <trimesh.Trimesh(vertices.shape=(84, 3), faces.shape=(159, 3))>,
#  <trimesh.Trimesh(vertices.shape=(80, 3), faces.shape=(138, 3))>,
#  <trimesh.Trimesh(vertices.shape=(80, 3), faces.shape=(164, 3))>,
#  <trimesh.Trimesh(vertices.shape=(77, 3), faces.shape=(137, 3))>,
#  <trimesh.Trimesh(vertices.shape=(76, 3), faces.shape=(147, 3))>,
#  <trimesh.Trimesh(vertices.shape=(75, 3), faces.shape=(144, 3))>,
#  <trimesh.Trimesh(vertices.shape=(73, 3), faces.shape=(139, 3))>,
#  <trimesh.Trimesh(vertices.shape=(72, 3), faces.shape=(137, 3))>,
#  <trimesh.Trimesh(vertices.shape=(68, 3), faces.shape=(130, 3))>,
#  <trimesh.Trimesh(vertices.shape=(66, 3), faces.shape=(114, 3))>,
#  <trimesh.Trimesh(vertices.shape=(66, 3), faces.shape=(120, 3))>,
#  <trimesh.Trimesh(vertices.shape=(64, 3), faces.shape=(97, 3))>,
#  <trimesh.Trimesh(vertices.shape=(64, 3), faces.shape=(113, 3))>,
#  <trimesh.Trimesh(vertices.shape=(63, 3), faces.shape=(108, 3))>,
#  <trimesh.Trimesh(vertices.shape=(63, 3), faces.shape=(108, 3))>,
#  <trimesh.Trimesh(vertices.shape=(62, 3), faces.shape=(110, 3))>,
#  <trimesh.Trimesh(vertices.shape=(62, 3), faces.shape=(118, 3))>,
#  <trimesh.Trimesh(vertices.shape=(61, 3), faces.shape=(117, 3))>,
#  <trimesh.Trimesh(vertices.shape=(60, 3), faces.shape=(108, 3))>,
#  <trimesh.Trimesh(vertices.shape=(59, 3), faces.shape=(107, 3))>,
#  <trimesh.Trimesh(vertices.shape=(59, 3), faces.shape=(118, 3))>,
#  <trimesh.Trimesh(vertices.shape=(57, 3), faces.shape=(109, 3))>,
#  <trimesh.Trimesh(vertices.shape=(57, 3), faces.shape=(91, 3))>,
#  <trimesh.Trimesh(vertices.shape=(56, 3), faces.shape=(102, 3))>,
#  <trimesh.Trimesh(vertices.shape=(56, 3), faces.shape=(105, 3))>,
#  <trimesh.Trimesh(vertices.shape=(55, 3), faces.shape=(100, 3))>,
#  <trimesh.Trimesh(vertices.shape=(55, 3), faces.shape=(105, 3))>,
#  <trimesh.Trimesh(vertices.shape=(55, 3), faces.shape=(95, 3))>,
#  <trimesh.Trimesh(vertices.shape=(54, 3), faces.shape=(102, 3))>,
#  <trimesh.Trimesh(vertices.shape=(53, 3), faces.shape=(92, 3))>,
#  <trimesh.Trimesh(vertices.shape=(52, 3), faces.shape=(89, 3))>,
#  <trimesh.Trimesh(vertices.shape=(49, 3), faces.shape=(94, 3))>,
#  <trimesh.Trimesh(vertices.shape=(48, 3), faces.shape=(53, 3))>,
#  <trimesh.Trimesh(vertices.shape=(48, 3), faces.shape=(53, 3))>,
#  <trimesh.Trimesh(vertices.shape=(46, 3), faces.shape=(87, 3))>,
#  <trimesh.Trimesh(vertices.shape=(45, 3), faces.shape=(80, 3))>,
#  <trimesh.Trimesh(vertices.shape=(44, 3), faces.shape=(81, 3))>,
#  <trimesh.Trimesh(vertices.shape=(44, 3), faces.shape=(77, 3))>,
#  <trimesh.Trimesh(vertices.shape=(43, 3), faces.shape=(79, 3))>,
#  <trimesh.Trimesh(vertices.shape=(42, 3), faces.shape=(66, 3))>,
#  <trimesh.Trimesh(vertices.shape=(42, 3), faces.shape=(57, 3))>,
#  <trimesh.Trimesh(vertices.shape=(41, 3), faces.shape=(66, 3))>,
#  <trimesh.Trimesh(vertices.shape=(40, 3), faces.shape=(69, 3))>,
#  <trimesh.Trimesh(vertices.shape=(40, 3), faces.shape=(73, 3))>,
#  <trimesh.Trimesh(vertices.shape=(38, 3), faces.shape=(69, 3))>,
#  <trimesh.Trimesh(vertices.shape=(37, 3), faces.shape=(67, 3))>,
#  <trimesh.Trimesh(vertices.shape=(37, 3), faces.shape=(68, 3))>,
#  <trimesh.Trimesh(vertices.shape=(37, 3), faces.shape=(65, 3))>,
#  <trimesh.Trimesh(vertices.shape=(36, 3), faces.shape=(71, 3))>,
#  <trimesh.Trimesh(vertices.shape=(36, 3), faces.shape=(61, 3))>,
#  <trimesh.Trimesh(vertices.shape=(36, 3), faces.shape=(66, 3))>,
#  <trimesh.Trimesh(vertices.shape=(36, 3), faces.shape=(68, 3))>,
#  <trimesh.Trimesh(vertices.shape=(35, 3), faces.shape=(52, 3))>,
#  <trimesh.Trimesh(vertices.shape=(35, 3), faces.shape=(57, 3))>,
#  <trimesh.Trimesh(vertices.shape=(35, 3), faces.shape=(66, 3))>,
#  <trimesh.Trimesh(vertices.shape=(34, 3), faces.shape=(55, 3))>,
#  <trimesh.Trimesh(vertices.shape=(33, 3), faces.shape=(51, 3))>,
#  <trimesh.Trimesh(vertices.shape=(33, 3), faces.shape=(62, 3))>,
#  <trimesh.Trimesh(vertices.shape=(33, 3), faces.shape=(66, 3))>,
#  <trimesh.Trimesh(vertices.shape=(33, 3), faces.shape=(60, 3))>,
#  <trimesh.Trimesh(vertices.shape=(32, 3), faces.shape=(42, 3))>,
#  <trimesh.Trimesh(vertices.shape=(32, 3), faces.shape=(60, 3))>,
#  <trimesh.Trimesh(vertices.shape=(31, 3), faces.shape=(54, 3))>,
#  <trimesh.Trimesh(vertices.shape=(31, 3), faces.shape=(62, 3))>,
#  <trimesh.Trimesh(vertices.shape=(31, 3), faces.shape=(62, 3))>,
#  <trimesh.Trimesh(vertices.shape=(29, 3), faces.shape=(49, 3))>,
#  <trimesh.Trimesh(vertices.shape=(29, 3), faces.shape=(52, 3))>,
#  <trimesh.Trimesh(vertices.shape=(29, 3), faces.shape=(51, 3))>,
#  <trimesh.Trimesh(vertices.shape=(29, 3), faces.shape=(54, 3))>,
#  <trimesh.Trimesh(vertices.shape=(27, 3), faces.shape=(49, 3))>,
#  <trimesh.Trimesh(vertices.shape=(27, 3), faces.shape=(45, 3))>,
#  <trimesh.Trimesh(vertices.shape=(26, 3), faces.shape=(35, 3))>,
#  <trimesh.Trimesh(vertices.shape=(26, 3), faces.shape=(42, 3))>,
#  <trimesh.Trimesh(vertices.shape=(26, 3), faces.shape=(45, 3))>,
#  <trimesh.Trimesh(vertices.shape=(26, 3), faces.shape=(46, 3))>,
#  <trimesh.Trimesh(vertices.shape=(26, 3), faces.shape=(47, 3))>,
#  <trimesh.Trimesh(vertices.shape=(25, 3), faces.shape=(33, 3))>,
#  <trimesh.Trimesh(vertices.shape=(25, 3), faces.shape=(46, 3))>,
#  <trimesh.Trimesh(vertices.shape=(24, 3), faces.shape=(40, 3))>,
#  <trimesh.Trimesh(vertices.shape=(24, 3), faces.shape=(42, 3))>,
#  <trimesh.Trimesh(vertices.shape=(24, 3), faces.shape=(35, 3))>,
#  <trimesh.Trimesh(vertices.shape=(24, 3), faces.shape=(44, 3))>,
#  <trimesh.Trimesh(vertices.shape=(23, 3), faces.shape=(31, 3))>,
#  <trimesh.Trimesh(vertices.shape=(23, 3), faces.shape=(40, 3))>,
#  <trimesh.Trimesh(vertices.shape=(23, 3), faces.shape=(42, 3))>,
#  <trimesh.Trimesh(vertices.shape=(23, 3), faces.shape=(42, 3))>,
#  <trimesh.Trimesh(vertices.shape=(22, 3), faces.shape=(35, 3))>,
#  <trimesh.Trimesh(vertices.shape=(22, 3), faces.shape=(36, 3))>,
#  <trimesh.Trimesh(vertices.shape=(22, 3), faces.shape=(35, 3))>,
#  <trimesh.Trimesh(vertices.shape=(22, 3), faces.shape=(37, 3))>,
#  <trimesh.Trimesh(vertices.shape=(22, 3), faces.shape=(39, 3))>,
#  <trimesh.Trimesh(vertices.shape=(22, 3), faces.shape=(21, 3))>,
#  <trimesh.Trimesh(vertices.shape=(22, 3), faces.shape=(21, 3))>,
#  <trimesh.Trimesh(vertices.shape=(21, 3), faces.shape=(31, 3))>,
#  <trimesh.Trimesh(vertices.shape=(21, 3), faces.shape=(34, 3))>,
#  <trimesh.Trimesh(vertices.shape=(21, 3), faces.shape=(34, 3))>,
#  <trimesh.Trimesh(vertices.shape=(21, 3), faces.shape=(33, 3))>,
#  <trimesh.Trimesh(vertices.shape=(21, 3), faces.shape=(38, 3))>,
#  <trimesh.Trimesh(vertices.shape=(21, 3), faces.shape=(36, 3))>,
#  <trimesh.Trimesh(vertices.shape=(21, 3), faces.shape=(33, 3))>,
#  <trimesh.Trimesh(vertices.shape=(21, 3), faces.shape=(33, 3))>,
#  <trimesh.Trimesh(vertices.shape=(21, 3), faces.shape=(38, 3))>,
#  <trimesh.Trimesh(vertices.shape=(21, 3), faces.shape=(22, 3))>,
#  <trimesh.Trimesh(vertices.shape=(20, 3), faces.shape=(34, 3))>,
#  <trimesh.Trimesh(vertices.shape=(20, 3), faces.shape=(35, 3))>,
#  <trimesh.Trimesh(vertices.shape=(20, 3), faces.shape=(44, 3))>,
#  <trimesh.Trimesh(vertices.shape=(20, 3), faces.shape=(31, 3))>,
#  <trimesh.Trimesh(vertices.shape=(19, 3), faces.shape=(34, 3))>,
#  <trimesh.Trimesh(vertices.shape=(19, 3), faces.shape=(34, 3))>,
#  <trimesh.Trimesh(vertices.shape=(19, 3), faces.shape=(31, 3))>,
#  <trimesh.Trimesh(vertices.shape=(19, 3), faces.shape=(33, 3))>,
#  <trimesh.Trimesh(vertices.shape=(19, 3), faces.shape=(18, 3))>,
#  <trimesh.Trimesh(vertices.shape=(18, 3), faces.shape=(32, 3))>,
#  <trimesh.Trimesh(vertices.shape=(18, 3), faces.shape=(31, 3))>,
#  <trimesh.Trimesh(vertices.shape=(18, 3), faces.shape=(32, 3))>,
#  <trimesh.Trimesh(vertices.shape=(18, 3), faces.shape=(32, 3))>,
#  <trimesh.Trimesh(vertices.shape=(18, 3), faces.shape=(32, 3))>,
#  <trimesh.Trimesh(vertices.shape=(17, 3), faces.shape=(16, 3))>,
#  <trimesh.Trimesh(vertices.shape=(17, 3), faces.shape=(28, 3))>,
#  <trimesh.Trimesh(vertices.shape=(17, 3), faces.shape=(27, 3))>,
#  <trimesh.Trimesh(vertices.shape=(17, 3), faces.shape=(27, 3))>,
#  <trimesh.Trimesh(vertices.shape=(17, 3), faces.shape=(28, 3))>,
#  <trimesh.Trimesh(vertices.shape=(17, 3), faces.shape=(29, 3))>,
#  <trimesh.Trimesh(vertices.shape=(17, 3), faces.shape=(29, 3))>,
#  <trimesh.Trimesh(vertices.shape=(17, 3), faces.shape=(30, 3))>,
#  <trimesh.Trimesh(vertices.shape=(17, 3), faces.shape=(17, 3))>,
#  <trimesh.Trimesh(vertices.shape=(17, 3), faces.shape=(17, 3))>,
#  <trimesh.Trimesh(vertices.shape=(17, 3), faces.shape=(30, 3))>,
#  <trimesh.Trimesh(vertices.shape=(16, 3), faces.shape=(32, 3))>,
#  <trimesh.Trimesh(vertices.shape=(16, 3), faces.shape=(15, 3))>,
#  <trimesh.Trimesh(vertices.shape=(16, 3), faces.shape=(15, 3))>,
#  <trimesh.Trimesh(vertices.shape=(16, 3), faces.shape=(28, 3))>,
#  <trimesh.Trimesh(vertices.shape=(16, 3), faces.shape=(17, 3))>,
#  <trimesh.Trimesh(vertices.shape=(16, 3), faces.shape=(28, 3))>,
#  <trimesh.Trimesh(vertices.shape=(15, 3), faces.shape=(17, 3))>,
#  <trimesh.Trimesh(vertices.shape=(15, 3), faces.shape=(25, 3))>,
#  <trimesh.Trimesh(vertices.shape=(15, 3), faces.shape=(21, 3))>,
#  <trimesh.Trimesh(vertices.shape=(15, 3), faces.shape=(25, 3))>,
#  <trimesh.Trimesh(vertices.shape=(15, 3), faces.shape=(26, 3))>,
#  <trimesh.Trimesh(vertices.shape=(15, 3), faces.shape=(24, 3))>,
#  <trimesh.Trimesh(vertices.shape=(15, 3), faces.shape=(21, 3))>,
#  <trimesh.Trimesh(vertices.shape=(15, 3), faces.shape=(20, 3))>,
#  <trimesh.Trimesh(vertices.shape=(15, 3), faces.shape=(14, 3))>,
#  <trimesh.Trimesh(vertices.shape=(15, 3), faces.shape=(14, 3))>,
#  <trimesh.Trimesh(vertices.shape=(15, 3), faces.shape=(14, 3))>,
#  <trimesh.Trimesh(vertices.shape=(15, 3), faces.shape=(14, 3))>,
#  <trimesh.Trimesh(vertices.shape=(15, 3), faces.shape=(14, 3))>,
#  <trimesh.Trimesh(vertices.shape=(15, 3), faces.shape=(15, 3))>,
#  <trimesh.Trimesh(vertices.shape=(15, 3), faces.shape=(15, 3))>,
#  <trimesh.Trimesh(vertices.shape=(15, 3), faces.shape=(14, 3))>,
#  <trimesh.Trimesh(vertices.shape=(15, 3), faces.shape=(30, 3))>,
#  <trimesh.Trimesh(vertices.shape=(15, 3), faces.shape=(14, 3))>,
#  <trimesh.Trimesh(vertices.shape=(14, 3), faces.shape=(20, 3))>,
#  <trimesh.Trimesh(vertices.shape=(14, 3), faces.shape=(15, 3))>,
#  <trimesh.Trimesh(vertices.shape=(14, 3), faces.shape=(13, 3))>,
#  <trimesh.Trimesh(vertices.shape=(14, 3), faces.shape=(13, 3))>,
#  <trimesh.Trimesh(vertices.shape=(14, 3), faces.shape=(13, 3))>,
#  <trimesh.Trimesh(vertices.shape=(14, 3), faces.shape=(13, 3))>,
#  <trimesh.Trimesh(vertices.shape=(14, 3), faces.shape=(13, 3))>,
#  <trimesh.Trimesh(vertices.shape=(14, 3), faces.shape=(12, 3))>,
#  <trimesh.Trimesh(vertices.shape=(14, 3), faces.shape=(16, 3))>,
#  <trimesh.Trimesh(vertices.shape=(14, 3), faces.shape=(16, 3))>,
#  <trimesh.Trimesh(vertices.shape=(14, 3), faces.shape=(14, 3))>,
#  <trimesh.Trimesh(vertices.shape=(14, 3), faces.shape=(24, 3))>,
#  <trimesh.Trimesh(vertices.shape=(13, 3), faces.shape=(14, 3))>,
#  <trimesh.Trimesh(vertices.shape=(13, 3), faces.shape=(15, 3))>,
#  <trimesh.Trimesh(vertices.shape=(13, 3), faces.shape=(20, 3))>,
#  <trimesh.Trimesh(vertices.shape=(13, 3), faces.shape=(13, 3))>,
#  <trimesh.Trimesh(vertices.shape=(13, 3), faces.shape=(26, 3))>,
#  <trimesh.Trimesh(vertices.shape=(13, 3), faces.shape=(12, 3))>,
#  <trimesh.Trimesh(vertices.shape=(13, 3), faces.shape=(12, 3))>,
#  <trimesh.Trimesh(vertices.shape=(13, 3), faces.shape=(22, 3))>,
#  <trimesh.Trimesh(vertices.shape=(13, 3), faces.shape=(22, 3))>,
#  <trimesh.Trimesh(vertices.shape=(13, 3), faces.shape=(22, 3))>,
#  <trimesh.Trimesh(vertices.shape=(13, 3), faces.shape=(21, 3))>,
#  <trimesh.Trimesh(vertices.shape=(13, 3), faces.shape=(22, 3))>,
#  <trimesh.Trimesh(vertices.shape=(12, 3), faces.shape=(19, 3))>,
#  <trimesh.Trimesh(vertices.shape=(12, 3), faces.shape=(15, 3))>,
#  <trimesh.Trimesh(vertices.shape=(12, 3), faces.shape=(20, 3))>,
#  <trimesh.Trimesh(vertices.shape=(12, 3), faces.shape=(24, 3))>,
#  <trimesh.Trimesh(vertices.shape=(12, 3), faces.shape=(20, 3))>,
#  <trimesh.Trimesh(vertices.shape=(12, 3), faces.shape=(18, 3))>,
#  <trimesh.Trimesh(vertices.shape=(12, 3), faces.shape=(13, 3))>,
#  <trimesh.Trimesh(vertices.shape=(12, 3), faces.shape=(18, 3))>,
#  <trimesh.Trimesh(vertices.shape=(12, 3), faces.shape=(12, 3))>,
#  <trimesh.Trimesh(vertices.shape=(12, 3), faces.shape=(10, 3))>,
#  <trimesh.Trimesh(vertices.shape=(12, 3), faces.shape=(11, 3))>,
#  <trimesh.Trimesh(vertices.shape=(12, 3), faces.shape=(11, 3))>,
#  <trimesh.Trimesh(vertices.shape=(12, 3), faces.shape=(11, 3))>,
#  <trimesh.Trimesh(vertices.shape=(12, 3), faces.shape=(11, 3))>,
#  <trimesh.Trimesh(vertices.shape=(12, 3), faces.shape=(11, 3))>,
#  <trimesh.Trimesh(vertices.shape=(12, 3), faces.shape=(20, 3))>,
#  <trimesh.Trimesh(vertices.shape=(12, 3), faces.shape=(13, 3))>,
#  <trimesh.Trimesh(vertices.shape=(12, 3), faces.shape=(20, 3))>,
#  <trimesh.Trimesh(vertices.shape=(12, 3), faces.shape=(20, 3))>,
#  <trimesh.Trimesh(vertices.shape=(12, 3), faces.shape=(13, 3))>,
# ...
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(3, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(3, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(3, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(3, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(3, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(2, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>,
#  ...]

# %%
inside_glia.bounding_box.

# %%
nviz.plot_objects(mesh_removed_glia)
# Out:
# VBox(children=(Figure(camera=PerspectiveCamera(fov=46.0, position=(0.0, 0.0, 2.0), quaternion=(0.0, 0.0, 0.0, …
