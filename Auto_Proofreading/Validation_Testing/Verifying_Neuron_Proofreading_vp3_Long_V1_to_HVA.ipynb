# %%
# %load_ext autoreload
# %autoreload 2

# %%
from os import sys
sys.path.append("/meshAfterParty/")
sys.path.append("/meshAfterParty/meshAfterParty")

# %%
import datajoint_utils as du
minnie,schema = du.configure_minnie_vm()
# Out:
# INFO - 2021-03-23 21:31:59,422 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-03-23 21:31:59,425 - settings - Setting database.user to celiib
# INFO - 2021-03-23 21:31:59,426 - settings - Setting database.password to newceliipass
# INFO - 2021-03-23 21:31:59,441 - settings - Setting stores to {'minnie65': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65', 'stage': '/mnt/dj-stor01/platinum/minnie65'}, 'meshes': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/meshes', 'stage': '/mnt/dj-stor01/platinum/minnie65/02/meshes'}, 'decimated_meshes': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/decimated_meshes', 'stage': '/mnt/dj-stor01/platinum/minnie65/02/decimated_meshes'}, 'skeletons': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/skeletons'}}
# INFO - 2021-03-23 21:31:59,442 - settings - Setting enable_python_native_blobs to True
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import networkx_utils as xu
import neuron_visualizations as nviz

# %% [markdown]
# # Looking at neurons that project out

# %%
segment_id = 864691136040977750
segment_id=864691136008407980
du.proofreading_neurons_table() & dict(segment_id=segment_id)
# Out:
# *segment_id    *decimation_ve *decimation_ra *ver      *process_versi *index    *split_index   *proof_version multiplicity   cell_type_pred spine_category n_axons     n_apicals     axon_length    axon_area      nucleus_id     nuclei_distanc n_nuclei_in_ra n_nuclei_in_bb soma_x     soma_y     soma_z     max_soma_n_fac max_soma_volum n_vertices     n_faces     n_not_processe n_error_limbs  n_same_soma_mu n_multi_soma_t n_somas     n_limbs     n_branches     max_limb_n_bra skeletal_lengt max_limb_skele median_branch_ width_median   width_no_spine width_90_perc  width_no_spine n_spines     spine_density  spines_per_bra skeletal_lengt n_spine_eligib spine_density_ spines_per_bra total_spine_vo spine_volume_m spine_volume_d spine_volume_d spine_volume_p axon_angle_max spine_density_ n_branches_pro skeletal_lengt n_branches_in_ skeletal_lengt run_time
# ...

# %%
print("hi")
# Out:
# hi

# %%
minnie.NeuronGliaNuclei() & "n_glia_faces > 80000"
# Out:
# *segment_id    *decimation_ve *decimation_ra *ver      n_glia_faces   glia_faces n_nuclei_faces nuclei_fac
# +------------+ +------------+ +------------+ +-------+ +------------+ +--------+ +------------+ +--------+
# 86469113487102 0              0.25           30.00     208065         =BLOB=     0              =BLOB=
# 86469113487959 0              0.25           30.00     416725         =BLOB=     10538          =BLOB=
# 86469113488264 0              0.25           30.00     241408         =BLOB=     18012          =BLOB=
# 86469113488474 0              0.25           30.00     4299651        =BLOB=     1981           =BLOB=
# 86469113488475 0              0.25           30.00     293709         =BLOB=     4103           =BLOB=
# 86469113488475 0              0.25           30.00     2848066        =BLOB=     3265           =BLOB=
# 86469113488476 0              0.25           30.00     617730         =BLOB=     756            =BLOB=
# ...

# %%
import ipyvolume as ipv
ipv.pylab.save(f"{segment_id}_long_axon_proofread.html")

# %% [markdown]
# # Verifying the Width of the neuron

# %%
segment_id=864691136040977750

# %%
neuron_obj = du.fetch_neuron_obj_manual(segment_id)
# Out:
# Decompressing Neuron in minimal output mode...please wait

# %%
nviz.visualize_neuron_path(neuron_obj,0,[32])
# Out:
#  Working on visualization type: mesh
#
#  Working on visualization type: skeleton
# ...

# %%
neuron_obj[0][32].width_new
# Out:
# {'median_mesh_center': 207.88780964831994,
#  'no_spine_median_mesh_center': 207.88780964831994}

# %%
nviz.visualize_neuron_specific_limb(neuron_obj,0)
# Out:
#  Working on visualization type: mesh
#
#  Working on visualization type: skeleton
# ...
# No limb name was given so using L0 because was the limb in the first key

# %%
curr_index = 100
curr_segment_id = long_axon_segment_ids[curr_index]
curr_split_index = long_axon_split_indexes[curr_index]

print(f"segment_id = {curr_segment_id}, split_index = {curr_split_index}")
du.plot_proofread_neuron(segment_id=curr_segment_id,
                        split_index = curr_split_index,
                        plot_proofreading_synapses=False,
                         plot_error_synapses=True,
                        plot_errored_faces=True)

# %%
curr_index = 200
curr_segment_id = long_axon_segment_ids[curr_index]
curr_split_index = long_axon_split_indexes[curr_index]

print(f"segment_id = {curr_segment_id}, split_index = {curr_split_index}")
du.plot_proofread_neuron(segment_id=curr_segment_id,
                        split_index = curr_split_index,
                        plot_proofreading_synapses=False,
                         plot_error_synapses=True,
                        plot_errored_faces=True)

# %%
curr_index = 500
curr_segment_id = long_axon_segment_ids[curr_index]
curr_split_index = long_axon_split_indexes[curr_index]

print(f"segment_id = {curr_segment_id}, split_index = {curr_split_index}")
du.plot_proofread_neuron(segment_id=curr_segment_id,
                        split_index = curr_split_index,
                        plot_proofreading_synapses=False,
                         plot_error_synapses=True,
                        plot_errored_faces=True)

# %% [markdown]
# # Looking at neurons that were manually proofread

# %%
m65 = minnie
(man_segment_ids,
man_nucleus_ids) = ((m65.UnitSeedGroup & 'group_method_id!=5' & 'group_method_id!=6') * (du.m65mat.ProofreadFunctionalCoregV2 & 'ver=30')).fetch('segment_id',"nucleus_id")

# %%
(manually_proofread_segment_ids)

# %%
minnie.AutoProofreadNeurons3() & [dict(segment_id=k,
                                      nucleus_id=v) for k,v in zip(man_segment_ids,man_nucleus_ids)]

# %%
du.proofreading_neurons_table() & dict(segment_id=864691135337845734)

# %%
curr_segment_id = 864691135337845734
curr_split_index = 0

print(f"segment_id = {curr_segment_id}, split_index = {curr_split_index}")
du.plot_proofread_neuron(segment_id=curr_segment_id,
                        split_index = curr_split_index,
                        plot_proofreading_synapses=False,
                         plot_error_synapses=True,
                        plot_errored_faces=True)
