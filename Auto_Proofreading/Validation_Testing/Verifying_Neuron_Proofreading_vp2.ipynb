# %%
# %load_ext autoreload
# %autoreload 2

# %%
from os import sys
sys.path.append("/meshAfterParty/")
sys.path.append("/meshAfterParty/meshAfterParty")

# %%
import datajoint_utils as du
minnie,schema = du.configure_minnie_vm()
# Out:
# INFO - 2021-03-02 18:19:12,676 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-03-02 18:19:12,678 - settings - Setting database.user to celiib
# INFO - 2021-03-02 18:19:12,679 - settings - Setting database.password to newceliipass
# INFO - 2021-03-02 18:19:12,684 - settings - Setting stores to {'minnie65': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65', 'stage': '/mnt/dj-stor01/platinum/minnie65'}, 'meshes': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/meshes', 'stage': '/mnt/dj-stor01/platinum/minnie65/02/meshes'}, 'decimated_meshes': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/decimated_meshes', 'stage': '/mnt/dj-stor01/platinum/minnie65/02/decimated_meshes'}, 'skeletons': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/skeletons'}}
# INFO - 2021-03-02 18:19:12,685 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-03-02 18:19:12,708 - connection - Connected celiib@at-database.ad.bcm.edu:3306
# Connecting celiib@at-database.ad.bcm.edu:3306
# INFO - 2021-03-02 18:19:13,071 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-03-02 18:19:13,075 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-03-02 18:19:13,076 - settings - Setting database.user to celiib
# INFO - 2021-03-02 18:19:13,077 - settings - Setting database.password to newceliipass
# INFO - 2021-03-02 18:19:13,078 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-03-02 18:19:13,079 - settings - Setting database.user to celiib
# INFO - 2021-03-02 18:19:13,080 - settings - Setting database.password to newceliipass
# INFO - 2021-03-02 18:19:13,082 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-03-02 18:19:13,477 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-03-02 18:19:13,510 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-03-02 18:19:13,512 - settings - Setting database.user to celiib
# INFO - 2021-03-02 18:19:13,513 - settings - Setting database.password to newceliipass
# INFO - 2021-03-02 18:19:13,515 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-03-02 18:19:13,938 - settings - Setting enable_python_native_blobs to True

# %%
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import networkx_utils as xu
import neuron_visualizations as nviz

# %% [markdown]
# # Looking at high degree nodes

# %%
long_axon_segment_ids, long_axon_split_indexes = (du.proofreading_neurons_table() & "axon_length>1000" & "spine_category = 'densely_spined'").fetch("segment_id","split_index")

# %%
du.plot_proofread_neuron(segment_id=864691134884782586,
                        split_index = 0,
                        plot_proofreading_synapses=False,
                         plot_error_synapses=True,
                        plot_errored_faces=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/traittypes/traittypes.py:101: UserWarning: Given trait value dtype "float64" does not match required type "float64". A coerced copy has been created.
#   np.dtype(self.dtype).name))
# VBox(children=(Figure(camera=PerspectiveCamera(fov=46.0, position=(0.0, 0.0, 2.0), projectionMatrix=(1.0, 0.0,…

# %%
curr_index = 100
curr_segment_id = long_axon_segment_ids[curr_index]
curr_split_index = long_axon_split_indexes[curr_index]

print(f"segment_id = {curr_segment_id}, split_index = {curr_split_index}")
du.plot_proofread_neuron(segment_id=curr_segment_id,
                        split_index = curr_split_index,
                        plot_proofreading_synapses=False,
                         plot_error_synapses=True,
                        plot_errored_faces=True)
# Out:
# segment_id = 864691134988381818, split_index = 0
# /usr/local/lib/python3.6/dist-packages/traittypes/traittypes.py:101: UserWarning: Given trait value dtype "float64" does not match required type "float64". A coerced copy has been created.
#   np.dtype(self.dtype).name))
# VBox(children=(Figure(camera=PerspectiveCamera(fov=46.0, position=(0.0, 0.0, 2.0), projectionMatrix=(1.0, 0.0,…

# %%
curr_index = 200
curr_segment_id = long_axon_segment_ids[curr_index]
curr_split_index = long_axon_split_indexes[curr_index]

print(f"segment_id = {curr_segment_id}, split_index = {curr_split_index}")
du.plot_proofread_neuron(segment_id=curr_segment_id,
                        split_index = curr_split_index,
                        plot_proofreading_synapses=False,
                         plot_error_synapses=True,
                        plot_errored_faces=True)
# Out:
# segment_id = 864691135012889750, split_index = 0
# /usr/local/lib/python3.6/dist-packages/traittypes/traittypes.py:101: UserWarning: Given trait value dtype "float64" does not match required type "float64". A coerced copy has been created.
#   np.dtype(self.dtype).name))
# VBox(children=(Figure(camera=PerspectiveCamera(fov=46.0, position=(0.0, 0.0, 2.0), projectionMatrix=(1.0, 0.0,…

# %%
curr_index = 500
curr_segment_id = long_axon_segment_ids[curr_index]
curr_split_index = long_axon_split_indexes[curr_index]

print(f"segment_id = {curr_segment_id}, split_index = {curr_split_index}")
du.plot_proofread_neuron(segment_id=curr_segment_id,
                        split_index = curr_split_index,
                        plot_proofreading_synapses=False,
                         plot_error_synapses=True,
                        plot_errored_faces=True)
# Out:
# segment_id = 864691135162197549, split_index = 0
# /usr/local/lib/python3.6/dist-packages/traittypes/traittypes.py:101: UserWarning: Given trait value dtype "float64" does not match required type "float64". A coerced copy has been created.
#   np.dtype(self.dtype).name))
# VBox(children=(Figure(camera=PerspectiveCamera(fov=46.0, position=(0.0, 0.0, 2.0), projectionMatrix=(1.0, 0.0,…

# %% [markdown]
# # Looking at neurons that were manually proofread

# %%
m65 = minnie
(man_segment_ids,
man_nucleus_ids) = ((m65.UnitSeedGroup & 'group_method_id!=5' & 'group_method_id!=6') * (du.m65mat.ProofreadFunctionalCoregV2 & 'ver=30')).fetch('segment_id',"nucleus_id")

# %%
(manually_proofread_segment_ids)
# Out:
# array([864691135293126156, 864691137019596142, 864691136378815445,
#        864691135367058169, 864691136108768952, 864691136903144370,
#        864691135446675028, 864691135162313773, 864691135724333739,
#        864691135463631941, 864691135953898760, 864691135569138566,
#        864691135278269857, 864691136116205476, 864691136951664863,
#        864691135462463389, 864691135564752471, 864691136008689326,
#        864691135517422218, 864691135517422218, 864691136023889209,
#        864691135718541617, 864691135117980637, 864691135617953423,
#        864691135385422677, 864691135776732256, 864691135809608652,
#        864691135012639734, 864691135888577417, 864691135809608652,
#        864691135850577863, 864691135440543560, 864691135367033849,
#        864691136811995507, 864691136023980601, 864691135233242713,
#        864691136194298600, 864691134884807418, 864691135583884664,
#        864691135593659947, 864691135272206865, 864691135700409211,
#        864691135345364127, 864691135915343462, 864691135462420637,
#        864691135937286404, 864691136903228594, 864691135915343462,
#        864691136108938168, 864691135497743635, 864691135761634358,
#        864691135564739159, 864691135848030814, 864691135975539779,
#        864691135517531786, 864691135815579983, 864691135334584297,
#        864691135782544435, 864691135117960925, 864691135382556378,
#        864691135337845734, 864691136436509342, 864691135884023664,
#        864691135771790587, 864691136378859477, 864691135761725238,
#        864691135644809967, 864691135771829499, 864691135775906989,
#        864691136925601354, 864691135724393131, 864691135609594119])

# %%
minnie.AutoProofreadNeurons3() & [dict(segment_id=k,
                                      nucleus_id=v) for k,v in zip(man_segment_ids,man_nucleus_ids)]
# Out:
# *segment_id    *decimation_ve *decimation_ra *ver      *process_versi *index    *split_index   *proof_version multiplicity   cell_type_pred spine_category n_axons     n_apicals     axon_length    axon_area      nucleus_id     nuclei_distanc n_nuclei_in_ra n_nuclei_in_bb soma_x     soma_y     soma_z     max_soma_n_fac max_soma_volum n_vertices     n_faces     n_not_processe n_error_limbs  n_same_soma_mu n_multi_soma_t n_somas     n_limbs     n_branches     max_limb_n_bra skeletal_lengt max_limb_skele median_branch_ width_median   width_no_spine width_90_perc  width_no_spine n_spines     spine_density  spines_per_bra skeletal_lengt n_spine_eligib spine_density_ spines_per_bra total_spine_vo spine_volume_m spine_volume_d spine_volume_d spine_volume_p axon_angle_max spine_density_ n_branches_pro skeletal_lengt n_branches_in_ skeletal_lengt run_time
# +------------+ +------------+ +------------+ +-------+ +------------+ +-------+ +------------+ +------------+ +------------+ +------------+ +------------+ +---------+ +-----------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +--------+ +--------+ +--------+ +------------+ +------------+ +------------+ +---------+ +------------+ +------------+ +------------+ +------------+ +---------+ +---------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +----------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +-----------+
# 86469113488480 0              0.25           30.00     5              0         0              3              1              excitatory     densely_spined 1           1             3327.337549415 2772.986575437 518848         462.46         1              1              299167     123231     22982      39233          954            876685         1747230     0              0              0              0              1           7           195            99             9143331.384164 4233959.360076 34832.312      304.052        260.105        510.543        440.698        3897         0.000426212267 19.98461538461 9140909.127    192            0.000426325209 20.297         920458171300.3 131000139.0383 100669.8907243 100696.5673230 4794052975.522 154.4108223529 0.000777580686 0              4022840.125511 110            5264763.784007 1376.1898
# 86469113501263 0              0.25           30.00     5              0         0              3              1              excitatory     densely_spined 1           1             11.55880989548 29.67110264630 559081         888.74         1              1              322325     175940     22800      42146          900            554390         1104900     0              0              0              0              1           8           85             41             5390194.133744 2787792.454674 44024.251      310.871        276.197        558.628        546.952        2438         0.000452302818 28.68235294117 5390194.134    85             0.000452302818 28.682         443800070079.9 116890512.5841 82334.70985796 82334.70985406 5221177295.058 158.8443827233 0.000512475982 0              4248218.537386 71             4430071.090994 328.3497
# 86469113511796 0              0.25           30.00     5              0         0              3              1              excitatory     densely_spined 0           0             0.0            0.0            588839         1177.04        1              1              331996     190945     19294      44325          1046           632108         1259329     0              0              0              0              1           6           69             21             5374689.543522 1845895.265396 53688.299      356.265        312.756        606.453        556.154        2468         0.000459189313 35.76811594202 5374689.544    69             0.000459189313 35.768         405340748173.4 108674307.2974 75416.58823103 75416.58822433 5874503596.716 0.0            0.000513841200 0              4062262.483573 54             4234159.256437 394.9745
# 86469113511798 0              0.25           30.00     5              0         0              3              1              excitatory     densely_spined 1           1             3746.148396775 3140.158909901 493968         982.45         1              1              292442     160501     25727      36049          943            601368         1196341     0              0              0              0              1           8           116            66             7179795.254740 3746148.396775 39725.477      105.836        105.836        487.281        459.249        2085         0.000290398253 17.97413793103 7178751.798    115            0.000290440463 18.13          482638633860.4 168711227.1700 67221.78234006 67231.55326179 4196857685.742 169.3725365108 0.000677951782 0              2911919.719083 65             4394316.529618 761.8727
# 86469113516231 0              0.25           30.00     5              0         0              3              1              excitatory     densely_spined 1           1             1745.817532152 1470.895437410 230236         741.77         1              1              162929     184507     19824      28264          539            336465         671249      0              0              0              0              1           6           95             63             4037056.897898 1745817.532152 19434.307      95.982         95.982         420.031        352.06         1420         0.000351741388 14.94736842105 4037056.898    95             0.000351741388 14.947         317677411011.2 147259744.1774 78690.34770766 78690.34770568 3343972747.487 140.3099427606 0.000639949506 0              2168314.871789 54             3159406.434049 259.5823
# 86469113527220 0              0.25           30.00     5              0         0              3              1              excitatory     densely_spined 1           1             2657.163655750 2294.517077929 487512         491.09         1              1              287075     125100     23875      27377          733            463522         923815      0              0              0              0              1           8           126            71             5899796.247482 2657163.655750 34593.443      142.621        142.621        434.865        364.047        1845         0.000312722664 14.64285714285 5899796.247    126            0.000312722664 14.643         414739320104.8 148736965.5450 70297.22768507 70297.22769082 3291581905.593 161.7574645548 0.000663442717 0              1920848.361154 50             3086718.241527 613.9513
# 86469113527826 0              0.25           30.00     5              0         0              3              1              excitatory     densely_spined 0           0             0.0            0.0            269380         1041.45        1              1              167768     216368     21534      34556          760            301141         600721      0              0              0              0              1           5           33             12             2754482.678599 1274407.759590 72477.061      333.071        299.874        560.669        555.092        1206         0.000437831760 36.54545454545 2754482.679    33             0.000437831760 36.545         266127911227.4 141211658.4525 96616.29506516 96616.29505111 8064482158.407 0.0            0.000447529985 0              2690914.317332 38             2866063.043959 111.2081
# 86469113533458 0              0.25           30.00     5              0         0              3              1              excitatory     densely_spined 1           1             1239.660532020 1491.606141583 562808         1797.35        1              1              327412     192561     21799      64273          1449           1067660        2131480     0              0              0              0              1           11          137            60             8618528.849886 3531144.112486 37566.956      299.445        281.797        671.478        671.454        2161         0.000250738848 15.77372262773 8618528.85     137            0.000250738848 15.774         450512820624.5 114570257.6383 52272.58949541 52272.58949472 3288414749.084 164.3535207233 0.000314165724 0              4989586.438215 78             5590780.560574 1093.1533
# 86469113533784 0              0.25           30.00     5              0         0              3              1              excitatory     densely_spined 1           1             3488.706305234 3420.577726678 588983         1418.44        1              1              341551     190657     20324      58560          1241           878799         1751321     0              0              0              0              1           10          178            72             9441943.415161 3488706.305234 32417.12       235.813        230.971        493.055        468.964        2465         0.000261069134 13.84831460674 9441943.415    178            0.000261069134 13.848         564599305512.1 112605201.2433 59796.93805467 59796.93805569 3171906210.742 160.5444273333 0.000447309177 0              4389827.606308 101            5992429.876167 1082.5173
# 86469113534536 0              0.25           30.00     5              0         0              3              1              excitatory     densely_spined 0           0             0.0            0.0            493569         334.23         1              1              294312     160512     23099      26273          529            306213         627611      0              0              0              0              1           4           45             23             2548649.647343 1381447.208290 49638.094      324.208        279.366        554.839        536.734        1392         0.000546171578 30.93333333333 2548649.647    45             0.000546171578 30.933         357219259889.2 170641599.0141 140160.2061160 140160.2061349 7938205775.317 0.0            0.000604430599 0              2185210.731969 39             2283562.593236 101.1189
# 86469113536703 0              0.25           30.00     5              0         0              3              1              excitatory     densely_spined 1           1             1876.805089151 1383.143292199 525758         647.86         1              1              299855     170676     26707      53861          1206           566564         1125773     0              0              0              0              1           8           115            41             6318820.701689 1917191.532142 41143.051      296.926        264.389        600.987        555.103        2038         0.000322528537 17.72173913043 6318600.107    114            0.000322539797 17.877         314616635941.6 115234550.2375 49790.40406344 49792.14234385 2759795052.119 169.0519429267 0.000535676535 0              3683867.728823 77             4364561.337459 515.6435
# 86469113536705 0              0.25           30.00     5              0         0              3              1              excitatory     densely_spined 1           1             2151.726865835 2245.047942766 335175         1268.5         1              1              198919     188690     19789      40337          686            424844         845937      0              0              0              0              1           8           94             45             5279575.526688 2151726.865835 37106.292      162.832        162.306        434.038        414.262        1277         0.000241875505 13.58510638297 5271987.164    93             0.000242223655 13.731         329584560591.8 129879033.2706 62426.33691397 62516.19177724 3543920006.363 176.3193507866 0.000442619268 0              2784544.804003 72             3886953.813293 800.592
#    ...
#  (Total: 57)

# %%
du.proofreading_neurons_table() & dict(segment_id=864691135337845734)
# Out:
# *segment_id    *decimation_ve *decimation_ra *ver      *process_versi *index    *split_index   *proof_version multiplicity   cell_type_pred spine_category n_axons     n_apicals     axon_length    axon_area      nucleus_id     nuclei_distanc n_nuclei_in_ra n_nuclei_in_bb soma_x     soma_y     soma_z     max_soma_n_fac max_soma_volum n_vertices     n_faces     n_not_processe n_error_limbs  n_same_soma_mu n_multi_soma_t n_somas     n_limbs     n_branches     max_limb_n_bra skeletal_lengt max_limb_skele median_branch_ width_median   width_no_spine width_90_perc  width_no_spine n_spines     spine_density  spines_per_bra skeletal_lengt n_spine_eligib spine_density_ spines_per_bra total_spine_vo spine_volume_m spine_volume_d spine_volume_d spine_volume_p axon_angle_max spine_density_ n_branches_pro skeletal_lengt n_branches_in_ skeletal_lengt run_time
# +------------+ +------------+ +------------+ +-------+ +------------+ +-------+ +------------+ +------------+ +------------+ +------------+ +------------+ +---------+ +-----------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +--------+ +--------+ +--------+ +------------+ +------------+ +------------+ +---------+ +------------+ +------------+ +------------+ +------------+ +---------+ +---------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +----------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +-----------+
# 86469113533784 0              0.25           30.00     5              0         0              3              1              excitatory     densely_spined 1           1             3488.706305234 3420.577726678 588983         1418.44        1              1              341551     190657     20324      58560          1241           878799         1751321     0              0              0              0              1           10          178            72             9441943.415161 3488706.305234 32417.12       235.813        230.971        493.055        468.964        2465         0.000261069134 13.84831460674 9441943.415    178            0.000261069134 13.848         564599305512.1 112605201.2433 59796.93805467 59796.93805569 3171906210.742 160.5444273333 0.000447309177 0              4389827.606308 101            5992429.876167 1082.5173
#  (Total: 1)

# %%
curr_segment_id = 864691135337845734
curr_split_index = 0

print(f"segment_id = {curr_segment_id}, split_index = {curr_split_index}")
du.plot_proofread_neuron(segment_id=curr_segment_id,
                        split_index = curr_split_index,
                        plot_proofreading_synapses=False,
                         plot_error_synapses=True,
                        plot_errored_faces=True)
# Out:
# segment_id = 864691135337845734, split_index = 0
# /usr/local/lib/python3.6/dist-packages/traittypes/traittypes.py:101: UserWarning: Given trait value dtype "float64" does not match required type "float64". A coerced copy has been created.
#   np.dtype(self.dtype).name))
# VBox(children=(Figure(camera=PerspectiveCamera(fov=46.0, position=(0.0, 0.0, 2.0), projectionMatrix=(1.0, 0.0,…
