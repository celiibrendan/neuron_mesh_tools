# %%
# %load_ext autoreload
# %autoreload 2

# %%
from os import sys
sys.path.append("/meshAfterParty/meshAfterParty/")
import datajoint as dj
import datajoint_utils as du

minnie,schema = du.configure_minnie_vm()
m65mat = du.m65mat
# Out:
# INFO - 2021-05-04 20:17:48,333 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-05-04 20:17:48,335 - settings - Setting database.user to celiib
# INFO - 2021-05-04 20:17:48,336 - settings - Setting database.password to newceliipass
# INFO - 2021-05-04 20:17:48,348 - settings - Setting stores to {'minnie65': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65', 'stage': '/mnt/dj-stor01/platinum/minnie65'}, 'meshes': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/meshes', 'stage': '/mnt/dj-stor01/platinum/minnie65/02/meshes'}, 'decimated_meshes': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/decimated_meshes', 'stage': '/mnt/dj-stor01/platinum/minnie65/02/decimated_meshes'}, 'skeletons': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/skeletons'}}
# INFO - 2021-05-04 20:17:48,349 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-05-04 20:17:48,363 - connection - Connected celiib@at-database.ad.bcm.edu:3306
# Connecting celiib@at-database.ad.bcm.edu:3306
# INFO - 2021-05-04 20:17:48,754 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-05-04 20:17:48,758 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-05-04 20:17:48,759 - settings - Setting database.user to celiib
# INFO - 2021-05-04 20:17:48,760 - settings - Setting database.password to newceliipass
# INFO - 2021-05-04 20:17:48,760 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-05-04 20:17:48,761 - settings - Setting database.user to celiib
# INFO - 2021-05-04 20:17:48,762 - settings - Setting database.password to newceliipass
# INFO - 2021-05-04 20:17:48,765 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-05-04 20:17:49,194 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-05-04 20:17:49,233 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-05-04 20:17:49,234 - settings - Setting database.user to celiib
# INFO - 2021-05-04 20:17:49,235 - settings - Setting database.password to newceliipass
# INFO - 2021-05-04 20:17:49,237 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-05-04 20:17:49,688 - settings - Setting enable_python_native_blobs to True

# %%
import allen_utils as alu
from annotationframeworkclient import FrameworkClient
client = alu.configure_client()

# %% [markdown]
# # Pulling Down the Table with the current proof status

# %%
"""
The proofread segments were not stored anywhere in the 
database but instead were on the spreadsheet 
szi-chieh shared with  me:

https://docs.google.com/spreadsheets/d/1lbLtQegeG7UPzGOmYE-lliPqTBldC9BP-JSzrWi8Ybo/edit?pli=1#gid=0

"""
# Out:
# '\nThe proofread segments were not stored anywhere in the \ndatabase but instead were on the spreadsheet \nszi-chieh shared with  me:\n\nhttps://docs.google.com/spreadsheets/d/1lbLtQegeG7UPzGOmYE-lliPqTBldC9BP-JSzrWi8Ybo/edit?pli=1#gid=0\n\n'

# %%
man_proof_df = alu.manual_proof_csv_to_annotated_df(csv_path='./Minnie65 core proofreading_5_3.csv',
                                    partial_strategy_idx_start = 83,
                                    partial_strategy_idx_end = 159)
man_proof_df
# Out:
# /meshAfterParty/meshAfterParty/allen_utils.py:113: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   proof_pd.iloc[partial_strategy_idx_start+1:partial_strategy_idx_end]["extension_type"]  = "partial"
#      Nucleus ID Finished_Den Finished_Ax extension_type
# 1      296726.0         True        TRUE           full
# 2      294545.0         True        TRUE           full
# 4      225498.0         True        TRUE           full
# 5      335175.0         True        TRUE           full
# 6      258307.0         True        TRUE           full
# ..          ...          ...         ...            ...
# 156    580774.0         True        TRUE        partial
# 158    582091.0         True        TRUE        partial
# 161    259167.0         True        TRUE           full
# 164    189149.0         True        TRUE           full
# 165    223037.0         True        TRUE           full
#
# [141 rows x 4 columns]

# %%
man_proof_nuc_ids = man_proof_df["Nucleus ID"].to_numpy()
# Out:
# array([296726., 294545., 225498., 335175., 258307., 271518., 269380.,
#        331945., 300763., 230236., 264870., 327859., 262773., 330079.,
#        301095., 301189., 330326., 269247., 332199., 236197., 559381.,
#        533187., 564808., 489675., 493419., 525758., 493968., 518898.,
#        556823., 531202., 522656., 518848., 487512., 460053., 557121.,
#        557030., 525498., 559081., 460391., 493885., 493806., 520364.,
#        525405., 588983., 560732., 588839., 560217., 560109., 562808.,
#        582129., 553325., 582056., 554921., 610498., 554741., 583848.,
#        583961., 582210., 560530., 585723., 558709., 526226., 554200.,
#        518853., 558684., 516758., 517056., 554833., 581967., 524491.,
#        587426., 616159., 553283., 554891., 580826., 612143., 612352.,
#        518623., 520027., 553321., 553407., 580988., 583891., 516621.,
#        518224., 580948., 612266., 518004., 520182., 581998., 583729.,
#        583739., 551802., 553339., 610396., 610607., 610403., 610535.,
#        582313., 582409., 553469., 582468., 584004., 583792., 608213.,
#        608166., 582390., 583741., 583659., 582011., 582388., 553360.,
#        519746., 553585., 518752., 518134., 582353., 554775., 518632.,
#        554734., 610615., 582444., 553556., 581988., 518312., 582414.,
#        553589., 553216., 610434., 555010., 582412., 580905., 516988.,
#        582294., 517993., 582471., 580774., 582091., 259167., 189149.,
#        223037.])

# %% [markdown]
# # Want to now relate these Nucleus Ids to Segment IDs

# %%
nuc_table = du.configure_nucleus_table(version = 82)
man_proof_info = (nuc_table & [dict(nucleus_id=k) for k in man_proof_nuc_ids]).proj("nucleus_id","segment_id").fetch(as_dict=True)
man_proof_info_df = pd.DataFrame.from_dict(man_proof_info)
man_proof_info_df
# Out:
#        ver  nucleus_id          segment_id
# 0    82.00      189149  864691135855890478
# 1    82.00      223037  864691135383094251
# 2    82.00      225498  864691135753932237
# 3    82.00      230236  864691135609687047
# 4    82.00      236197  864691136903144370
# ..     ...         ...                 ...
# 136  82.00      610615  864691135367284729
# 137  82.00      612143  864691135341198789
# 138  82.00      612266  864691135739733140
# 139  82.00      612352  864691136194400332
# 140  82.00      616159  864691135724393131
#
# [141 rows x 3 columns]

# %%
du.m65mat.ProofreadSynapse()
# Out:
# *ver     *synapse_id    *presyn        *postsyn       synapse_x     synapse_y     synapse_z     synapse_size   pre_is_core    post_is_core
# +------+ +------------+ +------------+ +------------+ +-----------+ +-----------+ +-----------+ +------------+ +------------+ +------------+
# 0.20     15135782       86469113608413 86469113461996 87605         207477        16965         3540           1              0
# 0.20     15136246       86469113608413 86469113399286 88307         207482        16970         21272          1              0
# 0.20     15186912       86469113690314 86469113524725 85481         212842        17434         1056           1              0
# 0.20     15187631       86469113690314 86469113355379 86374         213590        17445         4972           1              0
# 0.20     15187716       86469113690314 86469113524725 86472         213900        17444         6192           1              0
# 0.20     15187793       86469113690314 86469113391357 86577         213842        17450         1516           1              0
# 0.20     15187993       86469113690314 86469113460198 86866         214426        17477         3984           1              0
# 0.20     15188521       86469113690314 86469113596887 87518         215142        17463         2860           1              0
# 0.20     15265029       86469113690314 86469113435483 87568         216222        17506         5484           1              0
# 0.20     18916977       86469113690314 86469113692277 92049         218005        17427         12428          1              0
# 0.20     19008522       86469113608413 86469113629244 91646         207836        17206         15936          1              0
# 0.20     19008980       86469113608413 86469113629244 92161         207789        17220         30692          1              0
#    ...
#  (Total: 17051198)

# %%
du.m65mat.ProofreadNucSynInfo() & {'ver': 82}
# Out:
# *ver      *synapse_id    *presyn        *postsyn       *presyn_nucleu *postsyn_nucle pre_is_core    post_is_core   n_presyn_nuc   n_postsyn_nuc
# +-------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+
# 82.00     4307820        86469113546246 86469113622695 269247         126865         1              0              1              1
# 82.00     4308077        86469113546246 86469113594113 269247         81902          1              0              1              1
# 82.00     6746551        86469113690322 86469113643664 560530         30093          1              0              1              1
# 82.00     8356748        86469113597463 86469113592632 269380         84610          1              0              1              1
# 82.00     8356804        86469113597463 86469113546226 269380         82104          1              0              1              1
# 82.00     8438419        86469113546246 86469113533768 269247         126728         1              0              1              1
# 82.00     8492690        86469113546246 86469113561414 269247         38713          1              0              1              1
# 82.00     9764833        86469113690322 86469113572440 560530         67767          1              0              1              1
# 82.00     9766086        86469113508194 86469113549765 553589         30059          1              0              1              1
# 82.00     9767120        86469113508194 86469113511313 553589         73994          1              0              1              1
# 82.00     10122288       86469113690322 86469113549766 560530         153038         1              0              1              1
# 82.00     10538627       86469113690322 86469113511313 560530         73994          1              0              1              1
#    ...
#  (Total: 229439)

# %%
m65,_ = du.configure_minnie_vm()
# Out:
# INFO - 2021-05-04 23:07:23,806 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-05-04 23:07:23,808 - settings - Setting database.user to celiib
# INFO - 2021-05-04 23:07:23,809 - settings - Setting database.password to newceliipass
# INFO - 2021-05-04 23:07:23,820 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-05-04 23:07:24,358 - settings - Setting enable_python_native_blobs to True

# %%
alu.segment_id_to_pre_post_syn_neuroglancer(segment_id)
# Out:
# <a href="https://neuromancer-seung-import.appspot.com/#!%7B%22jsonStateServer%22:%22https://globalv1.daf-apis.com/nglstate/api/v1/post%22,%22navigation%22:%7B%22pose%22:%7B%22position%22:%7B%22voxelSize%22:%5B4.0,4.0,40.0%5D,%22voxelCoordinates%22:%5B127591.0,114043.0,23192.0%5D%7D%7D,%22zoomFactor%22:2.0%7D,%22showSlices%22:false,%22layout%22:%22xy-3d%22,%22perspectiveZoom%22:2000.0,%22layers%22:%5B%7B%22type%22:%22image%22,%22source%22:%22precomputed://https://seungdata.princeton.edu/minnie65-phase3-em/aligned/v1%22,%22name%22:%22img%22,%22shader%22:%22#uicontrol%20float%20black%20slider(min=0,%20max=1,%20default=0.35)%5Cn#uicontrol%20float%20white%20slider(min=0,%20max=1,%20default=0.65)%5Cnfloat%20rescale(float%20value)%20%7B%5Cn%20%20return%20(value%20-%20black)%20/%20(white%20-%20black);%5Cn%7D%5Cnvoid%20main()%20%7B%5Cn%20%20float%20val%20=%20toNormalized(getDataValue());%5Cn%20%20if%20(val%20%3C%20black)%20%7B%5Cn%20%20%20%20emitRGB(vec3(0,0,0));%5Cn%20%20%7D%20else%20if%20(val%20%3E%20white)%20%7B%5Cn%20%20%20%20emitRGB(vec3(1.0,%201.0,%201.0));%5Cn%20%20%7D%20else%20%7B%5Cn%20%20%20%20emitGrayscale(rescale(val));%5Cn%20%20%7D%5Cn%7D%5Cn%22%7D,%7B%22type%22:%22segmentation_with_graph%22,%22source%22:%22graphene://https://minnie.microns-daf.com/segmentation/table/minnie3_v1%22,%22name%22:%22seg%22,%22segments%22:%5B%22864691135855890478%22%5D,%22segmentColors%22:%7B%7D,%22objectAlpha%22:1.0%7D,%7B%22type%22:%22annotation%22,%22linkedSegmentationLayer%22:%22seg%22,%22filterBySegmentation%22:false,%22bracketShortcutsShowSegmentation%22:true,%22annotationSelectionShowsSegmentation%22:true,%22annotationColor%22:%22#ffff00%22,%22name%22:%22presyn%22,%22annotationTags%22:%5B%7B%22id%22:1,%22label%22:%22valid%22%7D,%7B%22id%22:2,%22label%22:%22not_valid%22%7D,%7B%22id%22:3,%22label%22:%22proof%22%7D%5D,%22annotations%22:%5B%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B169618.0,136642.0,26513.0%5D,%22id%22:%22819b62a84aaf908fe9f7eda9cfe6b609032f5738%22,%22segments%22:%5B%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B193530.0,188056.0,24320.0%5D,%22id%22:%22ef63421c5c1458616c62c13974625c56e62159a4%22,%22segments%22:%5B%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B195310.0,209256.0,24757.0%5D,%22id%22:%229a34e79b814f195ee58d3ae78926b13d8885e3f0%22,%22segments%22:%5B%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B202855.0,183705.0,16364.0%5D,%22id%22:%22ff57f5b160ec92e4b9583865c50a43387250af41%22,%22segments%22:%5B%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B150178.0,215484.0,21145.0%5D,%22id%22:%22d555bba8516e74345ae1c468a5218453d5145cfd%22,%22segments%22:%5B%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B154501.0,104014.0,21865.0%5D,%22id%22:%222839d5820c22b008f0ed18277c3beb837cbad2fd%22,%22segments%22:%5B%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B140974.0,99448.0,24302.0%5D,%22id%22:%224bd7967d6deac0e4fe60a1cf15708359864a98b4%22,%22segments%22:%5B%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B141518.0,142856.0,23717.0%5D,%22id%22:%22613b219ddf71fa4818c17b9c421a9d2058649b37%22,%22segments%22:%5B%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B125546.0,201470.0,22514.0%5D,%22id%22:%22c782bf04b8e1c1e7e5a0c86b50736fabc7dac1e8%22,%22segments%22:%5B%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B149466.0,131392.0,25275.0%5D,%22id%22:%222dfd8eaf69cf607db3f0aa242b109aef2c8dc145%22,%22segments%22:%5B%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B144616.0,149156.0,21521.0%5D,%22id%22:%22397d9183b1afee1f8685ca8e86c8cbc291bc6c01%22,%22segments%22:%5B%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B337084.0,113852.0,16894.0%5D,%22id%22:%2201e3972d1ec7bf1b4590a3885716c8682d730f5a%22,%22segments%22:%5B%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B164666.0,118890.0,27477.0%5D,%22 ...

# %%
segment_id = 864691135855890478
import pandas_utils as pu
df_pre = client.materialize.query_table('synapses_pni_2',
                                           filter_in_dict={'pre_pt_root_id':[segment_id]})
df_post = client.materialize.query_table('synapses_pni_2',
                                           filter_in_dict={'post_pt_root_id':[segment_id]})
df_pre_post = pu.concat([df_pre,df_post])
df_pre_post
# Out:
#              id valid  pre_pt_supervoxel_id      pre_pt_root_id  \
# 0     145653564     t     88111839669858096  864691135855890478
# 1     189764910     t     91355673581116923  864691135855890478
# 2     186530775     t     91640034842880289  864691135855890478
# 3     201341578     t     92692128891219835  864691135855890478
# 4     113736855     t     85448409519146147  864691135855890478
# ...         ...   ...                   ...                 ...
# 5597   71396129     t     82621565526993596  864691136465949156
# 5598  158510518     t     89371948177832906  864691134028475308
# 5599  109517336     t     85222185337418789  864691134383360261
# 5600  111611015     t     85013896402005785  864691135296768751
# 5601  100756667     t     84728092366657431  864691136313171607
#
#       post_pt_supervoxel_id     post_pt_root_id   size  \
# 0         88111839669860333  864691135465708530   2728
# 1         91426042325297729  864691135385343317  29288
# 2         91640034842880386  864691135341147825   3432
# 3         92692128891211891  864691136907008878   7440
# 4         85448409519142471  864691135604388611    648
# ...                     ...                 ...    ...
# 5597      82621565527001004  864691135855890478  14888
# 5598      89371948177826589  864691135855890478   1768
# 5599      85151816593234382  864691135855890478   2928
# 5600      85013896401999750  864691135855890478  31172
# 5601      84728092366649117  864691135855890478   6996
#
#               pre_pt_position         post_pt_position  \
# 0     [169652, 136662, 26515]  [169620, 136584, 26514]
# 1     [193484, 188040, 24316]  [193570, 188096, 24325]
# 2     [195382, 209228, 24750]  [195294, 209310, 24758]
# 3     [202858, 183650, 16368]  [202836, 183682, 16362]
# 4     [150218, 215452, 21147]  [150178, 215488, 21139]
# ...                       ...                      ...
# 5597  [129722, 125486, 24378]  [129832, 125518, 24384]
# 5598   [178774, 88048, 22417]   [178792, 88032, 22413]
# 5599  [148526, 102946, 23818]  [148444, 103004, 23804]
# 5600  [147106, 123886, 22181]  [147016, 123866, 22181]
# 5601   [144964, 91712, 24223]   [144960, 91708, 24210]
#
#               ctr_pt_position
# 0     [169618, 136642, 26513]
# 1     [193530, 188056, 24320]
# 2     [195310, 209256, 24757]
# 3     [202855, 183705, 16364]
# 4     [150178, 215484, 21145]
# ...                       ...
# 5597  [129792, 125534, 24382]
# 5598   [178771, 88035, 22416]
# 5599  [148502, 102998, 23813]
# 5600  [146973, 123904, 22183]
# 5601   [144996, 91728, 24220]
#
# [6876 rows x 10 columns]

# %%
from nglui import statebuilder
em_source = 'precomputed://https://seungdata.princeton.edu/minnie65-phase3-em/aligned/v1'
seg_source = 'graphene://https://minnie.microns-daf.com/segmentation/table/minnie3_v1'
view_options = {'layout': '3d'}
img = statebuilder.ImageLayerConfig(em_source, contrast_controls=True, black=0.35, white=0.7)
presyn = statebuilder.SegmentationLayerConfig(seg_source, name='presyn', selected_ids_column='presyn', fixed_ids=[segment_id], fixed_id_colors=['blue'])

points = statebuilder.PointMapper('synapse_xyz')
anno_layer = statebuilder.AnnotationLayerConfig(name='synapses',mapping_rules=points, color='white')

# %%
training_seg_id = minnie.AutoProofreadValidationSegmentMap.fetch("segment_id")
np.intersect1d(man_proof_seg_ids,training_seg_id)

# %%
# Out:
# <a href="https://neuromancer-seung-import.appspot.com/#!%7B%22jsonStateServer%22:%22https://globalv1.daf-apis.com/nglstate/api/v1/post%22,%22navigation%22:%7B%22pose%22:%7B%22position%22:%7B%22voxelSize%22:%5B4.0,4.0,40.0%5D,%22voxelCoordinates%22:%5B127591.0,114043.0,23192.0%5D%7D%7D,%22zoomFactor%22:2.0%7D,%22showSlices%22:false,%22layout%22:%22xy-3d%22,%22perspectiveZoom%22:2000.0,%22layers%22:%5B%7B%22type%22:%22image%22,%22source%22:%22precomputed://https://seungdata.princeton.edu/minnie65-phase3-em/aligned/v1%22,%22name%22:%22img%22,%22shader%22:%22#uicontrol%20float%20black%20slider(min=0,%20max=1,%20default=0.35)%5Cn#uicontrol%20float%20white%20slider(min=0,%20max=1,%20default=0.65)%5Cnfloat%20rescale(float%20value)%20%7B%5Cn%20%20return%20(value%20-%20black)%20/%20(white%20-%20black);%5Cn%7D%5Cnvoid%20main()%20%7B%5Cn%20%20float%20val%20=%20toNormalized(getDataValue());%5Cn%20%20if%20(val%20%3C%20black)%20%7B%5Cn%20%20%20%20emitRGB(vec3(0,0,0));%5Cn%20%20%7D%20else%20if%20(val%20%3E%20white)%20%7B%5Cn%20%20%20%20emitRGB(vec3(1.0,%201.0,%201.0));%5Cn%20%20%7D%20else%20%7B%5Cn%20%20%20%20emitGrayscale(rescale(val));%5Cn%20%20%7D%5Cn%7D%5Cn%22%7D,%7B%22type%22:%22segmentation_with_graph%22,%22source%22:%22graphene://https://minnie.microns-daf.com/segmentation/table/minnie3_v1%22,%22name%22:%22seg%22,%22segments%22:%5B%22864691135855890478%22%5D,%22segmentColors%22:%7B%7D,%22objectAlpha%22:1.0%7D,%7B%22type%22:%22annotation%22,%22linkedSegmentationLayer%22:%22seg%22,%22filterBySegmentation%22:false,%22bracketShortcutsShowSegmentation%22:true,%22annotationSelectionShowsSegmentation%22:true,%22annotationColor%22:%22#ffff00%22,%22name%22:%22presyn%22,%22annotationTags%22:%5B%7B%22id%22:1,%22label%22:%22valid%22%7D,%7B%22id%22:2,%22label%22:%22not_valid%22%7D,%7B%22id%22:3,%22label%22:%22proof%22%7D%5D,%22annotations%22:%5B%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B169618.0,136642.0,26513.0%5D,%22id%22:%2201b17c2da4fac829dd0b7b4549333a847310d052%22,%22segments%22:%5B%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B193530.0,188056.0,24320.0%5D,%22id%22:%22feed5fa05731a70b5fb5be9e85819704bd2b4190%22,%22segments%22:%5B%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B195310.0,209256.0,24757.0%5D,%22id%22:%22bec012608e8254f0a11463c588f365fbf0751c87%22,%22segments%22:%5B%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B202855.0,183705.0,16364.0%5D,%22id%22:%224fb51393c814a2b509d9edb9924e22739b4f3a8b%22,%22segments%22:%5B%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B150178.0,215484.0,21145.0%5D,%22id%22:%22bfa31bc1189c2268ca3052bd8042602cb378e38b%22,%22segments%22:%5B%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B154501.0,104014.0,21865.0%5D,%22id%22:%22b49768cfd0b85de55060f50291daa032cc44f75f%22,%22segments%22:%5B%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B140974.0,99448.0,24302.0%5D,%22id%22:%2206c39221fc0c57bd3697bcffd1223c4b7576a42d%22,%22segments%22:%5B%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B141518.0,142856.0,23717.0%5D,%22id%22:%22dd2e84e2875020669b77ab9184a59b433fd3e628%22,%22segments%22:%5B%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B125546.0,201470.0,22514.0%5D,%22id%22:%22fa0fef0c6af168c356d42fd0f284d138df1d2825%22,%22segments%22:%5B%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B149466.0,131392.0,25275.0%5D,%22id%22:%2270d706881bc8a69ce5277aea1f9ebd26f5a728f7%22,%22segments%22:%5B%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B144616.0,149156.0,21521.0%5D,%22id%22:%227e5aaaa3c973c0ef8caf4088393bf3244795fc3e%22,%22segments%22:%5B%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B337084.0,113852.0,16894.0%5D,%22id%22:%2202ea80f177e9873602c4c588883e6e64e0b3de8e%22,%22segments%22:%5B%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B164666.0,118890.0,27477.0%5D,%22 ...

# %% [markdown]
# ## Turning the Segment IDs into the Synapse Spreadsheets

# %%
client.materialize._version

# %%
nuc_df = client.materialize.query_table('nucleus_neuron_svm',
                                       filter_equal_dict={'cell_type':'neuron'},
                                       filter_out_dict={'pt_root_id':[0]})
nuc_df

# %%
ex_1 = nuc_df[nuc_df["pt_root_id"] == 864691136436509342]
ex_1

# %%
aug_nuc_df = alu.aug_nuc_df

# %%
ex_2 = aug_nuc_df[aug_nuc_df["flat_nuc_id"] == 560217]
ex_2

# %%
new_df = pd.merge(ex_1,ex_2,left_on="id",right_on="flat_nuc_id",how='inner')

# %%
overlap[overlap["id"] == 560217]

# %%
overlap = pd.merge(nuc_df, aug_nuc_df, left_on='id', right_on='flat_nuc_id', how='inner')
overlap_df = overlap.query('pt_root_id==root_id')

# %%
x = 864691136436509342
overlap.query(f"pt_root_id=={s}")["root_id"].to_list()

# %% [markdown]
# # New Way to Get Synapses

# %%
"""
Pseudocode: 
Using a segment Id from August
1) get all of the leaves of the segment id (during a current timestamp)
2) Query the synapse table based on those ids to get all of the 
synapse ids
3) Concatenate the synapse ids into one table
"""
import pandas as pd
import networkx_utils as xu

root_id = 864691136134446219
curr_time = datetime.datetime(2020, 8, 1, 1, 0, 0)

DiG = alu.seg_id_to_nx_lineage_graph(root_id=root_id,
                               timestamp_past = curr_time,
                               timestamp_future = None,#curr_time,
                              client=None)

# %%
"""
Get the edges of the graph

"""
import numpy_utils as nu

end_nodes = xu.end_nodes_of_digraph(DiG,verbose = True)
end_nodes_timestamps = xu.get_node_attributes(DiG,"timestamp",node_list=end_nodes)
last_datetime_edited = nu.float_to_datetime(np.max(end_nodes_timestamps))
print(f"last_datetime_edited = {last_datetime_edited}")

# %% [markdown]
# # Turn the end nodes into synapse

# %%
end_nodes

# %%
df_pre = client.materialize.query_table('synapses_pni_2',
                                           filter_in_dict={'pre_pt_root_id':end_nodes})
df_post = client.materialize.query_table('synapses_pni_2',
                                           filter_in_dict={'post_pt_root_id':end_nodes})
df_post

# %%
# Want to

# %%
ann_metadata = client.annotation.get_table_metadata(client.info.get_datastack_info()["synapse_table"])
ann_metadata

# %%
import system_utils as su
ex_df = su.load_object("./Syanpse_dfs/864691134988386682.pkl")
ex_df

# %%
import time
import datetime
import tqdm.notebook as tqdm
def get_input_output_df(aug_seg_id,  n_chunks=50, timestamp=datetime.datetime(2020, 8, 1, 1, 0, 0),
                       verbose = True,):
    st = time.time()
    
    svids=client.chunkedgraph.get_leaves(aug_seg_id)
    chunks = np.array_split(svids,n_chunks)
    #need to break the supervoxels up into chunks to query
    out_syn_dfs=[]
    for chunk in tqdm.tqdm(chunks):
        dft = client.materialize.query_table('synapses_pni_2',
                                           filter_in_dict={'pre_pt_supervoxel_id':chunk})
        out_syn_dfs.append(dft)
    out_syn_df = pd.concat(out_syn_dfs)
    out_syn_df['pre_pt_root_id_Aug']=aug_seg_id
    post_sv_ids=out_syn_df.post_pt_supervoxel_id.values
    post_root_ids_aug = client.chunkedgraph.get_roots(post_sv_ids, timestamp=august_timestamp)
    out_syn_df['post_pt_root_id_Aug']=post_root_ids_aug
    #  now the same for inputs
    in_syn_dfs=[]
    for chunk in tqdm.tqdm(chunks):
        dft = client.materialize.query_table('synapses_pni_2',
                                           filter_in_dict={'post_pt_supervoxel_id':chunk})
        in_syn_dfs.append(dft)
    in_syn_df = pd.concat(in_syn_dfs)
    in_syn_df['post_pt_root_id_Aug']=aug_seg_id
    pre_sv_ids=in_syn_df.pre_pt_supervoxel_id.values
    pre_root_ids_aug = client.chunkedgraph.get_roots(pre_sv_ids, timestamp=timestamp)
    in_syn_df['pre_pt_root_id_Aug']=pre_root_ids_aug
    
    if verbose:
        print(f"Total time for synapse table of segment {aug_seg_id} = {time.time() - st}")
    return pd.concat([out_syn_df, in_syn_df])

# %%
ret_df = get_input_output_df(864691136134446219)

# %%
@schema
class AutoProofreadValidationSegmentExclude(dj.Manual):
    definition="""
    segment_id           : bigint unsigned               # segments that were not finished proofreading
    """
AutoProofreadValidationSegmentExclude.insert((dj.U("segment_id") & (old_rel & [{'nucleus_id': n} for n in exclude])).fetch(as_dict=True),skip_duplicates=True)
AutoProofreadValidationSegmentExclude()

# %% [markdown]
# # Creating the Table with the valid synapses

# %%
minnie.AutoProofreadValidationManualSynapseUpdated

# %%
m65mat.ProofreadSynapse.describe()

# %%
"""
Purpose: To Create a table that has the 
valid synpases for the proofread targets
that can be used to restrict the set determined in the synapse spreadsheet

Pseudocode: 

"""

@schema
class AutoProofreadValidationManualSynapseUpdated(dj.Manual):
    definition="""
    -> m65mat.Materialization
    synapse_id           : bigint unsigned              # synapse index within the segmentation
    presyn               : bigint unsigned              # segment_id of the presynaptic cell. Equivalent to Allen 'pt_root_id'.
    postsyn              : bigint unsigned              # segment_id of the postsynaptic cell. Equivalent to Allen 'pt_root_id'.
    ---
    synapse_x            : int unsigned                 # x coordinate of synapse centroid in EM voxels (x: 4nm, y: 4nm, z: 40nm). From Allen 'ctr_pt_position'.
    synapse_y            : int unsigned                 # y coordinate of centroid in EM voxels (x: 4nm, y: 4nm, z: 40nm). From Allen 'ctr_pt_position'.
    synapse_z            : int unsigned                 # z coordinate of centroid in EM voxels (x: 4nm, y: 4nm, z: 40nm). From Allen 'ctr_pt_position'.
    synapse_size         : int unsigned                 # (EM voxels) scaled by (4x4x40)
    """

# %%
presyn_table = m65mat.ProofreadSynapse & subfinal.proj(presyn='segment_id')
presyn_data = presyn_table.proj("synapse_x","synapse_y","synapse_z","synapse_size").fetch(as_dict=True)
AutoProofreadValidationManualSynapseUpdated.insert(presyn_data,skip_duplicates=True)

# %%
postsyn_table = m65mat.ProofreadSynapse & subfinal.proj(postsyn='segment_id')
postsyn_data = postsyn_table.proj("synapse_x","synapse_y","synapse_z","synapse_size").fetch(as_dict=True)
AutoProofreadValidationManualSynapseUpdated.insert(postsyn_data,skip_duplicates=True)

# %%
minnie.AutoProofreadValidationManualSynapseUpdated()
