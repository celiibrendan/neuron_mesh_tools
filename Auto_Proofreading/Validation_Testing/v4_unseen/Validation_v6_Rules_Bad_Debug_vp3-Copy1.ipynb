# %%
"""
Purpose: To Run the proofreading of neurons in the 
test set and measure the precision and recall of the new rules

Segments to look out for that had no axon
864691135012395766 # one of the split segments files not there (split index = 1)
864691135865584005 #soma soma merger
864691136451113215 #it was an inhibitory neuron (part of split)

"""

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import datajoint as dj
import trimesh
from tqdm.notebook import tqdm
from pathlib import Path

from os import sys
sys.path.append("/meshAfterParty/")
sys.path.append("/meshAfterParty/meshAfterParty")

import datajoint_utils as du
from importlib import reload
# Out:
# INFO - 2021-06-24 22:23:51,648 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-06-24 22:23:51,650 - settings - Setting database.user to celiib
# INFO - 2021-06-24 22:23:51,651 - settings - Setting database.password to newceliipass
# INFO - 2021-06-24 22:23:51,652 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-06-24 22:23:51,652 - settings - Setting database.user to celiib
# INFO - 2021-06-24 22:23:51,653 - settings - Setting database.password to newceliipass
# INFO - 2021-06-24 22:23:51,657 - settings - Setting stores to {'minnie65': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65', 'stage': '/mnt/dj-stor01/platinum/minnie65'}, 'meshes': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/meshes', 'stage': '/mnt/dj-stor01/platinum/minnie65/02/meshes'}, 'decimated_meshes': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/decimated_meshes', 'stage': '/mnt/dj-stor01/platinum/minnie65/02/decimated_meshes'}, 'skeletons': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/skeletons'}}
# INFO - 2021-06-24 22:23:51,658 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-06-24 22:23:51,671 - connection - Connected celiib@at-database.ad.bcm.edu:3306
# Connecting celiib@at-database.ad.bcm.edu:3306
# INFO - 2021-06-24 22:23:52,228 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-06-24 22:23:52,280 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-06-24 22:23:52,282 - settings - Setting database.user to celiib
# INFO - 2021-06-24 22:23:52,283 - settings - Setting database.password to newceliipass
# INFO - 2021-06-24 22:23:52,285 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-06-24 22:23:52,902 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-06-24 22:23:52,964 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-06-24 22:23:52,965 - settings - Setting database.user to celiib
# INFO - 2021-06-24 22:23:52,966 - settings - Setting database.password to newceliipass
# INFO - 2021-06-24 22:23:52,967 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-06-24 22:23:52,968 - settings - Setting database.user to celiib
# INFO - 2021-06-24 22:23:52,969 - settings - Setting database.password to newceliipass
# INFO - 2021-06-24 22:23:52,972 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-06-24 22:23:53,641 - settings - Setting enable_python_native_blobs to True

# %%
#configuring will include the adapters
minnie,schema = du.configure_minnie_vm()
# Out:
# INFO - 2021-06-24 22:23:53,819 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-06-24 22:23:53,820 - settings - Setting database.user to celiib
# INFO - 2021-06-24 22:23:53,821 - settings - Setting database.password to newceliipass
# INFO - 2021-06-24 22:23:53,822 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-06-24 22:23:54,606 - settings - Setting enable_python_native_blobs to True

# %%
import validation_utils as vu
import neuron_visualizations as nviz
import neuron_utils as nru
import proofreading_utils as pru
import time
import system_utils as su

# %% [markdown]
# # Runnig the validation

# %%
"""
Psueodocode: 
1) Pull down the segment ids of the valid neurons

For each neuron
1) Dwonload the neuron object
2) Run the Proofreading
3) Print out the validation plot
4) Save the validation df

"""
# Out:
# '\nPsueodocode: \n1) Pull down the segment ids of the valid neurons\n\nFor each neuron\n1) Dwonload the neuron object\n2) Run the Proofreading\n3) Print out the validation plot\n4) Save the validation df\n\n'

# %%
"""
Pseudocode: 
1) Check if there are multiple somas associated with that segment

"""
# Out:
# '\nPseudocode: \n1) Check if there are multiple somas associated with that segment\n\n'

# %%
axon_segs = dj.U("segment_id") & (minnie.DecompositionAxon() 
                      & minnie.AutoProofreadValidationSegment4() - minnie.AutoProofreadValidationSegmentExclude4() )
axon_segs
# Out:
# *segment_id
# +------------+
#
#  (Total: 0)

# %%
"""
Pseudocode: 
1) Find the coordinates of the nucleus for that new segment
2) Make sure that same number of DecompositionAxon objects as in Decomposition
3) Pick the neuron object that is closest and within a certain range of the nucleus
4) Download the neuron object
5) Run the proofreading
6) Save off the validation df
"""
# Out:
# '\nPseudocode: \n1) Find the coordinates of the nucleus for that new segment\n2) Make sure that same number of DecompositionAxon objects as in Decomposition\n3) Pick the neuron object that is closest and within a certain range of the nucleus\n4) Download the neuron object\n5) Run the proofreading\n6) Save off the validation df\n'

# %%
val_table = minnie.AutoProofreadValidationScore6() * minnie.AutoProofreadValidationSegmentMap4()
val_table
# Out:
# *ver      *nucleus_id    *segment_id    *old_ver    *split_index   decomposit axon_length    validation validation pre_tp     pre_tn     pre_fp     pre_fn     pre_precision  pre_recall     pre_f1         post_tp     post_tn     post_fp     post_fn     post_precision post_recall    post_f1        run_time     old_segment_id finished_dendr finished_axon  extension_type n_somas     n_soma_mergers n_glia     large_splits   notes
# +-------+ +------------+ +------------+ +---------+ +------------+ +--------+ +------------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +------------+ +------------+ +------------+ +---------+ +---------+ +---------+ +---------+ +------------+ +------------+ +------------+ +----------+ +------------+ +------------+ +------------+ +------------+ +---------+ +------------+ +--------+ +------------+ +-------+
# 88.00     189149         86469113585589 0.08        0              =BLOB=     369.8499961914 =BLOB=     =BLOB=     7          160        11         0          0.388888888888 1.0            0.56           5280        7           39          4           0.992667794698 0.999242997728 0.995944543996 530.88       86469113558531 True           True           full           1           0              0          0
# 88.00     223037         86469113622716 0.08        0              =BLOB=     63.37572849023 =BLOB=     =BLOB=     0          450        0          0          nan            nan            nan            1           3416        3853        0           0.000259470679 1.0            0.000518806744 384.12       86469113553812 True           True           full           2           0              0          0
# 88.00     225498         86469113575393 0.08        0              =BLOB=     185.8554437449 =BLOB=     =BLOB=     6          77         0          5          1.0            0.545454545454 0.705882352941 1124        0           0           9           1.0            0.992056487202 0.996012405848 148.89       86469113556465 True           True           full           1           0              0          0
# 88.00     230236         86469113560968 0.08        0              =BLOB=     1401.751678838 =BLOB=     =BLOB=     31         552        9          19         0.775          0.62           0.688888888888 1960        22          1           2           0.999490056093 0.998980632008 0.999235279123 709.59       86469113574856 True           True           full           1           0              0          0
# 88.00     236197         86469113690314 0.08        0              =BLOB=     40.75344701234 =BLOB=     =BLOB=     0          974        0          6          nan            0.0            nan            2750        2333        3           48          0.998910279694 0.982844889206 0.990812466222 574.58       86469113575856 True           True           full           2           0              2          0
# 88.00     258307         86469113529312 0.08        0              =BLOB=     639.4047428112 =BLOB=     =BLOB=     7          342        10         63         0.411764705882 0.1            0.160919540229 2983        7           25          20          0.991688829787 0.993339993339 0.992513724837 401.35       86469113619404 True           True           full           1           0              0          0
# 88.00     262773         86469113602388 0.08        0              =BLOB=     183.4781000715 =BLOB=     =BLOB=     10         47         2          0          0.833333333333 1.0            0.909090909090 724         0           2           10          0.997245179063 0.986376021798 0.991780821917 110.48       86469113523310 True           True           full           1           0              0          0
# 88.00     264870         86469113695166 0.08        0              =BLOB=     1173.283605270 =BLOB=     =BLOB=     29         399        25         3          0.537037037037 0.90625        0.674418604651 2008        26          3           33          0.998508204873 0.983831455169 0.991115498519 506.46       86469113574022 True           True           full           1           0              0          0
# 88.00     269247         86469113558407 0.08        0              =BLOB=     2117.674205483 =BLOB=     =BLOB=     215        10         4          55         0.981735159817 0.796296296296 0.879345603271 805         0           7           66          0.991379310344 0.924225028702 0.956625074272 544.03       86469113610549 True           True           full           1           0              0          0
# 88.00     269380         86469113597463 0.08        0              =BLOB=     444.9136975586 =BLOB=     =BLOB=     28         257        4          10         0.875          0.736842105263 0.799999999999 1863        4           8           3           0.995724211651 0.998392282958 0.997056462402 186.86       86469113498838 True           True           full           1           0              0          0
# 88.00     271518         86469113610876 0.08        0              =BLOB=     319.3665253460 =BLOB=     =BLOB=     7          43         1          0          0.875          1.0            0.933333333333 2030        0           4           1           0.998033431661 0.999507631708 0.998769987699 166.32       86469113633377 True           True           full           1           0              0          0
# 88.00     294545         86469113551742 0.08        0              =BLOB=     1106.206477595 =BLOB=     =BLOB=     56         166        2          66         0.965517241379 0.459016393442 0.622222222222 1465        3           2           0           0.998636673483 1.0            0.999317871759 302.78       86469113577162 True           True           full           1           0              0          0
#    ...
#  (Total: 127)

# %%
bad_presyn_table = (minnie.AutoProofreadValidationScore6() & "pre_fp>20")
bad_presyn_table
# Out:
# *ver      *nucleus_id    *segment_id    *old_ver    *split_index   decomposit axon_length    validation validation pre_tp     pre_tn     pre_fp     pre_fn     pre_precision  pre_recall     pre_f1         post_tp     post_tn     post_fp     post_fn     post_precision post_recall    post_f1        run_time
# +-------+ +------------+ +------------+ +---------+ +------------+ +--------+ +------------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +------------+ +------------+ +------------+ +---------+ +---------+ +---------+ +---------+ +------------+ +------------+ +------------+ +----------+
# 88.00     264870         86469113695166 0.08        0              =BLOB=     1173.283605270 =BLOB=     =BLOB=     29         399        25         3          0.537037037037 0.90625        0.674418604651 2008        26          3           33          0.998508204873 0.983831455169 0.991115498519 506.46
# 88.00     301095         86469113544667 0.08        0              =BLOB=     1038.645742589 =BLOB=     =BLOB=     11         374        27         4          0.289473684210 0.733333333333 0.415094339622 3322        8           6           27          0.998197115384 0.991937891908 0.995057660626 412.56
# 88.00     335175         86469113536705 0.08        0              =BLOB=     1608.821432120 =BLOB=     =BLOB=     12         172        23         0          0.342857142857 1.0            0.510638297872 2216        8           6           25          0.997299729972 0.988844265952 0.993053999551 434.61
# 88.00     493968         86469113511798 0.08        0              =BLOB=     2186.513987649 =BLOB=     =BLOB=     61         605        42         1          0.592233009708 0.983870967741 0.739393939393 3600        2           49          3           0.986571663469 0.999167360532 0.992829564258 596.85
# 88.00     518853         86469113541566 0.08        0              =BLOB=     3396.544149491 =BLOB=     =BLOB=     308        466        43         27         0.877492877492 0.919402985074 0.897959183673 9304        4           3           5           0.999677661974 0.999462885379 0.999570262140 1024.26
# 88.00     554741         86469113576163 0.08        0              =BLOB=     2235.202825470 =BLOB=     =BLOB=     84         231        22         16         0.792452830188 0.84           0.815533980582 2993        2           0           2           1.0            0.999332220367 0.999665998663 675.41
# 88.00     583739         86469113633408 0.08        0              =BLOB=     1340.054723240 =BLOB=     =BLOB=     38         61         27         0          0.584615384615 1.0            0.737864077669 5430        4           2           13          0.999631811487 0.997611611243 0.998620689655 599.69
# 88.00     583848         86469113549774 0.08        0              =BLOB=     3466.004739023 =BLOB=     =BLOB=     87         300        30         30         0.743589743589 0.743589743589 0.743589743589 6886        34          11          88          0.998405103668 0.987381703470 0.992862807295 1140.96
#  (Total: 8)

# %%
bad_presyn_table = (minnie.AutoProofreadValidationScore5() & "pre_fp>100")
bad_postsyn_table_filt =  (bad_postsyn_table * minnie.AutoProofreadValidationSegmentMap4()) & axon_segs.proj(old_segment_id="segment_id")
#bad_postsyn_seg_ids = bad_postsyn_table.fetch("segment_id")
bad_postsyn_table_filt.proj("post_fn")

# %%
bad_postsyn_table = (minnie.AutoProofreadValidationScore5() & "post_fn>200")
bad_postsyn_table_filt =  (bad_postsyn_table * minnie.AutoProofreadValidationSegmentMap4()) & axon_segs.proj(old_segment_id="segment_id")
#bad_postsyn_seg_ids = bad_postsyn_table.fetch("segment_id")
bad_postsyn_table_filt.proj("post_fn")

# %%
import datajoint as dj
dj.config["display.limit"] = 30
bad_presyn_table = (minnie.AutoProofreadValidationScore5() & "pre_fp>10")
bad_presyn_seg_ids = bad_presyn_table.fetch("segment_id")
bad_presyn_table

# %%
# multi_soma_keys = (minnie.AutoProofreadValidationSegmentMap4() & "n_somas>1"
#                       & minnie.DecompositionAxon.proj(old_segment_id="segment_id")
#                   & dict(segment_id = 864691135415710906)).proj().fetch(as_dict=True)
# key = multi_soma_keys[0]
# key

# %%
segment_id = 864691135584074360
segment_id = 864691135517422218
segment_id = 864691136951664863
segment_id = 864691135446675028
segment_id = 864691135367058169
segment_id = 864691135117980637
segment_id = 864691135761634358
segment_id = 864691136334080435
segment_id = 864691135497743635
key = dict(segment_id=segment_id)

# %%
verbose = True

segment_id = key["segment_id"]
if verbose:
    print(f"\n-- Working on neuron {segment_id}---")

segment_map_dict = (minnie.AutoProofreadValidationSegmentMap4() & dict(segment_id=segment_id)).fetch1()

#1) Find the coordinates of the nucleus for that new segment
nucleus_id = segment_map_dict["nucleus_id"]
nuc_center_coords = du.nuclei_id_to_nucleus_centers(nucleus_id)
if verbose:
    print(f"nuc_center_coords = {nuc_center_coords}")

#2) Make sure that same number of DecompositionCellType objects as in Decomposition
old_segment_id = segment_map_dict["old_segment_id"]
if verbose:
    print(f"old_segment_id = {old_segment_id}")

search_key = dict(segment_id=old_segment_id)
n_somas = len(minnie.BaylorSegmentCentroid() & search_key)
n_decomp_axon = len(minnie.DecompositionCellType() & search_key)
if verbose:
    print(f"# of somas = {n_somas} and # of DecompositionCellType = {n_decomp_axon}")


if n_somas != n_decomp_axon:
    raise Exception(f"# of somas = {n_somas} NOT MATCH # of DecompositionCellType = {n_decomp_axon}")

#3) Pick the neuron object that is closest and within a certain range of the nucleus
neuron_objs,split_idxs = du.decomposition_with_spine_recalculation(old_segment_id)
if n_somas > 1:
    """
    Finding the closest soma:
    1) For each neuron object get the mesh center of the soma object
    2) Find the distance of each from the nucleus center
    3) Find the arg min distance and make sure within threshold
    4) Mark the current neuron and the current split index
    """
    nuclei_distance_threshold = 15000

    soma_center_coords = [k["S0"].mesh_center for k in neuron_objs]
    soma_distances = [np.linalg.norm(k-nuc_center_coords) for k in soma_center_coords]
    min_dist_arg = np.argmin(soma_distances)
    min_dist = soma_distances[min_dist_arg]

    if verbose:
        print(f"soma_distances = {soma_distances}")
        print(f"min_dist_arg = {min_dist_arg}, with min distance = {min_dist}")

    if min_dist > nuclei_distance_threshold:
        raise Exception(f"min_dist ({min_dist}) larger than nuclei_distance_threshold ({nuclei_distance_threshold})")

    neuron_obj = neuron_objs[min_dist_arg]
    split_index = split_idxs[min_dist_arg]

    if verbose:
        print(f"Winning split_index = {split_index}")
else:
    split_index = split_idxs[0]
    neuron_obj = neuron_objs[0]
# Out:
# -- Working on neuron 864691135497743635---
# nuc_center_coords = [1329920  547072  785520]
# old_segment_id = 864691136311791677
# # of somas = 1 and # of DecompositionCellType = 1
# **Using table __decomposition_cell_type for table_to_neuron_objs**
# Decompressing Neuron in minimal output mode...please wait
# Number of Neurons found = 1

# %%
(filt_neuron,
             return_synapse_df_revised,
             return_synapse_df_errors,
            return_validation_df_revised,
            return_validation_df_extension) =  vu.filtered_neuron_score(neuron_obj = neuron_obj,   
                                filter_list = pru.v6_exc_filters(),
                                #filter_list = [pru.exc_high_degree_branching_filter_v6],
                                plot_limb_branch_filter_with_disconnect_effect = False,
                                verbose = True,
                                plot_score=False,
                                nucleus_id = nucleus_id,
                                return_synapse_df_errors=True,
                                return_validation_df_extension = True,                                        
                                split_index=split_index)
# Out:
# *****Using v6 Filters!!!
#
#
#
# --- Working on filter 0:
# function = axon_on_dendrite_merges
# function __name__ = filter_away_axon_on_dendrite_merges
# function arguments = {'use_pre_existing_axon_labels': True}
#
#
# Recieved another instance of Neuron class in init -- so just copying data
# Recieved another instance of Neuron class in init -- so just copying data
# Recieved another instance of Neuron class in init -- so just copying data
# Recieved another instance of Neuron class in init -- so just copying data
# Recieved another instance of Neuron class in init -- so just copying data
# Recieved another instance of Neuron class in init -- so just copying data
# Recieved another instance of Neuron class in init -- so just copying data
#
# --- Working on filter 1:
# function = high_degree_branching
# function __name__ = filter_away_high_degree_branching
# function arguments = {}
#
#
# Recieved another instance of Neuron class in init -- so just copying data
#
#
#  ----- Working on limb L1-------
#
#
#  ----- Working on branch 0/390: 0--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 1/390: 1--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 2/390: 2--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 3/390: 3--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 4/390: 4--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 5/390: 5--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 6/390: 6--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 7/390: 7--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 8/390: 8--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 9/390: 9--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 10/390: 10--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 11/390: 11--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 12/390: 12--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 13/390: 13--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 14/390: 14--------
# ***Branch being considered after filters = 14***
# winning_downstream = 12,error_downstream = [13 16 18]
#
#
#  ----- Working on branch 15/390: 15--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 16/390: 16--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 17/390: 17--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 18/390: 18--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 19/390: 19--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 20/390: 20--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 21/390: 21--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 22/390: 22--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 23/390: 23--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 24/390: 24--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 25/390: 25--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 26/390: 26--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 27/390: 27--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 28/390: 28--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 29/390: 29--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 30/390: 30--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 31/390: 31--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 32/390: 32--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 33/390: 33--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 34/390: 34--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 35/390: 35--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 36/390: 36--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 37/390: 37--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 38/390: 38--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 39/390: 39--------
# ***Branch being considered after filters = 39***
# winning_downstream = None,error_downstream = [34 46 50]
#
#
#  ----- Working on branch 40/390: 40--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 41/390: 41--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 42/390: 42--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 43/390: 43--------
# ***Branch being considered after filters = 43***
# winning_downstream = None,error_downstream = [45 47 54]
#
#
#  ----- Working on branch 44/390: 44--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 45/390: 45--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch 46/390: 46--------
# winning_downstream = None,error_downstream = []
#
#
#  ----- Working on branch

#
#
# Recieved another instance of Neuron class in init -- so just copying data
# limb_branch_dict_to_cancel = {}
#
# --- Working on filter 4:
# function = width_jump_up_dendrite
# function __name__ = filter_away_width_jump_up_dendrite
# function arguments = {}
#
#
# Recieved another instance of Neuron class in init -- so just copying data
# limb_branch_dict_to_cancel = {}
#
# --- Working on filter 5:
# function = width_jump_up_axon
# function __name__ = filter_away_width_jump_up_axon
# function arguments = {}
#
#
# Recieved another instance of Neuron class in init -- so just copying data
# limb_branch_dict_to_cancel = {}
#
# --- Working on filter 6:
# function = double_back_dendrite
# function __name__ = filter_away_double_back_dendrite
# function arguments = {}
#
#
# Recieved another instance of Neuron class in init -- so just copying data
# limb_branch_dict_to_cancel = {'L0': array([47])}
# Recieved another instance of Neuron class in init -- so just copying data
#
# --- Working on filter 7:
# function = double_back_axon_thin
# function __name__ = filter_away_double_back_axon_thin
# function arguments = {}
#
#
# Recieved another instance of Neuron class in init -- so just copying data
# limb_branch_dict_to_cancel = {'L1': array([32, 52])}
# Recieved another instance of Neuron class in init -- so just copying data
#
# --- Working on filter 8:
# function = double_back_axon_thick
# function __name__ = filter_away_double_back_axon_thick
# function arguments = {}
#
#
# Recieved another instance of Neuron class in init -- so just copying data
# limb_branch_dict_to_cancel = {}
#
# --- Working on filter 9:
# function = axon_fork_divergence
# function __name__ = filter_away_small_axon_fork_divergence
# function arguments = {'divergence_threshold_mean': 165}
#
#
# Recieved another instance of Neuron class in init -- so just copying data
# limb_branch_dict_to_cancel = {}
#
#
#
#  ---- Total time for applying filter: 457.55654311180115 -----
#
# --- Finished Part 1: Filtering Neuron -----
# ---Step 1: Computing synapse_dict---
# # of beginning_direct_connections = 7466
# # of presyn: 447
# # of postsyn: 7019
#
# ---Step 2: Computing mesh_label_dict---
# -- Working on presyn--
# Using original_mesh_method
# # of distance_errored_syn_idx = 0
# # of mesh_errored_syn_idx = 296
# # of valid_syn_idx = 151
# -- Working on postsyn--
# Using original_mesh_method
# # of distance_errored_syn_idx = 1
# # of mesh_errored_syn_idx = 121
# # of valid_syn_idx = 6897
#
# ---Step 4: add_error_synapses_to_neuron_obj---
# Working on error_type = distance_errored
# Working on error_type = mesh_errored
# Total time for valid synapse objects = 0.014737367630004883
#
# --- Limb L0 soma calculation time = 0.681
#
# --- Limb L1 soma calculation time = 4.183
#
# --- Limb L2 soma calculation time = 0.284
#
# --- Limb L3 soma calculation time = 0.193
#
# --- Limb L4 soma calculation time = 0.143
#
# --- Limb L5 soma calculation time = 0.05
#
# --- Limb L6 soma calculation time = 0.04
#
# --- Limb L7 soma calculation time = 0.057
# Putting Soma Placeholders
#
# --- Soma 0 soma calculation time = 0.0
# Putting Error Placeholders
#
# --- Error soma calculation time = 0.086
# Total soma distance calculation time = 5.719691038131714
# Time for 7014 synapse entries = 0.0662083625793457
# Time for 452 synapse entries = 0.002717256546020508
# # of synapses in query = 34
# # of total_error_synapse_ids = 452
# set_presyns_on_dendrite_as_errors to default of True
# presyn_error = [391727091 385259489 405321048 382440628 396107836 406887042 419447925
#  430235535 430235801 430235948 430236474 430237013 430237653 430238283
#  430238355 437584861 390161903 426556808 433108823 391664972 425100864
#  427500044 434190548 434192853 434192933 434193019 435057303 419971073
#  433073920 433313639 437748169 439631423 439631670 430014784]
#
# --- Finished Part 2: Filtering Synapses -----
# Synapsse Results:
# Total Number of Synapses = 7466
# n_valid_syn_ids_presyn = 117
# n_errored_syn_ids_presyn = 330
# n_valid_syn_ids_postsyn = 6897
# n_errored_syn_ids_postsyn = 122
# Synapsse Results:
# Total Number of Synapses = 7466
# n_valid_syn_ids_presyn = 117
# n_errored_syn_ids_presyn = 330
# n_valid_syn_ids_postsyn = 6897
# n_errored_syn_ids_postsyn = 122
#
# --- Finished Part 3: Generating Validation Dataframe -----

# %%
vu.synapse_validation_df_to_score_plot(return_validation_df_revised)
# Out:
# Segment Id = 864691136311791677
# Postsyn counts:
# TP:6886
# TN:34
# FP:11
# FN:88
# Presyn counts:
# TP:87
# TN:300
# FP:30
# FN:30

# %%
# nviz.plot_axon(filt_neuron)

# %%
# import neuron_visualizations as nviz
# nviz.visualize_neuron(filt_neuron,
#                       limb_branch_dict="all")

# %%
vu.plot_validation_synapses(filt_neuron.segment_id,
                            validation_df = return_validation_df_revised,
                             synapse_dict = None,
                             synapses_type_to_plot = None,
                             synapses_type_to_not_plot = None,
                             verbose=False,
                             synapse_type = "presyn",
                             TP_color="yellow",
                            TN_color="aqua",
                            FP_color="black",
                            FN_color="orange",
                             synapse_scatter_size = 0.15,
                             
                             #for plotting the actual mesh parts to go along
                             
                             neuron_obj = filt_neuron,
                             plot_only_axon_skeleton = True,
                             error_mesh_color = "red",
                             valid_mesh_color = "green",
                             valid_skeleton_color = "black",
                             mesh_alpha = 0.3,)
# Out:
# Using the mesh from the neuron object
# VBox(children=(Figure(camera=PerspectiveCamera(fov=46.0, position=(0.0, 0.0, 2.0), projectionMatrix=(1.0, 0.0,…
# TP:yellow
# TN:aqua
# FP:black
# FN:orange

# %% [markdown]
# # Measuring the Downstream Synaptic Density

# %%
nviz.visualize_neuron_specific_limb(filt_neuron,2)

# %%
limb_obj = filt_neuron[2]
nru.upstream_node(limb_obj,57)

# %%
branch_obj = limb_obj[58]
branch_obj.synapse_density_pre

# %%
branch_obj = limb_obj[57]
print(branch_obj.synapse_density_pre*1000,branch_obj.n_synapses_pre)

branch_obj = limb_obj[64]
print(branch_obj.synapse_density_pre*1000,branch_obj.n_synapses_pre)

# %%
branch_obj = limb_obj[68]
print(branch_obj.synapse_density_pre*1000,branch_obj.n_synapses_pre)

branch_obj = limb_obj[69]
print(branch_obj.synapse_density_pre*1000,branch_obj.n_synapses_pre)

# %%
nviz.plot_limb_path(limb_obj,[58,68,69])

# %%
nviz.plot_objects(filt_neuron[2][64].mesh)

# %%
import axon_utils as au

curr_web = curr_branch.web
au.valid_web_for_t(curr_web,
                                   size_threshold = 120,
                                   size_type = "ray_trace_median",
                                   above_threshold = True,
                                       verbose=True)

# %%
curr_branch = filt_neuron[0][4]
nviz.plot_objects(curr_branch.mesh,
                 meshes=[curr_branch.web],
                 meshes_colors="red")

# %%
import error_detection as ed
ed.webbing_t_errors_limb_branch_dict(filt_neuron,
                                    plot_two_downstream_thin_axon_limb_branch  = True,
                                    plot_wide_angled_children = True,
                                    plot_web_errors=True, 
                                     child_skeletal_threshold = 2000,
                                    verbose = True)

# %%
nviz.visualize_neuron_specific_limb(filt_neuron,0)

# %% [markdown]
# # Debug 2: Looking at thick T errors

# %%
nru.downstream_nodes(neuron_obj[1],15)

# %%
ed.skip_distance_from_branch_width(neuron_obj[1][15].width)

# %%
neuron_obj[1][20].skeletal_length

# %%
nviz.plot_limb_branch_dict(neuron_obj,dict(L1=[15]))

# %%
au.axon_width(filt_neuron[1][13]),au.axon_width(filt_neuron[1][14])

# %%
import error_detection as ed
ed.thick_t_errors_limb_branch_dict(neuron_obj,
        axon_only = True,
        parent_width_maximum = 70,
        min_child_width_max = 80,
        child_skeletal_threshold = 7000,
        plot_two_downstream_thin_axon_limb_branch = False,
        plot_wide_angled_children = True,
        plot_thick_t_crossing_limb_branch = True,
        plot_t_error_limb_branch = True,
        verbose = True)

# %% [markdown]
# # Debug 1: Looking through all of the high degree branching points

# %%
ed.high_degree_branch_errors_limb_branch_dict(neuron_obj,
                                              plot_limb_branch_errors=True,
                                             high_degree_order_verbose=False)

# %%
"""
Pseudocode: 
1) Get the branch names of all those considered for the high degree branching points

"""
(filt_neuron,
             return_synapse_df_revised,
             return_synapse_df_errors,
            return_validation_df_revised,
            return_validation_df_extension) =  vu.filtered_neuron_score(neuron_obj = neuron_obj,   
                                #filter_list = pru.v6_exc_filters(),
                                filter_list = [pru.exc_high_degree_branching_filter_v6],
                                plot_limb_branch_filter_with_disconnect_effect = False,
                                verbose = True,
                                plot_score=False,
                                nucleus_id = nucleus_id,
                                return_synapse_df_errors=True,
                                return_validation_df_extension = True,                                        
                                split_index=split_index)

# %%
nviz.visualize_neuron_specific_limb(filt_neuron,
                                   2)

# %%
nru.upstream_node(limb_obj,24)

# %%
import axon_utils as au
au.axon_width(limb_obj[25])

# %%
limb_obj = filt_neuron[2]
nviz.plot_objects(limb_obj[25].mesh)

# %%
(filt_neuron_2,
             return_synapse_df_revised,
             return_synapse_df_errors,
            return_validation_df_revised,
            return_validation_df_extension) =  vu.filtered_neuron_score(neuron_obj = filt_neuron,   
                                #filter_list = pru.v6_exc_filters(),
                                filter_list = [pru.exc_high_degree_branching_filter_v6],
                                plot_limb_branch_filter_with_disconnect_effect = False,
                                verbose = True,
                                plot_score=False,
                                nucleus_id = nucleus_id,
                                return_synapse_df_errors=True,
                                return_validation_df_extension = True,                                        
                                split_index=split_index)

# %%
nru.downstream_nodes(filt_neuron[1],9)

# %%
limb_obj = filt_neuron[1]
nviz.plot_limb_path(limb_obj,[9,8,7])

# %%
[au.axon_width(limb_obj[k]) for k in [9,8,7]]

# %%
limb_obj[7].skeletal_length

# %%
nviz.plot_objects(filt_neuron[1][43].mesh)

# %%
#branches_to_check = [50,102,121,136,147,152,163,173,224,227,260]
branches_to_check = [53,185,177,154,138,124,115,108,92,14]

# %%
curr_idx = 9

limb_idx = 1
limb_obj = neuron_obj[limb_idx]

curr_branch = branches_to_check[curr_idx] 
nviz.visualize_branch_at_downstream_split(neuron_obj,
                                          limb_idx,
                                          curr_branch,
                                          print_axon_border_info=False,
                                         limb_branch_synapses=True)

# %%
import error_detection as ed


ed.high_degree_upstream_match(limb_obj,
                             branch_idx = curr_branch,
                              plot_starting_branches = True,
                             plot_extracted_skeletons = False,
                             plot_G_local_edge = True,
                              plot_G_global_edge = True,
                              plot_G_node_edge = True,
                              plot_G_exclusive_partner_edge = True,
                              plot_final_branch_matches = True
                             )
