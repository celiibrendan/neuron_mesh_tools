# %%
"""
Purpose: To Run the proofreading of neurons in the 
test set and measure the precision and recall of the new rules



"""
# Out:
# '\nPurpose: To Run the proofreading of neurons in the \ntest set and measure the precision and recall of the new rules\n\n\n\n'

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import datajoint as dj
import trimesh
from tqdm.notebook import tqdm
from pathlib import Path

from os import sys
sys.path.append("/meshAfterParty/")
sys.path.append("/meshAfterParty/meshAfterParty")

import datajoint_utils as du
from importlib import reload
# Out:
# INFO - 2021-04-25 19:39:23,360 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-04-25 19:39:23,362 - settings - Setting database.user to celiib
# INFO - 2021-04-25 19:39:23,363 - settings - Setting database.password to newceliipass
# INFO - 2021-04-25 19:39:23,384 - settings - Setting stores to {'minnie65': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65', 'stage': '/mnt/dj-stor01/platinum/minnie65'}, 'meshes': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/meshes', 'stage': '/mnt/dj-stor01/platinum/minnie65/02/meshes'}, 'decimated_meshes': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/decimated_meshes', 'stage': '/mnt/dj-stor01/platinum/minnie65/02/decimated_meshes'}, 'skeletons': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/skeletons'}}
# INFO - 2021-04-25 19:39:23,385 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-04-25 19:39:23,400 - connection - Connected celiib@at-database.ad.bcm.edu:3306
# Connecting celiib@at-database.ad.bcm.edu:3306
# INFO - 2021-04-25 19:39:24,118 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-04-25 19:39:24,121 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-04-25 19:39:24,122 - settings - Setting database.user to celiib
# INFO - 2021-04-25 19:39:24,122 - settings - Setting database.password to newceliipass
# INFO - 2021-04-25 19:39:24,123 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-04-25 19:39:24,123 - settings - Setting database.user to celiib
# INFO - 2021-04-25 19:39:24,123 - settings - Setting database.password to newceliipass
# INFO - 2021-04-25 19:39:24,124 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-04-25 19:39:24,773 - settings - Setting enable_python_native_blobs to True

# %%
#configuring will include the adapters
minnie,schema = du.configure_minnie_vm()
# Out:
# INFO - 2021-04-25 19:39:25,094 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-04-25 19:39:25,097 - settings - Setting database.user to celiib
# INFO - 2021-04-25 19:39:25,099 - settings - Setting database.password to newceliipass
# INFO - 2021-04-25 19:39:25,114 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-04-25 19:39:25,922 - settings - Setting enable_python_native_blobs to True

# %%
import validation_utils as vu
import neuron_visualizations as nviz
import neuron_utils as nru
import proofreading_utils as pru
import time
import system_utils as su

# %% [markdown]
# # Runnig the validation

# %%
"""
Psueodocode: 
1) Pull down the segment ids of the valid neurons

For each neuron
1) Dwonload the neuron object
2) Run the Proofreading
3) Print out the validation plot
4) Save the validation df

"""
# Out:
# '\nPsueodocode: \n1) Pull down the segment ids of the valid neurons\n\nFor each neuron\n1) Dwonload the neuron object\n2) Run the Proofreading\n3) Print out the validation plot\n4) Save the validation df\n\n'

# %%
segment_ids = minnie.AutoProofreadValidationBorderNeurons().fetch("segment_id")

# %%
job_idx = 10
job_step = 5
segments_to_process = segment_ids[job_idx*job_step:(job_idx+1)*job_step]
segments_to_process
# Out:
# array([864691136311740477, 864691135212690816, 864691135925564174,
#        864691136105484249])

# %%
for seg_id in segments_to_process:
    print(f"\n--- Working on Neuron {seg_id} --")
    st = time.time()
    
    
    #1) Dwonload the neuron object
    neuron_obj = du.fetch_neuron_obj_manual(seg_id,
                                       border_validation=True)
    
    (filt_neuron,
     return_synapse_df_revised,
    return_validation_df_revised) =  vu.filtered_neuron_score(neuron_obj = neuron_obj,   
                        filter_list = pru.v4_exc_filters(),
                        plot_limb_branch_filter_with_disconnect_effect = False,
                        verbose = False,
                        plot_score=False)
    
    vu.synapse_validation_df_to_score_plot(return_validation_df_revised)
    
    su.compressed_pickle(return_validation_df_revised,f"./validation_data/{seg_id}_validation_df")
    
    print(f"Total time for neuron {seg_id}: {time.time() - st}")
# Out:
# --- Working on Neuron 864691136311740477 --
# Decompressing Neuron in minimal output mode...please wait
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {'L0': [17]}
# limb_branch_dict_to_cancel = {}
# Apply the presyn non_error
# For presyn: # valid synapses = 0, # error synapses  = 230, # error presyns = 19
# For postsyn: # valid synapses = 3021, # error synapses  = 78, # error presyns = 0
# Synapsse Results:
# Total Number of Synapses = 3329
# n_valid_syn_ids_presyn = 0
# n_errored_syn_ids_presyn = 230
# n_valid_syn_ids_postsyn = 3021
# n_errored_syn_ids_postsyn = 78
# Segment Id = 864691136311740477
# Postsyn counts:
# TP:3018
# TN:6
# FP:3
# FN:72
# Presyn counts:
# TP:0
# TN:209
# FP:0
# FN:2
# Saved object at /neuron_mesh_tools/Auto_Proofreading/Validation_Testing/v4/validation_data/864691136311740477_validation_df.pbz2
# File size is 0.066413 MB
# Total time for neuron 864691136311740477: 118.54475736618042
#
# --- Working on Neuron 864691135212690816 --
# Decompressing Neuron in minimal output mode...please wait
#
#
#  ----- Working on coordinate [1171391.06669491  947608.61069489  711831.40067792]--------
# coordinate [1171391.06669491  947608.61069489  711831.40067792] had error branches [1 2]--------
#
#
#  ----- Working on coordinate [1185767.43360914 1048228.6672598   773578.87978605]--------
# coordinate [1185767.43360914 1048228.6672598   773578.87978605] had error branches []--------
#
#
#  ----- Working on coordinate [1194343.08510343  947284.83983802  701200.09047223]--------
# coordinate [1194343.08510343  947284.83983802  701200.09047223] had error branches [18  3]--------
#
#
#  ----- Working on coordinate [1197000.  952602.  720804.]--------
# coordinate [1197000.  952602.  720804.] had error branches [25 13]--------
#
#
#  ----- Working on coordinate [1197286.59637765  947125.05442725  694762.24057226]--------
# coordinate [1197286.59637765  947125.05442725  694762.24057226] had error branches [21 26]--------
#
#
#  ----- Working on coordinate [1215852.53814931  943487.21405488  698775.87618172]--------
# coordinate [1215852.53814931  943487.21405488  698775.87618172] had error branches [31 41 42 48 54 57 59]--------
#
#
#  ----- Working on coordinate [1218327.28750015 1032718.85275384  758266.75200292]--------
# coordinate [1218327.28750015 1032718.85275384  758266.75200292] had error branches [67 62]--------
#
#
#  ----- Working on coordinate [1218521.10210865  893880.87373329  669067.75531974]--------
# coordinate [1218521.10210865  893880.87373329  669067.75531974] had error branches [43 60]--------
#
#
#  ----- Working on coordinate [1219021.55811173 1028725.02759686  754937.03153499]--------
# coordinate [1219021.55811173 1028725.02759686  754937.03153499] had error branches [72 66]--------
#
#
#  ----- Working on coordinate [1219891.97070464 1025591.60255934  751685.47221365]--------
# coordinate [1219891.97070464 1025591.60255934  751685.47221365] had error branches []--------
#
#
#  ----- Working on coordinate [1221963.5  1023164.    749424.05]--------
# coordinate [1221963.5  1023164.    749424.05] had error branches [85 76]--------
#
#
#  ----- Working on coordinate [1222883.84415747  899517.15907868  689443.40001632]--------
# coordinate [1222883.84415747  899517.15907868  689443.40001632] had error branches [82 95]--------
#
#
#  ----- Working on coordinate [1224765.41415981  899314.31346135  690163.34924906]--------
# coordinate [1224765.41415981  899314.31346135  690163.34924906] had error branches [46 98 99 27]--------
#
#
#  ----- Working on coordinate [1230450.19013677  895794.5758181   676100.07868052]--------
# coordinate [1230450.19013677  895794.5758181   676100.07868052] had error branches [105 106]--------
#
#
#  ----- Working on coordinate [1234406.54071537  891755.889258    672305.3721294 ]--------
# coordinate [1234406.54071537  891755.889258    672305.3721294 ] had error branches [108 110  70]--------
# limb_branch_dict_to_cancel = {'L1': array([  1,   2,  18,   3,  25,  13,  21,  26,  31,  41,  42,  48,  54,
#         57,  59,  67,  62,  43,  60,  72,  66,  85,  76,  82,  95,  46,
#         98,  99,  27, 105, 106, 108, 110,  70])}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {'L1': [46, 2]}
# limb_branch_dict_to_cancel = {}
# Apply the presyn non_error
# For presyn: # valid synapses = 0, # error synapses  = 47, # error presyns = 16
# For postsyn: # valid synapses = 2333, # error synapses  = 3, # error presyns = 0
# Synapsse Results:
# Total Number of Synapses = 2383
# n_valid_syn_ids_presyn = 0
# n_errored_syn_ids_presyn = 47
# n_valid_syn_ids_postsyn = 2333
# n_errored_syn_ids_postsyn = 3
# Segment Id = 864691135212690816
# Postsyn counts:
# TP:2333
# TN:2
# FP:0
# FN:1
# Presyn counts:
# TP:0
# TN:31
# FP:0
# FN:0
# Saved object at /neuron_mesh_tools/Auto_Proofreading/Validation_Testing/v4/validation_data/864691135212690816_validation_df.pbz2
# File size is 0.048004 MB
# Total time for neuron 864691135212690816: 100.2301378250122
#
# --- Working on Neuron 864691135925564174 --
# Decompressing Neuron in minimal output mode...please wait
#
#
#  ----- Working on coordinate [1230557.18069785  735292.41490023  782660.62559692]--------
# coordinate [1230557.18069785  735292.41490023  782660.62559692] had error branches [8 3]--------
#
#
#  ----- Working on coordinate [1273075.96001104  719053.35933403  780299.91150362]--------
# coordinate [1273075.96001104  719053.35933403  780299.91150362] had error branches [19 20 15]--------
#
#
#  ----- Working on coordinate [1274799.36801067  699607.89458901  788623.55520716]--------
# coordinate [1274799.36801067  699607.89458901  788623.55520716] had error branches [16 12]--------
#
#
#  ----- Working on coordinate [1275538.27629044  717176.26079318  780341.85584429]--------
# coordinate [1275538.27629044  717176.26079318  780341.85584429] had error branches [30 26]--------
#
#
#  ----- Working on coordinate [1277062.57882842  723553.55810639  781922.72986314]--------
# coordinate [1277062.57882842  723553.55810639  781922.72986314] had error branches [28 31 32]--------
# limb_branch_dict_to_cancel = {'L1': array([ 8,  3, 19, 20, 15, 16, 12, 30, 26, 28, 31, 32])}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# Apply the presyn non_error
# For presyn: # valid synapses = 9, # error synapses  = 95, # error presyns = 13
# For postsyn: # valid synapses = 1592, # error synapses  = 12, # error presyns = 0
# Synapsse Results:
# Total Number of Synapses = 1708
# n_valid_syn_ids_presyn = 9
# n_errored_syn_ids_presyn = 95
# n_valid_syn_ids_postsyn = 1592
# n_errored_syn_ids_postsyn = 12
# Segment Id = 864691135925564174
# Postsyn counts:
# TP:1591
# TN:0
# FP:1
# FN:12
# Presyn counts:
# TP:8
# TN:82
# FP:1
# FN:0
# Saved object at /neuron_mesh_tools/Auto_Proofreading/Validation_Testing/v4/validation_data/864691135925564174_validation_df.pbz2
# File size is 0.035587 MB
# Total time for neuron 864691135925564174: 72.93753242492676
#
# --- Working on Neuron 864691136105484249 --
# Decompressing Neuron in minimal output mode...please wait
#
#
#  ----- Working on coordinate [666829.41822077 765592.1750928  789427.18293239]--------
# coordinate [666829.41822077 765592.1750928  789427.18293239] had error branches [3 5 7 1]--------
#
#
#  ----- Working on coordinate [670642.74353947 766091.64132243 788947.28968166]--------
# coordinate [670642.74353947 766091.64132243 788947.28968166] had error branches [10 11]--------
#
#
#  ----- Working on coordinate [722002.91271812 765347.30848021 795735.15123711]--------
# coordinate [722002.91271812 765347.30848021 795735.15123711] had error branches [23 18]--------
#
#
#  ----- Working on coordinate [738619.84805151 734335.18586258 767276.42578797]--------
# coordinate [738619.84805151 734335.18586258 767276.42578797] had error branches [29 36 38 39 40 41 42]--------
#
#
#  ----- Working on coordinate [746939.32175703 741602.15219871 769464.50032307]--------
# coordinate [746939.32175703 741602.15219871 769464.50032307] had error branches [53 54]--------
#
#
#  ----- Working on coordinate [755586.94895287 745933.4991701  771731.2192653 ]--------
# coordinate [755586.94895287 745933.4991701  771731.2192653 ] had error branches [57 59]--------
#
#
#  ----- Working on coordinate [775635.9512669  759182.78069102 768941.15942658]--------
# coordinate [775635.9512669  759182.78069102 768941.15942658] had error branches [66 70]--------
#
#
#  ----- Working on coordinate [781379.76057936 763931.27368276 761580.16378803]--------
# coordinate [781379.76057936 763931.27368276 761580.16378803] had error branches [73 77 84]--------
#
#
#  ----- Working on coordinate [781578.52894637 754353.01637808 768401.80173224]--------
# coordinate [781578.52894637 754353.01637808 768401.80173224] had error branches [82 88 78]--------
#
#
#  ----- Working on coordinate [782239.14754491 780462.41328254 760342.0468051 ]--------
# coordinate [782239.14754491 780462.41328254 760342.0468051 ] had error branches [89 72]--------
#
#
#  ----- Working on coordinate [787739.71096635 777973.28691372 762323.82283113]--------
# coordinate [787739.71096635 777973.28691372 762323.82283113] had error branches [ 99 100  97]--------
#
#
#  ----- Working on coordinate [792067.16342162 774743.81046706 762172.18981506]--------
# coordinate [792067.16342162 774743.81046706 762172.18981506] had error branches [101 102 110 112 113]--------
#
#
#  ----- Working on coordinate [793831.39842267 776390.29826096 756400.31346703]--------
# coordinate [793831.39842267 776390.29826096 756400.31346703] had error branches [118 119]--------
#
#
#  ----- Working on coordinate [795600.51389638 783634.98198718 767399.1305155 ]--------
# coordinate [795600.51389638 783634.98198718 767399.1305155 ] had error branches [ 79 122]--------
#
#
#  ----- Working on coordinate [797154.5207683  776987.96401799 757322.54190676]--------
# coordinate [797154.5207683  776987.96401799 757322.54190676] had error branches [124 125]--------
#
#
#  ----- Working on coordinate [807329.78972811 773685.10615857 756779.27922274]--------
# coordinate [807329.78972811 773685.10615857 756779.27922274] had error branches [128 136 123]--------
#
#
#  ----- Working on coordinate [812099.55628248 757799.69703752 760269.08808974]--------
# coordinate [812099.55628248 757799.69703752 760269.08808974] had error branches [135 140]--------
#
#
#  ----- Working on coordinate [814535.69136515 761289.29946625 758135.63329604]--------
# coordinate [814535.69136515 761289.29946625 758135.63329604] had error branches [144 139]--------
#
#
#  ----- Working on coordinate [817111.8794347  762006.39080823 752367.46272119]--------
# coordinate [817111.8794347  762006.39080823 752367.46272119] had error branches [147 148]--------
# limb_branch_dict_to_cancel = {'L1': array([  3,   5,   7,   1,  10,  11,  23,  18,  29,  36,  38,  39,  40,
#         41,  42,  53,  54,  57,  59,  66,  70,  73,  77,  84,  82,  88,
#         78,  89,  72,  99, 100,  97, 101, 102, 110, 112, 113, 118, 119,
#         79, 122, 124, 125, 128, 136, 123, 135, 140, 144, 139, 147, 148])}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# Apply the presyn non_error
# For presyn: # valid synapses = 10, # error synapses  = 234, # error presyns = 16
# For postsyn: # valid synapses = 1726, # error synapses  = 20, # error presyns = 0
# Synapsse Results:
# Total Number of Synapses = 1990
# n_valid_syn_ids_presyn = 10
# n_errored_syn_ids_presyn = 234
# n_valid_syn_ids_postsyn = 1726
# n_errored_syn_ids_postsyn = 20
# Segment Id = 864691136105484249
# Postsyn counts:
# TP:1724
# TN:20
# FP:2
# FN:0
# Presyn counts:
# TP:10
# TN:218
# FP:0
# FN:0
# Saved object at /neuron_mesh_tools/Auto_Proofreading/Validation_Testing/v4/validation_data/864691136105484249_validation_df.pbz2
# File size is 0.040173 MB
# Total time for neuron 864691136105484249: 105.4140350818634
