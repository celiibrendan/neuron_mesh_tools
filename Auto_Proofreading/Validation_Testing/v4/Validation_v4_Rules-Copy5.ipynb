# %%
"""
Purpose: To Run the proofreading of neurons in the 
test set and measure the precision and recall of the new rules



"""
# Out:
# '\nPurpose: To Run the proofreading of neurons in the \ntest set and measure the precision and recall of the new rules\n\n\n\n'

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import datajoint as dj
import trimesh
from tqdm.notebook import tqdm
from pathlib import Path

from os import sys
sys.path.append("/meshAfterParty/")
sys.path.append("/meshAfterParty/meshAfterParty")

import datajoint_utils as du
from importlib import reload
# Out:
# INFO - 2021-04-29 16:13:30,885 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-04-29 16:13:30,887 - settings - Setting database.user to celiib
# INFO - 2021-04-29 16:13:30,888 - settings - Setting database.password to newceliipass
# INFO - 2021-04-29 16:13:30,892 - settings - Setting stores to {'minnie65': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65', 'stage': '/mnt/dj-stor01/platinum/minnie65'}, 'meshes': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/meshes', 'stage': '/mnt/dj-stor01/platinum/minnie65/02/meshes'}, 'decimated_meshes': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/decimated_meshes', 'stage': '/mnt/dj-stor01/platinum/minnie65/02/decimated_meshes'}, 'skeletons': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/skeletons'}}
# INFO - 2021-04-29 16:13:30,893 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-04-29 16:13:30,905 - connection - Connected celiib@at-database.ad.bcm.edu:3306
# Connecting celiib@at-database.ad.bcm.edu:3306
# INFO - 2021-04-29 16:13:31,318 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-04-29 16:13:31,323 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-04-29 16:13:31,324 - settings - Setting database.user to celiib
# INFO - 2021-04-29 16:13:31,325 - settings - Setting database.password to newceliipass
# INFO - 2021-04-29 16:13:31,326 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-04-29 16:13:31,327 - settings - Setting database.user to celiib
# INFO - 2021-04-29 16:13:31,328 - settings - Setting database.password to newceliipass
# INFO - 2021-04-29 16:13:31,330 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-04-29 16:13:31,757 - settings - Setting enable_python_native_blobs to True

# %%
#configuring will include the adapters
minnie,schema = du.configure_minnie_vm()
# Out:
# INFO - 2021-04-29 16:13:31,904 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-04-29 16:13:31,905 - settings - Setting database.user to celiib
# INFO - 2021-04-29 16:13:31,906 - settings - Setting database.password to newceliipass
# INFO - 2021-04-29 16:13:31,911 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-04-29 16:13:32,452 - settings - Setting enable_python_native_blobs to True

# %%
import validation_utils as vu
import neuron_visualizations as nviz
import neuron_utils as nru
import proofreading_utils as pru
import time
import system_utils as su

# %% [markdown]
# # Runnig the validation

# %%
"""
Psueodocode: 
1) Pull down the segment ids of the valid neurons

For each neuron
1) Dwonload the neuron object
2) Run the Proofreading
3) Print out the validation plot
4) Save the validation df

"""
# Out:
# '\nPsueodocode: \n1) Pull down the segment ids of the valid neurons\n\nFor each neuron\n1) Dwonload the neuron object\n2) Run the Proofreading\n3) Print out the validation plot\n4) Save the validation df\n\n'

# %%
segment_ids = minnie.AutoProofreadValidationBorderNeurons().fetch("segment_id")

# %%
job_idx = 5
job_step = 5
segments_to_process = segment_ids[job_idx*job_step:(job_idx+1)*job_step]
segments_to_process
# Out:
# array([864691136618412685, 864691136545546146, 864691136537477538,
#        864691136105491417, 864691136056340440])

# %%
for seg_id in segments_to_process:
    print(f"\n--- Working on Neuron {seg_id} --")
    st = time.time()
    
    
    #1) Dwonload the neuron object
    neuron_obj = du.fetch_neuron_obj_manual(seg_id,
                                       border_validation=True)
    
    (filt_neuron,
     return_synapse_df_revised,
    return_validation_df_revised) =  vu.filtered_neuron_score(neuron_obj = neuron_obj,   
                        filter_list = pru.v4_exc_filters(),
                        plot_limb_branch_filter_with_disconnect_effect = False,
                        verbose = False,
                        plot_score=False)
    
    vu.synapse_validation_df_to_score_plot(return_validation_df_revised)
    
    su.compressed_pickle(return_validation_df_revised,f"./validation_data/{seg_id}_validation_df")
    
    print(f"Total time for neuron {seg_id}: {time.time() - st}")
# Out:
# --- Working on Neuron 864691136618412685 --
# Decompressing Neuron in minimal output mode...please wait
#
#
#  ----- Working on coordinate 0: [1378826.90328442  787337.43991306 1075602.6812615 ]--------
# winning_downstream = 37,error_downstream = [34 35 36 38]
# coordinate [1378826.90328442  787337.43991306 1075602.6812615 ] had error branches [34 35 36 38]--------
#
#
#  ----- Working on coordinate 1: [1390439.52564234  786097.86357203 1056168.23499344]--------
# winning_downstream = None,error_downstream = []
# coordinate [1390439.52564234  786097.86357203 1056168.23499344] had error branches []--------
# limb_branch_dict_to_cancel = {'L4': array([34, 35, 36, 38])}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# Apply the presyn non_error
# For presyn: # valid synapses = 27, # error synapses  = 107, # error presyns = 12
# For postsyn: # valid synapses = 1756, # error synapses  = 9, # error presyns = 0
# Synapsse Results:
# Total Number of Synapses = 1899
# n_valid_syn_ids_presyn = 27
# n_errored_syn_ids_presyn = 107
# n_valid_syn_ids_postsyn = 1756
# n_errored_syn_ids_postsyn = 9
# Segment Id = 864691136618412685
# Postsyn counts:
# TP:1754
# TN:0
# FP:2
# FN:9
# Presyn counts:
# TP:23
# TN:95
# FP:4
# FN:0
# Saved object at /neuron_mesh_tools/Auto_Proofreading/Validation_Testing/v4/validation_data/864691136618412685_validation_df.pbz2
# File size is 0.039594 MB
# Total time for neuron 864691136618412685: 149.4711446762085
#
# --- Working on Neuron 864691136545546146 --
# Decompressing Neuron in minimal output mode...please wait
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# Apply the presyn non_error
# For presyn: # valid synapses = 19, # error synapses  = 1, # error presyns = 1
# For postsyn: # valid synapses = 2834, # error synapses  = 21, # error presyns = 0
# Synapsse Results:
# Total Number of Synapses = 2875
# n_valid_syn_ids_presyn = 19
# n_errored_syn_ids_presyn = 1
# n_valid_syn_ids_postsyn = 2834
# n_errored_syn_ids_postsyn = 21
# Segment Id = 864691136545546146
# Postsyn counts:
# TP:2833
# TN:0
# FP:1
# FN:21
# Presyn counts:
# TP:19
# TN:0
# FP:0
# FN:0
# Saved object at /neuron_mesh_tools/Auto_Proofreading/Validation_Testing/v4/validation_data/864691136545546146_validation_df.pbz2
# File size is 0.058804 MB
# Total time for neuron 864691136545546146: 102.96413040161133
#
# --- Working on Neuron 864691136537477538 --
# Decompressing Neuron in minimal output mode...please wait
#
#
#  ----- Working on coordinate 0: [1323612.20463785  561023.93065606  828880.16691374]--------
# winning_downstream = 18,error_downstream = [20 13]
# coordinate [1323612.20463785  561023.93065606  828880.16691374] had error branches [20 13]--------
#
#
#  ----- Working on coordinate 1: [1327280.75392455  601868.69306324  808017.04224341]--------
# winning_downstream = 26,error_downstream = [24 19]
# coordinate [1327280.75392455  601868.69306324  808017.04224341] had error branches [24 19]--------
#
#
#  ----- Working on coordinate 2: [1351529.42628395  620941.73534404  895893.38855919]--------
# winning_downstream = 44,error_downstream = [43 45]
# coordinate [1351529.42628395  620941.73534404  895893.38855919] had error branches [43 45]--------
# limb_branch_dict_to_cancel = {'L3': array([20, 13, 24, 19, 43, 45])}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# Apply the presyn non_error
# For presyn: # valid synapses = 35, # error synapses  = 41, # error presyns = 27
# For postsyn: # valid synapses = 6639, # error synapses  = 1, # error presyns = 0
# Synapsse Results:
# Total Number of Synapses = 6716
# n_valid_syn_ids_presyn = 35
# n_errored_syn_ids_presyn = 41
# n_valid_syn_ids_postsyn = 6639
# n_errored_syn_ids_postsyn = 1
# Segment Id = 864691136537477538
# Postsyn counts:
# TP:6628
# TN:1
# FP:11
# FN:0
# Presyn counts:
# TP:33
# TN:11
# FP:2
# FN:3
# Saved object at /neuron_mesh_tools/Auto_Proofreading/Validation_Testing/v4/validation_data/864691136537477538_validation_df.pbz2
# File size is 0.132694 MB
# Total time for neuron 864691136537477538: 175.36906504631042
#
# --- Working on Neuron 864691136105491417 --
# Decompressing Neuron in minimal output mode...please wait
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# Apply the presyn non_error
# For presyn: # valid synapses = 2, # error synapses  = 152, # error presyns = 14
# For postsyn: # valid synapses = 2012, # error synapses  = 5, # error presyns = 0
# Synapsse Results:
# Total Number of Synapses = 2171
# n_valid_syn_ids_presyn = 2
# n_errored_syn_ids_presyn = 152
# n_valid_syn_ids_postsyn = 2012
# n_errored_syn_ids_postsyn = 5
# Segment Id = 864691136105491417
# Postsyn counts:
# TP:2011
# TN:2
# FP:1
# FN:3
# Presyn counts:
# TP:1
# TN:138
# FP:1
# FN:0
# Saved object at /neuron_mesh_tools/Auto_Proofreading/Validation_Testing/v4/validation_data/864691136105491417_validation_df.pbz2
# File size is 0.044682 MB
# Total time for neuron 864691136105491417: 62.40920686721802
#
# --- Working on Neuron 864691136056340440 --
# Decompressing Neuron in minimal output mode...please wait
#
#
#  ----- Working on coordinate 0: [1260388.78629687  820041.38758197  850371.74917425]--------
# winning_downstream = 4,error_downstream = [ 9 10]
# coordinate [1260388.78629687  820041.38758197  850371.74917425] had error branches [ 9 10]--------
#
#
#  ----- Working on coordinate 1: [1263824.05912633  798084.26398477  811197.29369602]--------
# winning_downstream = 8,error_downstream = [13 14]
# coordinate [1263824.05912633  798084.26398477  811197.29369602] had error branches [13 14]--------
#
#
#  ----- Working on coordinate 2: [1299585.98536865  801675.71545857  800165.63057607]--------
# winning_downstream = 17,error_downstream = [22 25]
# coordinate [1299585.98536865  801675.71545857  800165.63057607] had error branches [22 25]--------
#
#
#  ----- Working on coordinate 3: [1302705.76947138  803878.04245994  789281.8019496 ]--------
# winning_downstream = None,error_downstream = []
# coordinate [1302705.76947138  803878.04245994  789281.8019496 ] had error branches []--------
#
#
#  ----- Working on coordinate 4: [1390402.35070701  838508.76829429  803378.97103622]--------
# Changing max_degree_to_resolve = 8 because upstream width was 207.5922019125178
# winning_downstream = 53,error_downstream = [54 55 52]
# coordinate [1390402.35070701  838508.76829429  803378.97103622] had error branches [54 55 52]--------
#
#
#  ----- Working on coordinate 5: [1402572.   791900.4  791596.8]--------
# winning_downstream = None,error_downstream = []
# coordinate [1402572.   791900.4  791596.8] had error branches []--------
# limb_branch_dict_to_cancel = {'L2': array([ 9, 10, 13, 14, 22, 25, 54, 55, 52])}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {'L2': [4, 6, 7, 8, 9, 13, 14, 15, 16, 17, 18, 19, 21, 22, 23, 29, 30, 58, 59, 64, 67, 73, 74, 75, 76, 77, 79, 80, 81, 82, 83, 84, 85, 86, 78]}
# limb_branch_dict_to_cancel = {}
# Apply the presyn non_error
# For presyn: # valid synapses = 6, # error synapses  = 102, # error presyns = 15
# For postsyn: # valid synapses = 4743, # error synapses  = 511, # error presyns = 0
# Synapsse Results:
# Total Number of Synapses = 5362
# n_valid_syn_ids_presyn = 6
# n_errored_syn_ids_presyn = 102
# n_valid_syn_ids_postsyn = 4743
# n_errored_syn_ids_postsyn = 511
# Segment Id = 864691136056340440
# Postsyn counts:
# TP:4741
# TN:0
# FP:2
# FN:511
# Presyn counts:
# TP:4
# TN:86
# FP:2
# FN:1
# Saved object at /neuron_mesh_tools/Auto_Proofreading/Validation_Testing/v4/validation_data/864691136056340440_validation_df.pbz2
# File size is 0.105939 MB
# Total time for neuron 864691136056340440: 220.409916639328
