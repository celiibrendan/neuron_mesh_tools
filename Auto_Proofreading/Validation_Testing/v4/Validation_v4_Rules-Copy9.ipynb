# %%
"""
Purpose: To Run the proofreading of neurons in the 
test set and measure the precision and recall of the new rules



"""
# Out:
# '\nPurpose: To Run the proofreading of neurons in the \ntest set and measure the precision and recall of the new rules\n\n\n\n'

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import datajoint as dj
import trimesh
from tqdm.notebook import tqdm
from pathlib import Path

from os import sys
sys.path.append("/meshAfterParty/")
sys.path.append("/meshAfterParty/meshAfterParty")

import datajoint_utils as du
from importlib import reload
# Out:
# INFO - 2021-04-24 21:50:34,025 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-04-24 21:50:34,027 - settings - Setting database.user to celiib
# INFO - 2021-04-24 21:50:34,038 - settings - Setting database.password to newceliipass
# INFO - 2021-04-24 21:50:34,055 - settings - Setting stores to {'minnie65': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65', 'stage': '/mnt/dj-stor01/platinum/minnie65'}, 'meshes': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/meshes', 'stage': '/mnt/dj-stor01/platinum/minnie65/02/meshes'}, 'decimated_meshes': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/decimated_meshes', 'stage': '/mnt/dj-stor01/platinum/minnie65/02/decimated_meshes'}, 'skeletons': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/skeletons'}}
# INFO - 2021-04-24 21:50:34,056 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-04-24 21:50:34,067 - connection - Connected celiib@at-database.ad.bcm.edu:3306
# Connecting celiib@at-database.ad.bcm.edu:3306
# INFO - 2021-04-24 21:50:34,617 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-04-24 21:50:34,620 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-04-24 21:50:34,621 - settings - Setting database.user to celiib
# INFO - 2021-04-24 21:50:34,622 - settings - Setting database.password to newceliipass
# INFO - 2021-04-24 21:50:34,622 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-04-24 21:50:34,622 - settings - Setting database.user to celiib
# INFO - 2021-04-24 21:50:34,623 - settings - Setting database.password to newceliipass
# INFO - 2021-04-24 21:50:34,624 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-04-24 21:50:35,333 - settings - Setting enable_python_native_blobs to True

# %%
#configuring will include the adapters
minnie,schema = du.configure_minnie_vm()
# Out:
# INFO - 2021-04-24 21:50:35,514 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-04-24 21:50:35,515 - settings - Setting database.user to celiib
# INFO - 2021-04-24 21:50:35,516 - settings - Setting database.password to newceliipass
# INFO - 2021-04-24 21:50:35,530 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-04-24 21:50:36,177 - settings - Setting enable_python_native_blobs to True

# %%
import validation_utils as vu
import neuron_visualizations as nviz
import neuron_utils as nru
import proofreading_utils as pru
import time
import system_utils as su

# %% [markdown]
# # Runnig the validation

# %%
"""
Psueodocode: 
1) Pull down the segment ids of the valid neurons

For each neuron
1) Dwonload the neuron object
2) Run the Proofreading
3) Print out the validation plot
4) Save the validation df

"""
# Out:
# '\nPsueodocode: \n1) Pull down the segment ids of the valid neurons\n\nFor each neuron\n1) Dwonload the neuron object\n2) Run the Proofreading\n3) Print out the validation plot\n4) Save the validation df\n\n'

# %%
segment_ids = minnie.AutoProofreadValidationBorderNeurons().fetch("segment_id")

# %%
job_idx = 9
job_step = 5
segments_to_process = segment_ids[job_idx*job_step:(job_idx+1)*job_step]
segments_to_process
# Out:
# array([864691135974454895, 864691136201041854, 864691135785277636,
#        864691136550489250, 864691135348272855])

# %%
for seg_id in segments_to_process:
    print(f"\n--- Working on Neuron {seg_id} --")
    st = time.time()
    
    
    #1) Dwonload the neuron object
    neuron_obj = du.fetch_neuron_obj_manual(seg_id,
                                       border_validation=True)
    
    (filt_neuron,
     return_synapse_df_revised,
    return_validation_df_revised) =  vu.filtered_neuron_score(neuron_obj = neuron_obj,   
                        filter_list = pru.v4_exc_filters(),
                        plot_limb_branch_filter_with_disconnect_effect = False,
                        verbose = False,
                        plot_score=False)
    
    vu.synapse_validation_df_to_score_plot(return_validation_df_revised)
    
    su.compressed_pickle(return_validation_df_revised,f"./validation_data/{seg_id}_validation_df")
    
    print(f"Total time for neuron {seg_id}: {time.time() - st}")
# Out:
# --- Working on Neuron 864691135974454895 --
# Decompressing Neuron in minimal output mode...please wait
#
#
#  ----- Working on coordinate [1114491.45069704  624186.47815901 1079363.35915717]--------
# coordinate [1114491.45069704  624186.47815901 1079363.35915717] had error branches [2 4]--------
#
#
#  ----- Working on coordinate [1150585.94142523  679324.90843952 1016036.573792  ]--------
# coordinate [1150585.94142523  679324.90843952 1016036.573792  ] had error branches [24 25 29 21]--------
#
#
#  ----- Working on coordinate [1155692.14327461  669701.01801971 1015130.67026831]--------
# coordinate [1155692.14327461  669701.01801971 1015130.67026831] had error branches [51 52 46]--------
#
#
#  ----- Working on coordinate [1155698.40567762  665913.90073593 1016834.01720987]--------
# coordinate [1155698.40567762  665913.90073593 1016834.01720987] had error branches [54 39]--------
#
#
#  ----- Working on coordinate [1250107.19005484  707708.46867272 1046559.29209154]--------
# coordinate [1250107.19005484  707708.46867272 1046559.29209154] had error branches []--------
#
#
#  ----- Working on coordinate [1259645.   482452.9 1034744. ]--------
# coordinate [1259645.   482452.9 1034744. ] had error branches [ 98 101]--------
#
#
#  ----- Working on coordinate [1265468.60800573  617840.51727242 1089116.95245069]--------
# coordinate [1265468.60800573  617840.51727242 1089116.95245069] had error branches [118 126 127]--------
#
#
#  ----- Working on coordinate [1267889.78002564  578944.46970298 1094012.42351485]--------
# coordinate [1267889.78002564  578944.46970298 1094012.42351485] had error branches [131 132 103]--------
#
#
#  ----- Working on coordinate [1275494.84248464  476085.06913975 1107848.91256116]--------
# coordinate [1275494.84248464  476085.06913975 1107848.91256116] had error branches [137 150 105]--------
#
#
#  ----- Working on coordinate [1276831.76635911  430369.13325049 1090371.09272235]--------
# coordinate [1276831.76635911  430369.13325049 1090371.09272235] had error branches [162 163]--------
#
#
#  ----- Working on coordinate [1278898.1788399   457138.53227999 1099471.18928635]--------
# coordinate [1278898.1788399   457138.53227999 1099471.18928635] had error branches [169 172 156]--------
#
#
#  ----- Working on coordinate [1280648.   565620.9 1065872. ]--------
# coordinate [1280648.   565620.9 1065872. ] had error branches [174 181]--------
#
#
#  ----- Working on coordinate [1334993.37027936  336529.44872671 1100009.19541536]--------
# coordinate [1334993.37027936  336529.44872671 1100009.19541536] had error branches [212 205]--------
#
#
#  ----- Working on coordinate [1351718.21537161  343103.27105484 1062065.07903447]--------
# coordinate [1351718.21537161  343103.27105484 1062065.07903447] had error branches [214 218 219 220]--------
#
#
#  ----- Working on coordinate [1406964.38326862  724093.0626479   985379.22283044]--------
# coordinate [1406964.38326862  724093.0626479   985379.22283044] had error branches [225 228]--------
# limb_branch_dict_to_cancel = {'L1': array([  2,   4,  24,  25,  29,  21,  51,  52,  46,  54,  39,  98, 101,
#        118, 126, 127, 131, 132, 103, 137, 150, 105, 162, 163, 169, 172,
#        156, 174, 181, 212, 205, 214, 218, 219, 220, 225, 228])}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# Apply the presyn non_error
# For presyn: # valid synapses = 118, # error synapses  = 173, # error presyns = 12
# For postsyn: # valid synapses = 4329, # error synapses  = 13, # error presyns = 0
# Synapsse Results:
# Total Number of Synapses = 4633
# n_valid_syn_ids_presyn = 118
# n_errored_syn_ids_presyn = 173
# n_valid_syn_ids_postsyn = 4329
# n_errored_syn_ids_postsyn = 13
# Segment Id = 864691135974454895
# Postsyn counts:
# TP:4329
# TN:0
# FP:0
# FN:13
# Presyn counts:
# TP:104
# TN:123
# FP:14
# FN:38
# Saved object at /neuron_mesh_tools/Auto_Proofreading/Validation_Testing/v4/validation_data/864691135974454895_validation_df.pbz2
# File size is 0.093366 MB
# Total time for neuron 864691135974454895: 275.65368270874023
#
# --- Working on Neuron 864691136201041854 --
# Decompressing Neuron in minimal output mode...please wait
#
#
#  ----- Working on coordinate [1389391.95090269  614891.59782175  783856.80618499]--------
# coordinate [1389391.95090269  614891.59782175  783856.80618499] had error branches [43 44 45]--------
#
#
#  ----- Working on coordinate [1391299.81445433  618577.48106874  780281.98563781]--------
# coordinate [1391299.81445433  618577.48106874  780281.98563781] had error branches [42 46 47]--------
# limb_branch_dict_to_cancel = {'L6': array([43, 44, 45, 42, 46, 47])}
# limb_branch_dict_to_cancel = {'L6': [15, 28]}
# Skipping the double back even though double back threshold violated because the angle with the top is 37.2 which is less than set threshold 39
# and upstream_node_width (211.62919519848614) is greater than threshold 140
# limb_branch_dict_to_cancel = {'L6': [1]}
# limb_branch_dict_to_cancel = {}
# Apply the presyn non_error
# For presyn: # valid synapses = 6, # error synapses  = 58, # error presyns = 22
# For postsyn: # valid synapses = 4632, # error synapses  = 10, # error presyns = 0
# Synapsse Results:
# Total Number of Synapses = 4706
# n_valid_syn_ids_presyn = 6
# n_errored_syn_ids_presyn = 58
# n_valid_syn_ids_postsyn = 4632
# n_errored_syn_ids_postsyn = 10
# Segment Id = 864691136201041854
# Postsyn counts:
# TP:4630
# TN:2
# FP:2
# FN:8
# Presyn counts:
# TP:5
# TN:36
# FP:1
# FN:0
# Saved object at /neuron_mesh_tools/Auto_Proofreading/Validation_Testing/v4/validation_data/864691136201041854_validation_df.pbz2
# File size is 0.093899 MB
# Total time for neuron 864691136201041854: 202.25479292869568
#
# --- Working on Neuron 864691135785277636 --
# Decompressing Neuron in minimal output mode...please wait
#
#
#  ----- Working on coordinate [1183841.88080887  673617.8715042   960106.98774634]--------
# coordinate [1183841.88080887  673617.8715042   960106.98774634] had error branches [10 17 21  6]--------
# limb_branch_dict_to_cancel = {'L1': array([10, 17, 21,  6])}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {'L6': [11]}
# limb_branch_dict_to_cancel = {}
# Apply the presyn non_error
# For presyn: # valid synapses = 41, # error synapses  = 119, # error presyns = 38
# For postsyn: # valid synapses = 6713, # error synapses  = 237, # error presyns = 0
# Synapsse Results:
# Total Number of Synapses = 7110
# n_valid_syn_ids_presyn = 41
# n_errored_syn_ids_presyn = 119
# n_valid_syn_ids_postsyn = 6713
# n_errored_syn_ids_postsyn = 237
# Segment Id = 864691135785277636
# Postsyn counts:
# TP:6688
# TN:0
# FP:25
# FN:237
# Presyn counts:
# TP:34
# TN:77
# FP:7
# FN:4
# Saved object at /neuron_mesh_tools/Auto_Proofreading/Validation_Testing/v4/validation_data/864691135785277636_validation_df.pbz2
# File size is 0.140807 MB
# Total time for neuron 864691135785277636: 260.9951822757721
#
# --- Working on Neuron 864691136550489250 --
# Decompressing Neuron in minimal output mode...please wait
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# Apply the presyn non_error
# For presyn: # valid synapses = 23, # error synapses  = 23, # error presyns = 14
# For postsyn: # valid synapses = 2463, # error synapses  = 1, # error presyns = 0
# Synapsse Results:
# Total Number of Synapses = 2510
# n_valid_syn_ids_presyn = 23
# n_errored_syn_ids_presyn = 23
# n_valid_syn_ids_postsyn = 2463
# n_errored_syn_ids_postsyn = 1
# Segment Id = 864691136550489250
# Postsyn counts:
# TP:2462
# TN:0
# FP:1
# FN:1
# Presyn counts:
# TP:20
# TN:9
# FP:3
# FN:0
# Saved object at /neuron_mesh_tools/Auto_Proofreading/Validation_Testing/v4/validation_data/864691136550489250_validation_df.pbz2
# File size is 0.050738 MB
# Total time for neuron 864691136550489250: 72.31047821044922
#
# --- Working on Neuron 864691135348272855 --
# Decompressing Neuron in minimal output mode...please wait
#
#
#  ----- Working on coordinate [1080662.23715313  654158.81477147 1053517.52877773]--------
# coordinate [1080662.23715313  654158.81477147 1053517.52877773] had error branches [21 15]--------
#
#
#  ----- Working on coordinate [1080668.74230505  649539.47646253 1049814.74198096]--------
# coordinate [1080668.74230505  649539.47646253 1049814.74198096] had error branches [20 22]--------
#
#
#  ----- Working on coordinate [1123190.37826289  683966.62388446 1054111.18856573]--------
# coordinate [1123190.37826289  683966.62388446 1054111.18856573] had error branches [48 50 35]--------
#
#
#  ----- Working on coordinate [1185017.06190571  896939.36530133 1024772.85582627]--------
# coordinate [1185017.06190571  896939.36530133 1024772.85582627] had error branches []--------
#
#
#  ----- Working on coordinate [1214003.80396164  681847.78038438 1094105.44161534]--------
# coordinate [1214003.80396164  681847.78038438 1094105.44161534] had error branches [120 121]--------
# limb_branch_dict_to_cancel = {'L5': array([ 21,  15,  20,  22,  48,  50,  35, 120, 121])}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {'L5': [92]}
# limb_branch_dict_to_cancel = {'L5': array([14, 21])}
# Apply the presyn non_error
# For presyn: # valid synapses = 52, # error synapses  = 399, # error presyns = 16
# For postsyn: # valid synapses = 6018, # error synapses  = 5, # error presyns = 0
# Synapsse Results:
# Total Number of Synapses = 6474
# n_valid_syn_ids_presyn = 52
# n_errored_syn_ids_presyn = 399
# n_valid_syn_ids_postsyn = 6018
# n_errored_syn_ids_postsyn = 5
# Segment Id = 864691135348272855
# Postsyn counts:
# TP:6012
# TN:4
# FP:6
# FN:1
# Presyn counts:
# TP:40
# TN:375
# FP:12
# FN:8
# Saved object at /neuron_mesh_tools/Auto_Proofreading/Validation_Testing/v4/validation_data/864691135348272855_validation_df.pbz2
# File size is 0.12883 MB
# Total time for neuron 864691135348272855: 288.7722201347351
