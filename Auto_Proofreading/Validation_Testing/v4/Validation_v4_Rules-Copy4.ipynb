# %%
"""
Purpose: To Run the proofreading of neurons in the 
test set and measure the precision and recall of the new rules



"""
# Out:
# '\nPurpose: To Run the proofreading of neurons in the \ntest set and measure the precision and recall of the new rules\n\n\n\n'

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import datajoint as dj
import trimesh
from tqdm.notebook import tqdm
from pathlib import Path

from os import sys
sys.path.append("/meshAfterParty/")
sys.path.append("/meshAfterParty/meshAfterParty")

import datajoint_utils as du
from importlib import reload
# Out:
# INFO - 2021-04-30 20:50:16,963 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-04-30 20:50:16,965 - settings - Setting database.user to celiib
# INFO - 2021-04-30 20:50:16,966 - settings - Setting database.password to newceliipass
# INFO - 2021-04-30 20:50:16,969 - settings - Setting stores to {'minnie65': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65', 'stage': '/mnt/dj-stor01/platinum/minnie65'}, 'meshes': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/meshes', 'stage': '/mnt/dj-stor01/platinum/minnie65/02/meshes'}, 'decimated_meshes': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/decimated_meshes', 'stage': '/mnt/dj-stor01/platinum/minnie65/02/decimated_meshes'}, 'skeletons': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/skeletons'}}
# INFO - 2021-04-30 20:50:16,969 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-04-30 20:50:16,979 - connection - Connected celiib@at-database.ad.bcm.edu:3306
# Connecting celiib@at-database.ad.bcm.edu:3306
# INFO - 2021-04-30 20:50:17,378 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-04-30 20:50:17,382 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-04-30 20:50:17,383 - settings - Setting database.user to celiib
# INFO - 2021-04-30 20:50:17,383 - settings - Setting database.password to newceliipass
# INFO - 2021-04-30 20:50:17,383 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-04-30 20:50:17,384 - settings - Setting database.user to celiib
# INFO - 2021-04-30 20:50:17,384 - settings - Setting database.password to newceliipass
# INFO - 2021-04-30 20:50:17,385 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-04-30 20:50:17,792 - settings - Setting enable_python_native_blobs to True

# %%
#configuring will include the adapters
minnie,schema = du.configure_minnie_vm()
# Out:
# INFO - 2021-04-30 20:50:17,928 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-04-30 20:50:17,929 - settings - Setting database.user to celiib
# INFO - 2021-04-30 20:50:17,929 - settings - Setting database.password to newceliipass
# INFO - 2021-04-30 20:50:17,930 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-04-30 20:50:18,387 - settings - Setting enable_python_native_blobs to True

# %%
import validation_utils as vu
import neuron_visualizations as nviz
import neuron_utils as nru
import proofreading_utils as pru
import time
import system_utils as su

# %% [markdown]
# # Runnig the validation

# %%
"""
Psueodocode: 
1) Pull down the segment ids of the valid neurons

For each neuron
1) Dwonload the neuron object
2) Run the Proofreading
3) Print out the validation plot
4) Save the validation df

"""
# Out:
# '\nPsueodocode: \n1) Pull down the segment ids of the valid neurons\n\nFor each neuron\n1) Dwonload the neuron object\n2) Run the Proofreading\n3) Print out the validation plot\n4) Save the validation df\n\n'

# %%
segment_ids = minnie.AutoProofreadValidationBorderNeurons().fetch("segment_id")

# %%
job_idx = 4
job_step = 5
segments_to_process = segment_ids[job_idx*job_step:(job_idx+1)*job_step]
segments_to_process
# Out:
# array([864691136099807093, 864691135113167769, 864691135589906955,
#        864691136370815112, 864691135645592260])

# %%
for seg_id in segments_to_process:
    print(f"\n--- Working on Neuron {seg_id} --")
    st = time.time()
    
    
    #1) Dwonload the neuron object
    neuron_obj = du.fetch_neuron_obj_manual(seg_id,
                                       border_validation=True)
    
    (filt_neuron,
     return_synapse_df_revised,
    return_validation_df_revised) =  vu.filtered_neuron_score(neuron_obj = neuron_obj,   
                        filter_list = pru.v4_exc_filters(),
                        plot_limb_branch_filter_with_disconnect_effect = False,
                        verbose = False,
                        plot_score=False)
    
    vu.synapse_validation_df_to_score_plot(return_validation_df_revised)
    
    su.compressed_pickle(return_validation_df_revised,f"./validation_data/{seg_id}_validation_df")
    
    print(f"Total time for neuron {seg_id}: {time.time() - st}")
# Out:
# --- Working on Neuron 864691136099807093 --
# Decompressing Neuron in minimal output mode...please wait
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# Apply the presyn non_error
# For presyn: # valid synapses = 2, # error synapses  = 25, # error presyns = 16
# For postsyn: # valid synapses = 4817, # error synapses  = 2, # error presyns = 0
# Synapsse Results:
# Total Number of Synapses = 4846
# n_valid_syn_ids_presyn = 2
# n_errored_syn_ids_presyn = 25
# n_valid_syn_ids_postsyn = 4817
# n_errored_syn_ids_postsyn = 2
# Segment Id = 864691136099807093
# Postsyn counts:
# TP:4805
# TN:0
# FP:12
# FN:2
# Presyn counts:
# TP:2
# TN:9
# FP:0
# FN:0
# Saved object at /neuron_mesh_tools/Auto_Proofreading/Validation_Testing/v4/validation_data/864691136099807093_validation_df.pbz2
# File size is 0.096965 MB
# Total time for neuron 864691136099807093: 143.55834436416626
#
# --- Working on Neuron 864691135113167769 --
# Decompressing Neuron in minimal output mode...please wait
#
#
#  ----- Working on coordinate 0: [ 636400.34605221 1008930.48690478  854151.30585769]--------
# kiss_check = True
# winning_downstream = 7,error_downstream = [8 9]
# coordinate [ 636400.34605221 1008930.48690478  854151.30585769] had error branches [8 9]--------
#
#
#  ----- Working on coordinate 1: [ 647752.87182908 1013423.50629697  838676.90001795]--------
# kiss_check = True
# winning_downstream = 26,error_downstream = [23 16]
# coordinate [ 647752.87182908 1013423.50629697  838676.90001795] had error branches [23 16]--------
#
#
#  ----- Working on coordinate 2: [ 650026.12332756 1010570.97509635  814685.94043103]--------
# kiss_check = True
# winning_downstream = 31,error_downstream = [22 32 20]
# coordinate [ 650026.12332756 1010570.97509635  814685.94043103] had error branches [22 32 20]--------
#
#
#  ----- Working on coordinate 3: [ 744501.88036481 1000179.96935826  791231.52110387]--------
# kiss_check = True
# winning_downstream = 47,error_downstream = [51 45]
# coordinate [ 744501.88036481 1000179.96935826  791231.52110387] had error branches [51 45]--------
#
#
#  ----- Working on coordinate 4: [ 747369.79142313 1002917.79034136  779432.38840993]--------
# kiss_check = True
# winning_downstream = 59,error_downstream = [57 60]
# coordinate [ 747369.79142313 1002917.79034136  779432.38840993] had error branches [57 60]--------
#
#
#  ----- Working on coordinate 5: [752076.55 957781.05 843405.8 ]--------
# kiss_check = True
# winning_downstream = 70,error_downstream = [65 44]
# coordinate [752076.55 957781.05 843405.8 ] had error branches [65 44]--------
#
#
#  ----- Working on coordinate 6: [756934.30176889 986478.18244346 749270.32883012]--------
# kiss_check = True
# Working on Kissing check because possible upstream matches greater than 1: [74, 75]
# VBox(children=(Figure(camera=PerspectiveCamera(fov=46.0, position=(0.0, 0.0, 2.0), projectionMatrix=(1.0, 0.0,…
# ** triggered kiss check cut becuase cut_bbox_longest_side = 403.6858532617334***
# winning_downstream = 75,error_downstream = [73 74]
# coordinate [756934.30176889 986478.18244346 749270.32883012] had error branches [73 74]--------
#
#
#  ----- Working on coordinate 7: [793712.36231933 838665.07666046 799466.64907415]--------
# kiss_check = True
# winning_downstream = 94,error_downstream = [80 98]
# coordinate [793712.36231933 838665.07666046 799466.64907415] had error branches [80 98]--------
#
#
#  ----- Working on coordinate 8: [793762.8 836720.4 799250.6]--------
# kiss_check = True
# winning_downstream = 96,error_downstream = [99 82]
# coordinate [793762.8 836720.4 799250.6] had error branches [99 82]--------
#
#
#  ----- Working on coordinate 9: [794027.75627006 778379.46427594 792865.79932295]--------
# kiss_check = True
# winning_downstream = None,error_downstream = []
# coordinate [794027.75627006 778379.46427594 792865.79932295] had error branches []--------
#
#
#  ----- Working on coordinate 10: [795503.50531092 765681.73549365 791592.79784363]--------
# kiss_check = True
# winning_downstream = None,error_downstream = []
# coordinate [795503.50531092 765681.73549365 791592.79784363] had error branches []--------
#
#
#  ----- Working on coordinate 11: [804980.11042063 902785.50038308 826726.82628187]--------
# kiss_check = True
# winning_downstream = 116,error_downstream = [124 131]
# coordinate [804980.11042063 902785.50038308 826726.82628187] had error branches [124 131]--------
#
#
#  ----- Working on coordinate 12: [807284.9157971  958050.5842222  842313.80322411]--------
# kiss_check = True
# winning_downstream = None,error_downstream = []
# coordinate [807284.9157971  958050.5842222  842313.80322411] had error branches []--------
#
#
#  ----- Working on coordinate 13: [807452.16217986 838979.26674592 822200.96142541]--------
# kiss_check = True
# winning_downstream = None,error_downstream = []
# coordinate [807452.16217986 838979.26674592 822200.96142541] had error branches []--------
#
#
#  ----- Working on coordinate 14: [817271.03363775 759773.87024843 816703.83989338]--------
# kiss_check = True
# winning_downstream = 159,error_downstream = [156 158 154]
# coordinate [817271.03363775 759773.87024843 816703.83989338] had error branches [156 158 154]--------
#
#
#  ----- Working on coordinate 15: [817773.25 834461.15 819459.95]--------
# kiss_check = True
# winning_downstream = 162,error_downstream = [160 161]
# coordinate [817773.25 834461.15 819459.95] had error branches [160 161]--------
# limb_branch_dict_to_cancel = {'L1': array([  8,   9,  23,  16,  22,  32,  20,  51,  45,  57,  60,  65,  44,
#         73,  74,  80,  98,  99,  82, 124, 131, 156, 158, 154, 160, 161])}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {'L1': array([70, 74])}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# Apply the presyn non_error
# For presyn: # valid synapses = 31, # error synapses  = 176, # error presyns = 29
# For postsyn: # valid synapses = 2223, # error synapses  = 32, # error presyns = 0
# Synapsse Results:
# Total Number of Synapses = 2462
# n_valid_syn_ids_presyn = 31
# n_errored_syn_ids_presyn = 176
# n_valid_syn_ids_postsyn = 2223
# n_errored_syn_ids_postsyn = 32
# Segment Id = 864691135113167769
# Postsyn counts:
# TP:2216
# TN:7
# FP:7
# FN:25
# Presyn counts:
# TP:9
# TN:147
# FP:22
# FN:0
# Saved object at /neuron_mesh_tools/Auto_Proofreading/Validation_Testing/v4/validation_data/864691135113167769_validation_df.pbz2
# File size is 0.04917 MB
# Total time for neuron 864691135113167769: 188.4417018890381
#
# --- Working on Neuron 864691135589906955 --
# Decompressing Neuron in minimal output mode...please wait
#
#
#  ----- Working on coordinate 0: [1272119.96677466  775473.76335151  782832.47911201]--------
# kiss_check = True
# winning_downstream = None,error_downstream = []
# coordinate [1272119.96677466  775473.76335151  782832.47911201] had error branches []--------
#
#
#  ----- Working on coordinate 1: [1273833.42877536  775173.40529203  784058.92551187]--------
# kiss_check = True
# winning_downstream = 89,error_downstream = [91 94]
# coordinate [1273833.42877536  775173.40529203  784058.92551187] had error branches [91 94]--------
#
#
#  ----- Working on coordinate 2: [1278211.65237269  774986.34297231  784433.59353395]--------
# kiss_check = True
# Working on Kissing check because possible upstream matches greater than 1: [98, 99]
# winning_downstream = 99,error_downstream = [98 87]
# coordinate [1278211.65237269  774986.34297231  784433.59353395] had error branches [98 87]--------
#
#
#  ----- Working on coordinate 3: [1326877.347943    789882.89626418  795791.35485664]--------
# kiss_check = True
# winning_downstream = 104,error_downstream = [107  93]
# coordinate [1326877.347943    789882.89626418  795791.35485664] had error branches [107  93]--------
#
#
#  ----- Working on coordinate 4: [1333278.0812506   782904.82329901  792367.00204567]--------
# kiss_check = True
# winning_downstream = None,error_downstream = []
# coordinate [1333278.0812506   782904.82329901  792367.00204567] had error branches []--------
#
#
#  ----- Working on coordinate 5: [1333792.37969466  786072.64111202  784076.09334875]--------
# kiss_check = True
# winning_downstream = None,error_downstream = [122 126 115]
# coordinate [1333792.37969466  786072.64111202  784076.09334875] had error branches [122 126 115]--------
#
#
#  ----- Working on coordinate 6: [1339012.95028251  776247.89291625  789389.03285618]--------
# kiss_check = True
# winning_downstream = None,error_downstream = [111 121 124 125 130 131 132]
# coordinate [1339012.95028251  776247.89291625  789389.03285618] had error branches [111 121 124 125 130 131 132]--------
#
#
#  ----- Working on coordinate 7: [1349896.87117128  894282.95408682  839030.78300084]--------
# kiss_check = True
# winning_downstream = None,error_downstream = []
# coordinate [1349896.87117128  894282.95408682  839030.78300084] had error branches []--------
#
#
#  ----- Working on coordinate 8: [1365277.51317043  803588.85670767  780131.54467238]--------
# kiss_check = True
# winning_downstream = 141,error_downstream = [139 140 127]
# coordinate [1365277.51317043  803588.85670767  780131.54467238] had error branches [139 140 127]--------
#
#
#  ----- Working on coordinate 9: [1368449.22501035  842670.49042723  789342.31932781]--------
# kiss_check = True
# winning_downstream = 11,error_downstream = [56 66]
# coordinate [1368449.22501035  842670.49042723  789342.31932781] had error branches [56 66]--------
#
#
#  ----- Working on coordinate 10: [1368908.42383489  799567.57222881  763758.57953885]--------
# kiss_check = True
# winning_downstream = None,error_downstream = []
# coordinate [1368908.42383489  799567.57222881  763758.57953885] had error branches []--------
#
#
#  ----- Working on coordinate 11: [1371230.60515693  769516.29310575  757549.37989319]--------
# kiss_check = True
# winning_downstream = None,error_downstream = [156 157 149]
# coordinate [1371230.60515693  769516.29310575  757549.37989319] had error branches [156 157 149]--------
#
#
#  ----- Working on coordinate 12: [1371779.5822821   796759.78174711  763495.9       ]--------
# kiss_check = True
# winning_downstream = 148,error_downstream = [153 158 142]
# coordinate [1371779.5822821   796759.78174711  763495.9       ] had error branches [153 158 142]--------
#
#
#  ----- Working on coordinate 13: [1376752.80959531  760479.73839874  761449.0503935 ]--------
# kiss_check = True
# winning_downstream = None,error_downstream = [154 159 160]
# coordinate [1376752.80959531  760479.73839874  761449.0503935 ] had error branches [154 159 160]--------
#
#
#  ----- Working on coordinate 14: [1398063.04398429  841347.17418116  797150.6336296 ]--------
# kiss_check = True
# winning_downstream = None,error_downstream = [77 82 83 84]
# coordinate [1398063.04398429  841347.17418116  797150.6336296 ] had error branches [77 82 83 84]--------
# limb_branch_dict_to_cancel = {'L8': array([ 91,  94,  98,  87, 107,  93, 122, 126, 115, 111, 121, 124, 125,
#        130, 131, 132, 139, 140, 127,  56,  66, 156, 157, 149, 153, 158,
#        142, 154, 159, 160,  77,  82,  83,  84])}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {'L4': [8, 3, 6, 7]}
# limb_branch_dict_to_cancel = {}
# Apply the presyn non_error
# For presyn: # valid synapses = 13, # error synapses  = 378, # error presyns = 40
# For postsyn: # valid synapses = 5698, # error synapses  = 157, # error presyns = 0
# Synapsse Results:
# Total Number of Synapses = 6246
# n_valid_syn_ids_presyn = 13
# n_errored_syn_ids_presyn = 378
# n_valid_syn_ids_postsyn = 5698
# n_errored_syn_ids_postsyn = 157
# Segment Id = 864691135589906955
# Postsyn counts:
# TP:5681
# TN:13
# FP:17
# FN:144
# Presyn counts:
# TP:7
# TN:336
# FP:6
# FN:2
# Saved object at /neuron_mesh_tools/Auto_Proofreading/Validation_Testing/v4/validation_data/864691135589906955_validation_df.pbz2
# File size is 0.123677 MB
# Total time for neuron 864691135589906955: 294.6822233200073
#
# --- Working on Neuron 864691136370815112 --
# Decompressing Neuron in minimal output mode...please wait
#
#
#  ----- Working on coordinate 0: [1338920.72874933  676864.94436049  795604.08114899]--------
# kiss_check = True
# winning_downstream = 0,error_downstream = [3 4 5]
# coordinate [1338920.72874933  676864.94436049  795604.08114899] had error branches [3 4 5]--------
#
#
#  ----- Working on coordinate 1: [1343942.71429529  725455.60617988  810761.85015826]--------
# kiss_check = True
# winning_downstream = None,error_downstream = []
# coordinate [1343942.71429529  725455.60617988  810761.85015826] had error branches []--------
#
#
#  ----- Working on coordinate 2: [1347647.0723884   733560.02333853  815249.17033973]--------
# kiss_check = True
# winning_downstream = None,error_downstream = []
# coordinate [1347647.0723884   733560.02333853  815249.17033973] had error branches []--------
#
#
#  ----- Working on coordinate 3: [1348993.14569715  650538.41693819  813854.82333989]--------
# kiss_check = True
# winning_downstream = None,error_downstream = []
# coordinate [1348993.14569715  650538.41693819  813854.82333989] had error branches []--------
# limb_branch_dict_to_cancel = {'L6': array([3, 4, 5])}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {'L2': [7]}
# limb_branch_dict_to_cancel = {}
# Apply the presyn non_error
# For presyn: # valid synapses = 10, # error synapses  = 24, # error presyns = 20
# For postsyn: # valid synapses = 3892, # error synapses  = 64, # error presyns = 0
# Synapsse Results:
# Total Number of Synapses = 3990
# n_valid_syn_ids_presyn = 10
# n_errored_syn_ids_presyn = 24
# n_valid_syn_ids_postsyn = 3892
# n_errored_syn_ids_postsyn = 64
# Segment Id = 864691136370815112
# Postsyn counts:
# TP:3892
# TN:0
# FP:0
# FN:64
# Presyn counts:
# TP:6
# TN:3
# FP:4
# FN:1
# Saved object at /neuron_mesh_tools/Auto_Proofreading/Validation_Testing/v4/validation_data/864691136370815112_validation_df.pbz2
# File size is 0.08056 MB
# Total time for neuron 864691136370815112: 138.39687061309814
#
# --- Working on Neuron 864691135645592260 --
# Decompressing Neuron in minimal output mode...please wait
#
#
#  ----- Working on coordinate 0: [1108018.   669239.   992496.2]--------
# kiss_check = True
# winning_downstream = 5,error_downstream = [6 4]
# coordinate [1108018.   669239.   992496.2] had error branches [6 4]--------
#
#
#  ----- Working on coordinate 1: [1160807.65475588  642008.37968538  954025.54598041]--------
# kiss_check = True
# winning_downstream = 23,error_downstream = [25 17]
# coordinate [1160807.65475588  642008.37968538  954025.54598041] had error branches [25 17]--------
#
#
#  ----- Working on coordinate 2: [1161539.25381372  644671.27858742  954033.67945663]--------
# kiss_check = True
# winning_downstream = 24,error_downstream = [26 28]
# coordinate [1161539.25381372  644671.27858742  954033.67945663] had error branches [26 28]--------
#
#
#  ----- Working on coordinate 3: [1177920.54002733  983714.90675203 1080512.70437534]--------
# kiss_check = True
# winning_downstream = 30,error_downstream = [43 47 48]
# coordinate [1177920.54002733  983714.90675203 1080512.70437534] had error branches [43 47 48]--------
#
#
#  ----- Working on coordinate 4: [1180708.61393678  690209.03551246 1032158.66993392]--------
# kiss_check = True
# winning_downstream = 54,error_downstream = [51 45]
# coordinate [1180708.61393678  690209.03551246 1032158.66993392] had error branches [51 45]--------
#
#
#  ----- Working on coordinate 5: [1183664.68841281  982718.5503451  1079327.58273812]--------
# kiss_check = True
# Working on Kissing check because possible upstream matches greater than 1: [44, 49]
# VBox(children=(Figure(camera=PerspectiveCamera(fov=46.0, position=(0.0, 0.0, 2.0), projectionMatrix=(1.0, 0.0,…
# VBox(children=(Figure(camera=PerspectiveCamera(fov=46.0, position=(0.0, 0.0, 2.0), projectionMatrix=(1.0, 0.0,…
# VBox(children=(Figure(camera=PerspectiveCamera(fov=46.0, position=(0.0, 0.0, 2.0), projectionMatrix=(1.0, 0.0,…
# VBox(children=(Figure(camera=PerspectiveCamera(fov=46.0, position=(0.0, 0.0, 2.0), projectionMatrix=(1.0, 0.0,…
# winning_downstream = 44,error_downstream = [49 63 64 38]
# coordinate [1183664.68841281  982718.5503451  1079327.58273812] had error branches [49 63 64 38]--------
#
#
#  ----- Working on coordinate 6: [1211671.60640522  760184.99578821  977042.97469628]--------
# kiss_check = True
# winning_downstream = None,error_downstream = [80 82 85 87 78]
# coordinate [1211671.60640522  760184.99578821  977042.97469628] had error branches [80 82 85 87 78]--------
#
#
#  ----- Working on coordinate 7: [1213230.57359707  753876.49128702  965365.68345297]--------
# kiss_check = True
# winning_downstream = None,error_downstream = []
# coordinate [1213230.57359707  753876.49128702  965365.68345297] had error branches []--------
#
#
#  ----- Working on coordinate 8: [1215442.92459927  766084.81202729  938412.84748794]--------
# kiss_check = True
# winning_downstream = 102,error_downstream = [104  90]
# coordinate [1215442.92459927  766084.81202729  938412.84748794] had error branches [104  90]--------
#
#
#  ----- Working on coordinate 9: [1222411.22126537  833232.07857958  953282.32581396]--------
# kiss_check = True
# winning_downstream = None,error_downstream = []
# coordinate [1222411.22126537  833232.07857958  953282.32581396] had error branches []--------
#
#
#  ----- Working on coordinate 10: [1230361.95404703  763511.97065787  972487.01358683]--------
# kiss_check = True
# winning_downstream = None,error_downstream = []
# coordinate [1230361.95404703  763511.97065787  972487.01358683] had error branches []--------
# limb_branch_dict_to_cancel = {'L2': array([  6,   4,  25,  17,  26,  28,  43,  47,  48,  51,  45,  49,  63,
#         64,  38,  80,  82,  85,  87,  78, 104,  90])}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# Warning: start endpoint was not an end node: [1188470.  640209.  965368.] but not erroring
# Becasue catch_error = True, Gracefullly recovering from error index 1 is out of bounds for axis 0 with size 1
# limb_branch_dict_to_cancel = {}
# Apply the presyn non_error
# For presyn: # valid synapses = 36, # error synapses  = 123, # error presyns = 11
# For postsyn: # valid synapses = 3128, # error synapses  = 15, # error presyns = 0
# Synapsse Results:
# Total Number of Synapses = 3302
# n_valid_syn_ids_presyn = 36
# n_errored_syn_ids_presyn = 123
# n_valid_syn_ids_postsyn = 3128
# n_errored_syn_ids_postsyn = 15
# Segment Id = 864691135645592260
# Postsyn counts:
# TP:3127
# TN:1
# FP:1
# FN:14
# Presyn counts:
# TP:28
# TN:105
# FP:8
# FN:7
# Saved object at /neuron_mesh_tools/Auto_Proofreading/Validation_Testing/v4/validation_data/864691135645592260_validation_df.pbz2
# File size is 0.067223 MB
# Total time for neuron 864691135645592260: 149.10446047782898
