# %%
"""
Purpose: To Run the proofreading of neurons in the 
test set and measure the precision and recall of the new rules



"""
# Out:
# '\nPurpose: To Run the proofreading of neurons in the \ntest set and measure the precision and recall of the new rules\n\n\n\n'

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import datajoint as dj
import trimesh
from tqdm.notebook import tqdm
from pathlib import Path

from os import sys
sys.path.append("/meshAfterParty/")
sys.path.append("/meshAfterParty/meshAfterParty")

import datajoint_utils as du
from importlib import reload
# Out:
# INFO - 2021-04-24 10:16:33,430 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-04-24 10:16:33,432 - settings - Setting database.user to celiib
# INFO - 2021-04-24 10:16:33,432 - settings - Setting database.password to newceliipass
# INFO - 2021-04-24 10:16:33,438 - settings - Setting stores to {'minnie65': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65', 'stage': '/mnt/dj-stor01/platinum/minnie65'}, 'meshes': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/meshes', 'stage': '/mnt/dj-stor01/platinum/minnie65/02/meshes'}, 'decimated_meshes': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/decimated_meshes', 'stage': '/mnt/dj-stor01/platinum/minnie65/02/decimated_meshes'}, 'skeletons': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/skeletons'}}
# INFO - 2021-04-24 10:16:33,439 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-04-24 10:16:33,451 - connection - Connected celiib@at-database.ad.bcm.edu:3306
# Connecting celiib@at-database.ad.bcm.edu:3306
# INFO - 2021-04-24 10:16:33,838 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-04-24 10:16:33,843 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-04-24 10:16:33,844 - settings - Setting database.user to celiib
# INFO - 2021-04-24 10:16:33,845 - settings - Setting database.password to newceliipass
# INFO - 2021-04-24 10:16:33,845 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-04-24 10:16:33,846 - settings - Setting database.user to celiib
# INFO - 2021-04-24 10:16:33,847 - settings - Setting database.password to newceliipass
# INFO - 2021-04-24 10:16:33,850 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-04-24 10:16:34,280 - settings - Setting enable_python_native_blobs to True

# %%
#configuring will include the adapters
minnie,schema = du.configure_minnie_vm()
# Out:
# INFO - 2021-04-24 10:16:34,386 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-04-24 10:16:34,387 - settings - Setting database.user to celiib
# INFO - 2021-04-24 10:16:34,387 - settings - Setting database.password to newceliipass
# INFO - 2021-04-24 10:16:34,388 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-04-24 10:16:34,883 - settings - Setting enable_python_native_blobs to True

# %%
import validation_utils as vu
import neuron_visualizations as nviz
import neuron_utils as nru
import proofreading_utils as pru
import time
import system_utils as su

# %% [markdown]
# # Runnig the validation

# %%
"""
Psueodocode: 
1) Pull down the segment ids of the valid neurons

For each neuron
1) Dwonload the neuron object
2) Run the Proofreading
3) Print out the validation plot
4) Save the validation df

"""
# Out:
# '\nPsueodocode: \n1) Pull down the segment ids of the valid neurons\n\nFor each neuron\n1) Dwonload the neuron object\n2) Run the Proofreading\n3) Print out the validation plot\n4) Save the validation df\n\n'

# %%
segment_ids = minnie.AutoProofreadValidationBorderNeurons().fetch("segment_id")

# %%
job_idx = 4
job_step = 5
segments_to_process = segment_ids[job_idx*job_step:(job_idx+1)*job_step]
segments_to_process
# Out:
# array([864691136099807093, 864691135113167769, 864691135589906955,
#        864691136370815112, 864691135645592260])

# %%
for seg_id in segments_to_process:
    print(f"\n--- Working on Neuron {seg_id} --")
    st = time.time()
    
    
    #1) Dwonload the neuron object
    neuron_obj = du.fetch_neuron_obj_manual(seg_id,
                                       border_validation=True)
    
    (filt_neuron,
     return_synapse_df_revised,
    return_validation_df_revised) =  vu.filtered_neuron_score(neuron_obj = neuron_obj,   
                        filter_list = pru.v4_exc_filters(),
                        plot_limb_branch_filter_with_disconnect_effect = False,
                        verbose = False,
                        plot_score=False)
    
    vu.synapse_validation_df_to_score_plot(return_validation_df_revised)
    
    su.compressed_pickle(return_validation_df_revised,f"./validation_data/{seg_id}_validation_df")
    
    print(f"Total time for neuron {seg_id}: {time.time() - st}")
# Out:
# --- Working on Neuron 864691136099807093 --
# Decompressing Neuron in minimal output mode...please wait
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# Apply the presyn non_error
# For presyn: # valid synapses = 2, # error synapses  = 25, # error presyns = 16
# For postsyn: # valid synapses = 4817, # error synapses  = 2, # error presyns = 0
# Synapsse Results:
# Total Number of Synapses = 4846
# n_valid_syn_ids_presyn = 2
# n_errored_syn_ids_presyn = 25
# n_valid_syn_ids_postsyn = 4817
# n_errored_syn_ids_postsyn = 2
# Segment Id = 864691136099807093
# Postsyn counts:
# TP:4805
# TN:0
# FP:12
# FN:2
# Presyn counts:
# TP:2
# TN:9
# FP:0
# FN:0
# Saved object at /neuron_mesh_tools/Auto_Proofreading/Validation_Testing/v4/validation_data/864691136099807093_validation_df.pbz2
# File size is 0.096965 MB
# Total time for neuron 864691136099807093: 138.54780340194702
#
# --- Working on Neuron 864691135113167769 --
# Decompressing Neuron in minimal output mode...please wait
#
#
#  ----- Working on coordinate [ 636400.34605221 1008930.48690478  854151.30585769]--------
# coordinate [ 636400.34605221 1008930.48690478  854151.30585769] had error branches []--------
#
#
#  ----- Working on coordinate [ 647752.87182908 1013423.50629697  838676.90001795]--------
# coordinate [ 647752.87182908 1013423.50629697  838676.90001795] had error branches [8, 9]--------
#
#
#  ----- Working on coordinate [ 650026.12332756 1010570.97509635  814685.94043103]--------
# coordinate [ 650026.12332756 1010570.97509635  814685.94043103] had error branches [8, 9, 23, 16]--------
#
#
#  ----- Working on coordinate [ 744501.88036481 1000179.96935826  791231.52110387]--------
# coordinate [ 744501.88036481 1000179.96935826  791231.52110387] had error branches [8, 9, 23, 16, 22, 32, 20]--------
#
#
#  ----- Working on coordinate [ 747369.79142313 1002917.79034136  779432.38840993]--------
# coordinate [ 747369.79142313 1002917.79034136  779432.38840993] had error branches [8, 9, 23, 16, 22, 32, 20, 51, 45]--------
#
#
#  ----- Working on coordinate [752076.55 957781.05 843405.8 ]--------
# coordinate [752076.55 957781.05 843405.8 ] had error branches [8, 9, 23, 16, 22, 32, 20, 51, 45, 57, 60]--------
#
#
#  ----- Working on coordinate [756934.30176889 986478.18244346 749270.32883012]--------
# coordinate [756934.30176889 986478.18244346 749270.32883012] had error branches [8, 9, 23, 16, 22, 32, 20, 51, 45, 57, 60, 65, 44]--------
#
#
#  ----- Working on coordinate [793712.36231933 838665.07666046 799466.64907415]--------
# coordinate [793712.36231933 838665.07666046 799466.64907415] had error branches [8, 9, 23, 16, 22, 32, 20, 51, 45, 57, 60, 65, 44, 73, 74]--------
#
#
#  ----- Working on coordinate [793762.8 836720.4 799250.6]--------
# coordinate [793762.8 836720.4 799250.6] had error branches [8, 9, 23, 16, 22, 32, 20, 51, 45, 57, 60, 65, 44, 73, 74, 80, 98]--------
#
#
#  ----- Working on coordinate [794027.75627006 778379.46427594 792865.79932295]--------
# coordinate [794027.75627006 778379.46427594 792865.79932295] had error branches [8, 9, 23, 16, 22, 32, 20, 51, 45, 57, 60, 65, 44, 73, 74, 80, 98, 99, 82]--------
#
#
#  ----- Working on coordinate [795503.50531092 765681.73549365 791592.79784363]--------
# coordinate [795503.50531092 765681.73549365 791592.79784363] had error branches [8, 9, 23, 16, 22, 32, 20, 51, 45, 57, 60, 65, 44, 73, 74, 80, 98, 99, 82, 93, 100]--------
#
#
#  ----- Working on coordinate [804980.11042063 902785.50038308 826726.82628187]--------
# coordinate [804980.11042063 902785.50038308 826726.82628187] had error branches [8, 9, 23, 16, 22, 32, 20, 51, 45, 57, 60, 65, 44, 73, 74, 80, 98, 99, 82, 93, 100]--------
#
#
#  ----- Working on coordinate [807284.9157971  958050.5842222  842313.80322411]--------
# coordinate [807284.9157971  958050.5842222  842313.80322411] had error branches [8, 9, 23, 16, 22, 32, 20, 51, 45, 57, 60, 65, 44, 73, 74, 80, 98, 99, 82, 93, 100, 124, 131]--------
#
#
#  ----- Working on coordinate [807452.16217986 838979.26674592 822200.96142541]--------
# coordinate [807452.16217986 838979.26674592 822200.96142541] had error branches [8, 9, 23, 16, 22, 32, 20, 51, 45, 57, 60, 65, 44, 73, 74, 80, 98, 99, 82, 93, 100, 124, 131, 141, 144]--------
#
#
#  ----- Working on coordinate [817271.03363775 759773.87024843 816703.83989338]--------
# coordinate [817271.03363775 759773.87024843 816703.83989338] had error branches [8, 9, 23, 16, 22, 32, 20, 51, 45, 57, 60, 65, 44, 73, 74, 80, 98, 99, 82, 93, 100, 124, 131, 141, 144, 142, 134]--------
#
#
#  ----- Working on coordinate [817773.25 834461.15 819459.95]--------
# coordinate [817773.25 834461.15 819459.95] had error branches [8, 9, 23, 16, 22, 32, 20, 51, 45, 57, 60, 65, 44, 73, 74, 80, 98, 99, 82, 93, 100, 124, 131, 141, 144, 142, 134, 156, 158, 154]--------
# limb_branch_dict_to_cancel = {'L1': array([  8,   9,  23,  16,  22,  32,  20,  51,  45,  57,  60,  65,  44,
#         73,  74,  80,  98,  99,  82,  93, 100, 124, 131, 141, 144, 142,
#        134, 156, 158, 154, 160, 161])}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# Apply the presyn non_error
# For presyn: # valid synapses = 0, # error synapses  = 207, # error presyns = 29
# For postsyn: # valid synapses = 2218, # error synapses  = 37, # error presyns = 0
# Synapsse Results:
# Total Number of Synapses = 2462
# n_valid_syn_ids_presyn = 0
# n_errored_syn_ids_presyn = 207
# n_valid_syn_ids_postsyn = 2218
# n_errored_syn_ids_postsyn = 37
# Segment Id = 864691135113167769
# Postsyn counts:
# TP:2213
# TN:9
# FP:5
# FN:28
# Presyn counts:
# TP:0
# TN:169
# FP:0
# FN:9
# Saved object at /neuron_mesh_tools/Auto_Proofreading/Validation_Testing/v4/validation_data/864691135113167769_validation_df.pbz2
# File size is 0.049159 MB
# Total time for neuron 864691135113167769: 124.75752973556519
#
# --- Working on Neuron 864691135589906955 --
# Decompressing Neuron in minimal output mode...please wait
#
#
#  ----- Working on coordinate [1272119.96677466  775473.76335151  782832.47911201]--------
# coordinate [1272119.96677466  775473.76335151  782832.47911201] had error branches []--------
#
#
#  ----- Working on coordinate [1273833.42877536  775173.40529203  784058.92551187]--------
# coordinate [1273833.42877536  775173.40529203  784058.92551187] had error branches [90, 92]--------
#
#
#  ----- Working on coordinate [1278211.65237269  774986.34297231  784433.59353395]--------
# coordinate [1278211.65237269  774986.34297231  784433.59353395] had error branches [90, 92, 91, 94]--------
#
#
#  ----- Working on coordinate [1326877.347943    789882.89626418  795791.35485664]--------
# coordinate [1326877.347943    789882.89626418  795791.35485664] had error branches [90, 92, 91, 94, 98, 87]--------
#
#
#  ----- Working on coordinate [1333278.0812506   782904.82329901  792367.00204567]--------
# coordinate [1333278.0812506   782904.82329901  792367.00204567] had error branches [90, 92, 91, 94, 98, 87, 107, 93]--------
#
#
#  ----- Working on coordinate [1333792.37969466  786072.64111202  784076.09334875]--------
# coordinate [1333792.37969466  786072.64111202  784076.09334875] had error branches [90, 92, 91, 94, 98, 87, 107, 93, 118, 114]--------
#
#
#  ----- Working on coordinate [1339012.95028251  776247.89291625  789389.03285618]--------
# coordinate [1339012.95028251  776247.89291625  789389.03285618] had error branches [90, 92, 91, 94, 98, 87, 107, 93, 118, 114, 122, 126, 115]--------
#
#
#  ----- Working on coordinate [1349896.87117128  894282.95408682  839030.78300084]--------
# coordinate [1349896.87117128  894282.95408682  839030.78300084] had error branches [90, 92, 91, 94, 98, 87, 107, 93, 118, 114, 122, 126, 115, 111, 121, 124, 125, 130, 131, 132]--------
#
#
#  ----- Working on coordinate [1365277.51317043  803588.85670767  780131.54467238]--------
# coordinate [1365277.51317043  803588.85670767  780131.54467238] had error branches [90, 92, 91, 94, 98, 87, 107, 93, 118, 114, 122, 126, 115, 111, 121, 124, 125, 130, 131, 132]--------
#
#
#  ----- Working on coordinate [1368449.22501035  842670.49042723  789342.31932781]--------
# coordinate [1368449.22501035  842670.49042723  789342.31932781] had error branches [90, 92, 91, 94, 98, 87, 107, 93, 118, 114, 122, 126, 115, 111, 121, 124, 125, 130, 131, 132, 139, 140, 127]--------
#
#
#  ----- Working on coordinate [1368908.42383489  799567.57222881  763758.57953885]--------
# coordinate [1368908.42383489  799567.57222881  763758.57953885] had error branches [90, 92, 91, 94, 98, 87, 107, 93, 118, 114, 122, 126, 115, 111, 121, 124, 125, 130, 131, 132, 139, 140, 127, 56, 66]--------
#
#
#  ----- Working on coordinate [1371230.60515693  769516.29310575  757549.37989319]--------
# coordinate [1371230.60515693  769516.29310575  757549.37989319] had error branches [90, 92, 91, 94, 98, 87, 107, 93, 118, 114, 122, 126, 115, 111, 121, 124, 125, 130, 131, 132, 139, 140, 127, 56, 66, 145, 143]--------
#
#
#  ----- Working on coordinate [1371779.5822821   796759.78174711  763495.9       ]--------
# coordinate [1371779.5822821   796759.78174711  763495.9       ] had error branches [90, 92, 91, 94, 98, 87, 107, 93, 118, 114, 122, 126, 115, 111, 121, 124, 125, 130, 131, 132, 139, 140, 127, 56, 66, 145, 143, 156, 157, 149]--------
#
#
#  ----- Working on coordinate [1376752.80959531  760479.73839874  761449.0503935 ]--------
# coordinate [1376752.80959531  760479.73839874  761449.0503935 ] had error branches [90, 92, 91, 94, 98, 87, 107, 93, 118, 114, 122, 126, 115, 111, 121, 124, 125, 130, 131, 132, 139, 140, 127, 56, 66, 145, 143, 156, 157, 149, 153, 158, 142]--------
#
#
#  ----- Working on coordinate [1398063.04398429  841347.17418116  797150.6336296 ]--------
# coordinate [1398063.04398429  841347.17418116  797150.6336296 ] had error branches [90, 92, 91, 94, 98, 87, 107, 93, 118, 114, 122, 126, 115, 111, 121, 124, 125, 130, 131, 132, 139, 140, 127, 56, 66, 145, 143, 156, 157, 149, 153, 158, 142, 154, 159, 160]--------
# limb_branch_dict_to_cancel = {'L8': array([ 90,  92,  91,  94,  98,  87, 107,  93, 118, 114, 122, 126, 115,
#        111, 121, 124, 125, 130, 131, 132, 139, 140, 127,  56,  66, 145,
#        143, 156, 157, 149, 153, 158, 142, 154, 159, 160,  77,  82,  83])}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {'L4': [8, 3, 6, 7]}
# limb_branch_dict_to_cancel = {}
# Apply the presyn non_error
# For presyn: # valid synapses = 17, # error synapses  = 374, # error presyns = 40
# For postsyn: # valid synapses = 5698, # error synapses  = 157, # error presyns = 0
# Synapsse Results:
# Total Number of Synapses = 6246
# n_valid_syn_ids_presyn = 17
# n_errored_syn_ids_presyn = 374
# n_valid_syn_ids_postsyn = 5698
# n_errored_syn_ids_postsyn = 157
# Segment Id = 864691135589906955
# Postsyn counts:
# TP:5681
# TN:13
# FP:17
# FN:144
# Presyn counts:
# TP:7
# TN:332
# FP:10
# FN:2
# Saved object at /neuron_mesh_tools/Auto_Proofreading/Validation_Testing/v4/validation_data/864691135589906955_validation_df.pbz2
# File size is 0.12367 MB
# Total time for neuron 864691135589906955: 293.138720035553
#
# --- Working on Neuron 864691136370815112 --
# Decompressing Neuron in minimal output mode...please wait
#
#
#  ----- Working on coordinate [1338920.72874933  676864.94436049  795604.08114899]--------
# coordinate [1338920.72874933  676864.94436049  795604.08114899] had error branches []--------
#
#
#  ----- Working on coordinate [1343942.71429529  725455.60617988  810761.85015826]--------
# coordinate [1343942.71429529  725455.60617988  810761.85015826] had error branches [3, 4, 5]--------
#
#
#  ----- Working on coordinate [1347647.0723884   733560.02333853  815249.17033973]--------
# coordinate [1347647.0723884   733560.02333853  815249.17033973] had error branches [3, 4, 5]--------
#
#
#  ----- Working on coordinate [1348993.14569715  650538.41693819  813854.82333989]--------
# coordinate [1348993.14569715  650538.41693819  813854.82333989] had error branches [3, 4, 5]--------
# limb_branch_dict_to_cancel = {'L6': array([ 3,  4,  5, 34, 36, 38])}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {'L2': [7]}
# limb_branch_dict_to_cancel = {}
# Apply the presyn non_error
# For presyn: # valid synapses = 10, # error synapses  = 24, # error presyns = 20
# For postsyn: # valid synapses = 3892, # error synapses  = 64, # error presyns = 0
# Synapsse Results:
# Total Number of Synapses = 3990
# n_valid_syn_ids_presyn = 10
# n_errored_syn_ids_presyn = 24
# n_valid_syn_ids_postsyn = 3892
# n_errored_syn_ids_postsyn = 64
# Segment Id = 864691136370815112
# Postsyn counts:
# TP:3892
# TN:0
# FP:0
# FN:64
# Presyn counts:
# TP:6
# TN:3
# FP:4
# FN:1
# Saved object at /neuron_mesh_tools/Auto_Proofreading/Validation_Testing/v4/validation_data/864691136370815112_validation_df.pbz2
# File size is 0.08056 MB
# Total time for neuron 864691136370815112: 153.6031527519226
#
# --- Working on Neuron 864691135645592260 --
# Decompressing Neuron in minimal output mode...please wait
#
#
#  ----- Working on coordinate [1108018.   669239.   992496.2]--------
# coordinate [1108018.   669239.   992496.2] had error branches []--------
#
#
#  ----- Working on coordinate [1160807.65475588  642008.37968538  954025.54598041]--------
# coordinate [1160807.65475588  642008.37968538  954025.54598041] had error branches [6, 4]--------
#
#
#  ----- Working on coordinate [1161539.25381372  644671.27858742  954033.67945663]--------
# coordinate [1161539.25381372  644671.27858742  954033.67945663] had error branches [6, 4, 25, 17]--------
#
#
#  ----- Working on coordinate [1177920.54002733  983714.90675203 1080512.70437534]--------
# coordinate [1177920.54002733  983714.90675203 1080512.70437534] had error branches [6, 4, 25, 17, 26, 28]--------
#
#
#  ----- Working on coordinate [1180708.61393678  690209.03551246 1032158.66993392]--------
# coordinate [1180708.61393678  690209.03551246 1032158.66993392] had error branches [6, 4, 25, 17, 26, 28, 43, 47, 48]--------
#
#
#  ----- Working on coordinate [1183664.68841281  982718.5503451  1079327.58273812]--------
# coordinate [1183664.68841281  982718.5503451  1079327.58273812] had error branches [6, 4, 25, 17, 26, 28, 43, 47, 48, 51, 45]--------
#
#
#  ----- Working on coordinate [1211671.60640522  760184.99578821  977042.97469628]--------
# coordinate [1211671.60640522  760184.99578821  977042.97469628] had error branches [6, 4, 25, 17, 26, 28, 43, 47, 48, 51, 45, 49, 63, 64, 38]--------
#
#
#  ----- Working on coordinate [1213230.57359707  753876.49128702  965365.68345297]--------
# coordinate [1213230.57359707  753876.49128702  965365.68345297] had error branches [6, 4, 25, 17, 26, 28, 43, 47, 48, 51, 45, 49, 63, 64, 38, 80, 82, 85, 87, 78]--------
#
#
#  ----- Working on coordinate [1215442.92459927  766084.81202729  938412.84748794]--------
# coordinate [1215442.92459927  766084.81202729  938412.84748794] had error branches [6, 4, 25, 17, 26, 28, 43, 47, 48, 51, 45, 49, 63, 64, 38, 80, 82, 85, 87, 78, 84, 94]--------
#
#
#  ----- Working on coordinate [1222411.22126537  833232.07857958  953282.32581396]--------
# coordinate [1222411.22126537  833232.07857958  953282.32581396] had error branches [6, 4, 25, 17, 26, 28, 43, 47, 48, 51, 45, 49, 63, 64, 38, 80, 82, 85, 87, 78, 84, 94, 104, 90]--------
#
#
#  ----- Working on coordinate [1230361.95404703  763511.97065787  972487.01358683]--------
# coordinate [1230361.95404703  763511.97065787  972487.01358683] had error branches [6, 4, 25, 17, 26, 28, 43, 47, 48, 51, 45, 49, 63, 64, 38, 80, 82, 85, 87, 78, 84, 94, 104, 90, 112, 113]--------
# limb_branch_dict_to_cancel = {'L2': array([  6,   4,  25,  17,  26,  28,  43,  47,  48,  51,  45,  49,  63,
#         64,  38,  80,  82,  85,  87,  78,  84,  94, 104,  90, 112, 113,
#        117, 118])}
# limb_branch_dict_to_cancel = {}
# Warning: start endpoint was not an end node: [1188470.  640209.  965368.] but not erroring
# Becasue catch_error = True, Gracefullly recovering from error index 1 is out of bounds for axis 0 with size 1
# limb_branch_dict_to_cancel = {}
# Apply the presyn non_error
# For presyn: # valid synapses = 32, # error synapses  = 127, # error presyns = 11
# For postsyn: # valid synapses = 3128, # error synapses  = 15, # error presyns = 0
# Synapsse Results:
# Total Number of Synapses = 3302
# n_valid_syn_ids_presyn = 32
# n_errored_syn_ids_presyn = 127
# n_valid_syn_ids_postsyn = 3128
# n_errored_syn_ids_postsyn = 15
# Segment Id = 864691135645592260
# Postsyn counts:
# TP:3127
# TN:1
# FP:1
# FN:14
# Presyn counts:
# TP:28
# TN:109
# FP:4
# FN:7
# Saved object at /neuron_mesh_tools/Auto_Proofreading/Validation_Testing/v4/validation_data/864691135645592260_validation_df.pbz2
# File size is 0.067163 MB
# Total time for neuron 864691135645592260: 135.0222156047821
