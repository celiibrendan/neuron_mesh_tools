# %%
"""
Purpose: To Run the proofreading of neurons in the 
test set and measure the precision and recall of the new rules



"""
# Out:
# '\nPurpose: To Run the proofreading of neurons in the \ntest set and measure the precision and recall of the new rules\n\n\n\n'

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import datajoint as dj
import trimesh
from tqdm.notebook import tqdm
from pathlib import Path

from os import sys
sys.path.append("/meshAfterParty/")
sys.path.append("/meshAfterParty/meshAfterParty")

import datajoint_utils as du
from importlib import reload
# Out:
# INFO - 2021-04-24 21:50:19,869 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-04-24 21:50:19,871 - settings - Setting database.user to celiib
# INFO - 2021-04-24 21:50:19,872 - settings - Setting database.password to newceliipass
# INFO - 2021-04-24 21:50:19,876 - settings - Setting stores to {'minnie65': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65', 'stage': '/mnt/dj-stor01/platinum/minnie65'}, 'meshes': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/meshes', 'stage': '/mnt/dj-stor01/platinum/minnie65/02/meshes'}, 'decimated_meshes': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/decimated_meshes', 'stage': '/mnt/dj-stor01/platinum/minnie65/02/decimated_meshes'}, 'skeletons': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/skeletons'}}
# INFO - 2021-04-24 21:50:19,877 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-04-24 21:50:19,889 - connection - Connected celiib@at-database.ad.bcm.edu:3306
# Connecting celiib@at-database.ad.bcm.edu:3306
# INFO - 2021-04-24 21:50:20,273 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-04-24 21:50:20,277 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-04-24 21:50:20,278 - settings - Setting database.user to celiib
# INFO - 2021-04-24 21:50:20,279 - settings - Setting database.password to newceliipass
# INFO - 2021-04-24 21:50:20,279 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-04-24 21:50:20,280 - settings - Setting database.user to celiib
# INFO - 2021-04-24 21:50:20,280 - settings - Setting database.password to newceliipass
# INFO - 2021-04-24 21:50:20,281 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-04-24 21:50:20,811 - settings - Setting enable_python_native_blobs to True

# %%
#configuring will include the adapters
minnie,schema = du.configure_minnie_vm()
# Out:
# INFO - 2021-04-24 21:50:21,000 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-04-24 21:50:21,001 - settings - Setting database.user to celiib
# INFO - 2021-04-24 21:50:21,002 - settings - Setting database.password to newceliipass
# INFO - 2021-04-24 21:50:21,011 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-04-24 21:50:21,756 - settings - Setting enable_python_native_blobs to True

# %%
import validation_utils as vu
import neuron_visualizations as nviz
import neuron_utils as nru
import proofreading_utils as pru
import time
import system_utils as su

# %% [markdown]
# # Runnig the validation

# %%
"""
Psueodocode: 
1) Pull down the segment ids of the valid neurons

For each neuron
1) Dwonload the neuron object
2) Run the Proofreading
3) Print out the validation plot
4) Save the validation df

"""
# Out:
# '\nPsueodocode: \n1) Pull down the segment ids of the valid neurons\n\nFor each neuron\n1) Dwonload the neuron object\n2) Run the Proofreading\n3) Print out the validation plot\n4) Save the validation df\n\n'

# %%
segment_ids = minnie.AutoProofreadValidationBorderNeurons().fetch("segment_id")

# %%
job_idx = 7
job_step = 5
segments_to_process = segment_ids[job_idx*job_step:(job_idx+1)*job_step]
segments_to_process
# Out:
# array([864691136175008774, 864691135748575017, 864691136535575714,
#        864691135212632448, 864691135491233631])

# %%
for seg_id in segments_to_process:
    print(f"\n--- Working on Neuron {seg_id} --")
    st = time.time()
    
    
    #1) Dwonload the neuron object
    neuron_obj = du.fetch_neuron_obj_manual(seg_id,
                                       border_validation=True)
    
    (filt_neuron,
     return_synapse_df_revised,
    return_validation_df_revised) =  vu.filtered_neuron_score(neuron_obj = neuron_obj,   
                        filter_list = pru.v4_exc_filters(),
                        plot_limb_branch_filter_with_disconnect_effect = False,
                        verbose = False,
                        plot_score=False)
    
    vu.synapse_validation_df_to_score_plot(return_validation_df_revised)
    
    su.compressed_pickle(return_validation_df_revised,f"./validation_data/{seg_id}_validation_df")
    
    print(f"Total time for neuron {seg_id}: {time.time() - st}")
# Out:
# --- Working on Neuron 864691136175008774 --
# Decompressing Neuron in minimal output mode...please wait
#
#
#  ----- Working on coordinate [1178726.55477714  947344.87802562  967745.08426099]--------
# coordinate [1178726.55477714  947344.87802562  967745.08426099] had error branches [16 17]--------
#
#
#  ----- Working on coordinate [1203349.87450913  946704.79653701  959777.84773135]--------
# coordinate [1203349.87450913  946704.79653701  959777.84773135] had error branches [32 34]--------
#
#
#  ----- Working on coordinate [1235551.54635754  945554.07085967  960523.1719306 ]--------
# coordinate [1235551.54635754  945554.07085967  960523.1719306 ] had error branches [59 66 43]--------
#
#
#  ----- Working on coordinate [1236651.09577076  939491.70548213  960084.85877653]--------
# coordinate [1236651.09577076  939491.70548213  960084.85877653] had error branches [65 71 61]--------
#
#
#  ----- Working on coordinate [1244529.   640472.9  919366.7]--------
# coordinate [1244529.   640472.9  919366.7] had error branches []--------
#
#
#  ----- Working on coordinate [1272675.65090087  829588.96064137  726410.1551839 ]--------
# coordinate [1272675.65090087  829588.96064137  726410.1551839 ] had error branches [113 108]--------
#
#
#  ----- Working on coordinate [1407269.77004065  735578.9227646   963788.97791   ]--------
# coordinate [1407269.77004065  735578.9227646   963788.97791   ] had error branches [136 137]--------
#
#
#  ----- Working on coordinate [1414939.03444501  703296.91358367  961464.6280251 ]--------
# coordinate [1414939.03444501  703296.91358367  961464.6280251 ] had error branches []--------
#
#
#  ----- Working on coordinate [1435330.57523492  646345.20935587  957765.91810284]--------
# coordinate [1435330.57523492  646345.20935587  957765.91810284] had error branches [161 162]--------
#
#
#  ----- Working on coordinate [1451465.2940866   611781.38995699  951261.69478077]--------
# coordinate [1451465.2940866   611781.38995699  951261.69478077] had error branches [170 172]--------
#
#
#  ----- Working on coordinate [1458901.6968766   595174.50035677  950841.97559277]--------
# coordinate [1458901.6968766   595174.50035677  950841.97559277] had error branches [173 174]--------
# limb_branch_dict_to_cancel = {'L0': array([ 16,  17,  32,  34,  59,  66,  43,  65,  71,  61, 113, 108, 136,
#        137, 161, 162, 170, 172, 173, 174])}
# limb_branch_dict_to_cancel = {'L0': [100, 103]}
# limb_branch_dict_to_cancel = {'L6': [4, 9, 5, 6, 7, 8]}
# limb_branch_dict_to_cancel = {}
# Apply the presyn non_error
# For presyn: # valid synapses = 120, # error synapses  = 149, # error presyns = 4
# For postsyn: # valid synapses = 2240, # error synapses  = 248, # error presyns = 0
# Synapsse Results:
# Total Number of Synapses = 2757
# n_valid_syn_ids_presyn = 120
# n_errored_syn_ids_presyn = 149
# n_valid_syn_ids_postsyn = 2240
# n_errored_syn_ids_postsyn = 248
# Segment Id = 864691136175008774
# Postsyn counts:
# TP:2238
# TN:4
# FP:2
# FN:244
# Presyn counts:
# TP:105
# TN:145
# FP:15
# FN:0
# Saved object at /neuron_mesh_tools/Auto_Proofreading/Validation_Testing/v4/validation_data/864691136175008774_validation_df.pbz2
# File size is 0.056954 MB
# Total time for neuron 864691136175008774: 313.21492743492126
#
# --- Working on Neuron 864691135748575017 --
# Decompressing Neuron in minimal output mode...please wait
#
#
#  ----- Working on coordinate [719144.24119276 738337.65212566 884220.30338145]--------
# coordinate [719144.24119276 738337.65212566 884220.30338145] had error branches [15 16]--------
#
#
#  ----- Working on coordinate [719155.97435028 738260.75453165 883463.88568434]--------
# coordinate [719155.97435028 738260.75453165 883463.88568434] had error branches []--------
#
#
#  ----- Working on coordinate [730543. 587106. 876754.]--------
# coordinate [730543. 587106. 876754.] had error branches []--------
# limb_branch_dict_to_cancel = {'L5': array([15, 16])}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# Apply the presyn non_error
# For presyn: # valid synapses = 21, # error synapses  = 207, # error presyns = 31
# For postsyn: # valid synapses = 4524, # error synapses  = 51, # error presyns = 0
# Synapsse Results:
# Total Number of Synapses = 4803
# n_valid_syn_ids_presyn = 21
# n_errored_syn_ids_presyn = 207
# n_valid_syn_ids_postsyn = 4524
# n_errored_syn_ids_postsyn = 51
# Segment Id = 864691135748575017
# Postsyn counts:
# TP:4524
# TN:5
# FP:0
# FN:46
# Presyn counts:
# TP:12
# TN:176
# FP:9
# FN:0
# Saved object at /neuron_mesh_tools/Auto_Proofreading/Validation_Testing/v4/validation_data/864691135748575017_validation_df.pbz2
# File size is 0.094788 MB
# Total time for neuron 864691135748575017: 203.24954319000244
#
# --- Working on Neuron 864691136535575714 --
# Decompressing Neuron in minimal output mode...please wait
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# Apply the presyn non_error
# For presyn: # valid synapses = 0, # error synapses  = 99, # error presyns = 46
# For postsyn: # valid synapses = 7047, # error synapses  = 6, # error presyns = 0
# Synapsse Results:
# Total Number of Synapses = 7152
# n_valid_syn_ids_presyn = 0
# n_errored_syn_ids_presyn = 99
# n_valid_syn_ids_postsyn = 7047
# n_errored_syn_ids_postsyn = 6
# Segment Id = 864691136535575714
# Postsyn counts:
# TP:7041
# TN:0
# FP:6
# FN:6
# Presyn counts:
# TP:0
# TN:50
# FP:0
# FN:3
# Saved object at /neuron_mesh_tools/Auto_Proofreading/Validation_Testing/v4/validation_data/864691136535575714_validation_df.pbz2
# File size is 0.138622 MB
# Total time for neuron 864691136535575714: 128.58308243751526
#
# --- Working on Neuron 864691135212632448 --
# Decompressing Neuron in minimal output mode...please wait
#
#
#  ----- Working on coordinate [718510.40260698 788658.70415584 882128.08081726]--------
# coordinate [718510.40260698 788658.70415584 882128.08081726] had error branches [16 17 19]--------
#
#
#  ----- Working on coordinate [727091.11161244 825165.96089403 828409.80637862]--------
# coordinate [727091.11161244 825165.96089403 828409.80637862] had error branches [35 38]--------
#
#
#  ----- Working on coordinate [728990.82250472 799250.73705124 885278.29232359]--------
# coordinate [728990.82250472 799250.73705124 885278.29232359] had error branches [29 33 36 41]--------
#
#
#  ----- Working on coordinate [730166.02199552 788171.06586732 769444.32190551]--------
# coordinate [730166.02199552 788171.06586732 769444.32190551] had error branches [44 28]--------
#
#
#  ----- Working on coordinate [735580.95089437 780696.99022978 761977.32728417]--------
# coordinate [735580.95089437 780696.99022978 761977.32728417] had error branches [54 34]--------
#
#
#  ----- Working on coordinate [737693.59704097 742687.88244713 862933.90620757]--------
# coordinate [737693.59704097 742687.88244713 862933.90620757] had error branches [56 58  0]--------
#
#
#  ----- Working on coordinate [741599.49777625 744473.18051319 862690.96588407]--------
# coordinate [741599.49777625 744473.18051319 862690.96588407] had error branches [63 73 50]--------
#
#
#  ----- Working on coordinate [743333.40748851 749445.8566171  852136.60397999]--------
# coordinate [743333.40748851 749445.8566171  852136.60397999] had error branches []--------
#
#
#  ----- Working on coordinate [744109.54704652 751147.56255412 852591.71791479]--------
# coordinate [744109.54704652 751147.56255412 852591.71791479] had error branches []--------
#
#
#  ----- Working on coordinate [746963.5176251  744965.3293408  862480.76310377]--------
# coordinate [746963.5176251  744965.3293408  862480.76310377] had error branches [74 93 94 64]--------
#
#
#  ----- Working on coordinate [753141.1  856834.75 865745.  ]--------
# coordinate [753141.1  856834.75 865745.  ] had error branches [114 117 112]--------
#
#
#  ----- Working on coordinate [777954.05282527 820877.84538062 845056.80849058]--------
# coordinate [777954.05282527 820877.84538062 845056.80849058] had error branches [157 162]--------
#
#
#  ----- Working on coordinate [785791.467705   801403.33241788 876838.62797077]--------
# coordinate [785791.467705   801403.33241788 876838.62797077] had error branches [172 176]--------
#
#
#  ----- Working on coordinate [785956.39300568 798856.87078642 877554.21537454]--------
# coordinate [785956.39300568 798856.87078642 877554.21537454] had error branches [175 177 178 179 163]--------
#
#
#  ----- Working on coordinate [789126.0614212  776278.77227187 874273.97000722]--------
# coordinate [789126.0614212  776278.77227187 874273.97000722] had error branches [181 182]--------
# limb_branch_dict_to_cancel = {'L4': array([ 16,  17,  19,  35,  38,  29,  33,  36,  41,  44,  28,  54,  34,
#         56,  58,   0,  63,  73,  50,  74,  93,  94,  64, 114, 117, 112,
#        157, 162, 172, 176, 175, 177, 178, 179, 163, 181, 182])}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {'L4': [17, 18, 62]}
# limb_branch_dict_to_cancel = {'L4': array([34, 38])}
# Apply the presyn non_error
# For presyn: # valid synapses = 38, # error synapses  = 375, # error presyns = 28
# For postsyn: # valid synapses = 3319, # error synapses  = 40, # error presyns = 0
# Synapsse Results:
# Total Number of Synapses = 3772
# n_valid_syn_ids_presyn = 38
# n_errored_syn_ids_presyn = 375
# n_valid_syn_ids_postsyn = 3319
# n_errored_syn_ids_postsyn = 40
# Segment Id = 864691135212632448
# Postsyn counts:
# TP:3317
# TN:12
# FP:2
# FN:28
# Presyn counts:
# TP:11
# TN:345
# FP:27
# FN:2
# Saved object at /neuron_mesh_tools/Auto_Proofreading/Validation_Testing/v4/validation_data/864691135212632448_validation_df.pbz2
# File size is 0.074476 MB
# Total time for neuron 864691135212632448: 213.3160707950592
#
# --- Working on Neuron 864691135491233631 --
# Decompressing Neuron in minimal output mode...please wait
#
#
#  ----- Working on coordinate [823844.95579408 776401.76597974 789431.52445308]--------
# coordinate [823844.95579408 776401.76597974 789431.52445308] had error branches [30 31 21]--------
#
#
#  ----- Working on coordinate [840094.6 778931.4 848056.9]--------
# coordinate [840094.6 778931.4 848056.9] had error branches [59 60]--------
#
#
#  ----- Working on coordinate [861416.71315537 912625.59261422 785086.80150228]--------
# coordinate [861416.71315537 912625.59261422 785086.80150228] had error branches [73 78 80 83 84 85 86]--------
#
#
#  ----- Working on coordinate [867982.56502022 925891.96509503 797162.91356259]--------
# coordinate [867982.56502022 925891.96509503 797162.91356259] had error branches [93 96]--------
# limb_branch_dict_to_cancel = {'L2': array([30, 31, 21, 59, 60, 73, 78, 80, 83, 84, 85, 86, 93, 96])}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# limb_branch_dict_to_cancel = {}
# Apply the presyn non_error
# For presyn: # valid synapses = 13, # error synapses  = 153, # error presyns = 13
# For postsyn: # valid synapses = 753, # error synapses  = 4, # error presyns = 0
# Synapsse Results:
# Total Number of Synapses = 923
# n_valid_syn_ids_presyn = 13
# n_errored_syn_ids_presyn = 153
# n_valid_syn_ids_postsyn = 753
# n_errored_syn_ids_postsyn = 4
# Segment Id = 864691135491233631
# Postsyn counts:
# TP:749
# TN:1
# FP:4
# FN:3
# Presyn counts:
# TP:13
# TN:140
# FP:0
# FN:0
# Saved object at /neuron_mesh_tools/Auto_Proofreading/Validation_Testing/v4/validation_data/864691135491233631_validation_df.pbz2
# File size is 0.019782 MB
# Total time for neuron 864691135491233631: 66.3545708656311
