# %%
"""
Purpose: To implement the automatic
apical classification


"""

# %%
from os import sys
sys.path.append("/meshAfterParty/")
#sys.path.append("../../meshAfterParty/meshAfterParty")

# %%
from importlib import reload
import os
from pathlib import Path
os.getcwd()

import neuron_utils as nru
nru = reload(nru)
import neuron
neuron=reload(neuron)
import neuron_visualizations as nviz
import time
import system_utils as su
# Out:
# WARNING:root:Need to pip install annotationframeworkclient to repair mesh with pychunkedgraph
# WARNING:root:Need to pip install annotationframeworkclient to use dataset_name parameters

# %% [markdown]
# # Importing the Neuron

# %%
current_file = "/notebooks/test_neurons/meshafterparty_processed/12345_double_soma_meshafterparty_9_29"
current_neuron = nru.decompress_neuron(filepath=current_file,
                                  original_mesh=current_file,
                                  suppress_output=True)
# Out:
# Decompressing Neuron in minimal output mode...please wait

# %%
current_neuron.compartment_classification()

# %%
ret_col = nviz.visualize_neuron(current_neuron,
                                visualize_type=["mesh","skeleton"],
                     limb_branch_dict="all",
                     mesh_resolution="limb",
                                skeleton_resolution="limb",
                     return_color_dict=True)
# Out:
#  Working on visualization type: mesh
#
#  Working on visualization type: skeleton
# VBox(children=(Figure(camera=PerspectiveCamera(fov=46.0, position=(0.0, 0.0, 2.0), quaternion=(0.0, 0.0, 0.0, …

# %%
nviz.plot_soma_limb_concept_network(current_neuron,
                                   node_colors=ret_col,
                                   font_color="white")

# %%
#visualizing the apical branch for S1
ret_col = nviz.visualize_neuron(current_neuron,
                                visualize_type=["mesh","skeleton"],
                     limb_branch_dict="all",
                     #mesh_resolution="limb",
                    #skeleton_resolution="limb",
                     return_color_dict=True)
# Out:
#  Working on visualization type: mesh
#
#  Working on visualization type: skeleton
# VBox(children=(Figure(camera=PerspectiveCamera(fov=46.0, position=(0.0, 0.0, 2.0), quaternion=(0.0, 0.0, 0.0, …

# %%
#visualizing the apical branch for S1
ret_col = nviz.visualize_neuron(current_neuron,
                                visualize_type=["mesh","skeleton"],
                     limb_branch_dict=dict(L6="all",L0="all"),
                     #mesh_resolution="limb",
                    #skeleton_resolution="limb",
                     return_color_dict=True)
# Out:
#  Working on visualization type: mesh
#
#  Working on visualization type: skeleton
# VBox(children=(Figure(camera=PerspectiveCamera(fov=46.0, position=(0.0, 0.0, 2.0), quaternion=(0.0, 0.0, 0.0, …

# %%
current_neuron[0][49].width_new
# Out:
# {'median_mesh_center': 1503.8212574267725,
#  'no_spine_median_mesh_center': 1503.8212574267725,
#  'no_spine_mean_mesh_center': 1633.4558476737718}

# %%
#visualizing the apical branch for S1
ret_col = nviz.visualize_neuron(current_neuron,
                                visualize_type=["mesh","skeleton"],
                     limb_branch_dict=dict(L0=[49,29]),
                     #mesh_resolution="limb",
                    #skeleton_resolution="limb",
                     return_color_dict=True)
# Out:
#  Working on visualization type: mesh
#
#  Working on visualization type: skeleton
# VBox(children=(Figure(camera=PerspectiveCamera(fov=46.0, position=(0.0, 0.0, 2.0), quaternion=(0.0, 0.0, 0.0, …

# %%
nviz.plot_limb_concept_network_2D(current_neuron,
                                  node_colors=ret_col,
                                  limb_name="L0",
                                 )
