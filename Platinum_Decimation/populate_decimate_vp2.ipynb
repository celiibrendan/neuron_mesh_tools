# %%
import datajoint as dj
from meshlab import Decimator
from minfig import * # Required for the adapters to be used with locally defined tables

# Virtual module accessors
minnie = configure_minnie(return_virtual_module=True) # virtual module with the adapted attribute for mesh access from .h5 files
schema = dj.schema("microns_minnie65_01")
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
errors = (schema.jobs & "table_name='__decimation_test'").fetch("error_message")#.delete()
len(errors)
# Out:
# 51

# %%
dj.config["display.limit"] = 210
(schema.jobs & "table_name='__decimation_test'")#.delete()
# Out:
# *table_name    *key_hash      status       key        error_message  error_stac user           host           pid     connection_id  timestamp
# +------------+ +------------+ +----------+ +--------+ +------------+ +--------+ +------------+ +------------+ +-----+ +------------+ +------------+
# __decimation_t 011cdf9f339862 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node5       16      316035         2020-05-18 17:
# __decimation_t 014cc9caa874d1 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node43      16      316043         2020-05-18 17:
# __decimation_t 01caf13b1c1d5c reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node41      16      316048         2020-05-18 17:
# __decimation_t 09a741bc8ad75e reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node39      16      315972         2020-05-18 17:
# __decimation_t 0b8cb00f82727e reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node32      16      316116         2020-05-18 17:
# __decimation_t 0c501ae492696d reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node4       17      316083         2020-05-18 17:
# __decimation_t 0dd25f258bfc04 reserved     =BLOB=                    =BLOB=     celiib@10.66.4 at-compute005  16      316111         2020-05-18 17:
# __decimation_t 1094aac541585c reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node30      16      316039         2020-05-18 17:
# __decimation_t 1108811ffb1f62 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node19      16      315973         2020-05-18 17:
# __decimation_t 12b52aa7905300 reserved     =BLOB=                    =BLOB=     celiib@10.66.4 at-compute005  16      315990         2020-05-18 17:
# __decimation_t 13208d7d4d079c reserved     =BLOB=                    =BLOB=     celiib@10.66.4 at-compute005  16      315980         2020-05-18 17:
# __decimation_t 174f5da654b101 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node33      16      315939         2020-05-18 17:
# __decimation_t 1be51999d1c2b2 reserved     =BLOB=                    =BLOB=     celiib@10.66.4 at-compute005  16      316087         2020-05-18 17:
# __decimation_t 1dee02d8666d3a reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node42      17      315967         2020-05-18 17:
# __decimation_t 205794c2912b1d reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node1       16      316016         2020-05-18 17:
# __decimation_t 21850bb82a39ae reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-compute003  16      316102         2020-05-18 17:
# __decimation_t 241e1ad6008f33 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-compute003  16      316081         2020-05-18 17:
# __decimation_t 2878e0e83a9b08 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node40      16      316055         2020-05-18 17:
# __decimation_t 292855e7bc7fa4 reserved     =BLOB=                    =BLOB=     celiib@10.66.4 at-compute005  17      315958         2020-05-18 17:
# __decimation_t 292995efc7145b reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node19      16      315944         2020-05-18 17:
# __decimation_t 2ccdc7f15045c1 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-compute004  16      316068         2020-05-18 17:
# __decimation_t 2d3b391a6b89dd reserved     =BLOB=                    =BLOB=     celiib@10.66.4 at-compute005  16      315954         2020-05-18 17:
# __decimation_t 2d7ccb35f1c3ad reserved     =BLOB=                    =BLOB=     celiib@10.66.4 at-compute005  16      316076         2020-05-18 17:
# __decimation_t 2d9c9972db384a reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node3       16      315964         2020-05-18 17:
# __decimation_t 2e0a39beba4858 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node13      16      315994         2020-05-18 17:
# __decimation_t 2e583d25d98a92 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node7       17      315945         2020-05-18 17:
# __decimation_t 2e64b42d7b48e6 reserved     =BLOB=                    =BLOB=     celiib@10.66.4 at-compute005  16      315956         2020-05-18 17:
# __decimation_t 31bfa696a50c76 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node22      16      316079         2020-05-18 17:
# __decimation_t 32d42dc88f4bed error        =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      315955         2020-05-18 17:
# __decimation_t 3353ca0dbe06f3 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node28      16      315981         2020-05-18 17:
# __decimation_t 338b64a9cfbbaa reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node14      17      315991         2020-05-18 17:
# __decimation_t 34d4633aee17df reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node42      16      316027         2020-05-18 17:
# __decimation_t 373cd5b67a8afd reserved     =BLOB=                    =BLOB=     celiib@10.66.4 at-compute005  16      316089         2020-05-18 17:
# __decimation_t 39be9097fc7a36 reserved     =BLOB=                    =BLOB=     celiib@10.66.4 at-compute005  16      315996         2020-05-18 17:
# __decimation_t 3b3a66f5cb3af7 reserved     =BLOB=                    =BLOB=     celiib@10.66.4 at-compute005  16      315950         2020-05-18 17:
# __decimation_t 3cc8412b5302b5 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node32      16      315985         2020-05-18 17:
# __decimation_t 428d95a2037873 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node45      16      316007         2020-05-18 17:
# __decimation_t 45b36ff7c8c6ab reserved     =BLOB=                    =BLOB=     celiib@10.66.4 at-compute005  16      315955         2020-05-18 17:
# __decimation_t 464ca8aa882e92 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node11      16      315984         2020-05-18 17:
# __decimation_t 4786bb1a14ff38 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node28      17      316094         2020-05-18 17:
# __decimation_t 47fe50458c72c7 reserved     =BLOB=                    =BLOB=     celiib@10.66.4 at-compute005  16      316000         2020-05-18 17:
# __decimation_t 49b162a66148c5 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node29      16      315962         2020-05-18 17:
# __decimation_t 4da8d77a84565e reserved     =BLOB=                    =BLOB=     celiib@10.66.4 at-compute005  16      315999         2020-05-18 17:
# __decimation_t 4ed9de5bee1dff reserved     =BLOB=                    =BLOB=     celiib@10.66.4 at-compute005  16      315946         2020-05-18 17:
# __decimation_t 52ec97a2990aed reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node25      16      315977         2020-05-18 17:
# __decimation_t 5431031f527896 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node35      18      316099         2020-05-18 17:
# __decimation_t 545be157e605c7 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node1       16      315966         2020-05-18 17:
# __decimation_t 5481b3116c9299 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node5       16      316033         2020-05-18 17:
# __decimation_t 5493c7b91cce19 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-compute003  16      316073         2020-05-18 17:
# __decimation_t 55e4e311e12480 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node45      16      316026         2020-05-18 17:
# __decimation_t 58098b3c3bf7a2 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node34      16      316096         2020-05-18 17:
# __decimation_t 5851dd9329a241 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node3       16      316090         2020-05-18 17:
# __decimation_t 5dafcb3f7d2bf6 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node22      16      315940         2020-05-18 17:
# __decimation_t 5fc7b6d95a19c2 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node8       17      315937         2020-05-18 17:
# __decimation_t 63ee866b09548a reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node16      16      316060         2020-05-18 17:
# __decimation_t 65267c5d960a61 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node30      17      315942         2020-05-18 17:
# __decimation_t 65deb3bb0e9289 reserved     =BLOB=                    =BLOB=     celiib@10.66.4 at-compute005  16      315952         2020-05-18 17:
# __decimation_t 695e0148b64bd3 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node28      16      316050         2020-05-18 17:
# __decimation_t 6b5a28e1f0d05e reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node43      16      315998         2020-05-18 17:
# __decimation_t 6cf4ec300d5d3f reserved     =BLOB=                    =BLOB=     celiib@10.66.4 at-compute005  16      315974         2020-05-18 17:
# __decimation_t 6e9fdd4d5be1ad reserved     =BLOB=                    =BLOB=     celiib@10.66.4 at-compute005  16      315979         2020-05-18 17:
# __decimation_t 6ea44d4e1d726d reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node32      16      315970         2020-05-18 17:
# __decimation_t 7086e95ef2cb85 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node21      16      315947         2020-05-18 17:
# __decimation_t 739ba1766855de reserved     =BLOB=                    =BLOB=     celiib@10.66.4 at-compute005  16      315986         2020-05-18 17:
# __decimation_t 75c89ac17089fb reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node32      16      316115         2020-05-18 17:
# __decimation_t 79646e9f4bbdbb reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node10      17      315971         2020-05-18 17:
# __decimation_t 79c36894e8d148 reserved     =BLOB=                    =BLOB=     celiib@10.66.4 at-compute005  16      315938         2020-05-18 17:
# __decimation_t 79f36588c10d8c reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node39      17      316034         2020-05-18 17:
# __decimation_t 7cb1033cf2b8b5 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-compute004  16      316067         2020-05-18 17:
# __decimation_t 8055119a4f20ad reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node29      16      316022         2020-05-18 17:
# __decimation_t 805979ec0227d7 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node35      17      316054         2020-05-18 17:
# __decimation_t 80f3d7ad349a46 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-compute004  16      316070         2020-05-18 17:
# __decimation_t 88dd35222f648e reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node45      16      316058         2020-05-18 17:
# __decimation_t 893547063ec619 reserved     =BLOB=                    =BLOB=     celiib@10.66.4 at-compute005  16      315995         2020-05-18 17:
# __decimation_t 8a3e64db3e60eb reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-compute003  16      316100         2020-05-18 17:
# __decimation_t 8b39e5fa41ed8b reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node16      16      315969         2020-05-18 17:
# __decimation_t 8e1e1e3f6c3748 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-compute004  16      316072         2020-05-18 17:
# __decimation_t 9146bc589d46eb reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-compute004  16      316088         2020-05-18 17:
# __decimation_t 91e8eb57b7d9b9 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node41      17      316005         2020-05-18 17:
# __decimation_t 9b2a1b54b4f37c reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-compute004  16      316108         2020-05-18 17:
# __decimation_t 9f3f4be576206d reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node21      16      316077         2020-05-18 17:
# __decimation_t a115c0f7efdf6e reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node1       17      316085         2020-05-18 17:
# __decimation_t a294705b81ae8e reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node22      16      316014         2020-05-18 17:
# __decimation_t acbe9da8ae8ddb reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-compute004  16      316069         2020-05-18 17:
# __decimation_t adcb8287bddf3d reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node14      16      315965         2020-05-18 17:
# __decimation_t ae08ea74d5bf94 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node40      16      315992         2020-05-18 17:
# __decimation_t af7b5daeb607eb reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node34      16      315941         2020-05-18 17:
# __decimation_t b23cdde83ff19d reserved     =BLOB=                    =BLOB=     celiib@10.66.4 at-compute005  17      315953         2020-05-18 17:
# __decimation_t b7d39f43b5f304 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node15      17      315988         2020-05-18 17:
# __decimation_t bc01b046136805 reserved     =BLOB=                    =BLOB=     celiib@10.66.4 at-compute005  16      316078         2020-05-18 17:
# __decimation_t bcb2967125fd75 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node33      16      316040         2020-05-18 17:
# __decimation_t bd47b77f1b4090 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node27      16      315976         2020-05-18 17:
# __decimation_t bef60ada056f9b reserved     =BLOB=                    =BLOB=     celiib@10.66.4 at-compute005  16      315983         2020-05-18 17:
# __decimation_t bfdad534650f5a reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node21      16      316009         2020-05-18 17:
# __decimation_t c047193ede05bb reserved     =BLOB=                    =BLOB=     celiib@10.66.4 at-compute005  16      315997         2020-05-18 17:
# __decimation_t c566a715bf9758 reserved     =BLOB=                    =BLOB=     celiib@10.66.4 at-compute005  17      315948         2020-05-18 17:
# __decimation_t c5a2fa9db56f47 reserved     =BLOB=                    =BLOB=     celiib@10.66.4 at-compute005  16      315961         2020-05-18 17:
# __decimation_t c8027d6ef60697 reserved     =BLOB=                    =BLOB=     celiib@10.66.4 at-compute005  16      316074         2020-05-18 17:
# __decimation_t ce7eae4e9da40d reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node5       16      316045         2020-05-18 17:
# __decimation_t ce943baee9d746 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-compute004  16      316086         2020-05-18 17:
# __decimation_t d0184eb5d0c58c reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node10      16      316008         2020-05-18 17:
# __decimation_t d051264820d6cc reserved     =BLOB=                    =BLOB=     celiib@10.66.4 at-compute005  16      316010         2020-05-18 17:
# __decimation_t d0c811d95c18e2 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node25      16      316051         2020-05-18 17:
# __decimation_t d34696f79c8777 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node7       17      315993         2020-05-18 17:
# __decimation_t d4ee42f94000ed reserved     =BLOB=                    =BLOB=     celiib@10.66.4 at-compute005  16      316004         2020-05-18 17:
# __decimation_t d7ee5ea99ad45f reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node47      16      316059         2020-05-18 17:
# __decimation_t d9f47b1f8c02da reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node47      16      316062         2020-05-18 17:
# __decimation_t d9f63ad8e16e32 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node47      16      316011         2020-05-18 17:
# __decimation_t da43dc7cccd2d5 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node10      16      316056         2020-05-18 17:
# __decimation_t db15671dc1b94d reserved     =BLOB=                    =BLOB=     celiib@10.66.4 at-compute005  16      315951         2020-05-18 17:
# __decimation_t e021f23c3b31a9 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node4       16      316013         2020-05-18 17:
# __decimation_t e0e51dd7c366de reserved     =BLOB=                    =BLOB=     celiib@10.66.4 at-compute005  16      315982         2020-05-18 17:
# __decimation_t e2fc3847de27ba reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node13      16      316046         2020-05-18 17:
# __decimation_t e46417dc6de762 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node33      16      316084         2020-05-18 17:
# __decimation_t e9e414ef21ebd4 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node11      16      315987         2020-05-18 17:
# __decimation_t ea12c931a54033 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node19      16      316091         2020-05-18 17:
# __decimation_t ea44dbb5337794 reserved     =BLOB=                    =BLOB=     celiib@10.66.4 at-compute005  16      315959         2020-05-18 17:
# __decimation_t eb4a3d5fe56b84 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node3       16      316038         2020-05-18 17:
# __decimation_t ec01860cebccea reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node15      16      315963         2020-05-18 17:
# __decimation_t ec25c73530cb38 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node16      16      316053         2020-05-18 17:
# __decimation_t ec7def592868da reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node4       17      315949         2020-05-18 17:
# __decimation_t ed97a04b4dadb2 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node35      16      316001         2020-05-18 17:
# __decimation_t ef6e67c6965cd3 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node21      16      316029         2020-05-18 17:
# __decimation_t efdd232c09dae9 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node27      16      316030         2020-05-18 17:
# __decimation_t f088d89072da92 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node34      16      316002         2020-05-18 17:
# __decimation_t f0d78094f6926b reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-compute004  16      316071         2020-05-18 17:
# __decimation_t f229d0f42882de reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node43      16      316019         2020-05-18 17:
# __decimation_t f4f4070081cd9a reserved     =BLOB=                    =BLOB=     celiib@10.66.4 at-compute005  16      316012         2020-05-18 17:
# __decimation_t f51f766c63213a reserved     =BLOB=                    =BLOB=     celiib@10.66.4 at-compute005  16      315975         2020-05-18 17:
# __decimation_t f67a4137e772dd reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node19      16      315978         2020-05-18 17:
# __decimation_t f74a882d9834b8 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node8       16      316015         2020-05-18 17:
# __decimation_t f79ff67591918d reserved     =BLOB=                    =BLOB=     celiib@10.28.0 at-node22      16      316092         2020-05-18 17:
# __decimation_t fbbfa7fc4301ff reserved     =BLOB=                    =BLOB=     celiib@10.66.4 at-compute005  16      316003         2020-05-18 17:
# __decimation_t ff3d19f655b57e reserved     =BLOB=                    =BLOB=     celiib@10.66.4 at-compute005  16      316095         2020-05-18 17:
#  (Total: 133)

# %%
len((schema.jobs & "table_name='__decimation_test'"))
# Out:
# 376

# %%
error_table = (schema.jobs & "table_name='__decimation_test'" & "status='error'")
error_table
# Out:
# *table_name    *key_hash      status     key        error_message  error_stac user           host           pid     connection_id  timestamp
# +------------+ +------------+ +--------+ +--------+ +------------+ +--------+ +------------+ +------------+ +-----+ +------------+ +------------+
# __decimation_t 06491fe120cd0d error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      316166         2020-05-18 19:
# __decimation_t 07a700aa70f9b8 error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      316203         2020-05-18 21:
# __decimation_t 07b44f263fbc66 error      =BLOB=     Exception: neu =BLOB=     celiib@10.28.0 at-compute004  17      316223         2020-05-18 19:
# __decimation_t 09f5cd509da75e error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      316212         2020-05-18 18:
# __decimation_t 0cd82e5f1ea95e error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      316146         2020-05-18 20:
# __decimation_t 144dc300161db6 error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      315975         2020-05-18 22:
# __decimation_t 1eb36fbef4037f error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      316111         2020-05-18 19:
# __decimation_t 21b41c4428d5c4 error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      316010         2020-05-18 20:
# __decimation_t 241f3e967d84a8 error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      316012         2020-05-18 19:
# __decimation_t 248dddb8af56a7 error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      315955         2020-05-18 18:
# __decimation_t 252b90b7097fa6 error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      315959         2020-05-18 20:
# __decimation_t 2a945741c436a5 error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      316200         2020-05-18 21:
# __decimation_t 32d42dc88f4bed error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      315955         2020-05-18 17:
# __decimation_t 34d980cd1ce0b0 error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      315990         2020-05-18 18:
# __decimation_t 3a1bbcac1bc173 error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      316145         2020-05-18 19:
# __decimation_t 3a5932d6045be4 error      =BLOB=     Exception: neu =BLOB=     celiib@10.28.0 at-compute004  16      316068         2020-05-18 22:
# __decimation_t 3b45a1ac39bc88 error      =BLOB=     Exception: neu =BLOB=     celiib@10.28.0 at-compute004  16      316217         2020-05-18 20:
# __decimation_t 44b85bcc06050f error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      316146         2020-05-18 19:
# __decimation_t 46011717a8d5e7 error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute006  16      316241         2020-05-18 19:
# __decimation_t 46bf3744c84762 error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  17      315953         2020-05-18 20:
# __decimation_t 48ff2e7569af6d error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      315980         2020-05-18 18:
# __decimation_t 4f5e48779eede4 error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      316146         2020-05-18 20:
# __decimation_t 542ce65f71c056 error      =BLOB=     Exception: neu =BLOB=     celiib@10.28.0 at-node10      19      316256         2020-05-18 20:
# __decimation_t 5684e295005a17 error      =BLOB=     Exception: neu =BLOB=     celiib@10.28.0 at-compute004  16      316207         2020-05-18 21:
# __decimation_t 5ab4a4cabb8f05 error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      316167         2020-05-18 19:
# __decimation_t 5c9084d70a734a error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      316202         2020-05-18 19:
# __decimation_t 5dbe167a9e0d0a error      =BLOB=     Exception: neu =BLOB=     celiib@10.28.0 at-compute004  17      316220         2020-05-18 18:
# __decimation_t 5f1f548d48bfbf error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      315995         2020-05-18 18:
# __decimation_t 69ce55d63d702e error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      315974         2020-05-18 21:
# __decimation_t 7213c12ddb4a86 error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      316265         2020-05-18 19:
# __decimation_t 72a201f035a94a error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      316167         2020-05-18 21:
# __decimation_t 737af0650d524e error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      315982         2020-05-18 19:
# __decimation_t 73c96dfa033da4 error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      316134         2020-05-18 19:
# __decimation_t 7455015b2f26ff error      =BLOB=     Exception: neu =BLOB=     celiib@10.28.0 at-node22      16      316092         2020-05-18 17:
# __decimation_t 7458530bf3d091 error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      316201         2020-05-18 22:
# __decimation_t 76560266e12d86 error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      316159         2020-05-18 19:
# __decimation_t 7d50bd5cc2669d error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      316198         2020-05-18 21:
# __decimation_t 7d61044d653e14 error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      316074         2020-05-18 18:
# __decimation_t 8185dcb5baf2db error      =BLOB=     Exception: neu =BLOB=     celiib@10.28.0 at-compute004  16      316217         2020-05-18 18:
# __decimation_t 81b6834f44f160 error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      315996         2020-05-18 19:
# __decimation_t 8c2f0117eca27b error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      315951         2020-05-18 21:
# __decimation_t 95189d69b22874 error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      316136         2020-05-18 18:
# __decimation_t 9e48b696f816c6 error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  17      315948         2020-05-18 21:
# __decimation_t 9ec9c7f022ff66 error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      316076         2020-05-18 18:
# __decimation_t a34ca9cc353380 error      =BLOB=     Exception: neu =BLOB=     celiib@10.28.0 at-node1       17      316154         2020-05-18 18:
# __decimation_t a70eb44b263d62 error      =BLOB=     Exception: neu =BLOB=     celiib@10.28.0 at-compute004  17      316133         2020-05-18 18:
# __decimation_t b10d9f99e85a1c error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      316105         2020-05-18 18:
# __decimation_t b3187fb53baa5e error      =BLOB=     Exception: neu =BLOB=     celiib@10.28.0 at-node33      16      315939         2020-05-18 18:
# __decimation_t b39930cada48c0 error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      316203         2020-05-18 20:
# __decimation_t b4191244a7ef7b error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      315983         2020-05-18 18:
# __decimation_t bcb9987655b743 error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      316089         2020-05-18 18:
# __decimation_t c2d08c86e00dfb error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      316003         2020-05-18 21:
# __decimation_t c930d213d34ebc error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      315996         2020-05-18 21:
# __decimation_t ca4db127273572 error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      315997         2020-05-18 18:
# __decimation_t ca5b83e7268d42 error      =BLOB=     Exception: neu =BLOB=     celiib@10.28.0 at-compute003  16      316192         2020-05-18 18:
# __decimation_t cbf3a1a5dc156f error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      316089         2020-05-18 21:
# __decimation_t cdec52379dbbb5 error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      316111         2020-05-18 21:
# __decimation_t d86cd98f870344 error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      315961         2020-05-18 18:
# __decimation_t dbfbccb4108f0c error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      316201         2020-05-18 22:
# __decimation_t ddc8c4e68b51ad error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      316166         2020-05-18 21:
# __decimation_t e01490757e7051 error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      316167         2020-05-18 18:
# __decimation_t e09cf8207d7824 error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      315999         2020-05-18 18:
# __decimation_t e22a634391a4a0 error      =BLOB=     Exception: neu =BLOB=     celiib@10.28.0 at-compute004  16      316208         2020-05-18 21:
# __decimation_t e31b4953b51174 error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      315959         2020-05-18 20:
# __decimation_t e5a8819feaaebe error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      315974         2020-05-18 21:
# __decimation_t e876a4133c8c3a error      =BLOB=     Exception: neu =BLOB=     celiib@10.28.0 at-compute004  16      316217         2020-05-18 19:
# __decimation_t f1b3ccf32a9f4d error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      315995         2020-05-18 18:
# __decimation_t f37e3c49d5e69c error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      315980         2020-05-18 19:
# __decimation_t f4f658ec052a72 error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      315990         2020-05-18 18:
# __decimation_t fc8f9d004bce4d error      =BLOB=     Exception: neu =BLOB=     celiib@10.66.4 at-compute005  16      316167         2020-05-18 20:
#  (Total: 70)

# %%
error_table.fetch("error_message")
# Out:
# array(['Exception: neuron 83400568575880217 did not fix the manifold edges (meshlab script failed) with output: ',
#        'Exception: neuron 96427032451253768 did not fix the manifold edges (meshlab script failed) with output: ',
#        'Exception: neuron 111119325901336670 did not fix the manifold edges (meshlab script failed) with output: ',
#        'Exception: neuron 78399509058993603 did not fix the manifold edges (meshlab script failed) with output: '],
#       dtype=object)

# %%
def concatenated_rel(cls, core_segment=None, version=-1, return_with_meshes=False):
    """
    Returns all. You can restrict by a core_segment first though.

    :param core_segment: The core segment(s) to restrict by. If left empty will fetch all.
    :param version: The default of -1 will fetch the highest version for each core segment
        and its subsegments. If you happen to explicitely pass False, it will ignore version.
    :param return_with_meshes: When set to true or 'Decimation' will default
        to using the Decimation table for the meshes, otherwise 'Mesh' will
        choose the Mesh table with the original meshes.
    """

    subsegment_rel = cls.Subsegment.proj()

    if core_segment is not None:
        try:
            subsegment_rel &= [dict(segment_id=segment_id) for segment_id in core_segment]
        except TypeError:
            subsegment_rel &= dict(segment_id=core_segment)

    if version == -1:
        version_rel = dj.U('segment_id').aggr(subsegment_rel, version='max(version)')
    elif version is False:
        version_rel = subsegment_rel
    else:
        version_rel = subsegment_rel & dict(version=version)

    a_rel = dj.U('segment_id') & version_rel
    b_rel = dj.U('segment_id') & (subsegment_rel & version_rel).proj(_='segment_id', segment_id='subsegment_id')
    c_rel = a_rel + b_rel

    if return_with_meshes:
        if isinstance(return_with_meshes, str) and return_with_meshes.lower() == 'mesh':
            c_rel = minnie.Mesh & c_rel
        else:
            c_rel = minnie.Decimation & c_rel

    return c_rel

# %%
temporary_folder = 'decimation_temp'
meshlab_scripts = {}

# %%
@schema
class DecimationTest(dj.Computed):
    definition="""
    -> minnie.Mesh
    -> minnie.DecimationConfig
    ---
    n_vertices           : bigint                       
    n_faces              : bigint                       
    mesh                 : <decimated_mesh>             # in-place path to the hdf5 (decimated) mesh file
    INDEX (mesh)
    """
    @classmethod
    def make_file(cls, segment_id, version, decimation_ratio, vertices, faces):
        """Creates hf file at the proper location, returns the filepath of the newly created file"""

        assert vertices.ndim == 2 and vertices.shape[1] == 3
        assert faces.ndim == 2 and faces.shape[1] == 3

        filename = f'{segment_id}_{version}_{int(decimation_ratio*100):02}.h5'
        filepath = os.path.join(external_decimated_mesh_path, filename)
        with h5py.File(filepath, 'w') as hf:
            hf.create_dataset('segment_id', data=segment_id)
            hf.create_dataset('version', data=version)
            hf.create_dataset('decimation_ratio', data=float(decimation_ratio))
            hf.create_dataset('vertices', data=vertices)
            hf.create_dataset('faces', data=faces)

        return filepath

    @classmethod
    def make_entry(cls, segment_id, version, decimation_ratio, vertices, faces):
        key = dict(
            segment_id=segment_id,
            version=version,
            decimation_ratio=decimation_ratio,
            n_vertices=len(vertices),
            n_faces=len(faces)
        )

        filepath = cls.make_file(segment_id, version, decimation_ratio, vertices, faces)

        cls.insert1(dict(key, mesh=filepath), allow_direct_insert=True)



    key_source = minnie.Mesh.proj() * minnie.DecimationConfig

    def make(self, key):
        print(key)
        mesh = (minnie.Mesh & key).fetch1('mesh')
        segment_id = key['segment_id']
        version = key['version']
        decimation_ratio = key['decimation_ratio']

        # Here is where creates the decimator
        if decimation_ratio not in meshlab_scripts:
            meshlab_scripts[decimation_ratio] = Decimator(decimation_ratio, temporary_folder, overwrite=False)
            print("making new meshlab_scrip")
        mls_func = meshlab_scripts[decimation_ratio]

        try:
            expected_filepath = os.path.join(external_decimated_mesh_path, f'{segment_id}_{version}_{int(decimation_ratio*100):02}.h5')
            #if not os.path.isfile(expected_filepath):
            if True:
                #running the actual decimation
                new_mesh = mls_func(mesh.vertices, mesh.faces, segment_id,random_port=True)
                new_vertices, new_faces = new_mesh.vertices, new_mesh.faces
                #makes the entry into the table
#                 self.make_entry(
#                     segment_id=segment_id,
#                     version=version,
#                     decimation_ratio=decimation_ratio,
#                     vertices=new_vertices,
#                     faces=new_faces
#                 )
            else:
                print('File already exists.')
                raise FileExistsError('{} already exists'.format(expected_filepath))
#                 with h5py.File(expected_filepath, 'r') as hf:
#                     vertices = hf['vertices'][()].astype(np.float64)
#                     faces = hf['faces'][()].reshape(-1, 3).astype(np.uint32)
#                 self.insert1(dict(key, n_vertices=len(vertices), n_faces=len(faces), mesh=expected_filepath))
        #where throws the exception
        except Exception as e:
            minnie.DecimationError.insert1(dict(key, log=str(e)))
            print(e)
            raise e

# %%
import random
import time

allen_segment_rel = minnie.AllenSegmentCentroid
prioritize_allen_soma = allen_segment_rel * (minnie.DecimationConfig & {'version': 0, 'decimation_ratio': 0.25}) & 'segment_id!=0'

#     segment_rel = concatenated_rel(minnie.FromNeuromancer())

# Random sleep delay to avoid concurrent key_source queries from hangin
time.sleep(random.randint(0, 180))# * 15))
print('Populate Started')
DecimationTest.populate(prioritize_allen_soma, reserve_jobs=True, suppress_errors=True, order='random')
#     Decimation.populate(segment_rel, reserve_jobs=True, suppress_errors=True, order='random')
#     Decimation.populate({'decimation_ratio': 0.25}, reserve_jobs=True, suppress_errors=True, order='random')
print('Populate Done')

# %%
import random
random.randint(100,10000)
