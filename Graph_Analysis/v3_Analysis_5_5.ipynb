# %%
"""
Purpose: To look at basic statistics of the v3 graph

"""
# Out:
# '\nPurpose: To look at basic statistics of the v3 graph\n\n'

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import datajoint as dj
import trimesh
from tqdm.notebook import tqdm
from pathlib import Path

from os import sys
sys.path.append("/meshAfterParty/")
sys.path.append("/meshAfterParty/meshAfterParty")

import datajoint_utils as du
from importlib import reload
import networkx as nx
import system_utils as su
import networkx_utils as xu
# Out:
# INFO - 2021-05-05 16:19:54,692 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-05-05 16:19:54,695 - settings - Setting database.user to celiib
# INFO - 2021-05-05 16:19:54,695 - settings - Setting database.password to newceliipass
# INFO - 2021-05-05 16:19:54,707 - settings - Setting stores to {'minnie65': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65', 'stage': '/mnt/dj-stor01/platinum/minnie65'}, 'meshes': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/meshes', 'stage': '/mnt/dj-stor01/platinum/minnie65/02/meshes'}, 'decimated_meshes': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/decimated_meshes', 'stage': '/mnt/dj-stor01/platinum/minnie65/02/decimated_meshes'}, 'skeletons': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/skeletons'}}
# INFO - 2021-05-05 16:19:54,708 - settings - Setting enable_python_native_blobs to True
# ...

# %% [markdown]
# # Loading the Graph

# %%
G = su.decompress_pickle("./G_proof_v3_multi_di_with_attributes.pbz2")

# %% [markdown]
# # Turn the graph into non-multi-edge

# %%
G_non_multi = nx.DiGraph(G)

# %% [markdown]
# # Plotting the Degree Distribution

# %%
sys.path.append("/meshAfterParty/meshAfterParty/graph/")
import graph_visualizations as gviz

# %%
gviz.plot_degree_distribution(G_non_multi,
                             degree_type="in_and_out",
                             title_append="v3 In And Out Degree")
# Out:
# Mean in_and_out Degree = 31.6
# Median in_and_out Degree = 16.0

# %%
gviz.plot_degree_distribution(G_non_multi,
                             degree_type="in",
                             title_append="v3 In Degree")
# Out:
# Mean in Degree = 15.8
# Median in Degree = 11.0

# %%
gviz.plot_degree_distribution(G_non_multi,
                             degree_type="out",
                             title_append="v3 Out Degree")
# Out:
# Mean out Degree = 15.8
# Median out Degree = 1.0
